# %%
import requests as rq
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import time
import re

# %%
import requests as rq
from bs4 import BeautifulSoup

url = "https://www.ptt.cc/bbs/NBA/index.html" # PTT NBA 板
response = rq.get(url) # 用 requests 的 get 方法把網頁抓下來
html_doc = response.text # text 屬性就是 html 檔案
soup = BeautifulSoup(response.text, "lxml") # 指定 lxml 作為解析器
print(soup.prettify()) # 把排版後的 html 印出來
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <title>
#    看板 NBA 文章列表 - 批踢踢實業坊
#   </title>
#   <link href="//images.ptt.cc/bbs/v2.22/bbs-common.css" rel="stylesheet" type="text/css"/>
#   <link href="//images.ptt.cc/bbs/v2.22/bbs-base.css" media="screen" rel="stylesheet" type="text/css"/>
#   <link href="//images.ptt.cc/bbs/v2.22/bbs-custom.css" rel="stylesheet" type="text/css"/>
#   <link href="//images.ptt.cc/bbs/v2.22/pushstream.css" media="screen" rel="stylesheet" type="text/css"/>
#   <link href="//images.ptt.cc/bbs/v2.22/bbs-print.css" media="print" rel="stylesheet" type="text/css"/>
#  </head>
#  <body>
#   <div id="topbar-container">
#    <div class="bbs-content" id="topbar">
#     <a href="/" id="logo">
#      批踢踢實業坊
#     </a>
#     <span>
#      ›
#     </span>
#     <a class="board" href="/bbs/NBA/index.html">
#      <span class="board-label">
#       看板
#      </span>
#      NBA
#     </a>
#     <a class="right small" href="/about.html">
#      關於我們
#     </a>
#     <a class="right small" href="/contact.html">
#      聯絡資訊
#     </a>
#    </div>
#   </div>
#   <div id="main-container">
#    <div id="action-bar-container">
#     <div class="action-bar">
#      <div class="btn-group btn-group-dir">
#       <a class="btn selected" href="/bbs/NBA/index.html">
#        看板
#       </a>
#       <a class="btn" href="/man/NBA/index.html">
#        精華區
#       </a>
#      </div>
#      <div class="btn-group btn-group-paging">
#       <a class="btn wide" href="/bbs/NBA/index1.html">
#        最舊
#       </a>
#       <a class="btn wide" href="/bbs/NBA/index5349.html">
#        ‹ 上頁
#       </a>
#       <a class="btn wide disabled">
#        下頁 ›
#       </a>
#       <a class="btn wide" href="/bbs/NBA/index.html">
#        最新
#       </a>
#      </div>
#     </div>
#    </div>
#    <div class="r-list-container action-bar-margin bbs-screen">
#     <div class="r-ent">
#      <div class="nrec">
#       <span class="hl f3">
#        32
#       </span>
#      </div>
#      <div class="mark">
#      </div>
#      <div class="title">
#       <a href="/bbs/NBA/M.1510619897.A.3C2.html">
#        [新聞] 助小球迷選上班長 康特：追逐夢想很重要
#       </a>
#      </div>
#      <div class="meta">
#       <div class="date">
#        11/14
#       </div>
#       <div class="author">
#        IrvingKyrie
#       </div>
#      </div>
#     </div>
#     <div class="r-ent">
#      <div class="nrec">
#       <span class="hl f3">
#        35
#       </span>
#      </div>
#      <div class="mark">
#      </div>
#      <div class="title">
#       <a href="/bbs/NBA/M.1510620514.A.324.html">
#        [情報] LBJ：Ball會成為聯盟中一名很優秀的控衛
#       </a>
#      </div>
#      <div class="meta">
#       <div class="date">
#        11/14
#       </div>
#       <div class="author">
#        Yui5
#       </div>
#      </div>
#     </div>
#     <div class="r-ent">
#      <div class="nrec">
#       <span class="hl f3">
#        22
#       </span>
#      </div>
#      <div class="mark">
#      </div>
#      <div class="title">
#       <a href="/bbs/NBA/M.1510623018.A.CDE.html">
#        [Live] 湖人 @ 太陽
#       </a>
#      </div>
#      <div class="meta">
#       <div class="date">
#        11/14
#       </div>
#       <div class="author">
#        Rambo
#       </div>
#      </div>
#     </div>
#     <div class="r-ent">
#      <div class="nrec">
#       <span class="hl f2">
#        3
#       </span>
#      </div>
#      <div class="mark">
#      </div>
#      <div class="title">
#       <a href="/bbs/NBA/M.1510624001.A.E49.html">
#        [Live] 灰狼 @ 爵士
#       </a>
#      </div>
#      <div class="meta">
#       <div class="date">
#        11/14
#       </div>
#       <div class="author">
#        ryoyoung93
#       </div>
#      </div>
#     </div>
#     <div class="r-ent">
#      <div class="nrec">
#       <span class="hl f3">
#        24
#       </span>
#      </div>
#      <div class="mark">
#      </div>
#      <div class="title">
#       <a href="/bbs/NBA/M.1510624380.A.1FA.html">
#        [討論] 騎士防守這樣是誰的問題
#       </a>
#      </div>
#      <div class="meta">
#       <div class="date">
#        11/14
#       </div>
#       <div class="author">
#        tom80727
#       </div>
#      </div>
#     </div>
#     <div class="r-ent">
#      <div class="nrec">
#       <span class="hl f3">
#        11
#       </span>
#      </div>
#      <div class="mark">
#      </div>
#      <div class="title">
#       <a href="/bbs/NBA/M.1510625342.A.4B5.html">
#        [BOX ] Kings 92:110 Wizards 數據
#       </a>
#      </div>
#      <div class="meta">
#       <div class="date">
#        11/14
#       </div>
#       <div class="author">
#        Rambo
#       </div>
#      </div>
#     </div>
#     <div class="r-ent">
#      <div class="nrec">
#      </div>
#      <div class="mark">
#      </div>
#      <div class="title">
#       <a href="/bbs/NBA/M.1510625440.A.D0C.html">
#        [情報] Stephen Curry 今天比賽因傷缺陣
#       </a>
#      </div>
#      <div class="meta">
#       <div class="date">
#        11/14
#       </div>
#       <div class="author">
#        thnlkj0665
#       </div>
#      </div>
#     </div>
#     <div class="r-list-sep">
#     </div>
#     <div class="r-ent">
#      <div class="nrec">
#       <span class="hl f1">
#        爆
#       </span>
#      </div>
#      <div class="mark">
#      </div>
#      <div class="title">
#       <a href="/bbs/NBA/M.1498032247.A.C30.html">
#        [情報] 2017-18 自由球員市場異動整理表 (9/26)
#       </a>
#      </div>
#      <div class="meta">
#       <div class="date">
#        6/21
#       </div>
#       <div class="author">
#        laigei
#       </div>
#      </div>
#     </div>
#     <div class="r-ent">
#      <div class="nrec">
#      </div>
#      <div class="mark">
#       !
#      </div>
#      <div class="title">
#       <a href="/bbs/NBA/M.1504521964.A.8F9.html">
#        [公告] 板規v6.2
#       </a>
#      </div>
#      <div class="meta">
#       <div class="date">
#        9/04
#       </div>
#       <div class="author">
#        abc7360393
#       </div>
#      </div>
#     </div>
#     <div class="r-ent">
#      <div class="nrec">
#       <span class="hl f3">
#        16
#       </span>
#      </div>
#      <div class="mark">
#      </div>
#      <div class="title">
#       <a href="/bbs/NBA/M.1509694517.A.3A2.html">
#        [情報] 2017-18 例行賽賽程 (11/13-30)
#       </a>
#      </div>
#      <div class="meta">
#       <div class="date">
#        11/03
#       </div>
#       <div class="author">
#        laigei
#       </div>
#      </div>
#     </div>
#     <div class="r-ent">
#      <div class="nrec">
#       <span class="hl f3">
#        44
#       </span>
#      </div>
#      <div class="mark">
#      </div>
#      <div class="title">
#       <a href="/bbs/NBA/M.1510569838.A.430.html">
#        [情報] NBA Standings (NOV 13, 2017)
#       </a>
#      </div>
#      <div class="meta">
#       <div class="date">
#        11/13
#       </div>
#       <div class="author">
#        JerroLi
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <script>
#    (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');
#   </script>
#   <script src="//ajax.googleapis.com/ajax/libs/jquery/2.1.1/jquery.min.js">
#   </script>
#   <script src="//images.ptt.cc/bbs/v2.22/bbs.js">
#   </script>
#  </body>
# </html>

# %%
import requests as rq
from bs4 import BeautifulSoup

url = "https://www.ptt.cc/bbs/NBA/index.html" # PTT NBA 板
response = rq.get(url) # 用 requests 的 get 方法把網頁抓下來
html_doc = response.text # text 屬性就是 html 檔案
soup = BeautifulSoup(response.text, "lxml") # 指定 lxml 作為解析器

# 一些屬性或方法
print(soup.title) # 把 tag 抓出來
print("---")
print(soup.title.name) # 把 title 的 tag 名稱抓出來
print("---")
print(soup.title.string) # 把 title tag 的內容欻出來
print("---")
print(soup.title.parent.name) # title tag 的上一層 tag
print("---")
print(soup.a) # 把第一個 <a></a> 抓出來
print("---")
print(soup.find_all('a')) # 把所有的 <a></a> 抓出來
# Out:
# <title>看板 NBA 文章列表 - 批踢踢實業坊</title>
# ---
# title
# ---
# 看板 NBA 文章列表 - 批踢踢實業坊
# ---
# head
# ---
# <a href="/" id="logo">批踢踢實業坊</a>
# ---
# [<a href="/" id="logo">批踢踢實業坊</a>, <a class="board" href="/bbs/NBA/index.html"><span class="board-label">看板 </span>NBA</a>, <a class="right small" href="/about.html">關於我們</a>, <a class="right small" href="/contact.html">聯絡資訊</a>, <a class="btn selected" href="/bbs/NBA/index.html">看板</a>, <a class="btn" href="/man/NBA/index.html">精華區</a>, <a class="btn wide" href="/bbs/NBA/index1.html">最舊</a>, <a class="btn wide" href="/bbs/NBA/index5349.html">‹ 上頁</a>, <a class="btn wide disabled">下頁 ›</a>, <a class="btn wide" href="/bbs/NBA/index.html">最新</a>, <a href="/bbs/NBA/M.1510619897.A.3C2.html">[新聞] 助小球迷選上班長 康特：追逐夢想很重要</a>, <a href="/bbs/NBA/M.1510620514.A.324.html">[情報] LBJ：Ball會成為聯盟中一名很優秀的控衛</a>, <a href="/bbs/NBA/M.1510623018.A.CDE.html">[Live] 湖人 @ 太陽</a>, <a href="/bbs/NBA/M.1510624001.A.E49.html">[Live] 灰狼 @ 爵士</a>, <a href="/bbs/NBA/M.1510624380.A.1FA.html">[討論] 騎士防守這樣是誰的問題</a>, <a href="/bbs/NBA/M.1510625342.A.4B5.html">[BOX ] Kings 92:110 Wizards 數據</a>, <a href="/bbs/NBA/M.1510625440.A.D0C.html">[情報] Stephen Curry 今天比賽因傷缺陣</a>, <a href="/bbs/NBA/M.1498032247.A.C30.html">[情報] 2017-18 自由球員市場異動整理表 (9/26)</a>, <a href="/bbs/NBA/M.1504521964.A.8F9.html">[公告] 板規v6.2</a>, <a href="/bbs/NBA/M.1509694517.A.3A2.html">[情報] 2017-18 例行賽賽程 (11/13-30)</a>, <a href="/bbs/NBA/M.1510569838.A.430.html">[情報] NBA Standings (NOV 13, 2017)</a>]

# %%
# bs4 元素

#Beautiful Soup 幫我們將 html 檔案轉換為 bs4 的物件，像是標籤（Tag），標籤中的內容（NavigableString）與 BeautifulSoup 物件本身。

# %%
# 標籤（Tag）

print(type(soup.a))
print("---")
print(soup.a.name) # 抓標籤名 a
print("---")
print(soup.a['id']) # 抓<a></a>的 id 名稱
# Out:
# <class 'bs4.element.Tag'>
# ---
# a
# ---
# logo

# %%
# 標籤中的內容（NavigableString）

print(type(soup.a.string))
print("---")
print(soup.a.string)
# Out:
# <class 'bs4.element.NavigableString'>
# ---
# 批踢踢實業坊

# %%
# BeautifulSoup

type(soup)
# Out:
# bs4.BeautifulSoup

# %%
# 爬樹

# DOM（Document Object Model）的樹狀結構觀念在使用 BeautifulSoup 扮演至關重要的角色，所以我們也要練習爬樹。

# %%
# 往下爬

# 從標籤中回傳更多資訊。

#contents 屬性
#children 屬性
#string 屬性




print(soup.body.a.contents)
print(list(soup.body.a.children))
print(soup.body.a.string)
# Out:
# ['批踢踢實業坊']
# ['批踢踢實業坊']
# 批踢踢實業坊

# %%
# 往上爬

# 回傳上一階層的標籤。

#parent 屬性




print(soup.title)
print("---")
print(soup.title.parent)
# Out:
# <title>看板 NBA 文章列表 - 批踢踢實業坊</title>
# ---
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <title>看板 NBA 文章列表 - 批踢踢實業坊</title>
# <link href="//images.ptt.cc/bbs/v2.22/bbs-common.css" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.22/bbs-base.css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.22/bbs-custom.css" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.22/pushstream.css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.22/bbs-print.css" media="print" rel="stylesheet" type="text/css"/>
# </head>

# %%
# 往旁邊爬

# 回傳同一階層的標籤。

#next_sibling 屬性
#previous_sibling 屬性




first_a_tag = soup.body.a
next_to_first_a_tag = first_a_tag.next_sibling
print(first_a_tag)
print("---")
print(next_to_first_a_tag)
print("---")
print(next_to_first_a_tag.previous_sibling)
# Out:
# <a href="/" id="logo">批踢踢實業坊</a>
# ---
#
#
# ---
# <a href="/" id="logo">批踢踢實業坊</a>

# %%
# 搜尋

#這是我們主要使用 BeautifulSoup 套件來做網站解析的方法。

#find() 方法
#find_all() 方法




print(soup.find("a")) # 第一個 <a></a>
print("---")
print(soup.find_all("a")) # 全部 <a></a>



print("---------------------------")

# 可以在第二個參數 class_= 加入 CSS 的類別。
print(soup.find("div", class_= "r-ent"))
# Out:
# <a href="/" id="logo">批踢踢實業坊</a>
# ---
# [<a href="/" id="logo">批踢踢實業坊</a>, <a class="board" href="/bbs/NBA/index.html"><span class="board-label">看板 </span>NBA</a>, <a class="right small" href="/about.html">關於我們</a>, <a class="right small" href="/contact.html">聯絡資訊</a>, <a class="btn selected" href="/bbs/NBA/index.html">看板</a>, <a class="btn" href="/man/NBA/index.html">精華區</a>, <a class="btn wide" href="/bbs/NBA/index1.html">最舊</a>, <a class="btn wide" href="/bbs/NBA/index5349.html">‹ 上頁</a>, <a class="btn wide disabled">下頁 ›</a>, <a class="btn wide" href="/bbs/NBA/index.html">最新</a>, <a href="/bbs/NBA/M.1510619897.A.3C2.html">[新聞] 助小球迷選上班長 康特：追逐夢想很重要</a>, <a href="/bbs/NBA/M.1510620514.A.324.html">[情報] LBJ：Ball會成為聯盟中一名很優秀的控衛</a>, <a href="/bbs/NBA/M.1510623018.A.CDE.html">[Live] 湖人 @ 太陽</a>, <a href="/bbs/NBA/M.1510624001.A.E49.html">[Live] 灰狼 @ 爵士</a>, <a href="/bbs/NBA/M.1510624380.A.1FA.html">[討論] 騎士防守這樣是誰的問題</a>, <a href="/bbs/NBA/M.1510625342.A.4B5.html">[BOX ] Kings 92:110 Wizards 數據</a>, <a href="/bbs/NBA/M.1510625440.A.D0C.html">[情報] Stephen Curry 今天比賽因傷缺陣</a>, <a href="/bbs/NBA/M.1498032247.A.C30.html">[情報] 2017-18 自由球員市場異動整理表 (9/26)</a>, <a href="/bbs/NBA/M.1504521964.A.8F9.html">[公告] 板規v6.2</a>, <a href="/bbs/NBA/M.1509694517.A.3A2.html">[情報] 2017-18 例行賽賽程 (11/13-30)</a>, <a href="/bbs/NBA/M.1510569838.A.430.html">[情報] NBA Standings (NOV 13, 2017)</a>]
# ---------------------------
# <div class="r-ent">
# <div class="nrec"><span class="hl f3">32</span></div>
# <div class="mark"></div>
# <div class="title">
# <a href="/bbs/NBA/M.1510619897.A.3C2.html">[新聞] 助小球迷選上班長 康特：追逐夢想很重要</a>
# </div>
# <div class="meta">
# <div class="date">11/14</div>
# <div class="author">IrvingKyrie</div>
# </div>
# </div>

# %% [markdown]
# ## BeautifulSoup 牛刀小試

# %%
import requests as rq
from bs4 import BeautifulSoup

url = 'https://www.ptt.cc/bbs/NBA/index.html'
response = rq.get(url)
html_doc = response.text # text 屬性就是 html 檔案
soup = BeautifulSoup(response.text, "lxml") # 指定 lxml 作為解析器

posts = soup.find_all("div", class_ = "r-ent")
print(posts)
type(posts)
# Out:
# [<div class="r-ent">
# <div class="nrec"><span class="hl f3">32</span></div>
# <div class="mark"></div>
# <div class="title">
# <a href="/bbs/NBA/M.1510619897.A.3C2.html">[新聞] 助小球迷選上班長 康特：追逐夢想很重要</a>
# </div>
# <div class="meta">
# <div class="date">11/14</div>
# <div class="author">IrvingKyrie</div>
# </div>
# </div>, <div class="r-ent">
# <div class="nrec"><span class="hl f3">36</span></div>
# <div class="mark"></div>
# <div class="title">
# <a href="/bbs/NBA/M.1510620514.A.324.html">[情報] LBJ：Ball會成為聯盟中一名很優秀的控衛</a>
# </div>
# <div class="meta">
# <div class="date">11/14</div>
# <div class="author">Yui5</div>
# </div>
# </div>, <div class="r-ent">
# <div class="nrec"><span class="hl f3">22</span></div>
# <div class="mark"></div>
# <div class="title">
# <a href="/bbs/NBA/M.1510623018.A.CDE.html">[Live] 湖人 @ 太陽</a>
# </div>
# <div class="meta">
# <div class="date">11/14</div>
# <div class="author">Rambo</div>
# </div>
# </div>, <div class="r-ent">
# <div class="nrec"><span class="hl f2">4</span></div>
# <div class="mark"></div>
# <div class="title">
# <a href="/bbs/NBA/M.1510624001.A.E49.html">[Live] 灰狼 @ 爵士</a>
# </div>
# <div class="meta">
# <div class="date">11/14</div>
# <div class="author">ryoyoung93</div>
# </div>
# </div>, <div class="r-ent">
# <div class="nrec"><span class="hl f3">24</span></div>
# <div class="mark"></div>
# <div class="title">
# <a href="/bbs/NBA/M.1510624380.A.1FA.html">[討論] 騎士防守這樣是誰的問題</a>
# </div>
# <div class="meta">
# <div class="date">11/14</div>
# <div class="author">tom80727</div>
# </div>
# </div>, <div class="r-ent">
# <div class="nrec"><span class="hl f3">11</span></div>
# <div class="mark"></div>
# <div class="title">
# <a href="/bbs/NBA/M.1510625342.A.4B5.html">[BOX ] Kings 92:110 Wizards 數據</a>
# </div>
# <div class="meta">
# <div class="date">11/14</div>
# <div class="author">Rambo</div>
# </div>
# </div>, <div class="r-ent">
# <div class="nrec"><span class="hl f2">4</span></div>
# <div class="mark"></div>
# <div class="title">
# <a href="/bbs/NBA/M.1510625440.A.D0C.html">[情報] Stephen Curry 今天比賽因傷缺陣</a>
# </div>
# <div class="meta">
# <div class="date">11/14</div>
# <div class="author">thnlkj0665</div>
# </div>
# </div>, <div class="r-ent">
# <div class="nrec"><span class="hl f1">爆</span></div>
# <div class="mark"></div>
# <div class="title">
# <a href="/bbs/NBA/M.1498032247.A.C30.html">[情報] 2017-18 自由球員市場異動整理表 (9/26)</a>
# </div>
# <div class="meta">
# <div class="date"> 6/21</div>
# <div class="author">laigei</div>
# </div>
# </div>, <div class="r-ent">
# <div class="nrec"></div>
# <div class="mark">!</div>
# <div class="title">
# <a href="/bbs/NBA/M.1504521964.A.8F9.html">[公告] 板規v6.2</a>
# </div>
# <div class="meta">
# <div class="date"> 9/04</div>
# <div class="author">abc7360393</div>
# </div>
# </div>, <div class="r-ent">
# <div class="nrec"><span class="hl f3">16</span></div>
# <div class="mark"></div>
# <div class="title">
# <a href="/bbs/NBA/M.1509694517.A.3A2.html">[情報] 2017-18 例行賽賽程 (11/13-30)</a>
# </div>
# <div class="meta">
# <div class="date">11/03</div>
# <div class="author">laigei</div>
# </div>
# </div>, <div class="r-ent">
# <div class="nrec"><span class="hl f3">44</span></div>
# <div class="mark"></div>
# <div class="title">
# <a href="/bbs/NBA/M.1510569838.A.430.html">[情報] NBA Standings (NOV 13, 2017)</a>
# </div>
# <div class="meta">
# <div class="date">11/13</div>
# <div class="author">JerroLi</div>
# </div>
# </div>]
# bs4.element.ResultSet

# %%
author_ids = [] # 建立一個空的 list 來放置作者 id
posts = soup.find_all("div", class_ = "r-ent")
for post in posts:
    author_ids.extend(post.find("div", class_ = "author"))

print(author_ids)
# Out:
# ['IrvingKyrie', 'Yui5', 'Rambo', 'ryoyoung93', 'tom80727', 'Rambo', 'thnlkj0665', 'laigei', 'abc7360393', 'laigei', 'JerroLi']

# %%
author_ids = [] # 建立一個空的 list 來放作者 id
recommends = [] # 建立一個空的 list 來放推文數
post_titles = [] # 建立一個空的 list 來放文章標題
post_dates = [] # 建立一個空的 list 來放發文日期

posts = soup.find_all("div", class_ = "r-ent")
for post in posts:
    try:
        author_ids.append(post.find("div", class_ = "author").string)    
    except:
        author_ids.append(np.nan)
    try:
        post_titles.append(post.find("a").string)
    except:
        post_titles.append(np.nan)
    try:
        post_dates.append(post.find("div", class_ = "date").string)
    except:
        post_dates.append(np.nan)

# 推文數藏在 div 裡面的 span 所以分開處理
recommendations = soup.find_all("div", class_ = "nrec")
for recommendation in recommendations:
    try:
        recommends.append(int(recommendation.find("span").string))
    except:
        recommends.append(np.nan)

print(author_ids)
print(recommends)
print(post_titles)
print(post_dates)
# Out:
# ['IrvingKyrie', 'Yui5', 'Rambo', 'ryoyoung93', 'tom80727', 'Rambo', 'thnlkj0665', 'laigei', 'abc7360393', 'laigei', 'JerroLi']
# [32, 36, 22, 4, 24, 11, 4, nan, nan, 16, 44]
# ['[新聞] 助小球迷選上班長 康特：追逐夢想很重要', '[情報] LBJ：Ball會成為聯盟中一名很優秀的控衛', '[Live] 湖人 @ 太陽', '[Live] 灰狼 @ 爵士', '[討論] 騎士防守這樣是誰的問題', '[BOX ] Kings 92:110 Wizards 數據', '[情報] Stephen Curry 今天比賽因傷缺陣', '[情報] 2017-18 自由球員市場異動整理表 (9/26)', '[公告] 板規v6.2', '[情報] 2017-18 例行賽賽程 (11/13-30)', '[情報] NBA Standings (NOV 13, 2017)']
# ['11/14', '11/14', '11/14', '11/14', '11/14', '11/14', '11/14', ' 6/21', ' 9/04', '11/03', '11/13']

# %% [markdown]
# ## 檢查結果都沒有問題之後 那我們就可以把這幾個 list 放進 dictionary 接著轉換成 data frame 了

# %%
import numpy as np
import pandas as pd
import requests as rq
from bs4 import BeautifulSoup

url = 'https://www.ptt.cc/bbs/NBA/index.html'
response = rq.get(url)
html_doc = response.text # text 屬性就是 html 檔案
soup = BeautifulSoup(response.text, "lxml") # 指定 lxml 作為解析器




print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <title>
#    看板 NBA 文章列表 - 批踢踢實業坊
#   </title>
#   <link href="//images.ptt.cc/bbs/v2.22/bbs-common.css" rel="stylesheet" type="text/css"/>
#   <link href="//images.ptt.cc/bbs/v2.22/bbs-base.css" media="screen" rel="stylesheet" type="text/css"/>
#   <link href="//images.ptt.cc/bbs/v2.22/bbs-custom.css" rel="stylesheet" type="text/css"/>
#   <link href="//images.ptt.cc/bbs/v2.22/pushstream.css" media="screen" rel="stylesheet" type="text/css"/>
#   <link href="//images.ptt.cc/bbs/v2.22/bbs-print.css" media="print" rel="stylesheet" type="text/css"/>
#  </head>
#  <body>
#   <div id="topbar-container">
#    <div class="bbs-content" id="topbar">
#     <a href="/" id="logo">
#      批踢踢實業坊
#     </a>
#     <span>
#      ›
#     </span>
#     <a class="board" href="/bbs/NBA/index.html">
#      <span class="board-label">
#       看板
#      </span>
#      NBA
#     </a>
#     <a class="right small" href="/about.html">
#      關於我們
#     </a>
#     <a class="right small" href="/contact.html">
#      聯絡資訊
#     </a>
#    </div>
#   </div>
#   <div id="main-container">
#    <div id="action-bar-container">
#     <div class="action-bar">
#      <div class="btn-group btn-group-dir">
#       <a class="btn selected" href="/bbs/NBA/index.html">
#        看板
#       </a>
#       <a class="btn" href="/man/NBA/index.html">
#        精華區
#       </a>
#      </div>
#      <div class="btn-group btn-group-paging">
#       <a class="btn wide" href="/bbs/NBA/index1.html">
#        最舊
#       </a>
#       <a class="btn wide" href="/bbs/NBA/index5349.html">
#        ‹ 上頁
#       </a>
#       <a class="btn wide disabled">
#        下頁 ›
#       </a>
#       <a class="btn wide" href="/bbs/NBA/index.html">
#        最新
#       </a>
#      </div>
#     </div>
#    </div>
#    <div class="r-list-container action-bar-margin bbs-screen">
#     <div class="r-ent">
#      <div class="nrec">
#       <span class="hl f3">
#        33
#       </span>
#      </div>
#      <div class="mark">
#      </div>
#      <div class="title">
#       <a href="/bbs/NBA/M.1510619897.A.3C2.html">
#        [新聞] 助小球迷選上班長 康特：追逐夢想很重要
#       </a>
#      </div>
#      <div class="meta">
#       <div class="date">
#        11/14
#       </div>
#       <div class="author">
#        IrvingKyrie
#       </div>
#      </div>
#     </div>
#     <div class="r-ent">
#      <div class="nrec">
#       <span class="hl f3">
#        37
#       </span>
#      </div>
#      <div class="mark">
#      </div>
#      <div class="title">
#       <a href="/bbs/NBA/M.1510620514.A.324.html">
#        [情報] LBJ：Ball會成為聯盟中一名很優秀的控衛
#       </a>
#      </div>
#      <div class="meta">
#       <div class="date">
#        11/14
#       </div>
#       <div class="author">
#        Yui5
#       </div>
#      </div>
#     </div>
#     <div class="r-ent">
#      <div class="nrec">
#       <span class="hl f3">
#        24
#       </span>
#      </div>
#      <div class="mark">
#      </div>
#      <div class="title">
#       <a href="/bbs/NBA/M.1510623018.A.CDE.html">
#        [Live] 湖人 @ 太陽
#       </a>
#      </div>
#      <div class="meta">
#       <div class="date">
#        11/14
#       </div>
#       <div class="author">
#        Rambo
#       </div>
#      </div>
#     </div>
#     <div class="r-ent">
#      <div class="nrec">
#       <span class="hl f2">
#        5
#       </span>
#      </div>
#      <div class="mark">
#      </div>
#      <div class="title">
#       <a href="/bbs/NBA/M.1510624001.A.E49.html">
#        [Live] 灰狼 @ 爵士
#       </a>
#      </div>
#      <div class="meta">
#       <div class="date">
#        11/14
#       </div>
#       <div class="author">
#        ryoyoung93
#       </div>
#      </div>
#     </div>
#     <div class="r-ent">
#      <div class="nrec">
#       <span class="hl f3">
#        34
#       </span>
#      </div>
#      <div class="mark">
#      </div>
#      <div class="title">
#       <a href="/bbs/NBA/M.1510624380.A.1FA.html">
#        [討論] 騎士防守這樣是誰的問題
#       </a>
#      </div>
#      <div class="meta">
#       <div class="date">
#        11/14
#       </div>
#       <div class="author">
#        tom80727
#       </div>
#      </div>
#     </div>
#     <div class="r-ent">
#      <div class="nrec">
#       <span class="hl f3">
#        21
#       </span>
#      </div>
#      <div class="mark">
#      </div>
#      <div class="title">
#       <a href="/bbs/NBA/M.1510625342.A.4B5.html">
#        [BOX ] Kings 92:110 Wizards 數據
#       </a>
#      </div>
#      <div class="meta">
#       <div class="date">
#        11/14
#       </div>
#       <div class="author">
#        Rambo
#       </div>
#      </div>
#     </div>
#     <div class="r-ent">
#      <div class="nrec">
#       <span class="hl f3">
#        22
#       </span>
#      </div>
#      <div class="mark">
#      </div>
#      <div class="title">
#       <a href="/bbs/NBA/M.1510625440.A.D0C.html">
#        [情報] Stephen Curry 右大腿痠痛  今天確定不打
#       </a>
#      </div>
#      <div class="meta">
#       <div class="date">
#        11/14
#       </div>
#       <div class="author">
#        thnlkj0665
#       </div>
#      </div>
#     </div>
#     <div class="r-list-sep">
#     </div>
#     <div class="r-ent">
#      <div class="nrec">
#       <span class="hl f1">
#        爆
#       </span>
#      </div>
#      <div class="mark">
#      </div>
#      <div class="title">
#       <a href="/bbs/NBA/M.1498032247.A.C30.html">
#        [情報] 2017-18 自由球員市場異動整理表 (9/26)
#       </a>
#      </div>
#      <div class="meta">
#       <div class="date">
#        6/21
#       </div>
#       <div class="author">
#        laigei
#       </div>
#      </div>
#     </div>
#     <div class="r-ent">
#      <div class="nrec">
#      </div>
#      <div class="mark">
#       !
#      </div>
#      <div class="title">
#       <a href="/bbs/NBA/M.1504521964.A.8F9.html">
#        [公告] 板規v6.2
#       </a>
#      </div>
#      <div class="meta">
#       <div class="date">
#        9/04
#       </div>
#       <div class="author">
#        abc7360393
#       </div>
#      </div>
#     </div>
#     <div class="r-ent">
#      <div class="nrec">
#       <span class="hl f3">
#        16
#       </span>
#      </div>
#      <div class="mark">
#      </div>
#      <div class="title">
#       <a href="/bbs/NBA/M.1509694517.A.3A2.html">
#        [情報] 2017-18 例行賽賽程 (11/13-30)
#       </a>
#      </div>
#      <div class="meta">
#       <div class="date">
#        11/03
#       </div>
#       <div class="author">
#        laigei
#       </div>
#      </div>
#     </div>
#     <div class="r-ent">
#      <div class="nrec">
#       <span class="hl f3">
#        44
#       </span>
#      </div>
#      <div class="mark">
#      </div>
#      <div class="title">
#       <a href="/bbs/NBA/M.1510569838.A.430.html">
#        [情報] NBA Standings (NOV 13, 2017)
#       </a>
#      </div>
#      <div class="meta">
#       <div class="date">
#        11/13
#       </div>
#       <div class="author">
#        JerroLi
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <script>
#    (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');
#   </script>
#   <script src="//ajax.googleapis.com/ajax/libs/jquery/2.1.1/jquery.min.js">
#   </script>
#   <script src="//images.ptt.cc/bbs/v2.22/bbs.js">
#   </script>
#  </body>
# </html>

# %%
author_ids = [] # 建立一個空的 list 來放作者 id
recommends = [] # 建立一個空的 list 來放推文數
post_titles = [] # 建立一個空的 list 來放文章標題
post_dates = [] # 建立一個空的 list 來放發文日期

posts = soup.find_all("div", class_ = "r-ent")
for post in posts:
    try:
        author_ids.append(post.find("div", class_ = "author").string)    
    except:
        author_ids.append(np.nan)
    try:
        post_titles.append(post.find("a").string)
    except:
        post_titles.append(np.nan)
    try:
        post_dates.append(post.find("div", class_ = "date").string)
    except:
        post_dates.append(np.nan)

# 推文數藏在 div 裡面的 span 所以分開處理
recommendations = soup.find_all("div", class_ = "nrec")
for recommendation in recommendations:
    try:
        recommends.append(int(recommendation.find("span").string))
    except:
        recommends.append(np.nan)
        
ptt_nba_dict = {"author": author_ids,
                "recommends": recommends,
                "title": post_titles,
                "date": post_dates
}

ptt_nba_df = pd.DataFrame(ptt_nba_dict)
ptt_nba_df
# Out:
#          author   date  recommends                              title
# 0   IrvingKyrie  11/14        33.0           [新聞] 助小球迷選上班長 康特：追逐夢想很重要
# 1          Yui5  11/14        37.0        [情報] LBJ：Ball會成為聯盟中一名很優秀的控衛
# 2         Rambo  11/14        24.0                     [Live] 湖人 @ 太陽
# 3    ryoyoung93  11/14         5.0                     [Live] 灰狼 @ 爵士
# 4      tom80727  11/14        34.0                   [討論] 騎士防守這樣是誰的問題
# 5         Rambo  11/14        21.0     [BOX ] Kings 92:110 Wizards 數據
# 6    thnlkj0665  11/14        22.0   [情報] Stephen Curry 右大腿痠痛  今天確定不打
# 7        laigei   6/21         NaN    [情報] 2017-18 自由球員市場異動整理表 (9/26)
# 8    abc7360393   9/04         NaN                        [公告] 板規v6.2
# 9        laigei  11/03        16.0      [情報] 2017-18 例行賽賽程 (11/13-30)
# 10      JerroLi  11/13        44.0  [情報] NBA Standings (NOV 13, 2017)

# %%
import requests as rq
from bs4 import BeautifulSoup

url = 'https://www.ptt.cc/bbs/NBA/index.html'
response = rq.get(url)
html_doc = response.text # text 屬性就是 html 檔案
soup = BeautifulSoup(response.text, "lxml") # 指定 lxml 作為解析器

author_ids = [] # 建立一個空的 list 來放置作者 id
posts = soup.find_all("div", class_ = "r-ent")
for post in posts:
    author_ids.extend(post.find("div", class_ = "author"))

print(author_ids)
# Out:
# ['james008', 'Rambo', 'kenny1300175', '-', 'Ayanami5566', 'Rambo', 'thnlkj0665', 'Rambo', 'Yui5', 'YummyKidd', 'Rambo', '-', 'laigei', 'abc7360393', 'laigei', 'JerroLi']

# %%
import numpy as np
import requests as rq
from bs4 import BeautifulSoup

url = 'https://www.ptt.cc/bbs/NBA/index.html'
response = rq.get(url)
html_doc = response.text # text 屬性就是 html 檔案
soup = BeautifulSoup(response.text, "lxml") # 指定 lxml 作為解析器

author_ids = [] # 建立一個空的 list 來放作者 id
recommends = [] # 建立一個空的 list 來放推文數
post_titles = [] # 建立一個空的 list 來放文章標題
post_dates = [] # 建立一個空的 list 來放發文日期

posts = soup.find_all("div", class_ = "r-ent")
for post in posts:
    try:
        author_ids.append(post.find("div", class_ = "author").string)    
    except:
        author_ids.append(np.nan)
    try:
        post_titles.append(post.find("a").string)
    except:
        post_titles.append(np.nan)
    try:
        post_dates.append(post.find("div", class_ = "date").string)
    except:
        post_dates.append(np.nan)

# 推文數藏在 div 裡面的 span 所以分開處理
recommendations = soup.find_all("div", class_ = "nrec")
for recommendation in recommendations:
    try:
        recommends.append(int(recommendation.find("span").string))
    except:
        recommends.append(np.nan)

print("<< author_ids >>")
print("\n")
print(author_ids)
print("---")
print("<< recommends >>")
print("\n")
print(recommends)
print("---")
print("<< post_titles >>")
print("\n")
print(post_titles)
print("---")
print("<< post_dates >>")
print("\n")
print(post_dates)
# Out:
# << author_ids >>
#
#
# ['james008', 'Rambo', 'kenny1300175', '-', 'Ayanami5566', 'Rambo', 'thnlkj0665', 'Rambo', 'Yui5', 'YummyKidd', 'Rambo', '-', 'laigei', 'abc7360393', 'laigei', 'JerroLi']
# ---
# << recommends >>
#
#
# [40, nan, nan, nan, 66, 9, 74, 76, 22, 5, nan, nan, nan, nan, 16, 45]
# ---
# << post_titles >>
#
#
# ['[新聞] 詹姆士準大三元 騎士演出本季最大逆轉秀', '[BOX ] Lakers 100:93 Suns 數據', '[專欄] 瘋狂三分雨，騎士幸運「解套」 LYS', nan, '[討論] LBJ為啥看起來沒啥攻擊欲望?', '[BOX ] Nuggets 82:99 Blazers 數據', '[新聞] 不在乎詹皇是誰 康特：沒人可以欺負我們', '[BOX ] Magic 100:110 Warriors 數據', '[花邊] Booker：成為球隊門面需承擔很多責任', '[情報] Booker26次30+追平Nash，隊史第15', '[BOX ] Sixers 109:105 Clippers 數據', nan, '[情報] 2017-18 自由球員市場異動整理表 (9/26)', '[公告] 板規v6.2', '[情報] 2017-18 例行賽賽程 (11/13-30)', '[情報] NBA Standings (NOV 13, 2017)']
# ---
# << post_dates >>
#
#
# ['11/14', '11/14', '11/14', '11/14', '11/14', '11/14', '11/14', '11/14', '11/14', '11/14', '11/14', '11/14', ' 6/21', ' 9/04', '11/03', '11/13']
