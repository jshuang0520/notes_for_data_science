# %%
import numpy as np
import pandas as pd
from datetime import datetime
import datetime
import calendar
import time
from functools import reduce

# %%
# 2. 品類_list
品類_list = ["洗衣精", "膠囊"]      # 品類_list = ["洗衣粉"] 

# ===============================================================================================
# 1. 原始資料路徑
# 原始資料路徑 = "C:/Users/EOL/py_ds/永豐餘洗衣_跑表用_數據部門專用(0802).xlsx"
# 原始資料路徑 = "C:/Users/EOL/py_ds/2018.09.20 洗衣精訴求/永豐餘洗衣(精&膠囊&粉)_跑表用 0905(6月).xlsx"
原始資料路徑 = "C:/Users/EOL/py_ds/2018.09.20 洗衣精訴求/永豐餘洗衣_跑表用 0904(6月)(未刪除雜訊)-1003修.xlsx"

# ===============================================================================================

# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!記得改檔名，尤其欲產出報表的時間月份!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!

MAT_檔名 = "洗衣精銷售表現_MAT_18JUN_訴求-2018.10.03"
YTD_檔名 = "洗衣精銷售表現_YTD_18JUN_訴求-2018.10.03"
逐月_檔名 = "洗衣精銷售表現_逐月_18JUN_訴求-2018.10.03"

# ===============================================================================================
# 3. 通路自有品牌 、 讀EXCEL.xlsx 定義"其他" 
# 通路自有品牌              --------------> 到底下去改 !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!

定義其他品牌的EXCEL檔名 = "C:/Users/EOL/py_ds/2018.09.20 洗衣精訴求/永豐餘洗衣(精&膠囊&粉)_跑表用 0905(6月)-訴求18JUN_定義其他品牌.xlsx"
# ===============================================================================================
# 4. def 表頭排序()        --------------> 到底下去改 !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!


# 5. MAT、YTD、逐月報表 附加資訊及檔名
時間點_1 = "2017-07-01"
時間點_2 = "2018-07-01"
全台家戶數 = 8566285
洗衣粉_市調結果購買率 = 0.794651384909265

# YTD
x_1 = "2017-01-01"
x_2 = "2017-07-01"

y_1 = "2018-01-01"
y_2 = "2018-07-01"

x_3 = "2017年1-6月"
y_3 = "2018年1-6月"

# 逐月

month_list = ["2017-01-01", "2017-02-01", "2017-03-01", "2017-04-01", "2017-05-01", "2017-06-01", "2017-07-01", "2017-08-01", "2017-09-01", "2017-10-01", "2017-11-01", "2017-12-01", "2018-01-01", "2018-02-01", "2018-03-01", "2018-04-01", "2018-05-01", "2018-06-01", "2018-07-01"]

# %%
# # 2. 品類_list
# 品類_list = ["洗衣精", "膠囊"]      # 品類_list = ["洗衣粉"] 

# # ===============================================================================================
# # 1. 原始資料路徑
# 原始資料路徑 = "C:/Users/EOL/py_ds/永豐餘洗衣_跑表用_數據部門專用(0802).xlsx"
# # ===============================================================================================

# # !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!記得改檔名，尤其欲產出報表的時間月份!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!

# MAT_檔名 = "洗衣精銷售表現_MAT_18APR_訴求-20180919"
# YTD_檔名 = "洗衣精銷售表現_YTD_18APR_訴求-20180919"
# 逐月_檔名 = "洗衣精銷售表現_逐月_18APR_訴求-20180919"

# # ===============================================================================================
# # 3. 通路自有品牌 、 讀EXCEL.xlsx 定義"其他" 
# # 通路自有品牌              --------------> 到底下去改 !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# 定義其他品牌的EXCEL檔名 = "C:/Users/EOL/py_ds/系列_洗衣精_膠囊_MAT_2018_APR_定義其他品牌.xlsx"
# # ===============================================================================================
# # 4. def 表頭排序()        --------------> 到底下去改 !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!


# # 5. MAT、YTD、逐月報表 附加資訊及檔名
# 時間點_1 = "2017-05-01"
# 時間點_2 = "2018-05-01"
# 全台家戶數 = 8566285
# 洗衣粉_市調結果購買率 = 0.855660377358491

# # YTD
# x_1 = "2017-01-01"
# x_2 = "2017-05-01"

# y_1 = "2018-01-01"
# y_2 = "2018-05-01"

# x_3 = "2017年1-4月"
# y_3 = "2018年1-4月"

# # 逐月

# month_list = ["2017-01-01", "2017-02-01", "2017-03-01", "2017-04-01", "2017-05-01", "2017-06-01", "2017-07-01", "2017-08-01", "2017-09-01", "2017-10-01", "2017-11-01", "2017-12-01", "2018-01-01", "2018-02-01", "2018-03-01", "2018-04-01", "2018-05-01"]

# %%
# 讀取原始資料
def 讀取原始資料(原始資料路徑) :
    df_row_data = pd.read_excel(str(原始資料路徑))
    return df_row_data
    
    

# 選入欄位多一個 "價位帶"    
def 整理原始資料_時間格式(df_row_data) :

    # 選取欄位
    df_row_data_useful_columns = df_row_data[["invDate", "invTime", "品類", "通路", "YFY經銷", "通路類型(客戶用)", "處理與否", "總容量", "正確價錢", "invNum", "desc", "xdid", "品牌", "系列", "價位帶", "系列(一匙靈專用)", "天然", "香氛", "強效", "抗菌", "防蟎", "防霉", "潔白", "柔軟", "亮彩/護色", "不傷衣料", "嬰兒", "去味", "柔膚", "低敏", "無味", "超濃縮", "環保", "酵素", "運動"]]
#     df_row_data_useful_columns = df_row_data[["invDate", "invTime", "品類", "通路", "全通路不含C", "YFY經銷", "通路類型(客戶用)", "處理與否", "總容量", "正確價錢", "invNum", "desc", "xdid", "品牌", "系列"]]



    # --- 修改 invDate, invTime 格式 ---

    invDate_list_of_df_row_data_useful_columns = list(df_row_data_useful_columns["invDate"])
    invTime_list_of_df_row_data_useful_columns = list(df_row_data_useful_columns["invTime"])

    for i in range(0, len(invDate_list_of_df_row_data_useful_columns)):
        # === 修改 invDate 格式 ===
        invDate_list_of_df_row_data_useful_columns[i] = str(invDate_list_of_df_row_data_useful_columns[i]).split(" ")[0].replace("/", "-")
        # === 修改 invTime 格式 ===
        invTime_list_of_df_row_data_useful_columns[i] = str(invTime_list_of_df_row_data_useful_columns[i]).split(" ")[0]    



    df_row_data_useful_columns["invDate"] = invDate_list_of_df_row_data_useful_columns
    df_row_data_useful_columns["invTime"] = invTime_list_of_df_row_data_useful_columns




    # --- 新增欄位 : year month date ---

    list_of_row_data_useful_columns_year = []
    list_of_row_data_useful_columns_month = []
    list_of_row_data_useful_columns_day = []


    for i in range(0,len(invDate_list_of_df_row_data_useful_columns)) :
        list_of_row_data_useful_columns_year.append(invDate_list_of_df_row_data_useful_columns[i].split("-")[0])
        list_of_row_data_useful_columns_month.append(invDate_list_of_df_row_data_useful_columns[i].split("-")[1])
        list_of_row_data_useful_columns_day.append(invDate_list_of_df_row_data_useful_columns[i].split("-")[2])

    df_row_data_useful_columns["year"] = list_of_row_data_useful_columns_year
    df_row_data_useful_columns["month"] = list_of_row_data_useful_columns_month
    df_row_data_useful_columns["date"] = list_of_row_data_useful_columns_day



    invDate_strptime = []
    for i in range(0, len(df_row_data_useful_columns["invDate"])) :
        invDate_strptime.append(datetime.datetime.strptime(df_row_data_useful_columns["invDate"][i], '%Y-%m-%d'))
    df_row_data_useful_columns["invDate_datetime"] = invDate_strptime




    # 可能2017年的發票編號 跟 2018年的發票編號 ， 明明是不同張內容的發票 但編號會重複
    # --- 修改 invNum 格式 ---
    # 先新增統一日期格式的 str_invDate (從invDate_datetime做出的)
    df_row_data_useful_columns["str_invDate"] = df_row_data_useful_columns["invDate_datetime"].apply(lambda x: str(x))
    df_row_data_useful_columns["str_invDate"] = df_row_data_useful_columns['str_invDate'].apply(lambda x: x.split(" ")[0])
    # 再更新invNum
    df_row_data_useful_columns["invNum"] = df_row_data_useful_columns[['str_invDate', 'invNum']].apply(lambda x: ' '.join(x), axis = 1)
    return df_row_data_useful_columns

# %%
# # 讀取原始資料
# def 讀取原始資料(原始資料路徑) :
#     df_row_data = pd.read_excel(str(原始資料路徑))
#     return df_row_data
    
    

# # 選入欄位多一個 "價位帶"    
# def 整理原始資料_時間格式(df_row_data) :

#     # 選取欄位
#     df_row_data_useful_columns = df_row_data[["invDate", "invTime", "品類", "通路", "YFY經銷", "通路類型(客戶用)", "處理與否", "總容量", "正確價錢", "invNum", "desc", "xdid", "品牌", "系列", "價位帶", "系列(一匙靈專用)", "天然", "香氛", "強效"]]
# #     df_row_data_useful_columns = df_row_data[["invDate", "invTime", "品類", "通路", "全通路不含C", "YFY經銷", "通路類型(客戶用)", "處理與否", "總容量", "正確價錢", "invNum", "desc", "xdid", "品牌", "系列"]]



#     # --- 修改 invDate, invTime 格式 ---

#     invDate_list_of_df_row_data_useful_columns = list(df_row_data_useful_columns["invDate"])
#     invTime_list_of_df_row_data_useful_columns = list(df_row_data_useful_columns["invTime"])

#     for i in range(0, len(invDate_list_of_df_row_data_useful_columns)):
#         # === 修改 invDate 格式 ===
#         invDate_list_of_df_row_data_useful_columns[i] = str(invDate_list_of_df_row_data_useful_columns[i]).split(" ")[0].replace("/", "-")
#         # === 修改 invTime 格式 ===
#         invTime_list_of_df_row_data_useful_columns[i] = str(invTime_list_of_df_row_data_useful_columns[i]).split(" ")[0]    



#     df_row_data_useful_columns["invDate"] = invDate_list_of_df_row_data_useful_columns
#     df_row_data_useful_columns["invTime"] = invTime_list_of_df_row_data_useful_columns




#     # --- 新增欄位 : year month date ---

#     list_of_row_data_useful_columns_year = []
#     list_of_row_data_useful_columns_month = []
#     list_of_row_data_useful_columns_day = []


#     for i in range(0,len(invDate_list_of_df_row_data_useful_columns)) :
#         list_of_row_data_useful_columns_year.append(invDate_list_of_df_row_data_useful_columns[i].split("-")[0])
#         list_of_row_data_useful_columns_month.append(invDate_list_of_df_row_data_useful_columns[i].split("-")[1])
#         list_of_row_data_useful_columns_day.append(invDate_list_of_df_row_data_useful_columns[i].split("-")[2])

#     df_row_data_useful_columns["year"] = list_of_row_data_useful_columns_year
#     df_row_data_useful_columns["month"] = list_of_row_data_useful_columns_month
#     df_row_data_useful_columns["date"] = list_of_row_data_useful_columns_day



#     invDate_strptime = []
#     for i in range(0, len(df_row_data_useful_columns["invDate"])) :
#         invDate_strptime.append(datetime.datetime.strptime(df_row_data_useful_columns["invDate"][i], '%Y-%m-%d'))
#     df_row_data_useful_columns["invDate_datetime"] = invDate_strptime




#     # 可能2017年的發票編號 跟 2018年的發票編號 ， 明明是不同張內容的發票 但編號會重複
#     # --- 修改 invNum 格式 ---
#     # 先新增統一日期格式的 str_invDate (從invDate_datetime做出的)
#     df_row_data_useful_columns["str_invDate"] = df_row_data_useful_columns["invDate_datetime"].apply(lambda x: str(x))
#     df_row_data_useful_columns["str_invDate"] = df_row_data_useful_columns['str_invDate'].apply(lambda x: x.split(" ")[0])
#     # 再更新invNum
#     df_row_data_useful_columns["invNum"] = df_row_data_useful_columns[['str_invDate', 'invNum']].apply(lambda x: ' '.join(x), axis = 1)
#     return df_row_data_useful_columns

# %% [markdown]
# ## 原始資料路徑

# %%
# 讀取原始資料
df_row_data = 讀取原始資料(原始資料路徑)

# %%
# 整理原始資料_時間格式
df_row_data_useful_columns = 整理原始資料_時間格式(df_row_data)

# "全通路不含C" 之欄位
全通路何者不含C_list = df_row_data_useful_columns["通路"].tolist()
for i in range(0, len(全通路何者不含C_list)) :
    if 全通路何者不含C_list[i] == "COSTCO 好市多" :
        全通路何者不含C_list[i] = "1"
    else :
        全通路何者不含C_list[i] = "0"
df_row_data_useful_columns["全通路何者不含C"] = 全通路何者不含C_list

# "YFY經銷含_1_2_3_4" 之欄位
YFY經銷含_1_2_3_4_list = df_row_data_useful_columns["YFY經銷"].tolist()
for i in range(0, len(YFY經銷含_1_2_3_4_list)) :
    if (YFY經銷含_1_2_3_4_list[i] == "1.經銷-超市(整體超市扣除全聯、頂好、楓康)") or (YFY經銷含_1_2_3_4_list[i] == "2.經銷-藥妝(整體個人用品店扣除美華泰、寶雅、屈臣氏、康是美)") or (YFY經銷含_1_2_3_4_list[i] == "3.經銷-藥局/嬰幼(包括全部藥局&嬰幼兒店)") or (YFY經銷含_1_2_3_4_list[i] == "4.經銷-五金百貨(包括五金、百貨行、文具行、雜貨店)") :
        YFY經銷含_1_2_3_4_list[i] = "1"
    else :
        YFY經銷含_1_2_3_4_list[i] = "0"
df_row_data_useful_columns["YFY經銷含_1_2_3_4"] = YFY經銷含_1_2_3_4_list
# Out:
# C:\Users\EOL\Anaconda3\lib\site-packages\ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\EOL\Anaconda3\lib\site-packages\ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\EOL\Anaconda3\lib\site-packages\ipykernel_launcher.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df_row_data_useful_columns.columns
# Out:
# Index(['invDate', 'invTime', '品類', '通路', 'YFY經銷', '通路類型(客戶用)', '處理與否', '總容量',
#        '正確價錢', 'invNum', 'desc', 'xdid', '品牌', '系列', '價位帶', '系列(一匙靈專用)', '天然',
#        '香氛', '強效', '抗菌', '防蟎', '防霉', '潔白', '柔軟', '亮彩/護色', '不傷衣料', '嬰兒', '去味',
#        '柔膚', '低敏', '無味', '超濃縮', '環保', '酵素', '運動', 'year', 'month', 'date',
#        'invDate_datetime', 'str_invDate', '全通路何者不含C', 'YFY經銷含_1_2_3_4'],
#       dtype='object')

# %% [markdown]
# ## 自定義品牌 (通路自有品牌)

# %%
df = df_row_data_useful_columns

# =================================== 6.品牌_ ===================================   
# 分為 : 品牌，自定義品牌

# 自定義品牌 - 定義自有品牌 : for - MAT_洗衣粉_品牌
df["自定義品牌"] = df["品牌"]

df.ix[df["品牌"] == "7-11_PL", "自定義品牌"] = "通路自有品牌"
df.ix[df["品牌"] == "HOLA_PL", "自定義品牌"] = "通路自有品牌"
df.ix[df["品牌"] == "UNIDESIGN", "自定義品牌"] = "通路自有品牌"
df.ix[df["品牌"] == "大創_PL", "自定義品牌"] = "通路自有品牌"
df.ix[df["品牌"] == "大潤發_PL", "自定義品牌"] = "通路自有品牌"
df.ix[df["品牌"] == "全家_PL", "自定義品牌"] = "通路自有品牌"
# df.ix[df["品牌"] == "全家自有品牌", "自定義品牌"] = "通路自有品牌"
df.ix[df["品牌"] == "美廉社_PL", "自定義品牌"] = "通路自有品牌"
df.ix[df["品牌"] == "家樂福_PL", "自定義品牌"] = "通路自有品牌"
df.ix[df["品牌"] == "特力屋_PL", "自定義品牌"] = "通路自有品牌"
df.ix[df["品牌"] == "康是美_PL", "自定義品牌"] = "通路自有品牌"
df.ix[df["品牌"] == "萊爾富_PL", "自定義品牌"] = "通路自有品牌"
df.ix[df["品牌"] == "愛買_PL", "自定義品牌"] = "通路自有品牌"

# =================================== 定義"其他" : read_excel ===================================
# load
# df_定義其他品牌 = pd.read_excel("C:/Users/johnson_huang.EOL/py_ds/系列_洗衣粉_MAT_2018_FEB_定義其他品牌.xlsx")
df_定義其他品牌 = pd.read_excel("%s" % (定義其他品牌的EXCEL檔名))
# 不在報表表頭範圍的，改成其他
df.ix[~df["自定義品牌"].isin(df_定義其他品牌["自定義品牌"]), "自定義品牌"] = "其他"





# =================================== 7.系列_ ===================================
# 系列幾乎是NA，但 group by 會自動 drop 掉有 NA 的那些 row， 

df.xdid = df.xdid.fillna("missing")
df["系列(一匙靈專用)"] = df["系列(一匙靈專用)"].fillna("*不分系列")


訴求們 = ["天然", "香氛", "強效", "抗菌", "防蟎", "防霉", "潔白", "柔軟", "亮彩/護色", "不傷衣料", "嬰兒", "去味", "柔膚", "低敏", "無味", "超濃縮", "環保", "酵素", "運動"]
for i in range(0, len(訴求們)) :
    df[訴求們[i]] = df[訴求們[i]].replace("0", "非"+str(訴求們[i]))
    df[訴求們[i]] = df[訴求們[i]].replace(0, "非"+str(訴求們[i]))
    df[訴求們[i]] = df[訴求們[i]].fillna("非"+str(訴求們[i]))

# ----------------------------------------------------- 
# 處理有斜線的column，例如 "亮彩/護色"
df["亮彩_護色"] = df["亮彩/護色"].str.replace("/", "_")
# -----------------------------------------------------
    
# =================================== 品類_list ===================================
df["品類_list"] = pd.Series()
for i in range(0, len(品類_list)) :
    df.ix[df["品類"] == str(品類_list[i]), "品類_list"] = int(1)
df["品類_list"] = df["品類_list"].fillna(0)
        






df_整理 = df
df_整理
# Out:
# C:\Users\EOL\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# C:\Users\EOL\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   if __name__ == '__main__':
# C:\Users\EOL\Anaconda3\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df_整理.columns
# Out:
# Index(['invDate', 'invTime', '品類', '通路', 'YFY經銷', '通路類型(客戶用)', '處理與否', '總容量',
#        '正確價錢', 'invNum', 'desc', 'xdid', '品牌', '系列', '價位帶', '系列(一匙靈專用)', '天然',
#        '香氛', '強效', '抗菌', '防蟎', '防霉', '潔白', '柔軟', '亮彩/護色', '不傷衣料', '嬰兒', '去味',
#        '柔膚', '低敏', '無味', '超濃縮', '環保', '酵素', '運動', 'year', 'month', 'date',
#        'invDate_datetime', 'str_invDate', '全通路何者不含C', 'YFY經銷含_1_2_3_4',
#        '自定義品牌', '亮彩_護色', '品類_list'],
#       dtype='object')

# %%
# df = df_row_data_useful_columns

# # =================================== 6.品牌_ ===================================   
# # 分為 : 品牌，自定義品牌

# # 自定義品牌 - 定義自有品牌 : for - MAT_洗衣粉_品牌
# df["自定義品牌"] = df["品牌"]

# df.ix[df["品牌"] == "7-11_PL", "自定義品牌"] = "通路自有品牌"
# df.ix[df["品牌"] == "HOLA_PL", "自定義品牌"] = "通路自有品牌"
# df.ix[df["品牌"] == "UNIDESIGN", "自定義品牌"] = "通路自有品牌"
# df.ix[df["品牌"] == "大創_PL", "自定義品牌"] = "通路自有品牌"
# df.ix[df["品牌"] == "大潤發_PL", "自定義品牌"] = "通路自有品牌"
# df.ix[df["品牌"] == "全家_PL", "自定義品牌"] = "通路自有品牌"
# # df.ix[df["品牌"] == "全家自有品牌", "自定義品牌"] = "通路自有品牌"
# df.ix[df["品牌"] == "美廉社_PL", "自定義品牌"] = "通路自有品牌"
# df.ix[df["品牌"] == "家樂福_PL", "自定義品牌"] = "通路自有品牌"
# df.ix[df["品牌"] == "特力屋_PL", "自定義品牌"] = "通路自有品牌"
# df.ix[df["品牌"] == "康是美_PL", "自定義品牌"] = "通路自有品牌"
# df.ix[df["品牌"] == "萊爾富_PL", "自定義品牌"] = "通路自有品牌"
# # df.ix[df["品牌"] == "愛買_PL", "自定義品牌"] = "通路自有品牌"

# # =================================== 定義"其他" : read_excel ===================================
# # load
# # df_定義其他品牌 = pd.read_excel("C:/Users/johnson_huang.EOL/py_ds/系列_洗衣粉_MAT_2018_FEB_定義其他品牌.xlsx")
# df_定義其他品牌 = pd.read_excel("%s" % (定義其他品牌的EXCEL檔名))
# # 不在報表表頭範圍的，改成其他
# df.ix[~df["自定義品牌"].isin(df_定義其他品牌["自定義品牌"]), "自定義品牌"] = "其他"





# # =================================== 7.系列_ ===================================
# # 系列幾乎是NA，但 group by 會自動 drop 掉有 NA 的那些 row， 

# df.xdid = df.xdid.fillna("missing")
# df["系列(一匙靈專用)"] = df["系列(一匙靈專用)"].fillna("*不分系列")


# 訴求們 = ["天然", "香氛", "強效"]
# for i in range(0, len(訴求們)) :
#     df[訴求們[i]] = df[訴求們[i]].replace("0", "非"+str(訴求們[i]))
#     df[訴求們[i]] = df[訴求們[i]].replace(0, "非"+str(訴求們[i]))
#     df[訴求們[i]] = df[訴求們[i]].fillna("非"+str(訴求們[i]))

# # =================================== 品類_list ===================================
# df["品類_list"] = pd.Series()
# for i in range(0, len(品類_list)) :
#     df.ix[df["品類"] == str(品類_list[i]), "品類_list"] = int(1)
# df["品類_list"] = df["品類_list"].fillna(0)
        






# df_整理 = df
# df_整理

# %%
# ================================================================
訴求正面敘述_list = ["天然", "香氛", "強效", "抗菌", "防螨", "防霉", "潔白", "柔軟", "亮彩/護色", "不傷衣料", "嬰兒", "去味", "柔膚", "低敏", "無味", "超濃縮", "環保", "酵素", "運動"]

for i in range(0, len(訴求正面敘述_list)) :
    訴求正面敘述 = 訴求正面敘述_list[i]

    # ================================================================
    訴求優先順序 = [訴求正面敘述, "非"+訴求正面敘述]
    print(訴求優先順序)
# Out:
# ['天然', '非天然']
# ['香氛', '非香氛']
# ['強效', '非強效']
# ['抗菌', '非抗菌']
# ['防螨', '非防螨']
# ['防霉', '非防霉']
# ['潔白', '非潔白']
# ['柔軟', '非柔軟']
# ['亮彩/護色', '非亮彩/護色']
# ['不傷衣料', '非不傷衣料']
# ['嬰兒', '非嬰兒']
# ['去味', '非去味']
# ['柔膚', '非柔膚']
# ['低敏', '非低敏']
# ['無味', '非無味']
# ['超濃縮', '非超濃縮']
# ['環保', '非環保']
# ['酵素', '非酵素']
# ['運動', '非運動']

# %%
# 報表類型 = ["訴求", "品牌", "系列"]

# 訴求_表頭順序 寫在 def 系列表頭順序(DataFrame, 訴求) 裡面；
# 訴求_表頭順序: * (10 ** ( len(報表類型)+1 )) ----
#                                                  |------> 考慮到有可能品牌有一百多個，所以在次方落差上故意弄得大一點
# 品牌_表頭順序  : * (10 ** ( len(報表類型)-1-1 )) --
# 系列_表頭順序  : * (10 ** ( len(報表類型)-1-1-1 )) 

# 這些部分和 "品牌x系列" 的規則不一樣

# ================================================================

# 報表類型決定編碼是10的幾次方

報表類型 = ["訴求", "品牌", "系列"]

# ================================================================



# ================================================================

# 訴求優先順序 = ["天然", "0"]

品牌優先順序 = ["-", "橘子工坊", "植淨美", "Frosch"]
品牌最後順序 = ["通路自有品牌", "其他"]

系列優先順序 = ["Grand Total", "SubTotal", "Total"]
系列最後順序 = ["其他", "DN"]

# ================================================================

def 品牌x系列_表頭排序(DataFrame, 訴求_column, 訴求_value) :   
    
    訴求_column = 訴求_column
    訴求_value = 訴求_value
    
    # ----------------

    def 品牌表頭順序(DataFrame) :
    
        # ----------------
        df_優先表頭順序 = DataFrame[DataFrame["系列(一匙靈專用)"].str.contains("Total|Grand Total")==True].sort_values(by=["銷額市佔率"], ascending=[False])
        df_優先表頭順序 = df_優先表頭順序.ix[df_優先表頭順序["自定義品牌"].isin(品牌優先順序)]
        df_優先表頭順序 = df_優先表頭順序[["自定義品牌"]].reset_index(drop = True)

        df_優先表頭順序["品牌_表頭順序"] = pd.Series()
        for i in range(0, len(df_優先表頭順序["自定義品牌"])) :
            df_優先表頭順序["品牌_表頭順序"][i] = (1 + i) * (10 ** ( len(報表類型)-1-1 ))   

        # ----------------   

        df_中間表頭順序 = DataFrame[DataFrame["系列(一匙靈專用)"].str.contains("Total|Grand Total")==True].sort_values(by=["銷額市佔率"], ascending=[False])
        df_中間表頭順序 = df_中間表頭順序.ix[(~df_中間表頭順序["自定義品牌"].isin(品牌優先順序)) & (~df_中間表頭順序["自定義品牌"].isin(品牌最後順序))]
        df_中間表頭順序 = df_中間表頭順序[["自定義品牌"]].reset_index(drop = True)

        df_中間表頭順序["品牌_表頭順序"] = pd.Series()
        for i in range(0, len(df_中間表頭順序["自定義品牌"])) :
            df_中間表頭順序["品牌_表頭順序"][i] = (1 + i + len(品牌優先順序)) * (10 ** ( len(報表類型)-1-1 ))

        # ----------------

        df_最後表頭順序 = DataFrame[DataFrame["系列(一匙靈專用)"].str.contains("Total|Grand Total")==True]
        df_最後表頭順序 = df_最後表頭順序.ix[df_最後表頭順序["自定義品牌"].isin(品牌最後順序)].sort_values(by=["自定義品牌"], ascending=[False])
        df_最後表頭順序 = df_最後表頭順序[["自定義品牌"]].reset_index(drop = True)

        df_最後表頭順序["品牌_表頭順序"] = pd.Series()
        for i in range(0, len(df_最後表頭順序["自定義品牌"])) :
            df_最後表頭順序["品牌_表頭順序"][i] = (1 + i + len(品牌優先順序) + len(df_中間表頭順序["品牌_表頭順序"]))  * (10 ** ( len(報表類型)-1-1 ))

        # ----------------

        df_表頭順序 = pd.concat([df_優先表頭順序, df_中間表頭順序, df_最後表頭順序], axis = 0).reset_index(drop = True)

        return df_表頭順序





    # ================================================================



    def 系列表頭順序(DataFrame, 訴求_column, 訴求_value) :

        
        # 訴求_表頭順序
        DataFrame["訴求_表頭順序"] = pd.Series()

        DataFrame.ix[DataFrame[str(訴求_column)] == str(訴求_value), "訴求_表頭順序"] = (1) * (10 ** ( len(報表類型)+3 ))   
#         DataFrame.ix[DataFrame[str(訴求_column)] == 0, "訴求_表頭順序"] = (2) * (10 ** ( len(報表類型)+3 ))
        DataFrame.ix[DataFrame[str(訴求_column)] == "非"+str(訴求_column), "訴求_表頭順序"] = (2) * (10 ** ( len(報表類型)+3 ))   
   


        # 系列_表頭順序
        DataFrame["系列_表頭順序"] = pd.Series()

        DataFrame.ix[DataFrame["系列(一匙靈專用)"].isin(系列優先順序), "系列_表頭順序"] = 0 * (10 ** ( len(報表類型)-1-1-1 ))   
        DataFrame.ix[~DataFrame["系列(一匙靈專用)"].isin(系列優先順序), "系列_表頭順序"] = 2 * (10 ** ( len(報表類型)-1-1-1 ))   
        DataFrame.ix[DataFrame["系列(一匙靈專用)"].isin(系列最後順序), "系列_表頭順序"] = 9 * (10 ** ( len(報表類型)-1-1-1 )) 


        return DataFrame



    # 系列排序 & 價位帶排序
    DataFrame = 系列表頭順序(DataFrame, 訴求_column, 訴求_value)
    # 品牌排序
    DataFrame = pd.merge(DataFrame, 品牌表頭順序(DataFrame), how = "left", on = ["自定義品牌"])
    # 相加決定總排序
    DataFrame["總排序"] = DataFrame["訴求_表頭順序"] + DataFrame["品牌_表頭順序"] + DataFrame["系列_表頭順序"]
    DataFrame = DataFrame.sort_values(by = ["總排序", "銷額市佔率"], ascending = [True, False])
    
    
    # 這是 品牌x系列 的報表
#     DataFrame = DataFrame[["自定義品牌","系列(一匙靈專用)","銷額市佔率","銷量市佔率","每公升均價(元)","每次購買金額(元)","每次購買量(公升)","平均購買次數","每人平均花費","每人平均購買量","普及率", "普及率_除以33915","銷售額(百萬元)","銷售量(千公升)"]]
    
    return DataFrame



# 品牌x系列_表頭排序(DataFrame)

# %%
# # ================================================================

# # 報表類型決定編碼是10的幾次方

# 報表類型 = ["品牌"]

# # ================================================================

# # test = 指標總表_1_2_3_4_5_6_7_8_9_10_11

# # DataFrame = test

# # ================================================================

# 品牌優先順序 = ["-", "橘子工坊", "植淨美", "Frosch"]
# 品牌最後順序 = ["通路自有品牌", "其他"]

# # ================================================================

# def 品牌x系列_表頭排序(DataFrame) :   
    
#     # ----------------
#     def 品牌表頭順序(DataFrame) :
#         df_優先表頭順序 = DataFrame[DataFrame["系列(一匙靈專用)"].str.contains("Total|Grand Total")==True].sort_values(by=["銷額市佔率"], ascending=[False])
#         df_優先表頭順序 = df_優先表頭順序.ix[df_優先表頭順序["自定義品牌"].isin(品牌優先順序)]
#         df_優先表頭順序 = df_優先表頭順序[["自定義品牌"]].reset_index(drop = True)

#         df_優先表頭順序["品牌_表頭順序"] = pd.Series()
#         for i in range(0, len(df_優先表頭順序["自定義品牌"])) :
#             df_優先表頭順序["品牌_表頭順序"][i] = (1 + i) * (10 ** ( len(報表類型)-1 ))   

#         # ----------------   

#         df_中間表頭順序 = DataFrame[DataFrame["系列(一匙靈專用)"].str.contains("Total|Grand Total")==True].sort_values(by=["銷額市佔率"], ascending=[False])
#         df_中間表頭順序 = df_中間表頭順序.ix[(~df_中間表頭順序["自定義品牌"].isin(品牌優先順序)) & (~df_中間表頭順序["自定義品牌"].isin(品牌最後順序))]
#         df_中間表頭順序 = df_中間表頭順序[["自定義品牌"]].reset_index(drop = True)

#         df_中間表頭順序["品牌_表頭順序"] = pd.Series()
#         for i in range(0, len(df_中間表頭順序["自定義品牌"])) :
#             df_中間表頭順序["品牌_表頭順序"][i] = (1 + i + len(品牌優先順序)) * (10 ** ( len(報表類型)-1 ))

#         # ----------------

#         df_最後表頭順序 = DataFrame[DataFrame["系列(一匙靈專用)"].str.contains("Total|Grand Total")==True]
#         df_最後表頭順序 = df_最後表頭順序.ix[df_最後表頭順序["自定義品牌"].isin(品牌最後順序)].sort_values(by=["自定義品牌"], ascending=[False])
#         df_最後表頭順序 = df_最後表頭順序[["自定義品牌"]].reset_index(drop = True)

#         df_最後表頭順序["品牌_表頭順序"] = pd.Series()
#         for i in range(0, len(df_最後表頭順序["自定義品牌"])) :
#             df_最後表頭順序["品牌_表頭順序"][i] = (1 + i + len(品牌優先順序) + len(df_中間表頭順序["品牌_表頭順序"]))  * (10 ** ( len(報表類型)-1 ))

#         # ----------------

#         df_表頭順序 = pd.concat([df_優先表頭順序, df_中間表頭順序, df_最後表頭順序], axis = 0).reset_index(drop = True)

#         return df_表頭順序





#     # ================================================================

#     # 品牌排序
#     DataFrame = pd.merge(DataFrame, 品牌表頭順序(DataFrame), how = "left", on = ["自定義品牌"])
#     # 相加決定總排序
#     DataFrame["總排序"] = DataFrame["品牌_表頭順序"]
#     DataFrame = DataFrame.sort_values(by = ["總排序", "銷額市佔率"], ascending = [True, False])
    
    
#     # 這是 品牌x系列 的報表
# #     DataFrame = DataFrame[["自定義品牌","系列(一匙靈專用)","銷額市佔率","銷量市佔率","每公升均價(元)","每次購買金額(元)","每次購買量(公升)","平均購買次數","每人平均花費","每人平均購買量","普及率", "普及率_除以33915","銷售額(百萬元)","銷售量(千公升)"]]
    
#     return DataFrame



# # 品牌x系列_表頭排序(DataFrame)

# %% [markdown]
# ## MAT
# >> MAT_全通路

# %%
# =========================================================================================
# for 洗衣精 總容量>=0
# =========================================================================================


df = df_整理


# =================================== 1. 處理與否 = 1 =================================== 
df = df[df["處理與否"] == 1]
# =================================== 2. 總容量有值 且 >=1 =================================== 
df = df[np.isfinite(df['總容量'])]
df = df[df['總容量'] >= 0]

# =================================== 3.時間_MAT ===================================    
df = df[(df['invDate_datetime'] >= str(時間點_1)) & (df['invDate_datetime'] < str(時間點_2))]

# =================================== 4.品類_洗衣粉 ===================================
df = df[df["品類_list"] == 1]

# =================================== 5.通路_全通路 =================================== 
#全通路
df_全通路 = df 
# reset_index
df_全通路 = df.reset_index(drop = True)   




# =================================== 8-1.指標_MAT_洗衣粉_銷額市佔率 ===================================
# 算總金額(正確價錢 Grand Total)
洗衣粉_MAT_全通路總金額_Grand_Total = 0
list_of_洗衣粉_MAT_全通路總金額_Grand_Total = []
for i in range(0, len(df_全通路["正確價錢"])) :
    洗衣粉_MAT_全通路總金額_Grand_Total = 洗衣粉_MAT_全通路總金額_Grand_Total + float(df_全通路["正確價錢"][i])






# =================================== 8-2.指標_MAT_洗衣粉_銷量市佔率 ===================================
# 算總金額(正確價錢 Grand Total)
洗衣粉_MAT_全通路總容量_Grand_Total = 0
list_of_洗衣粉_MAT_全通路總容量_Grand_Total = []
for i in range(0, len(df_全通路["總容量"])) :
    洗衣粉_MAT_全通路總容量_Grand_Total = 洗衣粉_MAT_全通路總容量_Grand_Total + float(df_全通路["總容量"][i])






# # =================================== 8-4.指標_MAT_洗衣粉_每次購買金額(元) ===================================
# # =================================== 8-5.指標_MAT_洗衣粉_每次購買量(公升) ===================================
df_copy = df_全通路
df_copy = df_copy.reset_index(drop = True)
#----------------------------------------------------------------------------------
df_corss_variable_distinct_invNum = df_copy.loc[:, ["xdid", "invNum", "自定義品牌", "系列(一匙靈專用)"]]
df_corss_variable_distinct_invNum['自定義品牌_系列'] = df_corss_variable_distinct_invNum[['自定義品牌', '系列(一匙靈專用)']].apply(lambda x: ','.join(x), axis=1)
#----------------------------------------------------------------------------------
# 各品牌各系列
df_自定義品牌_系列 = df_corss_variable_distinct_invNum[['自定義品牌_系列']].drop_duplicates().reset_index(drop = True)
df_自定義品牌_系列["不重複的發票編號"] = ""
df_自定義品牌_系列["總發票張數(不重複)"] = ""

for i in range(0, len(df_自定義品牌_系列["自定義品牌_系列"])) :
    不重複的發票編號_list = []
    for j in range(0, len(df_corss_variable_distinct_invNum["自定義品牌_系列"])) :
        if df_自定義品牌_系列["自定義品牌_系列"][i] == df_corss_variable_distinct_invNum["自定義品牌_系列"][j] :
            不重複的發票編號_list.append(df_corss_variable_distinct_invNum["invNum"][j])
        else :
            None
    df_自定義品牌_系列["不重複的發票編號"][i] = list(set(不重複的發票編號_list))
    df_自定義品牌_系列["總發票張數(不重複)"][i] = len(list(set(不重複的發票編號_list)))
    不重複的發票編號_list = []
#--------------
# 各品牌Total    
df_自定義品牌_系列_Total = df_corss_variable_distinct_invNum[['自定義品牌']].drop_duplicates().reset_index(drop = True)
df_自定義品牌_系列_Total["系列(一匙靈專用)"] = "Total"
df_自定義品牌_系列_Total["不重複的發票編號"] = ""
df_自定義品牌_系列_Total["總發票張數(不重複)"] = ""    

for i in range(0, len(df_自定義品牌_系列_Total["自定義品牌"])) :
    不重複的發票編號_list = []
    for j in range(0, len(df_corss_variable_distinct_invNum["自定義品牌"])) :
        if df_自定義品牌_系列_Total["自定義品牌"][i] == df_corss_variable_distinct_invNum["自定義品牌"][j] :
            不重複的發票編號_list.append(df_corss_variable_distinct_invNum["invNum"][j])
        else :
            None
    df_自定義品牌_系列_Total["不重複的發票編號"][i] = list(set(不重複的發票編號_list))
    df_自定義品牌_系列_Total["總發票張數(不重複)"][i] = len(list(set(不重複的發票編號_list)))
    不重複的發票編號_list = []
#----------------------------------------------------------------------------------            



# # =================================== 8-6.指標_MAT_洗衣粉_平均購買次數 ===================================
# 這裡有篩選條件需要選到 "品項" : "洗衣粉" !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!

df_copy_2 = df_整理




# =================================== 挑有買過兩張發票的裝置 xdid ===================================
df_copy_3 = df_copy_2
df_copy_4 = df_copy_2
#---------------------------------------------------------------------------------------------------------

#---------------------------------------------------------------------------------------------------------
# for df_copy_2 : 要找到 總裝置數 的 那些"裝置(xdid)"候選人名單
# =================================== 0. 挑有買過2張以上發票的裝置 =================================== 
# 挑有買過兩張發票的裝置

df_all_of_xdid_with_multiple_invNum_list = df_copy_2


df_all_of_xdid_with_multiple_invNum_list = df_copy_2.loc[:, ["xdid", "invNum"]]
# 將裝置數missing的刪除
df_all_of_xdid_with_multiple_invNum_list = df_all_of_xdid_with_multiple_invNum_list.loc[df_all_of_xdid_with_multiple_invNum_list["xdid"] != "missing" ]
df_all_of_xdid_with_multiple_invNum_list = df_all_of_xdid_with_multiple_invNum_list.drop_duplicates().reset_index(drop = True)

df_all_of_xdid_with_multiple_invNum_list = df_all_of_xdid_with_multiple_invNum_list.groupby(["xdid"])['invNum'].nunique()

df_all_of_xdid_with_multiple_invNum_list = df_all_of_xdid_with_multiple_invNum_list[df_all_of_xdid_with_multiple_invNum_list > 1]
df_all_of_xdid_with_multiple_invNum_list = df_all_of_xdid_with_multiple_invNum_list.to_frame().reset_index()
# #---------------------------------------------------------------------------------------------------------
# < 交叉變項 : 總裝置數 的 那些"裝置(xdid)"候選人名單 >
df_all_of_xdid_with_multiple_invNum_list = list(set(df_all_of_xdid_with_multiple_invNum_list["xdid"]))

#---------------------------------------------------------------------------------------------------------
# for df_copy_3 : 要從原始資料 找到 符合那些裝置候選人名單 & 符合後續條件 的那些row

# < 交叉變項 : 總裝置數 的 那些"裝置(xdid)"候選人名單 ；待會兒要加上 原本1~5的篩選條件 再得到 df，最後才要groupby >
df_copy_3 = df_copy_3[df_copy_3['xdid'].isin(df_all_of_xdid_with_multiple_invNum_list)]
# =================================== 1. 處理與否 = 1 =================================== 
df_copy_3 = df_copy_3[df_copy_3["處理與否"] == 1]
# =================================== 2. 總容量有值 且 >=1 =================================== 
df_copy_3 = df_copy_3[np.isfinite(df_copy_3['總容量'])]
df_copy_3 = df_copy_3[df_copy_3['總容量'] >= 0]
# =================================== 3.時間_MAT ===================================
df_copy_3 = df_copy_3[(df_copy_3['invDate_datetime'] >= str(時間點_1)) & (df_copy_3['invDate_datetime'] < str(時間點_2))]
# =================================== 4.品類_洗衣粉 - < 至少有一張發票有買到該品項 > ===================================
df_copy_3 = df_copy_3[df_copy_3["品類_list"] == 1]
# =================================== 5.通路_全通路 =================================== 
df_copy_3 = df_copy_3 #全通路
# # df_copy_3 = df_copy_3[df_copy_3["通路"] == "全聯"] #全聯
# # reset_index
# df_copy_3 = df_copy_3.reset_index(drop = True)   


# Grand Total
平均購買次數_總裝置數_list_of_xdid__with_multiple_invNum = len(list(set(df_copy_3["xdid"])))





#---------------------------------------------------------------------------------------------------------
# for df_copy_4 : 要找到總發票張數 : 1.挑有2張發票的裝置  2.其中有買到該品項的發票皆列入

# 挑有買過兩張發票的裝置

df_all_of_xdid_with_multiple_invNum_list = df_copy_2

df_all_of_xdid_with_multiple_invNum_list = df_copy_2.loc[:, ["xdid", "invNum"]]
# 將裝置數missing的保留
# df_all_of_xdid_with_multiple_invNum_list = df_all_of_xdid_with_multiple_invNum_list.loc[df_all_of_xdid_with_multiple_invNum_list["xdid"] != "missing" ]
df_all_of_xdid_with_multiple_invNum_list = df_all_of_xdid_with_multiple_invNum_list.drop_duplicates().reset_index(drop = True)

df_all_of_xdid_with_multiple_invNum_list = df_all_of_xdid_with_multiple_invNum_list.groupby(["xdid"])['invNum'].nunique()

df_all_of_xdid_with_multiple_invNum_list = df_all_of_xdid_with_multiple_invNum_list[df_all_of_xdid_with_multiple_invNum_list > 1]
df_all_of_xdid_with_multiple_invNum_list = df_all_of_xdid_with_multiple_invNum_list.to_frame().reset_index()


# #---------------------------------------------------------------------------------------------------------
# < 交叉變項 : 總裝置數 的 那些"裝置(xdid)"候選人名單 >
list_of_xdid__with_multiple_invNum = list(set(df_all_of_xdid_with_multiple_invNum_list["xdid"]))

df_copy_4 = df_copy_4[df_copy_4['xdid'].isin(list_of_xdid__with_multiple_invNum)]

# < 交叉變項 : 總裝置數 的 那些"裝置(xdid)"候選人名單 加上 原本1~5的篩選條件所得到的 df，接下來要groupby了 >
# =================================== 1. 處理與否 = 1 =================================== 
df_copy_4 = df_copy_4[df_copy_4["處理與否"] == 1]
# =================================== 2. 總容量有值 且 >=1 =================================== 
df_copy_4 = df_copy_4[np.isfinite(df_copy_4['總容量'])]
df_copy_4 = df_copy_4[df_copy_4['總容量'] >= 0]
# =================================== 3.時間_MAT ===================================    
df_copy_4 = df_copy_4[(df_copy_4['invDate_datetime'] >= str(時間點_1)) & (df_copy_4['invDate_datetime'] < str(時間點_2))]
# =================================== 4.品類_洗衣粉 - < 有買到該品項的皆列入 > ===================================
df_copy_4 = df_copy_4[df_copy_4["品類_list"] == 1]

# =================================== 5.通路_全通路 =================================== 
df_copy_4 = df_copy_4 #全通路
# df_copy_4 = df_copy_4[df_copy_4["通路"] == "全聯"] #全聯
# reset_index
df_copy_4 = df_copy_4.reset_index(drop = True)   


# 平均購買次數_總發票張數_(Grand_Total)
list_of_invNum__by_xdid__with_multiple_invNum = len(list(set(df_copy_4["invNum"])))



# # =================================== 8-6.指標_MAT_洗衣粉_平均購買次數 ===================================



# # =================================== 8-9.指標_MAT_洗衣粉_普及率 ===================================
# # 總裝置數
# =================================== 挑有買過兩張發票的裝置 xdid ===================================
df_copy_5 = df_copy_2
#---------------------------------------------------------------------------------------------------------

#---------------------------------------------------------------------------------------------------------
# for df_copy_5 : 要找到 總裝置數 的 那些"裝置(xdid)"候選人名單
# =================================== 0. 總裝置數 =================================== 


# < 交叉變項 : 總裝置數 >
df_copy_5 = df_copy_5[df_copy_5['xdid'] != "missing"]
# =================================== 1. 處理與否 = 1 =================================== 
df_copy_5 = df_copy_5[df_copy_5["處理與否"] == 1]
# =================================== 2. 總容量有值 且 >=1 =================================== 
df_copy_5 = df_copy_5[np.isfinite(df_copy_5['總容量'])]
df_copy_5 = df_copy_5[df_copy_5['總容量'] >= 0]
# =================================== 3.時間_MAT ===================================
df_copy_5 = df_copy_5[(df_copy_5['invDate_datetime'] >= str(時間點_1)) & (df_copy_5['invDate_datetime'] < str(時間點_2))]
# =================================== 4.品類_洗衣粉 - < 至少有一張發票有買到該品項 > ===================================
df_copy_5 = df_copy_5[df_copy_5["品類_list"] == 1]
# =================================== 5.通路_全通路 =================================== 
# 全通路
df_copy_5_全通路 = df_copy_5 
# 單一通路
# # df_copy_5_單一通路 = df_copy_5[df_copy_5["通路"] == "全聯"] #全聯
# # reset_index
# df_copy_5 = df_copy_5.reset_index(drop = True)   




洗衣粉_市調結果購買率 = float(洗衣粉_市調結果購買率)
# < 交叉變項 : 總裝置數 >
all_distinct_xdid_of_one_item_list = list(set(df_copy_5_全通路["xdid"]))
ALL_普及率_總裝置數_該品類總裝置數 = len(all_distinct_xdid_of_one_item_list)





# # =================================== 8-10.指標_MAT_洗衣粉_銷售額(百萬元) ===================================
# # =================================== 8-11.指標_MAT_洗衣粉_銷售量(千公升) ===================================
# - 6.平均購買次數 - 兩張發票之不重複總發票張數
洗衣粉_ALL_全通路_平均購買次數_兩張發票之不重複總發票張數 = list_of_invNum__by_xdid__with_multiple_invNum
# - 6.平均購買次數 - 兩張發票之不重複總裝置數
洗衣粉_ALL_全通路_平均購買次數_兩張發票之不重複總裝置數 = 平均購買次數_總裝置數_list_of_xdid__with_multiple_invNum
# ALL_全通路_平均購買次數
ALL_全通路_平均購買次數 = 洗衣粉_ALL_全通路_平均購買次數_兩張發票之不重複總發票張數 / 洗衣粉_ALL_全通路_平均購買次數_兩張發票之不重複總裝置數
ALL_全通路_平均購買次數

# - 4.每次購買金額 - 總金額
ALL_洗衣粉_全通路_總銷額 = 洗衣粉_MAT_全通路總金額_Grand_Total
# - 4.每次購買金額 - 不重複總發票張數
ALL_洗衣粉_ALL_全通路_每次購買金額_不重複總發票張數 = []
for i in range(0, len(df_corss_variable_distinct_invNum["invNum"])) :
    ALL_洗衣粉_ALL_全通路_每次購買金額_不重複總發票張數.append(df_corss_variable_distinct_invNum["invNum"][i])
ALL_洗衣粉_ALL_全通路_每次購買金額_不重複總發票張數 = list(set(ALL_洗衣粉_ALL_全通路_每次購買金額_不重複總發票張數))

ALL_洗衣粉_ALL_全通路_每次購買金額_不重複總發票張數 = len(ALL_洗衣粉_ALL_全通路_每次購買金額_不重複總發票張數) # 49344
# ALL_全通路_每次購買金額
ALL_全通路_每次購買金額 = ALL_洗衣粉_全通路_總銷額 / ALL_洗衣粉_ALL_全通路_每次購買金額_不重複總發票張數


# - 5.每次購買量 - 總容量
ALL_洗衣粉_全通路_總容量 = 洗衣粉_MAT_全通路總容量_Grand_Total
# ALL_全通路_每次購買量
ALL_全通路_每次購買量 = ALL_洗衣粉_全通路_總容量 / ALL_洗衣粉_ALL_全通路_每次購買金額_不重複總發票張數 #/ 1000




# 該通路銷額佔比
# ALL_全通路_銷額佔比
ALL_全通路_銷額佔比 = ALL_洗衣粉_全通路_總銷額 / ALL_洗衣粉_全通路_總銷額
# 單一通路_銷額佔比
# 單一通路_銷額佔比 =                  / ALL_洗衣粉_全通路_總銷額
















全台家戶數 = float(全台家戶數)
洗衣粉_市調結果購買率 = float(洗衣粉_市調結果購買率)

# ALL_全通路_銷額市佔率
ALL_全通路_銷額市佔率 = ALL_洗衣粉_全通路_總銷額 / ALL_洗衣粉_全通路_總銷額
# ALL_全通路_銷量市佔率
ALL_全通路_銷量市佔率 = ALL_洗衣粉_全通路_總容量 / ALL_洗衣粉_全通路_總容量
# ALL_全通路_每公升均價(元)
ALL_全通路_每公升均價 = ALL_洗衣粉_全通路_總銷額 / ALL_洗衣粉_全通路_總容量 * 1000
# ALL_全通路_每次購買金額(元)
ALL_全通路_每次購買金額 = ALL_洗衣粉_全通路_總銷額 / ALL_洗衣粉_ALL_全通路_每次購買金額_不重複總發票張數
# ALL_全通路_每次購買量(公升)
ALL_全通路_每次購買量 = ALL_洗衣粉_全通路_總容量 / ALL_洗衣粉_ALL_全通路_每次購買金額_不重複總發票張數 / 1000
# ALL_全通路_平均購買次數
ALL_全通路_平均購買次數 = 洗衣粉_ALL_全通路_平均購買次數_兩張發票之不重複總發票張數 / 洗衣粉_ALL_全通路_平均購買次數_兩張發票之不重複總裝置數
# ALL_全通路_每人平均花費
ALL_全通路_每人平均花費 = ALL_全通路_每次購買金額 * ALL_全通路_平均購買次數
# ALL_全通路_每人平均購買量
ALL_全通路_每人平均購買量 = ALL_全通路_每次購買量 * ALL_全通路_平均購買次數


ALL_洗衣粉_ALL_全通路_普及率_總裝置數 = ALL_普及率_總裝置數_該品類總裝置數 
# ALL_全通路_普及率
ALL_全通路_普及率 = 洗衣粉_市調結果購買率 * (ALL_洗衣粉_ALL_全通路_普及率_總裝置數 / ALL_洗衣粉_ALL_全通路_普及率_總裝置數)



# 洗衣粉_單一通路_普及率_總裝置數 = 
# 單一通路_普及率_除以33915 = 洗衣粉_市調結果購買率 * (洗衣粉_單一通路_普及率_總裝置數 / ALL_洗衣粉_ALL_全通路_普及率_總裝置數)

# ALL_全通路_銷售額(百萬元)
ALL_全通路_銷售額 = 全台家戶數 * 洗衣粉_市調結果購買率 * ALL_全通路_平均購買次數 * ALL_全通路_每次購買金額 / 1000000 * (ALL_洗衣粉_全通路_總銷額 / ALL_洗衣粉_全通路_總銷額) * ALL_全通路_銷額市佔率
# ALL_全通路_銷售量(千公升)
ALL_全通路_銷售量 = 全台家戶數 * 洗衣粉_市調結果購買率 * ALL_全通路_平均購買次數 * ALL_全通路_每次購買量 / 1000 * (ALL_洗衣粉_全通路_總容量 / ALL_洗衣粉_全通路_總容量) * ALL_全通路_銷量市佔率

# %%
ALL_洗衣粉_ALL_全通路_每次購買金額_不重複總發票張數
# Out:
# 210574

# %%
洗衣粉_ALL_全通路_平均購買次數_兩張發票之不重複總發票張數
# Out:
# 151654

# %%
洗衣粉_ALL_全通路_平均購買次數_兩張發票之不重複總裝置數
# Out:
# 64246

# %%
洗衣粉_ALL_全通路_平均購買次數_兩張發票之不重複總發票張數  / 洗衣粉_ALL_全通路_平均購買次數_兩張發票之不重複總裝置數
# Out:
# 2.360520499330698

# %%
ALL_洗衣粉_全通路_總銷額 / ALL_洗衣粉_全通路_總容量 * 1000
# Out:
# 75.00335283369958

# %%
print(洗衣粉_MAT_全通路總金額_Grand_Total)

print(ALL_洗衣粉_全通路_總銷額)

print(ALL_洗衣粉_全通路_總容量)

print(ALL_全通路_每次購買金額)

print(ALL_全通路_平均購買次數)

print(set(list(df_整理["天然"])))

print(set(list(df_整理["防蟎"])))
# Out:
# 57041055.85000009
# 57041055.85000009
# 760513413.0
# 270.88366013847906
# 2.360520499330698
# {'天然', '非天然'}
# {'非防蟎', '防蟎'}

# %%
df_整理.columns
# Out:
# Index(['invDate', 'invTime', '品類', '通路', 'YFY經銷', '通路類型(客戶用)', '處理與否', '總容量',
#        '正確價錢', 'invNum', 'desc', 'xdid', '品牌', '系列', '價位帶', '系列(一匙靈專用)', '天然',
#        '香氛', '強效', '抗菌', '防蟎', '防霉', '潔白', '柔軟', '亮彩/護色', '不傷衣料', '嬰兒', '去味',
#        '柔膚', '低敏', '無味', '超濃縮', '環保', '酵素', '運動', 'year', 'month', 'date',
#        'invDate_datetime', 'str_invDate', '全通路何者不含C', 'YFY經銷含_1_2_3_4',
#        '自定義品牌', '亮彩_護色', '品類_list'],
#       dtype='object')

# %%
# df_全通路["亮彩_護色"] = df_全通路["亮彩/護色"].str.replace("/", "_")

# df_全通路["亮彩_護色"]
# # df_全通路["亮彩/護色"]

# %%
# df_整理["天然"] = df_整理["天然"].astype(str)
# type(df_整理["天然"][0])
# df_整理["天然"] = df_整理["天然"].replace("0", "非天然")
# df_整理["天然"] = df_整理["天然"].fillna("非天然")


# df_全通路["天然"] = df_全通路["天然"].astype(str)
# type(df_全通路["天然"][0])
# df_全通路["天然"] = df_全通路["天然"].replace("0", "非天然")
# df_全通路["天然"] = df_全通路["天然"].fillna("非天然")



def MAT_全通路_總_訴求(訴求_column, 時間點_1, 時間點_2, 品類_list, 全台家戶數, 洗衣粉_市調結果購買率) :     
    
    訴求_column = str(訴求_column)
    
    
    def MAT_全通路_個別_訴求(訴求_column, 訴求_value, 時間點_1, 時間點_2, 品類_list, 全台家戶數, 洗衣粉_市調結果購買率) :    
        
#         訴求_value = 訴求_value
        
        try :

#             global 全台家戶數
#             global 洗衣粉_市調結果購買率

            global ALL_洗衣粉_全通路_總銷額
            global ALL_全通路_銷額市佔率

            global ALL_洗衣粉_全通路_總容量
            global ALL_全通路_銷量市佔率

            global ALL_全通路_每公升均價

            global ALL_洗衣粉_ALL_全通路_每次購買金額_不重複總發票張數
            global ALL_全通路_每次購買金額
            global ALL_全通路_每次購買量

            global 洗衣粉_ALL_全通路_平均購買次數_兩張發票之不重複總發票張數
            global 洗衣粉_ALL_全通路_平均購買次數_兩張發票之不重複總裝置數
            global ALL_全通路_平均購買次數

            global ALL_全通路_每人平均花費
            global ALL_全通路_每人平均購買量

            global ALL_洗衣粉_ALL_全通路_普及率_總裝置數


            df_某訴求_全通路 = df_全通路.loc[df_全通路[str(訴求_column)] == str(訴求_value), :].reset_index(drop = True)

            # =================================== 8-1.指標_MAT_洗衣粉_銷額市佔率 ===================================

            list_of_ALL_洗衣粉_全通路_總銷額 = []
            for i in range(0, len(df_某訴求_全通路["正確價錢"])) :
                list_of_ALL_洗衣粉_全通路_總銷額.append(ALL_洗衣粉_全通路_總銷額)

            df_某訴求_全通路["總銷額"] = list_of_ALL_洗衣粉_全通路_總銷額

            df_某訴求_全通路["各系列銷額市佔率"] = df_某訴求_全通路["正確價錢"] / df_某訴求_全通路["總銷額"]



            # 各品牌x各系列_之_各系列正確價錢
            df_1 = df_某訴求_全通路.groupby(['自定義品牌', "系列(一匙靈專用)"])["正確價錢"].sum().reset_index(name = '品項_品牌_系列_正確價錢')
            # 各品牌Total銷額市佔率
            df_2 = df_某訴求_全通路.groupby(['自定義品牌'])["正確價錢"].sum().reset_index(name = '品項_品牌_系列_正確價錢')
            # concat
            df_指標1_銷額市佔率_正確價錢 = pd.concat([df_1, df_2], axis = 0).reset_index(drop = True)
            df_指標1_銷額市佔率_正確價錢["系列(一匙靈專用)"] = df_指標1_銷額市佔率_正確價錢["系列(一匙靈專用)"].fillna("Total")

            # 各品牌x各系列_之_各系列銷額市佔率
            df_1 = df_某訴求_全通路.groupby([str(訴求_column), '自定義品牌', "系列(一匙靈專用)"])["各系列銷額市佔率"].sum().reset_index(name = '銷額市佔率')
            # 各品牌Total銷額市佔率
            df_2 = df_某訴求_全通路.groupby([str(訴求_column), '自定義品牌'])["各系列銷額市佔率"].sum().reset_index(name = '銷額市佔率')
            # concat
            df_指標1_銷額市佔率 = pd.concat([df_1, df_2], axis = 0).reset_index(drop = True)
            df_指標1_銷額市佔率["系列(一匙靈專用)"] = df_指標1_銷額市佔率["系列(一匙靈專用)"].fillna("Total")

            # merge
            df_指標1_銷額市佔率 = pd.merge(df_指標1_銷額市佔率, df_指標1_銷額市佔率_正確價錢, on = ['自定義品牌', "系列(一匙靈專用)"], how = "outer")






            # 調整欄位順序
            df_指標1_銷額市佔率 = df_指標1_銷額市佔率.loc[: , [str(訴求_column), "自定義品牌", "系列(一匙靈專用)", "銷額市佔率", "品項_品牌_系列_正確價錢"]]


            #         # # 插入 訴求 SubTotal
            #         洗衣粉_MAT_訴求_全通路總金額_Grand_Total = 0

            #         for i in range(0, len(df_某訴求_全通路["正確價錢"])) :
            #             洗衣粉_MAT_訴求_全通路總金額_Grand_Total = 洗衣粉_MAT_訴求_全通路總金額_Grand_Total + float(df_某訴求_全通路["正確價錢"][i])

            #         df_指標1_銷額市佔率.loc[-1] = [str(訴求_column), '-', 'SubTotal', (洗衣粉_MAT_訴求_全通路總金額_Grand_Total / ALL_洗衣粉_全通路_總銷額), 洗衣粉_MAT_訴求_全通路總金額_Grand_Total]  # adding a row 
            #         df_指標1_銷額市佔率.index = df_指標1_銷額市佔率.index + 1  # shifting index
            #         df_指標1_銷額市佔率.sort_index(inplace=True) 






            # =================================== 8-2.指標_MAT_洗衣粉_銷量市佔率 ===================================



            list_of_ALL_洗衣粉_全通路_總容量 = []
            for i in range(0, len(df_某訴求_全通路["總容量"])) :
                list_of_ALL_洗衣粉_全通路_總容量.append(ALL_洗衣粉_全通路_總容量)

            df_某訴求_全通路["最後總銷量"] = list_of_ALL_洗衣粉_全通路_總容量

            df_某訴求_全通路["各系列銷量市佔率"] = df_某訴求_全通路["總容量"] / df_某訴求_全通路["最後總銷量"]





            #         list_of_洗衣粉_MAT_全通路總容量_Grand_Total = []
            #         for i in range(0, len(df_某訴求_全通路["總容量"])) :
            #             list_of_洗衣粉_MAT_全通路總容量_Grand_Total.append(洗衣粉_MAT_全通路總容量_Grand_Total)

            #         df_某訴求_全通路["總銷量"] = list_of_洗衣粉_MAT_全通路總容量_Grand_Total

            #         df_某訴求_全通路["各系列銷量市佔率"] = df_某訴求_全通路["總容量"] / df_某訴求_全通路["總銷量"]



            # 各品牌x各系列_之_各系列總容量
            df_1 = df_某訴求_全通路.groupby(['自定義品牌', "系列(一匙靈專用)"])["總容量"].sum().reset_index(name = '品項_品牌_系列_總容量')
            # 各品牌Total銷量市佔率
            df_2 = df_某訴求_全通路.groupby(['自定義品牌'])["總容量"].sum().reset_index(name = '品項_品牌_系列_總容量')
            # concat
            df_指標2_銷量市佔率_總容量 = pd.concat([df_1, df_2], axis = 0).reset_index(drop = True)
            df_指標2_銷量市佔率_總容量["系列(一匙靈專用)"] = df_指標2_銷量市佔率_總容量["系列(一匙靈專用)"].fillna("Total")

            # 各品牌x各系列_之_各系列銷量市佔率
            df_1 = df_某訴求_全通路.groupby([str(訴求_column), '自定義品牌', "系列(一匙靈專用)"])["各系列銷量市佔率"].sum().reset_index(name = '銷量市佔率')
            # 各品牌Total銷量市佔率
            df_2 = df_某訴求_全通路.groupby([str(訴求_column), '自定義品牌'])["各系列銷量市佔率"].sum().reset_index(name = '銷量市佔率')
            # concat
            df_指標2_銷量市佔率 = pd.concat([df_1, df_2], axis = 0).reset_index(drop = True)
            df_指標2_銷量市佔率["系列(一匙靈專用)"] = df_指標2_銷量市佔率["系列(一匙靈專用)"].fillna("Total")

            # merge
            df_指標2_銷量市佔率 = pd.merge(df_指標2_銷量市佔率, df_指標2_銷量市佔率_總容量, on = ['自定義品牌', "系列(一匙靈專用)"], how = "outer")






            # 調整欄位順序
            df_指標2_銷量市佔率 = df_指標2_銷量市佔率.loc[: , [str(訴求_column), "自定義品牌", "系列(一匙靈專用)", "銷量市佔率", "品項_品牌_系列_總容量"]]


            #         # # 插入 訴求 Total
            #         洗衣粉_MAT_訴求_全通路總容量_Grand_Total = 0

            #         for i in range(0, len(df_某訴求_全通路["總容量"])) :
            #             洗衣粉_MAT_訴求_全通路總容量_Grand_Total = 洗衣粉_MAT_訴求_全通路總容量_Grand_Total + float(df_某訴求_全通路["總容量"][i])

            #         df_指標2_銷量市佔率.loc[-1] = [str(訴求_column), '-', 'SubTotal', (洗衣粉_MAT_訴求_全通路總容量_Grand_Total / 洗衣粉_MAT_全通路總容量_Grand_Total), 洗衣粉_MAT_訴求_全通路總容量_Grand_Total]  # adding a row 
            #         df_指標2_銷量市佔率.index = df_指標2_銷量市佔率.index + 1  # shifting index
            #         df_指標2_銷量市佔率.sort_index(inplace=True) 





            # # =================================== 8-3.指標_MAT_洗衣粉_每公升均價(元) ===================================
            dfs = [df_指標1_銷額市佔率, df_指標2_銷量市佔率]
            df_指標3_每公升均價 = reduce(lambda left,right: pd.merge(left, right, how = "outer", on = [str(訴求_column), '自定義品牌', "系列(一匙靈專用)"]), dfs)

            df_指標3_每公升均價["每公升均價(元)"] = df_指標3_每公升均價["品項_品牌_系列_正確價錢"] / df_指標3_每公升均價["品項_品牌_系列_總容量"] * 1000
            df_指標3_每公升均價





            # # # =================================== 8-4.指標_MAT_洗衣粉_每次購買金額(元) ===================================
            # # # =================================== 8-5.指標_MAT_洗衣粉_每次購買量(公升) ===================================
            # df_copy = df_全通路
            # df_copy = df_copy.reset_index(drop = True)

            # df_corss_variable_distinct_invNum = df_copy.loc[:, ["xdid", "invNum", "自定義品牌", "系列(一匙靈專用)"]]



            # df_copy = df_全通路
            # df_copy = df_copy.reset_index(drop = True)


            # df_copy = df_copy.loc[df_copy[str(訴求_column)] == str(訴求_value), :].reset_index(drop = True)


            # #----------------------------------------------------------------------------------
            # df_corss_variable_distinct_invNum = df_copy.loc[:, ["xdid", "invNum", "自定義品牌", "系列(一匙靈專用)", str(訴求_column), "正確價錢", "總容量"]]
            # df_corss_variable_distinct_invNum['自定義品牌_系列_訴求'] = df_corss_variable_distinct_invNum[['自定義品牌', '系列(一匙靈專用)', str(訴求_column)]].apply(lambda x: ','.join(x), axis=1)
            # #----------------------------------------------------------------------------------

            # # 訴求各品牌各系列
            # df_自定義品牌_系列_訴求 = df_corss_variable_distinct_invNum[['自定義品牌_系列_訴求']].drop_duplicates().reset_index(drop = True)
            # df_自定義品牌_系列_訴求["不重複的發票編號"] = ""
            # df_自定義品牌_系列_訴求["總發票張數(不重複)"] = ""

            # for i in range(0, len(df_自定義品牌_系列_訴求["自定義品牌_系列_訴求"])) :
            #     不重複的發票編號_list = []
            #     for j in range(0, len(df_corss_variable_distinct_invNum["自定義品牌_系列_訴求"])) :
            #         if df_自定義品牌_系列_訴求["自定義品牌_系列_訴求"][i] == df_corss_variable_distinct_invNum["自定義品牌_系列_訴求"][j] :
            #             不重複的發票編號_list.append(df_corss_variable_distinct_invNum["invNum"][j])
            #         else :
            #             None
            #     df_自定義品牌_系列_訴求["不重複的發票編號"][i] = list(set(不重複的發票編號_list))
            #     df_自定義品牌_系列_訴求["總發票張數(不重複)"][i] = len(list(set(不重複的發票編號_list)))
            #     不重複的發票編號_list = []
            # #--------------
            # # 各品牌Total    
            # df_自定義品牌_系列_訴求_Total = df_corss_variable_distinct_invNum[['自定義品牌']].drop_duplicates().reset_index(drop = True)
            # df_自定義品牌_系列_訴求_Total["系列(一匙靈專用)"] = "Total"
            # # 訴求
            # df_自定義品牌_系列_訴求_Total[str(訴求_column)] = str(str(訴求_value))
            # #             df_自定義品牌_系列_訴求_Total[str(訴求_column)] = str(訴求_column)

            # df_自定義品牌_系列_訴求_Total["不重複的發票編號"] = ""
            # df_自定義品牌_系列_訴求_Total["總發票張數(不重複)"] = ""    

            # for i in range(0, len(df_自定義品牌_系列_訴求_Total["自定義品牌"])) :
            #     不重複的發票編號_list = []
            #     for j in range(0, len(df_corss_variable_distinct_invNum["自定義品牌"])) :
            #         if df_自定義品牌_系列_訴求_Total["自定義品牌"][i] == df_corss_variable_distinct_invNum["自定義品牌"][j] :
            #             不重複的發票編號_list.append(df_corss_variable_distinct_invNum["invNum"][j])
            #         else :
            #             None
            #     df_自定義品牌_系列_訴求_Total["不重複的發票編號"][i] = list(set(不重複的發票編號_list))
            #     df_自定義品牌_系列_訴求_Total["總發票張數(不重複)"][i] = len(list(set(不重複的發票編號_list)))
            #     不重複的發票編號_list = []
            # #----------------------------------------------------------------------------------            
            # # 彙整
            # df_自定義品牌_系列_訴求["自定義品牌"] = df_自定義品牌_系列_訴求["自定義品牌_系列_訴求"].apply(lambda x: x.split(',')[0])
            # df_自定義品牌_系列_訴求["系列(一匙靈專用)"] = df_自定義品牌_系列_訴求["自定義品牌_系列_訴求"].apply(lambda x: x.split(',')[1])
            # df_自定義品牌_系列_訴求[str(訴求_column)] = df_自定義品牌_系列_訴求["自定義品牌_系列_訴求"].apply(lambda x: x.split(',')[2])

            # df_自定義品牌_系列_訴求_看各系列不重複發票數 = df_自定義品牌_系列_訴求[[str(訴求_column), "自定義品牌", "系列(一匙靈專用)", "總發票張數(不重複)"]]

            # df_自定義品牌_系列_訴求_看各品牌Total不重複發票數 = df_自定義品牌_系列_訴求_Total[[str(訴求_column), "自定義品牌", "系列(一匙靈專用)", "總發票張數(不重複)"]]
            # #----------------------------------------------------------------------------------
            # # 各品牌x各系列
            # df_1 = df_自定義品牌_系列_訴求_看各系列不重複發票數
            # # 各品牌
            # df_2 = df_自定義品牌_系列_訴求_看各品牌Total不重複發票數
            # # 總表
            # df_自定義品牌_系列_訴求_不重複發票數_總表 = pd.concat([df_1, df_2], axis = 0).reset_index(drop = True)
            # #         #----------------------------------------------------------------------------------
            # #         # 插入 訴求 SubTotal
            # #         #----------------------------------------------------------------------------------
            # #         df_corss_variable_distinct_invNum = df_copy.loc[:, ["xdid", "invNum", "自定義品牌", "系列(一匙靈專用)", str(訴求_column), "正確價錢", "總容量"]]

            # #         洗衣粉_全通路_每次購買金額_不重複總發票張數 = []
            # #         for i in range(0, len(df_corss_variable_distinct_invNum["invNum"])) :
            # #             洗衣粉_全通路_每次購買金額_不重複總發票張數.append(df_corss_variable_distinct_invNum["invNum"][i])
            # #         洗衣粉_全通路_每次購買金額_不重複總發票張數 = len(list(set(洗衣粉_全通路_每次購買金額_不重複總發票張數)))

            # #         df_自定義品牌_系列_訴求_不重複發票數_總表.loc[-1] = [str(訴求_column), '-', 'SubTotal', 洗衣粉_全通路_每次購買金額_不重複總發票張數]  # adding a row 
            # #         df_自定義品牌_系列_訴求_不重複發票數_總表.index = df_自定義品牌_系列_訴求_不重複發票數_總表.index + 1  # shifting index
            # #         df_自定義品牌_系列_訴求_不重複發票數_總表.sort_index(inplace=True) 

            # #----------------------------------------------------------------------------------    
            # df_指標4_每次購買金額_指標5_每次購買量 = pd.merge(df_指標3_每公升均價, df_自定義品牌_系列_訴求_不重複發票數_總表, on = [str(訴求_column), '自定義品牌', "系列(一匙靈專用)"], how = "outer")
            # df_指標4_每次購買金額_指標5_每次購買量["每次購買金額(元)"] = df_指標4_每次購買金額_指標5_每次購買量["品項_品牌_系列_正確價錢"] / df_指標4_每次購買金額_指標5_每次購買量["總發票張數(不重複)"]
            # df_指標4_每次購買金額_指標5_每次購買量["每次購買量(公升)"] = df_指標4_每次購買金額_指標5_每次購買量["品項_品牌_系列_總容量"] / df_指標4_每次購買金額_指標5_每次購買量["總發票張數(不重複)"] / 1000
            # #----------------------------------------------------------------------------------






            df_copy_2 = df_整理
            df_copy_3 = df_copy_2
            df_copy_4 = df_copy_2

            # # # =================================== 8-6.指標_MAT_洗衣粉_平均購買次數 ===================================
            # # 這裡有篩選條件需要選到 "品項" : "洗衣粉" !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!






            # #         df_copy_2 = df_copy_2.loc[df_copy_2[str(訴求_column)] == str(訴求_value), :].reset_index(drop = True)


            # # =================================== 挑有買過兩張發票的裝置 xdid ===================================
            # #---------------------------------------------------------------------------------------------------------

            # #---------------------------------------------------------------------------------------------------------
            # # for df_copy_2 : 要找到 總裝置數 的 那些"裝置(xdid)"候選人名單
            # # =================================== 0. 挑有買過2張以上發票的裝置 =================================== 
            # # 挑有買過兩張發票的裝置

            # df_all_of_xdid_with_multiple_invNum_list = df_copy_2


            # df_all_of_xdid_with_multiple_invNum_list = df_copy_2.loc[:, [str(訴求_column), "xdid", "invNum"]]
            # # 將裝置數missing的刪除
            # df_all_of_xdid_with_multiple_invNum_list = df_all_of_xdid_with_multiple_invNum_list.loc[df_all_of_xdid_with_multiple_invNum_list["xdid"] != "missing" ]
            # df_all_of_xdid_with_multiple_invNum_list = df_all_of_xdid_with_multiple_invNum_list.drop_duplicates().reset_index(drop = True)

            # df_all_of_xdid_with_multiple_invNum_list = df_all_of_xdid_with_multiple_invNum_list.groupby(["xdid"])['invNum'].nunique()

            # df_all_of_xdid_with_multiple_invNum_list = df_all_of_xdid_with_multiple_invNum_list[df_all_of_xdid_with_multiple_invNum_list > 1]
            # df_all_of_xdid_with_multiple_invNum_list = df_all_of_xdid_with_multiple_invNum_list.to_frame().reset_index()
            # # #---------------------------------------------------------------------------------------------------------
            # # < 交叉變項 : 總裝置數 的 那些"裝置(xdid)"候選人名單 >
            # df_all_of_xdid_with_multiple_invNum_list = list(set(df_all_of_xdid_with_multiple_invNum_list["xdid"]))

            # #---------------------------------------------------------------------------------------------------------
            # # for df_copy_3 : 要從原始資料 找到 符合那些裝置候選人名單 & 符合後續條件 的那些row



            # df_copy_3 = df_copy_3.loc[df_copy_3[str(訴求_column)] == str(訴求_value), :].reset_index(drop = True)



            # # < 交叉變項 : 總裝置數 的 那些"裝置(xdid)"候選人名單 ；待會兒要加上 原本1~5的篩選條件 再得到 df，最後才要groupby >
            # df_copy_3 = df_copy_3[df_copy_3['xdid'].isin(df_all_of_xdid_with_multiple_invNum_list)]
            # # =================================== 1. 處理與否 = 1 =================================== 
            # df_copy_3 = df_copy_3[df_copy_3["處理與否"] == 1]
            # # =================================== 2. 總容量有值 且 >=1 =================================== 
            # df_copy_3 = df_copy_3[np.isfinite(df_copy_3['總容量'])]
            # df_copy_3 = df_copy_3[df_copy_3['總容量'] >= 0]
            # # =================================== 3.時間_MAT ===================================
            # df_copy_3 = df_copy_3[(df_copy_3['invDate_datetime'] >= str(時間點_1)) & (df_copy_3['invDate_datetime'] < str(時間點_2))]
            # # =================================== 4.品類_洗衣粉 - < 至少有一張發票有買到該品項 > ===================================
            # df_copy_3 = df_copy_3[df_copy_3["品類_list"] == 1]
            # # =================================== 5.通路_全通路 =================================== 
            # df_copy_3 = df_copy_3 #全通路
            # # # df_copy_3 = df_copy_3[df_copy_3["通路"] == "全聯"] #全聯
            # # # reset_index
            # # df_copy_3 = df_copy_3.reset_index(drop = True)   


            # # Grand Total
            # 平均購買次數_總裝置數_list_of_xdid__with_multiple_invNum = len(list(set(df_copy_3["xdid"])))



            # # Count unique values with pandas per groups
            # df_平均購買次數_總裝置數 = df_copy_3.groupby([str(訴求_column), "自定義品牌", "系列(一匙靈專用)"])['xdid'].nunique()










            # #---------------------------------------------------------------------------------------------------------
            # # for df_copy_4 : 要找到總發票張數 : 1.挑有2張發票的裝置  2.其中有買到該品項的發票皆列入

            # # 挑有買過兩張發票的裝置

            # df_all_of_xdid_with_multiple_invNum_list = df_copy_2

            # df_all_of_xdid_with_multiple_invNum_list = df_copy_2.loc[:, [str(訴求_column), "xdid", "invNum"]]
            # # 將裝置數missing的保留
            # # df_all_of_xdid_with_multiple_invNum_list = df_all_of_xdid_with_multiple_invNum_list.loc[df_all_of_xdid_with_multiple_invNum_list["xdid"] != "missing" ]
            # df_all_of_xdid_with_multiple_invNum_list = df_all_of_xdid_with_multiple_invNum_list.drop_duplicates().reset_index(drop = True)

            # df_all_of_xdid_with_multiple_invNum_list = df_all_of_xdid_with_multiple_invNum_list.groupby(["xdid"])['invNum'].nunique()

            # df_all_of_xdid_with_multiple_invNum_list = df_all_of_xdid_with_multiple_invNum_list[df_all_of_xdid_with_multiple_invNum_list > 1]
            # df_all_of_xdid_with_multiple_invNum_list = df_all_of_xdid_with_multiple_invNum_list.to_frame().reset_index()


            # # #---------------------------------------------------------------------------------------------------------
            # # < 交叉變項 : 總裝置數 的 那些"裝置(xdid)"候選人名單 >
            # list_of_xdid__with_multiple_invNum = list(set(df_all_of_xdid_with_multiple_invNum_list["xdid"]))



            # df_copy_4 = df_copy_4[df_copy_4['xdid'].isin(list_of_xdid__with_multiple_invNum)]


            # df_copy_4 = df_copy_4.loc[df_copy_4[str(訴求_column)] == str(訴求_value), :].reset_index(drop = True)        



            # # < 交叉變項 : 總裝置數 的 那些"裝置(xdid)"候選人名單 加上 原本1~5的篩選條件所得到的 df，接下來要groupby了 >
            # # =================================== 1. 處理與否 = 1 =================================== 
            # df_copy_4 = df_copy_4[df_copy_4["處理與否"] == 1]
            # # =================================== 2. 總容量有值 且 >=1 =================================== 
            # df_copy_4 = df_copy_4[np.isfinite(df_copy_4['總容量'])]
            # df_copy_4 = df_copy_4[df_copy_4['總容量'] >= 0]
            # # =================================== 3.時間_MAT ===================================    
            # df_copy_4 = df_copy_4[(df_copy_4['invDate_datetime'] >= str(時間點_1)) & (df_copy_4['invDate_datetime'] < str(時間點_2))]
            # # =================================== 4.品類_洗衣粉 - < 有買到該品項的皆列入 > ===================================
            # df_copy_4 = df_copy_4[df_copy_4["品類_list"] == 1]

            # # =================================== 5.通路_全通路 =================================== 
            # df_copy_4 = df_copy_4 #全通路
            # # df_copy_4 = df_copy_4[df_copy_4["通路"] == "全聯"] #全聯
            # # reset_index
            # df_copy_4 = df_copy_4.reset_index(drop = True)   


            # # 平均購買次數_總發票張數_(Grand_Total)
            # list_of_invNum__by_xdid__with_multiple_invNum = len(list(set(df_copy_4["invNum"])))


            # # Count unique values with pandas per groups
            # df_平均購買次數_總發票張數 = df_copy_4.groupby([str(訴求_column), "自定義品牌", "系列(一匙靈專用)"])['invNum'].nunique()

            # # # =================================== 8-6.指標_MAT_洗衣粉_平均購買次數 ===================================
            # df_平均購買次數_總發票張數 = df_平均購買次數_總發票張數.to_frame().reset_index()
            # df_平均購買次數_總裝置數 = df_平均購買次數_總裝置數.to_frame().reset_index()

            # df_平均購買次數 = pd.merge(df_平均購買次數_總發票張數, df_平均購買次數_總裝置數, on = [str(訴求_column), "自定義品牌", "系列(一匙靈專用)"], how = "outer")
            # df_平均購買次數["平均購買次數"] = df_平均購買次數["invNum"] / df_平均購買次數["xdid"]




            # # 各品牌_Total_平均購買次數
            # df_平均購買次數_total = pd.DataFrame()
            # list_平均購買次數_自定義品牌 = list(set(df_平均購買次數['自定義品牌']))
            # 平均購買次數_系列_total = []
            # 平均購買次數_訴求_total = []
            # for i in range(0, len(list_平均購買次數_自定義品牌)) :
            #     平均購買次數_系列_total.append("Total")
            #     平均購買次數_訴求_total.append(str(str(訴求_value)))
            # #                 平均購買次數_訴求_total.append(str(訴求_column))

            # df_平均購買次數_total["自定義品牌"] = list_平均購買次數_自定義品牌
            # df_平均購買次數_total["系列(一匙靈專用)"] = 平均購買次數_系列_total
            # # 訴求
            # #         df_平均購買次數_total[str(訴求_column)] = str(訴求_column) 
            # df_平均購買次數_total[str(訴求_column)] = 平均購買次數_訴求_total

            # df_平均購買次數_total = pd.merge(df_平均購買次數_total, df_copy_3.groupby([str(訴求_column), "自定義品牌"])['xdid'].nunique().to_frame(), on = ["自定義品牌"])
            # df_平均購買次數_total = pd.merge(df_平均購買次數_total, df_copy_4.groupby([str(訴求_column), "自定義品牌"])['invNum'].nunique().to_frame(), on = ["自定義品牌"])
            # df_平均購買次數_total["平均購買次數"] = df_平均購買次數_total["invNum"] / df_平均購買次數_total["xdid"]
            # # concat 品牌_各系列 和 品牌_total
            # df_指標6_平均購買次數 = pd.concat([df_平均購買次數, df_平均購買次數_total], axis = 0)




            # dfs = [df_指標4_每次購買金額_指標5_每次購買量, df_指標6_平均購買次數]
            # 指標總表_1_2_3_4_5_6_7_8 = reduce(lambda left,right: pd.merge(left, right, how = "outer", on = [str(訴求_column), '自定義品牌', "系列(一匙靈專用)"]), dfs)

            # # =============================================================================================================================
            # # 在算 "df_指標 7 _每人平均花費" 之前 :
            # # 手動修改的例外 : 
            # #    如果銷額、銷量有值 
            # # -> 從 6.平均購買次數開始，如果因為分母的"總裝置數"為0而造成後面運算結果為NA， 就要把平均購買次數補成"1"


            # 指標總表_1_2_3_4_5_6_7_8.loc[ (指標總表_1_2_3_4_5_6_7_8["平均購買次數"].isnull() == True)  & ((指標總表_1_2_3_4_5_6_7_8['銷額市佔率'] != None) | (指標總表_1_2_3_4_5_6_7_8['銷量市佔率'] != None)), ["平均購買次數"]] = 1

            # # =============================================================================================================================

            # # df_指標7_每人平均花費
            # 指標總表_1_2_3_4_5_6_7_8["每人平均花費"] = 指標總表_1_2_3_4_5_6_7_8["每次購買金額(元)"] * 指標總表_1_2_3_4_5_6_7_8["平均購買次數"]
            # # df_指標8_每人平均購買量
            # 指標總表_1_2_3_4_5_6_7_8["每人平均購買量"] = 指標總表_1_2_3_4_5_6_7_8["每次購買量(公升)"] * 指標總表_1_2_3_4_5_6_7_8["平均購買次數"]









            # # =================================== 8-9.指標_MAT_洗衣粉_普及率 ===================================
            # # 總裝置數
            # =================================== 挑有買過兩張發票的裝置 xdid ===================================
            df_copy_5 = df_全通路
            # df_copy_5 = df_copy_2
            #---------------------------------------------------------------------------------------------------------

            #---------------------------------------------------------------------------------------------------------
            # for df_copy_5 : 要找到 總裝置數 的 那些"裝置(xdid)"候選人名單
            # =================================== 0. 總裝置數 =================================== 


            df_copy_5 = df_copy_5.loc[df_copy_5[str(訴求_column)] == str(訴求_value), :].reset_index(drop = True)



            # < 交叉變項 : 總裝置數 >
            df_copy_5 = df_copy_5[df_copy_5['xdid'] != "missing"]
            # =================================== 1. 處理與否 = 1 =================================== 
            df_copy_5 = df_copy_5[df_copy_5["處理與否"] == 1]
            # =================================== 2. 總容量有值 且 >=1 =================================== 
            df_copy_5 = df_copy_5[np.isfinite(df_copy_5['總容量'])]
            df_copy_5 = df_copy_5[df_copy_5['總容量'] >= 0]
            # =================================== 3.時間_MAT ===================================
            df_copy_5 = df_copy_5[(df_copy_5['invDate_datetime'] >= str(時間點_1)) & (df_copy_5['invDate_datetime'] < str(時間點_2))]
            # =================================== 4.品類_洗衣粉 - < 至少有一張發票有買到該品項 > ===================================
            df_copy_5 = df_copy_5[df_copy_5["品類_list"] == 1]
            # =================================== 5.通路_全通路 =================================== 
            # 全通路
            df_copy_5_全通路 = df_copy_5 
            # 單一通路
            # # df_copy_5_單一通路 = df_copy_5[df_copy_5["通路"] == "全聯"] #全聯
            # # reset_index
            # df_copy_5 = df_copy_5.reset_index(drop = True)   




            洗衣粉_市調結果購買率 = float(洗衣粉_市調結果購買率)
            # < 交叉變項 : 總裝置數 >
            #         all_distinct_xdid_of_one_item_list = list(set(df_copy_5_全通路["xdid"]))
            #         普及率_總裝置數_該品類總裝置數 = len(all_distinct_xdid_of_one_item_list)
            ALL_洗衣粉_ALL_全通路_普及率_總裝置數 = ALL_洗衣粉_ALL_全通路_普及率_總裝置數

            # Count unique values with pandas per groups
            df_指標9_普及率_總裝置數 = df_copy_5_全通路.groupby([str(訴求_column), "自定義品牌", "系列(一匙靈專用)"])['xdid'].nunique().to_frame()
            df_指標9_普及率_總裝置數['普及率'] = 洗衣粉_市調結果購買率 * (df_指標9_普及率_總裝置數['xdid'] / ALL_洗衣粉_ALL_全通路_普及率_總裝置數)
            #         df_指標9_普及率_總裝置數['普及率_除以33915'] = 洗衣粉_市調結果購買率 * (df_指標9_普及率_總裝置數['xdid'] / 33915)
            df_指標9_普及率_總裝置數 = df_指標9_普及率_總裝置數.reset_index()


            # 各品牌 Total
            df_普及率_各品牌_Total_總裝置數 = df_copy_5_全通路.groupby([str(訴求_column), "自定義品牌"])['xdid'].nunique().to_frame()

            普及率_各品牌_Total_總裝置數_list = []
            for i in range(0, len(df_普及率_各品牌_Total_總裝置數["xdid"])) :
                普及率_各品牌_Total_總裝置數_list.append("Total")
            df_普及率_各品牌_Total_總裝置數["系列(一匙靈專用)"] = 普及率_各品牌_Total_總裝置數_list

            df_普及率_各品牌_Total_總裝置數['普及率'] = 洗衣粉_市調結果購買率 * (df_普及率_各品牌_Total_總裝置數['xdid'] / ALL_洗衣粉_ALL_全通路_普及率_總裝置數)
            #         df_普及率_各品牌_Total_總裝置數['普及率_除以33915'] = 洗衣粉_市調結果購買率 * (df_普及率_各品牌_Total_總裝置數['xdid'] / 33915)
            df_普及率_各品牌_Total_總裝置數 = df_普及率_各品牌_Total_總裝置數.reset_index()


            # concat
            df_指標9_普及率_總裝置數 = pd.concat([df_指標9_普及率_總裝置數, df_普及率_各品牌_Total_總裝置數], axis = 0)
            df_指標9_普及率_總裝置數
            # 總表 - merge
            指標總表_1_2_3_4_5_6_7_8_9_10_11 = pd.merge(df_指標3_每公升均價, df_指標9_普及率_總裝置數, on = [str(訴求_column), '自定義品牌', "系列(一匙靈專用)"], how = "outer")
            # 指標總表_1_2_3_4_5_6_7_8_9_10_11 = pd.merge(指標總表_1_2_3_4_5_6_7_8, df_指標9_普及率_總裝置數, on = [str(訴求_column), '自定義品牌', "系列(一匙靈專用)"], how = "outer")



            # =============================================================================================================================
            # 在算 "df_指標 9 _普及率" 的下一個指標 之前 :
            # 手動修改的例外 : 
            #    如果銷額、銷量有值 
            # -> 從 9.普及率 開始，如果因為空白的"裝置編號"而造成後面運算結果為NA， 就要把 普及率 強制改成"0"


            指標總表_1_2_3_4_5_6_7_8_9_10_11.loc[ (指標總表_1_2_3_4_5_6_7_8_9_10_11["普及率"].isnull() == True)  & ((指標總表_1_2_3_4_5_6_7_8_9_10_11['銷額市佔率'] != None) | (指標總表_1_2_3_4_5_6_7_8_9_10_11['銷量市佔率'] != None)), ["普及率"]] = 0

            # =============================================================================================================================







            洗衣粉_MAT_全通路總金額_Grand_Total = 0
            list_of_洗衣粉_MAT_全通路總金額_Grand_Total = []
            for i in range(0, len(df_某訴求_全通路["正確價錢"])) :
                洗衣粉_MAT_全通路總金額_Grand_Total = 洗衣粉_MAT_全通路總金額_Grand_Total + float(df_某訴求_全通路["正確價錢"][i])



            洗衣粉_MAT_全通路總容量_Grand_Total = 0
            list_of_洗衣粉_MAT_全通路總容量_Grand_Total = []
            for i in range(0, len(df_某訴求_全通路["總容量"])) :
                洗衣粉_MAT_全通路總容量_Grand_Total = 洗衣粉_MAT_全通路總容量_Grand_Total + float(df_某訴求_全通路["總容量"][i])




            # # =================================== 8-10.指標_MAT_洗衣粉_銷售額(百萬元) ===================================
            # # =================================== 8-11.指標_MAT_洗衣粉_銷售量(千公升) ===================================
            # # - 6.平均購買次數 - 兩張發票之不重複總發票張數
            # 洗衣粉_全通路_平均購買次數_兩張發票之不重複總發票張數 = list_of_invNum__by_xdid__with_multiple_invNum
            # # - 6.平均購買次數 - 兩張發票之不重複總裝置數
            # 洗衣粉_全通路_平均購買次數_兩張發票之不重複總裝置數 = 平均購買次數_總裝置數_list_of_xdid__with_multiple_invNum
            # # 全通路_平均購買次數
            # 全通路_平均購買次數 = 洗衣粉_全通路_平均購買次數_兩張發票之不重複總發票張數 / 洗衣粉_全通路_平均購買次數_兩張發票之不重複總裝置數
            # 全通路_平均購買次數

            # # - 4.每次購買金額 - 總金額
            洗衣粉_全通路_總銷額 = 洗衣粉_MAT_全通路總金額_Grand_Total
            # # - 4.每次購買金額 - 不重複總發票張數
            # 洗衣粉_全通路_每次購買金額_不重複總發票張數 = []
            # for i in range(0, len(df_corss_variable_distinct_invNum["invNum"])) :
            #     洗衣粉_全通路_每次購買金額_不重複總發票張數.append(df_corss_variable_distinct_invNum["invNum"][i])
            # 洗衣粉_全通路_每次購買金額_不重複總發票張數 = list(set(洗衣粉_全通路_每次購買金額_不重複總發票張數))

            # 洗衣粉_全通路_每次購買金額_不重複總發票張數 = len(洗衣粉_全通路_每次購買金額_不重複總發票張數) # 49344
            # # 全通路_每次購買金額
            # 全通路_每次購買金額 = 洗衣粉_全通路_總銷額 / 洗衣粉_全通路_每次購買金額_不重複總發票張數


            # # - 5.每次購買量 - 總容量
            洗衣粉_全通路_總容量 = 洗衣粉_MAT_全通路總容量_Grand_Total
            # # 全通路_每次購買量
            # 全通路_每次購買量 = 洗衣粉_全通路_總容量 / 洗衣粉_全通路_每次購買金額_不重複總發票張數 #/ 1000




            # 該通路銷額佔比
            # 全通路_銷額佔比
            全通路_銷額佔比 = 洗衣粉_全通路_總銷額 / 洗衣粉_全通路_總銷額
            # 單一通路_銷額佔比
            # 單一通路_銷額佔比 =                  / 洗衣粉_全通路_總銷額


            # 全通路_銷量
            全通路_銷量佔比 = 洗衣粉_全通路_總容量 / 洗衣粉_全通路_總容量













            全台家戶數 = float(全台家戶數)
            洗衣粉_市調結果購買率 = float(洗衣粉_市調結果購買率)

            # 全通路_銷額市佔率
            全通路_銷額市佔率 = 洗衣粉_全通路_總銷額 / ALL_洗衣粉_全通路_總銷額
            # 全通路_銷量市佔率
            全通路_銷量市佔率 = 洗衣粉_全通路_總容量 / ALL_洗衣粉_全通路_總容量
            # 全通路_每公升均價(元)
            全通路_每公升均價 = 洗衣粉_全通路_總銷額 / 洗衣粉_全通路_總容量 * 1000
            # # 全通路_每次購買金額(元)
            # 全通路_每次購買金額 = 洗衣粉_全通路_總銷額 / 洗衣粉_全通路_每次購買金額_不重複總發票張數
            # # 全通路_每次購買量(公升)
            # 全通路_每次購買量 = 洗衣粉_全通路_總容量 / 洗衣粉_全通路_每次購買金額_不重複總發票張數 / 1000
            # # 全通路_平均購買次數
            # 全通路_平均購買次數 = 洗衣粉_全通路_平均購買次數_兩張發票之不重複總發票張數 / 洗衣粉_全通路_平均購買次數_兩張發票之不重複總裝置數
            # # 全通路_每人平均花費
            # 全通路_每人平均花費 = 全通路_每次購買金額 * 全通路_平均購買次數
            # # 全通路_每人平均購買量
            # 全通路_每人平均購買量 = 全通路_每次購買量 * 全通路_平均購買次數


            # < 交叉變項 : 總裝置數 >
            all_distinct_xdid_of_one_item_list = list(set(df_copy_5_全通路["xdid"]))
            普及率_總裝置數_該品類總裝置數 = len(all_distinct_xdid_of_one_item_list)
            洗衣粉_全通路_普及率_總裝置數 = 普及率_總裝置數_該品類總裝置數 
            # 全通路_普及率
            全通路_普及率 = 洗衣粉_市調結果購買率 * (洗衣粉_全通路_普及率_總裝置數 / ALL_洗衣粉_ALL_全通路_普及率_總裝置數)



            # 洗衣粉_單一通路_普及率_總裝置數 = 
            # 單一通路_普及率_除以33915 = 洗衣粉_市調結果購買率 * (洗衣粉_單一通路_普及率_總裝置數 / 洗衣粉_全通路_普及率_總裝置數)

            # 全通路_銷售額(百萬元)
            全通路_銷售額 = 全台家戶數 * 洗衣粉_市調結果購買率 * ALL_全通路_平均購買次數 * ALL_全通路_每次購買金額 / 1000000 * (洗衣粉_全通路_總銷額 / 洗衣粉_全通路_總銷額) * 全通路_銷額市佔率  
            # 全通路_銷售量(千公升)
            全通路_銷售量 = 全台家戶數 * 洗衣粉_市調結果購買率 * ALL_全通路_平均購買次數 * ALL_全通路_每次購買量 / 1000 * (洗衣粉_全通路_總容量 / 洗衣粉_全通路_總容量) * 全通路_銷量市佔率

            # 銷售額(百萬元)
            指標總表_1_2_3_4_5_6_7_8_9_10_11["銷售額(百萬元)"] = 全台家戶數 * 洗衣粉_市調結果購買率 * ALL_全通路_平均購買次數 * ALL_全通路_每次購買金額 / 1000000 * 全通路_銷額佔比 * 指標總表_1_2_3_4_5_6_7_8_9_10_11["銷額市佔率"]   
            # 銷售量(千公升)
            指標總表_1_2_3_4_5_6_7_8_9_10_11["銷售量(千公升)"] = 全台家戶數 * 洗衣粉_市調結果購買率 * ALL_全通路_平均購買次數 * ALL_全通路_每次購買量 / 1000 * 全通路_銷量佔比 * 指標總表_1_2_3_4_5_6_7_8_9_10_11["銷量市佔率"]   

            # # =================================== 8-12.MAT_洗衣粉_加入Grand_Total ===================================

            # 在加入Grand_Total之前 : sort_values
            指標總表_1_2_3_4_5_6_7_8_9_10_11 = 指標總表_1_2_3_4_5_6_7_8_9_10_11.sort_values(by=['銷額市佔率'], ascending=[False])
            指標總表_1_2_3_4_5_6_7_8_9_10_11 = 指標總表_1_2_3_4_5_6_7_8_9_10_11.reset_index(drop=True) 

            # 挑選適當欄位 : 只留11個指標當作column
            指標總表_1_2_3_4_5_6_7_8_9_10_11 = 指標總表_1_2_3_4_5_6_7_8_9_10_11[[str(訴求_column), "自定義品牌", "系列(一匙靈專用)", "銷額市佔率", "銷量市佔率", "每公升均價(元)", "普及率", "銷售額(百萬元)", "銷售量(千公升)"]]


            # adding a row : SubTotal
            指標總表_1_2_3_4_5_6_7_8_9_10_11.loc[-1] = [str(str(訴求_value)), "-", "SubTotal", 全通路_銷額市佔率, 全通路_銷量市佔率, 全通路_每公升均價, 全通路_普及率, 全通路_銷售額, 全通路_銷售量]  # adding a row 
            #             指標總表_1_2_3_4_5_6_7_8_9_10_11.loc[-1] = [str(訴求_column), "-", "SubTotal", 全通路_銷額市佔率, 全通路_銷量市佔率, 全通路_每公升均價, 全通路_每次購買金額, 全通路_每次購買量, 全通路_平均購買次數, 全通路_每人平均花費, 全通路_每人平均購買量, 全通路_普及率, 全通路_銷售額, 全通路_銷售量]  # adding a row 

            指標總表_1_2_3_4_5_6_7_8_9_10_11.index = 指標總表_1_2_3_4_5_6_7_8_9_10_11.index + 1  # shifting index
            指標總表_1_2_3_4_5_6_7_8_9_10_11.sort_index(inplace=True) 







            # -----------------------------------------------------------------------------------------------
            # 排序用的 df 要跟隨 最新的 df 喔!!!
            指標總表_1_2_3_4_5_6_7_8_9_10_11 = 品牌x系列_表頭排序(指標總表_1_2_3_4_5_6_7_8_9_10_11, 訴求_column, 訴求_value)
            # -----------------------------------------------------------------------------------------------

            return 指標總表_1_2_3_4_5_6_7_8_9_10_11


        except :

            指標總表_1_2_3_4_5_6_7_8_9_10_11 = pd.DataFrame()

            return 指標總表_1_2_3_4_5_6_7_8_9_10_11

        
        
        

    訴求正面敘述 = MAT_全通路_個別_訴求(訴求_column, 訴求_column, 時間點_1, 時間點_2, 品類_list, 全台家戶數, 洗衣粉_市調結果購買率)

    
#     訴求_value = "非"+str(訴求_column) # 新增的作法
    訴求反面敘述 = MAT_全通路_個別_訴求(訴求_column, "非"+str(訴求_column), 時間點_1, 時間點_2, 品類_list, 全台家戶數, 洗衣粉_市調結果購買率)
#     訴求反面敘述


    
    

    df_all = pd.concat([訴求正面敘述, 訴求反面敘述], axis = 0).reset_index(drop = True)
    # 把排序用的欄位drop掉
    df_all = df_all.drop(["訴求_表頭順序", "系列_表頭順序", "品牌_表頭順序", "總排序"], axis = 1)
    
    # adding a row : Grand Total
    df_all.loc[-1] = ["-", "-", "Grand Total", ALL_全通路_銷額市佔率, ALL_全通路_銷量市佔率, ALL_全通路_每公升均價, ALL_全通路_普及率, ALL_全通路_銷售額, ALL_全通路_銷售量]  # adding a row 
    df_all.index = df_all.index + 1  # shifting index
    df_all.sort_index(inplace=True)

    
    
    
    MAT_表頭 = df_all[[str(訴求_column), "自定義品牌", "系列(一匙靈專用)"]].reset_index(drop = True)

#     # 去掉整個row都沒有值的品牌系列
    df_all = df_all.replace("-", np.nan)
    df_all = df_all.dropna(how = "all")
    df_all = df_all.fillna("-")
    
#     df_all = df_all.set_index([str(訴求_column), "自定義品牌", "系列(一匙靈專用)"])
    
    return df_all#, MAT_表頭


    

# test_abc_info = 總_訴求()

# test_abc = test_abc_info[0]

# test_abcd = test_abc_info[1]
# test_abcde = test_abc_info[2]

# print(test_abcd)
# print(test_abcde)





# MAT_訴求全通路_info = MAT_全通路_總_訴求(時間點_1, 時間點_2, 品類_list, 全台家戶數, 洗衣粉_市調結果購買率)

# MAT_訴求全通路 = MAT_訴求全通路_info[0]

# MAT_表頭 = MAT_訴求全通路_info[1]


# MAT_訴求全通路

# %%
# 訴求表

MAT_訴求_天然全通路 = MAT_全通路_總_訴求("天然", 時間點_1, 時間點_2, 品類_list, 全台家戶數, 洗衣粉_市調結果購買率)
MAT_訴求_天然全通路_包含系列 = MAT_訴求_天然全通路
MAT_訴求_天然全通路 = MAT_訴求_天然全通路.loc[MAT_訴求_天然全通路["系列(一匙靈專用)"].str.contains("Total|Grand Total")].reset_index(drop = True)
print("目前進度 : " + "{:.2%}".format( 1 / 20 ) )


MAT_訴求_香氛全通路 = MAT_全通路_總_訴求("香氛", 時間點_1, 時間點_2, 品類_list, 全台家戶數, 洗衣粉_市調結果購買率)
MAT_訴求_香氛全通路_包含系列 = MAT_訴求_香氛全通路
MAT_訴求_香氛全通路 = MAT_訴求_香氛全通路.loc[MAT_訴求_香氛全通路["系列(一匙靈專用)"].str.contains("Total|Grand Total")].reset_index(drop = True)
print("目前進度 : " + "{:.2%}".format( 2 / 20 ) )


MAT_訴求_強效全通路 = MAT_全通路_總_訴求("強效", 時間點_1, 時間點_2, 品類_list, 全台家戶數, 洗衣粉_市調結果購買率)
MAT_訴求_強效全通路_包含系列 = MAT_訴求_強效全通路
MAT_訴求_強效全通路 = MAT_訴求_強效全通路.loc[MAT_訴求_強效全通路["系列(一匙靈專用)"].str.contains("Total|Grand Total")].reset_index(drop = True)
print("目前進度 : " + "{:.2%}".format( 3 / 20 ) )


MAT_訴求_抗菌全通路 = MAT_全通路_總_訴求("抗菌", 時間點_1, 時間點_2, 品類_list, 全台家戶數, 洗衣粉_市調結果購買率)
MAT_訴求_抗菌全通路_包含系列 = MAT_訴求_抗菌全通路
MAT_訴求_抗菌全通路 = MAT_訴求_抗菌全通路.loc[MAT_訴求_抗菌全通路["系列(一匙靈專用)"].str.contains("Total|Grand Total")].reset_index(drop = True)
print("目前進度 : " + "{:.2%}".format( 4 / 20 ) )


MAT_訴求_防蟎全通路 = MAT_全通路_總_訴求("防蟎", 時間點_1, 時間點_2, 品類_list, 全台家戶數, 洗衣粉_市調結果購買率)
MAT_訴求_防蟎全通路_包含系列 = MAT_訴求_防蟎全通路
MAT_訴求_防蟎全通路 = MAT_訴求_防蟎全通路.loc[MAT_訴求_防蟎全通路["系列(一匙靈專用)"].str.contains("Total|Grand Total")].reset_index(drop = True)
print("目前進度 : " + "{:.2%}".format( 5 / 20 ) )


MAT_訴求_防霉全通路 = MAT_全通路_總_訴求("防霉", 時間點_1, 時間點_2, 品類_list, 全台家戶數, 洗衣粉_市調結果購買率)
MAT_訴求_防霉全通路_包含系列 = MAT_訴求_防霉全通路
MAT_訴求_防霉全通路 = MAT_訴求_防霉全通路.loc[MAT_訴求_防霉全通路["系列(一匙靈專用)"].str.contains("Total|Grand Total")].reset_index(drop = True)
print("目前進度 : " + "{:.2%}".format( 6 / 20 ) )


MAT_訴求_潔白全通路 = MAT_全通路_總_訴求("潔白", 時間點_1, 時間點_2, 品類_list, 全台家戶數, 洗衣粉_市調結果購買率)
MAT_訴求_潔白全通路_包含系列 = MAT_訴求_潔白全通路
MAT_訴求_潔白全通路 = MAT_訴求_潔白全通路.loc[MAT_訴求_潔白全通路["系列(一匙靈專用)"].str.contains("Total|Grand Total")].reset_index(drop = True)
print("目前進度 : " + "{:.2%}".format( 7 / 20 ) )


MAT_訴求_柔軟全通路 = MAT_全通路_總_訴求("柔軟", 時間點_1, 時間點_2, 品類_list, 全台家戶數, 洗衣粉_市調結果購買率)
MAT_訴求_柔軟全通路_包含系列 = MAT_訴求_柔軟全通路
MAT_訴求_柔軟全通路 = MAT_訴求_柔軟全通路.loc[MAT_訴求_柔軟全通路["系列(一匙靈專用)"].str.contains("Total|Grand Total")].reset_index(drop = True)
print("目前進度 : " + "{:.2%}".format( 8 / 20 ) )


MAT_訴求_亮彩_護色全通路 = MAT_全通路_總_訴求("亮彩_護色", 時間點_1, 時間點_2, 品類_list, 全台家戶數, 洗衣粉_市調結果購買率)
MAT_訴求_亮彩_護色全通路_包含系列 = MAT_訴求_亮彩_護色全通路
MAT_訴求_亮彩_護色全通路 = MAT_訴求_亮彩_護色全通路.loc[MAT_訴求_亮彩_護色全通路["系列(一匙靈專用)"].str.contains("Total|Grand Total")].reset_index(drop = True)
print("目前進度 : " + "{:.2%}".format( 9 / 20 ) )


MAT_訴求_不傷衣料全通路 = MAT_全通路_總_訴求("不傷衣料", 時間點_1, 時間點_2, 品類_list, 全台家戶數, 洗衣粉_市調結果購買率)
MAT_訴求_不傷衣料全通路_包含系列 = MAT_訴求_不傷衣料全通路
MAT_訴求_不傷衣料全通路 = MAT_訴求_不傷衣料全通路.loc[MAT_訴求_不傷衣料全通路["系列(一匙靈專用)"].str.contains("Total|Grand Total")].reset_index(drop = True)
print("目前進度 : " + "{:.2%}".format( 10 / 20 ) )


MAT_訴求_嬰兒全通路 = MAT_全通路_總_訴求("嬰兒", 時間點_1, 時間點_2, 品類_list, 全台家戶數, 洗衣粉_市調結果購買率)
MAT_訴求_嬰兒全通路_包含系列 = MAT_訴求_嬰兒全通路
MAT_訴求_嬰兒全通路 = MAT_訴求_嬰兒全通路.loc[MAT_訴求_嬰兒全通路["系列(一匙靈專用)"].str.contains("Total|Grand Total")].reset_index(drop = True)
print("目前進度 : " + "{:.2%}".format( 11 / 20 ) )


MAT_訴求_去味全通路 = MAT_全通路_總_訴求("去味", 時間點_1, 時間點_2, 品類_list, 全台家戶數, 洗衣粉_市調結果購買率)
MAT_訴求_去味全通路_包含系列 = MAT_訴求_去味全通路
MAT_訴求_去味全通路 = MAT_訴求_去味全通路.loc[MAT_訴求_去味全通路["系列(一匙靈專用)"].str.contains("Total|Grand Total")].reset_index(drop = True)
print("目前進度 : " + "{:.2%}".format( 12 / 20 ) )


MAT_訴求_柔膚全通路 = MAT_全通路_總_訴求("柔膚", 時間點_1, 時間點_2, 品類_list, 全台家戶數, 洗衣粉_市調結果購買率)
MAT_訴求_柔膚全通路_包含系列 = MAT_訴求_柔膚全通路
MAT_訴求_柔膚全通路 = MAT_訴求_柔膚全通路.loc[MAT_訴求_柔膚全通路["系列(一匙靈專用)"].str.contains("Total|Grand Total")].reset_index(drop = True)
print("目前進度 : " + "{:.2%}".format( 13 / 20 ) )


MAT_訴求_低敏全通路 = MAT_全通路_總_訴求("低敏", 時間點_1, 時間點_2, 品類_list, 全台家戶數, 洗衣粉_市調結果購買率)
MAT_訴求_低敏全通路_包含系列 = MAT_訴求_低敏全通路
MAT_訴求_低敏全通路 = MAT_訴求_低敏全通路.loc[MAT_訴求_低敏全通路["系列(一匙靈專用)"].str.contains("Total|Grand Total")].reset_index(drop = True)
print("目前進度 : " + "{:.2%}".format( 14 / 20 ) )


MAT_訴求_無味全通路 = MAT_全通路_總_訴求("無味", 時間點_1, 時間點_2, 品類_list, 全台家戶數, 洗衣粉_市調結果購買率)
MAT_訴求_無味全通路_包含系列 = MAT_訴求_無味全通路
MAT_訴求_無味全通路 = MAT_訴求_無味全通路.loc[MAT_訴求_無味全通路["系列(一匙靈專用)"].str.contains("Total|Grand Total")].reset_index(drop = True)
print("目前進度 : " + "{:.2%}".format( 15 / 20 ) )


MAT_訴求_超濃縮全通路 = MAT_全通路_總_訴求("超濃縮", 時間點_1, 時間點_2, 品類_list, 全台家戶數, 洗衣粉_市調結果購買率)
MAT_訴求_超濃縮全通路_包含系列 = MAT_訴求_超濃縮全通路
MAT_訴求_超濃縮全通路 = MAT_訴求_超濃縮全通路.loc[MAT_訴求_超濃縮全通路["系列(一匙靈專用)"].str.contains("Total|Grand Total")].reset_index(drop = True)
print("目前進度 : " + "{:.2%}".format( 16 / 20 ) )


MAT_訴求_環保全通路 = MAT_全通路_總_訴求("環保", 時間點_1, 時間點_2, 品類_list, 全台家戶數, 洗衣粉_市調結果購買率)
MAT_訴求_環保全通路_包含系列 = MAT_訴求_環保全通路
MAT_訴求_環保全通路 = MAT_訴求_環保全通路.loc[MAT_訴求_環保全通路["系列(一匙靈專用)"].str.contains("Total|Grand Total")].reset_index(drop = True)
print("目前進度 : " + "{:.2%}".format( 17 / 20 ) )


MAT_訴求_酵素全通路 = MAT_全通路_總_訴求("酵素", 時間點_1, 時間點_2, 品類_list, 全台家戶數, 洗衣粉_市調結果購買率)
MAT_訴求_酵素全通路_包含系列 = MAT_訴求_酵素全通路
MAT_訴求_酵素全通路 = MAT_訴求_酵素全通路.loc[MAT_訴求_酵素全通路["系列(一匙靈專用)"].str.contains("Total|Grand Total")].reset_index(drop = True)
print("目前進度 : " + "{:.2%}".format( 18 / 20 ) )


MAT_訴求_運動全通路 = MAT_全通路_總_訴求("運動", 時間點_1, 時間點_2, 品類_list, 全台家戶數, 洗衣粉_市調結果購買率)
MAT_訴求_運動全通路_包含系列 = MAT_訴求_運動全通路
MAT_訴求_運動全通路 = MAT_訴求_運動全通路.loc[MAT_訴求_運動全通路["系列(一匙靈專用)"].str.contains("Total|Grand Total")].reset_index(drop = True)
print("目前進度 : " + "{:.2%}".format( 19 / 20 ) )



# ================================================================
# 總表

# 亮彩護色有斜線 / ， 要處理

# ================================================================

# MAT_訴求_天然全通路_info = MAT_全通路_總_訴求("天然", 時間點_1, 時間點_2, 品類_list, 全台家戶數, 洗衣粉_市調結果購買率)
# MAT_訴求_天然全通路 = MAT_訴求_天然全通路_info[0]
# MAT_訴求_天然全通路 = MAT_訴求_天然全通路.loc[MAT_訴求_天然全通路["系列(一匙靈專用)"].str.contains("Total|Grand Total")].reset_index(drop = True)

# MAT_訴求_天然全通路_正面訴求Total = MAT_訴求_天然全通路.loc[(MAT_訴求_天然全通路["系列(一匙靈專用)"].str.contains("SubTotal")), :].reset_index(drop = True)
# MAT_訴求_天然全通路_正面訴求Total

# ================================================================

訴求們 = ["天然", "香氛", "強效", "抗菌", "防蟎", "防霉", "潔白", "柔軟", "亮彩_護色", "不傷衣料", "嬰兒", "去味", "柔膚", "低敏", "無味", "超濃縮", "環保", "酵素", "運動"]

# 訴求們 = ["天然", "香氛", "強效", "抗菌", "防蟎", "防霉", "潔白", "柔軟", "不傷衣料", "嬰兒", "去味", "柔膚", "低敏", "無味", "超濃縮", "環保", "酵素", "運動"]

MAT_all訴求_全通路_正面訴求Total = pd.DataFrame()
for i in range(0, len(訴求們)) :
# df.columns = df.columns.str.replace('$','')
   
    exec(f'MAT_訴求_{訴求們[i]}全通路_正面訴求Total = MAT_訴求_{訴求們[i]}全通路.loc[(MAT_訴求_{訴求們[i]}全通路["系列(一匙靈專用)"].str.contains("SubTotal")), :].reset_index(drop = True)')
    exec(f'MAT_訴求_{訴求們[i]}全通路_正面訴求Total.columns = MAT_訴求_{訴求們[i]}全通路_正面訴求Total.columns.str.replace("{訴求們[i]}", "訴求")')

#     exec(f'MAT_all訴求_全通路_正面訴求Total = pd.concat([MAT_訴求_{訴求們[i]}全通路_正面訴求Total, MAT_訴求_{訴求們[i+1]}全通路_正面訴求Total], axis = 0)')
    exec(f'MAT_all訴求_全通路_正面訴求Total = MAT_all訴求_全通路_正面訴求Total.append(MAT_訴求_{訴求們[i]}全通路_正面訴求Total)')

    #---------------------------------------------
    # MAT表頭 - for 天然YTD，sheet_by_通路 用的
    exec(f'MAT_訴求_{訴求們[i]}全通路_for_sheet_by通路_表頭 = MAT_訴求_{訴求們[i]}全通路_包含系列[["{訴求們[i]}", "自定義品牌", "系列(一匙靈專用)"]]')
#     exec(f'MAT_訴求_{訴求們[i]}全通路_表頭 = MAT_訴求_{訴求們[i]}全通路[["{訴求們[i]}", "自定義品牌"]]')
    #---------------------------------------------
    
    # 把單一訴求sheet裡不必要的欄位drop掉
    exec(f'MAT_訴求_{訴求們[i]}全通路 = MAT_訴求_{訴求們[i]}全通路.drop(["系列(一匙靈專用)"], axis=1)')
    
    #---------------------------------------------
    # MAT表頭
    exec(f'MAT_訴求_{訴求們[i]}全通路_表頭 = MAT_訴求_{訴求們[i]}全通路[["{訴求們[i]}", "自定義品牌"]]')
    #---------------------------------------------
    
    
MAT_all訴求_全通路_正面訴求Total = MAT_all訴求_全通路_正面訴求Total.drop_duplicates().reset_index(drop = True)
MAT_all訴求_全通路_正面訴求Total = MAT_all訴求_全通路_正面訴求Total.loc[~MAT_all訴求_全通路_正面訴求Total["訴求"].str.contains("非"), :].reset_index(drop = True)


單一訴求x品牌_總表 = MAT_all訴求_全通路_正面訴求Total.drop(["自定義品牌", "系列(一匙靈專用)"], axis=1)
單一訴求x品牌_總表 = 單一訴求x品牌_總表.set_index(["訴求"])
單一訴求x品牌_總表


# 每一個訴求的sheet都set_index
for i in range(0, len(訴求們)) :
    exec(f'MAT_訴求_{訴求們[i]}全通路 = MAT_訴求_{訴求們[i]}全通路.set_index(["{訴求們[i]}", "自定義品牌"])')

print("目前進度 : " + "{:.2%}".format( 20 / 20 ) )

print("Done!")
# Out:
# C:\Users\EOL\Anaconda3\lib\site-packages\ipykernel_launcher.py:69: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
#
# C:\Users\EOL\Anaconda3\lib\site-packages\ipykernel_launcher.py:77: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
#
# C:\Users\EOL\Anaconda3\lib\site-packages\ipykernel_launcher.py:138: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# ...

# %% [markdown]
# ## MAT 匯出表格

# %%
writer = pd.ExcelWriter("%s.xlsx" % (MAT_檔名), engine = "xlsxwriter")
# 全通路
單一訴求x品牌_總表.to_excel(writer, sheet_name = "總表", index = True)
# 單一通路
MAT_訴求_天然全通路.to_excel(writer, sheet_name = "天然", index = True)
MAT_訴求_香氛全通路.to_excel(writer, sheet_name = "香氛", index = True)
MAT_訴求_強效全通路.to_excel(writer, sheet_name = "強效", index = True)
MAT_訴求_抗菌全通路.to_excel(writer, sheet_name = "抗菌", index = True)
MAT_訴求_防蟎全通路.to_excel(writer, sheet_name = "防蟎", index = True)

MAT_訴求_防霉全通路.to_excel(writer, sheet_name = "防霉", index = True)
MAT_訴求_潔白全通路.to_excel(writer, sheet_name = "潔白", index = True)
MAT_訴求_柔軟全通路.to_excel(writer, sheet_name = "柔軟", index = True)
MAT_訴求_亮彩_護色全通路.to_excel(writer, sheet_name = "亮彩_護色", index = True)
MAT_訴求_不傷衣料全通路.to_excel(writer, sheet_name = "不傷衣料", index = True)

MAT_訴求_嬰兒全通路.to_excel(writer, sheet_name = "嬰兒", index = True)
MAT_訴求_去味全通路.to_excel(writer, sheet_name = "去味", index = True)
MAT_訴求_柔膚全通路.to_excel(writer, sheet_name = "柔膚", index = True)
MAT_訴求_低敏全通路.to_excel(writer, sheet_name = "低敏", index = True)
MAT_訴求_無味全通路.to_excel(writer, sheet_name = "無味", index = True)

MAT_訴求_超濃縮全通路.to_excel(writer, sheet_name = "超濃縮", index = True)
MAT_訴求_環保全通路.to_excel(writer, sheet_name = "環保", index = True)
MAT_訴求_酵素全通路.to_excel(writer, sheet_name = "酵素", index = True)
MAT_訴求_運動全通路.to_excel(writer, sheet_name = "運動", index = True)

writer.save()

# %%
# MAT_訴求_天然全通路_表頭

# %%
# MAT_訴求_天然全通路

# %%
# MAT_訴求_防螨全通路

# %%
# MAT_訴求_天然全通路_正面訴求Total.columns = MAT_訴求_天然全通路_正面訴求Total.columns.str.replace("天然", "訴求")
# MAT_訴求_天然全通路_正面訴求Total

# %%
# MAT_訴求_運動全通路_正面訴求Total

# %%
# MAT_訴求_天然全通路_info = MAT_全通路_總_訴求("天然", 時間點_1, 時間點_2, 品類_list, 全台家戶數, 洗衣粉_市調結果購買率)
# MAT_訴求_天然全通路 = MAT_訴求_天然全通路_info[0]
# MAT_訴求_天然全通路.loc[MAT_訴求_天然全通路["系列(一匙靈專用)"].str.contains("Total|Grand Total")].reset_index(drop = True)

# %%
# a = MAT_訴求全通路.loc[MAT_訴求全通路["系列(一匙靈專用)"].str.contains("Total|Grand Total")].reset_index(drop = True)
# (a["銷售額(百萬元)"] / a["每公升均價(元)"]).round(15)

# %%
# df_指標9_普及率_總裝置數 = df_copy_5_全通路.groupby([str(訴求_column), "自定義品牌", "系列(一匙靈專用)"])['xdid'].nunique().to_frame()
# df_指標9_普及率_總裝置數

# %%
# df_指標9_普及率_總裝置數

# %%
# 指標總表_1_2_3_4_5_6_7_8_9_10_11

# %%
# df_指標4_每次購買金額_指標5_每次購買量.loc[df_指標4_每次購買金額_指標5_每次購買量["系列(一匙靈專用)"].str.contains("Total|Grand Total"), :].reset_index(drop = True)

# %%
# list_of_invNum__by_xdid__with_multiple_invNum

# %%
# df_平均購買次數_總發票張數

# %%
# df_平均購買次數

# %%
# df_平均購買次數_total[str(訴求_column)]

# %%
# df_平均購買次數_total

# %%
# df_copy_3.groupby([str(訴求_column), "自定義品牌"])['xdid'].nunique().to_frame()

# %%
# a = 訴求_天然0.drop_duplicates()

# a.loc[a["系列(一匙靈專用)"].str.contains("Total|SubTotal"), :].reset_index(drop = True)

# %% [markdown]
# ------------------------------

# %% [markdown]
# ------------------------------

# %% [markdown]
# ## YTD
# >> YTD_全通路

# %%
# YTD - 2 版
def YTD_全通路_完整sheet(訴求_column, x_1, x_2, y_1, y_2, x_3, y_3, 品類_list, 全台家戶數, 洗衣粉_市調結果購買率) :

    def YTD_全通路_總_訴求(訴求_column, A_1, A_2, 品類_list, 全台家戶數, 洗衣粉_市調結果購買率) :     

        訴求_column = str(訴求_column)

        #------------------------------------------------------------------------------------------------------------------------
        global ALL_洗衣粉_全通路_總銷額
        global ALL_全通路_銷額市佔率

        global ALL_洗衣粉_全通路_總容量
        global ALL_全通路_銷量市佔率

        global ALL_全通路_每公升均價

        global ALL_洗衣粉_ALL_全通路_每次購買金額_不重複總發票張數
        global ALL_全通路_每次購買金額
        global ALL_全通路_每次購買量

        global 洗衣粉_ALL_全通路_平均購買次數_兩張發票之不重複總發票張數
        global 洗衣粉_ALL_全通路_平均購買次數_兩張發票之不重複總裝置數
        global ALL_全通路_平均購買次數

        global ALL_全通路_每人平均花費
        global ALL_全通路_每人平均購買量


        global ALL_洗衣粉_ALL_全通路_普及率_總裝置數

        # =========================================================================================
        # for YTD各時間區間的ALL_全通路變數
        # =========================================================================================


        df = df_整理


        # =================================== 1. 處理與否 = 1 =================================== 
        df = df[df["處理與否"] == 1]
        # =================================== 2. 總容量有值 且 >=1 =================================== 
        df = df[np.isfinite(df['總容量'])]
        df = df[df['總容量'] >= 0]

        # =================================== 3.時間_MAT ===================================    
        df = df[(df['invDate_datetime'] >= str(A_1)) & (df['invDate_datetime'] < str(A_2))]

        # =================================== 4.品類_洗衣粉 ===================================
        df = df[df["品類_list"] == 1]

        # =================================== 5.通路_全通路 =================================== 
        #全通路
        df_全通路 = df 
        # reset_index
        df_全通路 = df.reset_index(drop = True)   




        # =================================== 8-1.指標_MAT_洗衣粉_銷額市佔率 ===================================
        # 算總金額(正確價錢 Grand Total)
        洗衣粉_MAT_全通路總金額_Grand_Total = 0
        list_of_洗衣粉_MAT_全通路總金額_Grand_Total = []
        for i in range(0, len(df_全通路["正確價錢"])) :
            洗衣粉_MAT_全通路總金額_Grand_Total = 洗衣粉_MAT_全通路總金額_Grand_Total + float(df_全通路["正確價錢"][i])






        # =================================== 8-2.指標_MAT_洗衣粉_銷量市佔率 ===================================
        # 算總金額(正確價錢 Grand Total)
        洗衣粉_MAT_全通路總容量_Grand_Total = 0
        list_of_洗衣粉_MAT_全通路總容量_Grand_Total = []
        for i in range(0, len(df_全通路["總容量"])) :
            洗衣粉_MAT_全通路總容量_Grand_Total = 洗衣粉_MAT_全通路總容量_Grand_Total + float(df_全通路["總容量"][i])






    #         # # =================================== 8-4.指標_MAT_洗衣粉_每次購買金額(元) ===================================
    #         # # =================================== 8-5.指標_MAT_洗衣粉_每次購買量(公升) ===================================
    #         df_copy = df_全通路
    #         df_copy = df_copy.reset_index(drop = True)
    #         #----------------------------------------------------------------------------------
    #         df_corss_variable_distinct_invNum = df_copy.loc[:, ["xdid", "invNum", "自定義品牌", "系列(一匙靈專用)"]]
    #         df_corss_variable_distinct_invNum['自定義品牌_系列'] = df_corss_variable_distinct_invNum[['自定義品牌', '系列(一匙靈專用)']].apply(lambda x: ','.join(x), axis=1)
    #         #----------------------------------------------------------------------------------
    #         # 各品牌各系列
    #         df_自定義品牌_系列 = df_corss_variable_distinct_invNum[['自定義品牌_系列']].drop_duplicates().reset_index(drop = True)
    #         df_自定義品牌_系列["不重複的發票編號"] = ""
    #         df_自定義品牌_系列["總發票張數(不重複)"] = ""

    #         for i in range(0, len(df_自定義品牌_系列["自定義品牌_系列"])) :
    #             不重複的發票編號_list = []
    #             for j in range(0, len(df_corss_variable_distinct_invNum["自定義品牌_系列"])) :
    #                 if df_自定義品牌_系列["自定義品牌_系列"][i] == df_corss_variable_distinct_invNum["自定義品牌_系列"][j] :
    #                     不重複的發票編號_list.append(df_corss_variable_distinct_invNum["invNum"][j])
    #                 else :
    #                     None
    #             df_自定義品牌_系列["不重複的發票編號"][i] = list(set(不重複的發票編號_list))
    #             df_自定義品牌_系列["總發票張數(不重複)"][i] = len(list(set(不重複的發票編號_list)))
    #             不重複的發票編號_list = []
    #         #--------------
    #         # 各品牌Total    
    #         df_自定義品牌_系列_Total = df_corss_variable_distinct_invNum[['自定義品牌']].drop_duplicates().reset_index(drop = True)
    #         df_自定義品牌_系列_Total["系列(一匙靈專用)"] = "Total"
    #         df_自定義品牌_系列_Total["不重複的發票編號"] = ""
    #         df_自定義品牌_系列_Total["總發票張數(不重複)"] = ""    

    #         for i in range(0, len(df_自定義品牌_系列_Total["自定義品牌"])) :
    #             不重複的發票編號_list = []
    #             for j in range(0, len(df_corss_variable_distinct_invNum["自定義品牌"])) :
    #                 if df_自定義品牌_系列_Total["自定義品牌"][i] == df_corss_variable_distinct_invNum["自定義品牌"][j] :
    #                     不重複的發票編號_list.append(df_corss_variable_distinct_invNum["invNum"][j])
    #                 else :
    #                     None
    #             df_自定義品牌_系列_Total["不重複的發票編號"][i] = list(set(不重複的發票編號_list))
    #             df_自定義品牌_系列_Total["總發票張數(不重複)"][i] = len(list(set(不重複的發票編號_list)))
    #             不重複的發票編號_list = []
    #         #----------------------------------------------------------------------------------            



    #         # # =================================== 8-6.指標_MAT_洗衣粉_平均購買次數 ===================================
    #         # 這裡有篩選條件需要選到 "品項" : "洗衣粉" !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!

        df_copy_2 = df_整理




    #         # =================================== 挑有買過兩張發票的裝置 xdid ===================================
    #         df_copy_3 = df_copy_2
    #         df_copy_4 = df_copy_2
    #         #---------------------------------------------------------------------------------------------------------

    #         #---------------------------------------------------------------------------------------------------------
    #         # for df_copy_2 : 要找到 總裝置數 的 那些"裝置(xdid)"候選人名單
    #         # =================================== 0. 挑有買過2張以上發票的裝置 =================================== 
    #         # 挑有買過兩張發票的裝置

    #         df_all_of_xdid_with_multiple_invNum_list = df_copy_2


    #         df_all_of_xdid_with_multiple_invNum_list = df_copy_2.loc[:, ["xdid", "invNum"]]
    #         # 將裝置數missing的刪除
    #         df_all_of_xdid_with_multiple_invNum_list = df_all_of_xdid_with_multiple_invNum_list.loc[df_all_of_xdid_with_multiple_invNum_list["xdid"] != "missing" ]
    #         df_all_of_xdid_with_multiple_invNum_list = df_all_of_xdid_with_multiple_invNum_list.drop_duplicates().reset_index(drop = True)

    #         df_all_of_xdid_with_multiple_invNum_list = df_all_of_xdid_with_multiple_invNum_list.groupby(["xdid"])['invNum'].nunique()

    #         df_all_of_xdid_with_multiple_invNum_list = df_all_of_xdid_with_multiple_invNum_list[df_all_of_xdid_with_multiple_invNum_list > 1]
    #         df_all_of_xdid_with_multiple_invNum_list = df_all_of_xdid_with_multiple_invNum_list.to_frame().reset_index()
    #         # #---------------------------------------------------------------------------------------------------------
    #         # < 交叉變項 : 總裝置數 的 那些"裝置(xdid)"候選人名單 >
    #         df_all_of_xdid_with_multiple_invNum_list = list(set(df_all_of_xdid_with_multiple_invNum_list["xdid"]))

    #         #---------------------------------------------------------------------------------------------------------
    #         # for df_copy_3 : 要從原始資料 找到 符合那些裝置候選人名單 & 符合後續條件 的那些row

    #         # < 交叉變項 : 總裝置數 的 那些"裝置(xdid)"候選人名單 ；待會兒要加上 原本1~5的篩選條件 再得到 df，最後才要groupby >
    #         df_copy_3 = df_copy_3[df_copy_3['xdid'].isin(df_all_of_xdid_with_multiple_invNum_list)]
    #         # =================================== 1. 處理與否 = 1 =================================== 
    #         df_copy_3 = df_copy_3[df_copy_3["處理與否"] == 1]
    #         # =================================== 2. 總容量有值 且 >=1 =================================== 
    #         df_copy_3 = df_copy_3[np.isfinite(df_copy_3['總容量'])]
    #         df_copy_3 = df_copy_3[df_copy_3['總容量'] >= 0]
    #         # =================================== 3.時間_MAT ===================================
    #         df_copy_3 = df_copy_3[(df_copy_3['invDate_datetime'] >= str(A_1)) & (df_copy_3['invDate_datetime'] < str(A_2))]
    #         # =================================== 4.品類_洗衣粉 - < 至少有一張發票有買到該品項 > ===================================
    #         df_copy_3 = df_copy_3[df_copy_3["品類_list"] == 1]
    #         # =================================== 5.通路_全通路 =================================== 
    #         df_copy_3 = df_copy_3 #全通路
    #         # # df_copy_3 = df_copy_3[df_copy_3["通路"] == "全聯"] #全聯
    #         # # reset_index
    #         # df_copy_3 = df_copy_3.reset_index(drop = True)   


    #         # Grand Total
    #         平均購買次數_總裝置數_list_of_xdid__with_multiple_invNum = len(list(set(df_copy_3["xdid"])))





    #         #---------------------------------------------------------------------------------------------------------
    #         # for df_copy_4 : 要找到總發票張數 : 1.挑有2張發票的裝置  2.其中有買到該品項的發票皆列入

    #         # 挑有買過兩張發票的裝置

    #         df_all_of_xdid_with_multiple_invNum_list = df_copy_2

    #         df_all_of_xdid_with_multiple_invNum_list = df_copy_2.loc[:, ["xdid", "invNum"]]
    #         # 將裝置數missing的保留
    #         # df_all_of_xdid_with_multiple_invNum_list = df_all_of_xdid_with_multiple_invNum_list.loc[df_all_of_xdid_with_multiple_invNum_list["xdid"] != "missing" ]
    #         df_all_of_xdid_with_multiple_invNum_list = df_all_of_xdid_with_multiple_invNum_list.drop_duplicates().reset_index(drop = True)

    #         df_all_of_xdid_with_multiple_invNum_list = df_all_of_xdid_with_multiple_invNum_list.groupby(["xdid"])['invNum'].nunique()

    #         df_all_of_xdid_with_multiple_invNum_list = df_all_of_xdid_with_multiple_invNum_list[df_all_of_xdid_with_multiple_invNum_list > 1]
    #         df_all_of_xdid_with_multiple_invNum_list = df_all_of_xdid_with_multiple_invNum_list.to_frame().reset_index()


    #         # #---------------------------------------------------------------------------------------------------------
    #         # < 交叉變項 : 總裝置數 的 那些"裝置(xdid)"候選人名單 >
    #         list_of_xdid__with_multiple_invNum = list(set(df_all_of_xdid_with_multiple_invNum_list["xdid"]))

    #         df_copy_4 = df_copy_4[df_copy_4['xdid'].isin(list_of_xdid__with_multiple_invNum)]

    #         # < 交叉變項 : 總裝置數 的 那些"裝置(xdid)"候選人名單 加上 原本1~5的篩選條件所得到的 df，接下來要groupby了 >
    #         # =================================== 1. 處理與否 = 1 =================================== 
    #         df_copy_4 = df_copy_4[df_copy_4["處理與否"] == 1]
    #         # =================================== 2. 總容量有值 且 >=1 =================================== 
    #         df_copy_4 = df_copy_4[np.isfinite(df_copy_4['總容量'])]
    #         df_copy_4 = df_copy_4[df_copy_4['總容量'] >= 0]
    #         # =================================== 3.時間_MAT ===================================    
    #         df_copy_4 = df_copy_4[(df_copy_4['invDate_datetime'] >= str(A_1)) & (df_copy_4['invDate_datetime'] < str(A_2))]
    #         # =================================== 4.品類_洗衣粉 - < 有買到該品項的皆列入 > ===================================
    #         df_copy_4 = df_copy_4[df_copy_4["品類_list"] == 1]

    #         # =================================== 5.通路_全通路 =================================== 
    #         df_copy_4 = df_copy_4 #全通路
    #         # df_copy_4 = df_copy_4[df_copy_4["通路"] == "全聯"] #全聯
    #         # reset_index
    #         df_copy_4 = df_copy_4.reset_index(drop = True)   


    #         # 平均購買次數_總發票張數_(Grand_Total)
    #         list_of_invNum__by_xdid__with_multiple_invNum = len(list(set(df_copy_4["invNum"])))



    #         # # =================================== 8-6.指標_MAT_洗衣粉_平均購買次數 ===================================



        # # =================================== 8-9.指標_MAT_洗衣粉_普及率 ===================================
        # # 總裝置數
        # =================================== 挑有買過兩張發票的裝置 xdid ===================================
        df_copy_5 = df_copy_2
        #---------------------------------------------------------------------------------------------------------

        #---------------------------------------------------------------------------------------------------------
        # for df_copy_5 : 要找到 總裝置數 的 那些"裝置(xdid)"候選人名單
        # =================================== 0. 總裝置數 =================================== 


        # < 交叉變項 : 總裝置數 >
        df_copy_5 = df_copy_5[df_copy_5['xdid'] != "missing"]
        # =================================== 1. 處理與否 = 1 =================================== 
        df_copy_5 = df_copy_5[df_copy_5["處理與否"] == 1]
        # =================================== 2. 總容量有值 且 >=1 =================================== 
        df_copy_5 = df_copy_5[np.isfinite(df_copy_5['總容量'])]
        df_copy_5 = df_copy_5[df_copy_5['總容量'] >= 0]
        # =================================== 3.時間_MAT ===================================
        df_copy_5 = df_copy_5[(df_copy_5['invDate_datetime'] >= str(A_1)) & (df_copy_5['invDate_datetime'] < str(A_2))]
        # =================================== 4.品類_洗衣粉 - < 至少有一張發票有買到該品項 > ===================================
        df_copy_5 = df_copy_5[df_copy_5["品類_list"] == 1]
        # =================================== 5.通路_全通路 =================================== 
        # 全通路
        df_copy_5_全通路 = df_copy_5 
        # 單一通路
        # # df_copy_5_單一通路 = df_copy_5[df_copy_5["通路"] == "全聯"] #全聯
        # # reset_index
        # df_copy_5 = df_copy_5.reset_index(drop = True)   




        洗衣粉_市調結果購買率 = float(洗衣粉_市調結果購買率)
        # < 交叉變項 : 總裝置數 >
        all_distinct_xdid_of_one_item_list = list(set(df_copy_5_全通路["xdid"]))
        ALL_普及率_總裝置數_該品類總裝置數 = len(all_distinct_xdid_of_one_item_list)





    #         # # =================================== 8-10.指標_MAT_洗衣粉_銷售額(百萬元) ===================================
    #         # # =================================== 8-11.指標_MAT_洗衣粉_銷售量(千公升) ===================================
    #         # - 6.平均購買次數 - 兩張發票之不重複總發票張數
    #         洗衣粉_ALL_全通路_平均購買次數_兩張發票之不重複總發票張數 = list_of_invNum__by_xdid__with_multiple_invNum
    #         # - 6.平均購買次數 - 兩張發票之不重複總裝置數
    #         洗衣粉_ALL_全通路_平均購買次數_兩張發票之不重複總裝置數 = 平均購買次數_總裝置數_list_of_xdid__with_multiple_invNum
    #         # ALL_全通路_平均購買次數
    #         ALL_全通路_平均購買次數 = 洗衣粉_ALL_全通路_平均購買次數_兩張發票之不重複總發票張數 / 洗衣粉_ALL_全通路_平均購買次數_兩張發票之不重複總裝置數
    #         ALL_全通路_平均購買次數

        # - 4.每次購買金額 - 總金額
        ALL_洗衣粉_全通路_總銷額 = 洗衣粉_MAT_全通路總金額_Grand_Total
    #         # - 4.每次購買金額 - 不重複總發票張數
    #         ALL_洗衣粉_ALL_全通路_每次購買金額_不重複總發票張數 = []
    #         for i in range(0, len(df_corss_variable_distinct_invNum["invNum"])) :
    #             ALL_洗衣粉_ALL_全通路_每次購買金額_不重複總發票張數.append(df_corss_variable_distinct_invNum["invNum"][i])
    #         ALL_洗衣粉_ALL_全通路_每次購買金額_不重複總發票張數 = list(set(ALL_洗衣粉_ALL_全通路_每次購買金額_不重複總發票張數))

    #         ALL_洗衣粉_ALL_全通路_每次購買金額_不重複總發票張數 = len(ALL_洗衣粉_ALL_全通路_每次購買金額_不重複總發票張數) # 49344
    #         # ALL_全通路_每次購買金額
    #         ALL_全通路_每次購買金額 = ALL_洗衣粉_全通路_總銷額 / ALL_洗衣粉_ALL_全通路_每次購買金額_不重複總發票張數


        # - 5.每次購買量 - 總容量
        ALL_洗衣粉_全通路_總容量 = 洗衣粉_MAT_全通路總容量_Grand_Total
    #         # ALL_全通路_每次購買量
    #         ALL_全通路_每次購買量 = ALL_洗衣粉_全通路_總容量 / ALL_洗衣粉_ALL_全通路_每次購買金額_不重複總發票張數 #/ 1000




        # 該通路銷額佔比
        # ALL_全通路_銷額佔比
        ALL_全通路_銷額佔比 = ALL_洗衣粉_全通路_總銷額 / ALL_洗衣粉_全通路_總銷額
        # 單一通路_銷額佔比
        # 單一通路_銷額佔比 =                  / ALL_洗衣粉_全通路_總銷額
















        全台家戶數 = float(全台家戶數)
        洗衣粉_市調結果購買率 = float(洗衣粉_市調結果購買率)

        # ALL_全通路_銷額市佔率
        ALL_全通路_銷額市佔率 = ALL_洗衣粉_全通路_總銷額 / ALL_洗衣粉_全通路_總銷額
        # ALL_全通路_銷量市佔率
        ALL_全通路_銷量市佔率 = ALL_洗衣粉_全通路_總容量 / ALL_洗衣粉_全通路_總容量
        # ALL_全通路_每公升均價(元)
        ALL_全通路_每公升均價 = ALL_洗衣粉_全通路_總銷額 / ALL_洗衣粉_全通路_總容量 * 1000
    #         # ALL_全通路_每次購買金額(元)
    #         ALL_全通路_每次購買金額 = ALL_洗衣粉_全通路_總銷額 / ALL_洗衣粉_ALL_全通路_每次購買金額_不重複總發票張數
    #         # ALL_全通路_每次購買量(公升)
    #         ALL_全通路_每次購買量 = ALL_洗衣粉_全通路_總容量 / ALL_洗衣粉_ALL_全通路_每次購買金額_不重複總發票張數 / 1000
    #         # ALL_全通路_平均購買次數
    #         ALL_全通路_平均購買次數 = 洗衣粉_ALL_全通路_平均購買次數_兩張發票之不重複總發票張數 / 洗衣粉_ALL_全通路_平均購買次數_兩張發票之不重複總裝置數
    #         # ALL_全通路_每人平均花費
    #         ALL_全通路_每人平均花費 = ALL_全通路_每次購買金額 * ALL_全通路_平均購買次數
    #         # ALL_全通路_每人平均購買量
    #         ALL_全通路_每人平均購買量 = ALL_全通路_每次購買量 * ALL_全通路_平均購買次數


        ALL_洗衣粉_ALL_全通路_普及率_總裝置數 = ALL_普及率_總裝置數_該品類總裝置數 
        # ALL_全通路_普及率
        ALL_全通路_普及率 = (ALL_洗衣粉_ALL_全通路_普及率_總裝置數 / ALL_洗衣粉_ALL_全通路_普及率_總裝置數)



        def YTD_全通路_個別_訴求(訴求_column, 訴求_value, A_1, A_2, 品類_list, 全台家戶數, 洗衣粉_市調結果購買率) :    

    #         訴求_value = 訴求_value

            try :

    #             global 全台家戶數
    #             global 洗衣粉_市調結果購買率

                global ALL_洗衣粉_全通路_總銷額
                global ALL_全通路_銷額市佔率

                global ALL_洗衣粉_全通路_總容量
                global ALL_全通路_銷量市佔率

                global ALL_全通路_每公升均價

                global ALL_洗衣粉_ALL_全通路_每次購買金額_不重複總發票張數
                global ALL_全通路_每次購買金額
                global ALL_全通路_每次購買量

                global 洗衣粉_ALL_全通路_平均購買次數_兩張發票之不重複總發票張數
                global 洗衣粉_ALL_全通路_平均購買次數_兩張發票之不重複總裝置數
                global ALL_全通路_平均購買次數

                global ALL_全通路_每人平均花費
                global ALL_全通路_每人平均購買量

                global ALL_洗衣粉_ALL_全通路_普及率_總裝置數


                df_某訴求_全通路 = df_全通路.loc[df_全通路[str(訴求_column)] == str(訴求_value), :].reset_index(drop = True)

                # =================================== 8-1.指標_YTD_洗衣粉_銷額市佔率 ===================================

                list_of_ALL_洗衣粉_全通路_總銷額 = []
                for i in range(0, len(df_某訴求_全通路["正確價錢"])) :
                    list_of_ALL_洗衣粉_全通路_總銷額.append(ALL_洗衣粉_全通路_總銷額)

                df_某訴求_全通路["總銷額"] = list_of_ALL_洗衣粉_全通路_總銷額

                df_某訴求_全通路["各系列銷額市佔率"] = df_某訴求_全通路["正確價錢"] / df_某訴求_全通路["總銷額"]



                # 各品牌x各系列_之_各系列正確價錢
                df_1 = df_某訴求_全通路.groupby(['自定義品牌', "系列(一匙靈專用)"])["正確價錢"].sum().reset_index(name = '品項_品牌_系列_正確價錢')
                # 各品牌Total銷額市佔率
                df_2 = df_某訴求_全通路.groupby(['自定義品牌'])["正確價錢"].sum().reset_index(name = '品項_品牌_系列_正確價錢')
                # concat
                df_指標1_銷額市佔率_正確價錢 = pd.concat([df_1, df_2], axis = 0).reset_index(drop = True)
                df_指標1_銷額市佔率_正確價錢["系列(一匙靈專用)"] = df_指標1_銷額市佔率_正確價錢["系列(一匙靈專用)"].fillna("Total")

                # 各品牌x各系列_之_各系列銷額市佔率
                df_1 = df_某訴求_全通路.groupby([str(訴求_column), '自定義品牌', "系列(一匙靈專用)"])["各系列銷額市佔率"].sum().reset_index(name = '銷額市佔率')
                # 各品牌Total銷額市佔率
                df_2 = df_某訴求_全通路.groupby([str(訴求_column), '自定義品牌'])["各系列銷額市佔率"].sum().reset_index(name = '銷額市佔率')
                # concat
                df_指標1_銷額市佔率 = pd.concat([df_1, df_2], axis = 0).reset_index(drop = True)
                df_指標1_銷額市佔率["系列(一匙靈專用)"] = df_指標1_銷額市佔率["系列(一匙靈專用)"].fillna("Total")

                # merge
                df_指標1_銷額市佔率 = pd.merge(df_指標1_銷額市佔率, df_指標1_銷額市佔率_正確價錢, on = ['自定義品牌', "系列(一匙靈專用)"], how = "outer")






                # 調整欄位順序
                df_指標1_銷額市佔率 = df_指標1_銷額市佔率.loc[: , [str(訴求_column), "自定義品牌", "系列(一匙靈專用)", "銷額市佔率", "品項_品牌_系列_正確價錢"]]


                #         # # 插入 訴求 SubTotal
                #         洗衣粉_YTD_訴求_全通路總金額_Grand_Total = 0

                #         for i in range(0, len(df_某訴求_全通路["正確價錢"])) :
                #             洗衣粉_YTD_訴求_全通路總金額_Grand_Total = 洗衣粉_YTD_訴求_全通路總金額_Grand_Total + float(df_某訴求_全通路["正確價錢"][i])

                #         df_指標1_銷額市佔率.loc[-1] = [str(訴求_column), '-', 'SubTotal', (洗衣粉_YTD_訴求_全通路總金額_Grand_Total / ALL_洗衣粉_全通路_總銷額), 洗衣粉_YTD_訴求_全通路總金額_Grand_Total]  # adding a row 
                #         df_指標1_銷額市佔率.index = df_指標1_銷額市佔率.index + 1  # shifting index
                #         df_指標1_銷額市佔率.sort_index(inplace=True) 






                # =================================== 8-2.指標_YTD_洗衣粉_銷量市佔率 ===================================



                list_of_ALL_洗衣粉_全通路_總容量 = []
                for i in range(0, len(df_某訴求_全通路["總容量"])) :
                    list_of_ALL_洗衣粉_全通路_總容量.append(ALL_洗衣粉_全通路_總容量)

                df_某訴求_全通路["最後總銷量"] = list_of_ALL_洗衣粉_全通路_總容量

                df_某訴求_全通路["各系列銷量市佔率"] = df_某訴求_全通路["總容量"] / df_某訴求_全通路["最後總銷量"]





                #         list_of_洗衣粉_YTD_全通路總容量_Grand_Total = []
                #         for i in range(0, len(df_某訴求_全通路["總容量"])) :
                #             list_of_洗衣粉_YTD_全通路總容量_Grand_Total.append(洗衣粉_YTD_全通路總容量_Grand_Total)

                #         df_某訴求_全通路["總銷量"] = list_of_洗衣粉_YTD_全通路總容量_Grand_Total

                #         df_某訴求_全通路["各系列銷量市佔率"] = df_某訴求_全通路["總容量"] / df_某訴求_全通路["總銷量"]



                # 各品牌x各系列_之_各系列總容量
                df_1 = df_某訴求_全通路.groupby(['自定義品牌', "系列(一匙靈專用)"])["總容量"].sum().reset_index(name = '品項_品牌_系列_總容量')
                # 各品牌Total銷量市佔率
                df_2 = df_某訴求_全通路.groupby(['自定義品牌'])["總容量"].sum().reset_index(name = '品項_品牌_系列_總容量')
                # concat
                df_指標2_銷量市佔率_總容量 = pd.concat([df_1, df_2], axis = 0).reset_index(drop = True)
                df_指標2_銷量市佔率_總容量["系列(一匙靈專用)"] = df_指標2_銷量市佔率_總容量["系列(一匙靈專用)"].fillna("Total")

                # 各品牌x各系列_之_各系列銷量市佔率
                df_1 = df_某訴求_全通路.groupby([str(訴求_column), '自定義品牌', "系列(一匙靈專用)"])["各系列銷量市佔率"].sum().reset_index(name = '銷量市佔率')
                # 各品牌Total銷量市佔率
                df_2 = df_某訴求_全通路.groupby([str(訴求_column), '自定義品牌'])["各系列銷量市佔率"].sum().reset_index(name = '銷量市佔率')
                # concat
                df_指標2_銷量市佔率 = pd.concat([df_1, df_2], axis = 0).reset_index(drop = True)
                df_指標2_銷量市佔率["系列(一匙靈專用)"] = df_指標2_銷量市佔率["系列(一匙靈專用)"].fillna("Total")

                # merge
                df_指標2_銷量市佔率 = pd.merge(df_指標2_銷量市佔率, df_指標2_銷量市佔率_總容量, on = ['自定義品牌', "系列(一匙靈專用)"], how = "outer")






                # 調整欄位順序
                df_指標2_銷量市佔率 = df_指標2_銷量市佔率.loc[: , [str(訴求_column), "自定義品牌", "系列(一匙靈專用)", "銷量市佔率", "品項_品牌_系列_總容量"]]


                #         # # 插入 訴求 Total
                #         洗衣粉_YTD_訴求_全通路總容量_Grand_Total = 0

                #         for i in range(0, len(df_某訴求_全通路["總容量"])) :
                #             洗衣粉_YTD_訴求_全通路總容量_Grand_Total = 洗衣粉_YTD_訴求_全通路總容量_Grand_Total + float(df_某訴求_全通路["總容量"][i])

                #         df_指標2_銷量市佔率.loc[-1] = [str(訴求_column), '-', 'SubTotal', (洗衣粉_YTD_訴求_全通路總容量_Grand_Total / 洗衣粉_YTD_全通路總容量_Grand_Total), 洗衣粉_YTD_訴求_全通路總容量_Grand_Total]  # adding a row 
                #         df_指標2_銷量市佔率.index = df_指標2_銷量市佔率.index + 1  # shifting index
                #         df_指標2_銷量市佔率.sort_index(inplace=True) 





                # # =================================== 8-3.指標_YTD_洗衣粉_每公升均價(元) ===================================
                dfs = [df_指標1_銷額市佔率, df_指標2_銷量市佔率]
                df_指標3_每公升均價 = reduce(lambda left,right: pd.merge(left, right, how = "outer", on = [str(訴求_column), '自定義品牌', "系列(一匙靈專用)"]), dfs)

                df_指標3_每公升均價["每公升均價(元)"] = df_指標3_每公升均價["品項_品牌_系列_正確價錢"] / df_指標3_每公升均價["品項_品牌_系列_總容量"] * 1000
                df_指標3_每公升均價





                # # # =================================== 8-4.指標_YTD_洗衣粉_每次購買金額(元) ===================================
                # # # =================================== 8-5.指標_YTD_洗衣粉_每次購買量(公升) ===================================
                # df_copy = df_全通路
                # df_copy = df_copy.reset_index(drop = True)

                # df_corss_variable_distinct_invNum = df_copy.loc[:, ["xdid", "invNum", "自定義品牌", "系列(一匙靈專用)"]]



                # df_copy = df_全通路
                # df_copy = df_copy.reset_index(drop = True)


                # df_copy = df_copy.loc[df_copy[str(訴求_column)] == str(訴求_value), :].reset_index(drop = True)


                # #----------------------------------------------------------------------------------
                # df_corss_variable_distinct_invNum = df_copy.loc[:, ["xdid", "invNum", "自定義品牌", "系列(一匙靈專用)", str(訴求_column), "正確價錢", "總容量"]]
                # df_corss_variable_distinct_invNum['自定義品牌_系列_訴求'] = df_corss_variable_distinct_invNum[['自定義品牌', '系列(一匙靈專用)', str(訴求_column)]].apply(lambda x: ','.join(x), axis=1)
                # #----------------------------------------------------------------------------------

                # # 訴求各品牌各系列
                # df_自定義品牌_系列_訴求 = df_corss_variable_distinct_invNum[['自定義品牌_系列_訴求']].drop_duplicates().reset_index(drop = True)
                # df_自定義品牌_系列_訴求["不重複的發票編號"] = ""
                # df_自定義品牌_系列_訴求["總發票張數(不重複)"] = ""

                # for i in range(0, len(df_自定義品牌_系列_訴求["自定義品牌_系列_訴求"])) :
                #     不重複的發票編號_list = []
                #     for j in range(0, len(df_corss_variable_distinct_invNum["自定義品牌_系列_訴求"])) :
                #         if df_自定義品牌_系列_訴求["自定義品牌_系列_訴求"][i] == df_corss_variable_distinct_invNum["自定義品牌_系列_訴求"][j] :
                #             不重複的發票編號_list.append(df_corss_variable_distinct_invNum["invNum"][j])
                #         else :
                #             None
                #     df_自定義品牌_系列_訴求["不重複的發票編號"][i] = list(set(不重複的發票編號_list))
                #     df_自定義品牌_系列_訴求["總發票張數(不重複)"][i] = len(list(set(不重複的發票編號_list)))
                #     不重複的發票編號_list = []
                # #--------------
                # # 各品牌Total    
                # df_自定義品牌_系列_訴求_Total = df_corss_variable_distinct_invNum[['自定義品牌']].drop_duplicates().reset_index(drop = True)
                # df_自定義品牌_系列_訴求_Total["系列(一匙靈專用)"] = "Total"
                # # 訴求
                # df_自定義品牌_系列_訴求_Total[str(訴求_column)] = str(str(訴求_value))
                # #             df_自定義品牌_系列_訴求_Total[str(訴求_column)] = str(訴求_column)

                # df_自定義品牌_系列_訴求_Total["不重複的發票編號"] = ""
                # df_自定義品牌_系列_訴求_Total["總發票張數(不重複)"] = ""    

                # for i in range(0, len(df_自定義品牌_系列_訴求_Total["自定義品牌"])) :
                #     不重複的發票編號_list = []
                #     for j in range(0, len(df_corss_variable_distinct_invNum["自定義品牌"])) :
                #         if df_自定義品牌_系列_訴求_Total["自定義品牌"][i] == df_corss_variable_distinct_invNum["自定義品牌"][j] :
                #             不重複的發票編號_list.append(df_corss_variable_distinct_invNum["invNum"][j])
                #         else :
                #             None
                #     df_自定義品牌_系列_訴求_Total["不重複的發票編號"][i] = list(set(不重複的發票編號_list))
                #     df_自定義品牌_系列_訴求_Total["總發票張數(不重複)"][i] = len(list(set(不重複的發票編號_list)))
                #     不重複的發票編號_list = []
                # #----------------------------------------------------------------------------------            
                # # 彙整
                # df_自定義品牌_系列_訴求["自定義品牌"] = df_自定義品牌_系列_訴求["自定義品牌_系列_訴求"].apply(lambda x: x.split(',')[0])
                # df_自定義品牌_系列_訴求["系列(一匙靈專用)"] = df_自定義品牌_系列_訴求["自定義品牌_系列_訴求"].apply(lambda x: x.split(',')[1])
                # df_自定義品牌_系列_訴求[str(訴求_column)] = df_自定義品牌_系列_訴求["自定義品牌_系列_訴求"].apply(lambda x: x.split(',')[2])

                # df_自定義品牌_系列_訴求_看各系列不重複發票數 = df_自定義品牌_系列_訴求[[str(訴求_column), "自定義品牌", "系列(一匙靈專用)", "總發票張數(不重複)"]]

                # df_自定義品牌_系列_訴求_看各品牌Total不重複發票數 = df_自定義品牌_系列_訴求_Total[[str(訴求_column), "自定義品牌", "系列(一匙靈專用)", "總發票張數(不重複)"]]
                # #----------------------------------------------------------------------------------
                # # 各品牌x各系列
                # df_1 = df_自定義品牌_系列_訴求_看各系列不重複發票數
                # # 各品牌
                # df_2 = df_自定義品牌_系列_訴求_看各品牌Total不重複發票數
                # # 總表
                # df_自定義品牌_系列_訴求_不重複發票數_總表 = pd.concat([df_1, df_2], axis = 0).reset_index(drop = True)
                # #         #----------------------------------------------------------------------------------
                # #         # 插入 訴求 SubTotal
                # #         #----------------------------------------------------------------------------------
                # #         df_corss_variable_distinct_invNum = df_copy.loc[:, ["xdid", "invNum", "自定義品牌", "系列(一匙靈專用)", str(訴求_column), "正確價錢", "總容量"]]

                # #         洗衣粉_全通路_每次購買金額_不重複總發票張數 = []
                # #         for i in range(0, len(df_corss_variable_distinct_invNum["invNum"])) :
                # #             洗衣粉_全通路_每次購買金額_不重複總發票張數.append(df_corss_variable_distinct_invNum["invNum"][i])
                # #         洗衣粉_全通路_每次購買金額_不重複總發票張數 = len(list(set(洗衣粉_全通路_每次購買金額_不重複總發票張數)))

                # #         df_自定義品牌_系列_訴求_不重複發票數_總表.loc[-1] = [str(訴求_column), '-', 'SubTotal', 洗衣粉_全通路_每次購買金額_不重複總發票張數]  # adding a row 
                # #         df_自定義品牌_系列_訴求_不重複發票數_總表.index = df_自定義品牌_系列_訴求_不重複發票數_總表.index + 1  # shifting index
                # #         df_自定義品牌_系列_訴求_不重複發票數_總表.sort_index(inplace=True) 

                # #----------------------------------------------------------------------------------    
                # df_指標4_每次購買金額_指標5_每次購買量 = pd.merge(df_指標3_每公升均價, df_自定義品牌_系列_訴求_不重複發票數_總表, on = [str(訴求_column), '自定義品牌', "系列(一匙靈專用)"], how = "outer")
                # df_指標4_每次購買金額_指標5_每次購買量["每次購買金額(元)"] = df_指標4_每次購買金額_指標5_每次購買量["品項_品牌_系列_正確價錢"] / df_指標4_每次購買金額_指標5_每次購買量["總發票張數(不重複)"]
                # df_指標4_每次購買金額_指標5_每次購買量["每次購買量(公升)"] = df_指標4_每次購買金額_指標5_每次購買量["品項_品牌_系列_總容量"] / df_指標4_每次購買金額_指標5_每次購買量["總發票張數(不重複)"] / 1000
                # #----------------------------------------------------------------------------------






                df_copy_2 = df_整理
#                 df_copy_3 = df_copy_2
#                 df_copy_4 = df_copy_2

                # # # =================================== 8-6.指標_YTD_洗衣粉_平均購買次數 ===================================
                # # 這裡有篩選條件需要選到 "品項" : "洗衣粉" !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!






                # #         df_copy_2 = df_copy_2.loc[df_copy_2[str(訴求_column)] == str(訴求_value), :].reset_index(drop = True)


                # # =================================== 挑有買過兩張發票的裝置 xdid ===================================
                # #---------------------------------------------------------------------------------------------------------

                # #---------------------------------------------------------------------------------------------------------
                # # for df_copy_2 : 要找到 總裝置數 的 那些"裝置(xdid)"候選人名單
                # # =================================== 0. 挑有買過2張以上發票的裝置 =================================== 
                # # 挑有買過兩張發票的裝置

                # df_all_of_xdid_with_multiple_invNum_list = df_copy_2


                # df_all_of_xdid_with_multiple_invNum_list = df_copy_2.loc[:, [str(訴求_column), "xdid", "invNum"]]
                # # 將裝置數missing的刪除
                # df_all_of_xdid_with_multiple_invNum_list = df_all_of_xdid_with_multiple_invNum_list.loc[df_all_of_xdid_with_multiple_invNum_list["xdid"] != "missing" ]
                # df_all_of_xdid_with_multiple_invNum_list = df_all_of_xdid_with_multiple_invNum_list.drop_duplicates().reset_index(drop = True)

                # df_all_of_xdid_with_multiple_invNum_list = df_all_of_xdid_with_multiple_invNum_list.groupby(["xdid"])['invNum'].nunique()

                # df_all_of_xdid_with_multiple_invNum_list = df_all_of_xdid_with_multiple_invNum_list[df_all_of_xdid_with_multiple_invNum_list > 1]
                # df_all_of_xdid_with_multiple_invNum_list = df_all_of_xdid_with_multiple_invNum_list.to_frame().reset_index()
                # # #---------------------------------------------------------------------------------------------------------
                # # < 交叉變項 : 總裝置數 的 那些"裝置(xdid)"候選人名單 >
                # df_all_of_xdid_with_multiple_invNum_list = list(set(df_all_of_xdid_with_multiple_invNum_list["xdid"]))

                # #---------------------------------------------------------------------------------------------------------
                # # for df_copy_3 : 要從原始資料 找到 符合那些裝置候選人名單 & 符合後續條件 的那些row



                # df_copy_3 = df_copy_3.loc[df_copy_3[str(訴求_column)] == str(訴求_value), :].reset_index(drop = True)



                # # < 交叉變項 : 總裝置數 的 那些"裝置(xdid)"候選人名單 ；待會兒要加上 原本1~5的篩選條件 再得到 df，最後才要groupby >
                # df_copy_3 = df_copy_3[df_copy_3['xdid'].isin(df_all_of_xdid_with_multiple_invNum_list)]
                # # =================================== 1. 處理與否 = 1 =================================== 
                # df_copy_3 = df_copy_3[df_copy_3["處理與否"] == 1]
                # # =================================== 2. 總容量有值 且 >=1 =================================== 
                # df_copy_3 = df_copy_3[np.isfinite(df_copy_3['總容量'])]
                # df_copy_3 = df_copy_3[df_copy_3['總容量'] >= 0]
                # # =================================== 3.時間_YTD ===================================
                # df_copy_3 = df_copy_3[(df_copy_3['invDate_datetime'] >= str(A_1)) & (df_copy_3['invDate_datetime'] < str(A_2))]
                # # =================================== 4.品類_洗衣粉 - < 至少有一張發票有買到該品項 > ===================================
                # df_copy_3 = df_copy_3[df_copy_3["品類_list"] == 1]
                # # =================================== 5.通路_全通路 =================================== 
                # df_copy_3 = df_copy_3 #全通路
                # # # df_copy_3 = df_copy_3[df_copy_3["通路"] == "全聯"] #全聯
                # # # reset_index
                # # df_copy_3 = df_copy_3.reset_index(drop = True)   


                # # Grand Total
                # 平均購買次數_總裝置數_list_of_xdid__with_multiple_invNum = len(list(set(df_copy_3["xdid"])))



                # # Count unique values with pandas per groups
                # df_平均購買次數_總裝置數 = df_copy_3.groupby([str(訴求_column), "自定義品牌", "系列(一匙靈專用)"])['xdid'].nunique()










                # #---------------------------------------------------------------------------------------------------------
                # # for df_copy_4 : 要找到總發票張數 : 1.挑有2張發票的裝置  2.其中有買到該品項的發票皆列入

                # # 挑有買過兩張發票的裝置

                # df_all_of_xdid_with_multiple_invNum_list = df_copy_2

                # df_all_of_xdid_with_multiple_invNum_list = df_copy_2.loc[:, [str(訴求_column), "xdid", "invNum"]]
                # # 將裝置數missing的保留
                # # df_all_of_xdid_with_multiple_invNum_list = df_all_of_xdid_with_multiple_invNum_list.loc[df_all_of_xdid_with_multiple_invNum_list["xdid"] != "missing" ]
                # df_all_of_xdid_with_multiple_invNum_list = df_all_of_xdid_with_multiple_invNum_list.drop_duplicates().reset_index(drop = True)

                # df_all_of_xdid_with_multiple_invNum_list = df_all_of_xdid_with_multiple_invNum_list.groupby(["xdid"])['invNum'].nunique()

                # df_all_of_xdid_with_multiple_invNum_list = df_all_of_xdid_with_multiple_invNum_list[df_all_of_xdid_with_multiple_invNum_list > 1]
                # df_all_of_xdid_with_multiple_invNum_list = df_all_of_xdid_with_multiple_invNum_list.to_frame().reset_index()


                # # #---------------------------------------------------------------------------------------------------------
                # # < 交叉變項 : 總裝置數 的 那些"裝置(xdid)"候選人名單 >
                # list_of_xdid__with_multiple_invNum = list(set(df_all_of_xdid_with_multiple_invNum_list["xdid"]))



                # df_copy_4 = df_copy_4[df_copy_4['xdid'].isin(list_of_xdid__with_multiple_invNum)]


                # df_copy_4 = df_copy_4.loc[df_copy_4[str(訴求_column)] == str(訴求_value), :].reset_index(drop = True)        



                # # < 交叉變項 : 總裝置數 的 那些"裝置(xdid)"候選人名單 加上 原本1~5的篩選條件所得到的 df，接下來要groupby了 >
                # # =================================== 1. 處理與否 = 1 =================================== 
                # df_copy_4 = df_copy_4[df_copy_4["處理與否"] == 1]
                # # =================================== 2. 總容量有值 且 >=1 =================================== 
                # df_copy_4 = df_copy_4[np.isfinite(df_copy_4['總容量'])]
                # df_copy_4 = df_copy_4[df_copy_4['總容量'] >= 0]
                # # =================================== 3.時間_YTD ===================================    
                # df_copy_4 = df_copy_4[(df_copy_4['invDate_datetime'] >= str(A_1)) & (df_copy_4['invDate_datetime'] < str(A_2))]
                # # =================================== 4.品類_洗衣粉 - < 有買到該品項的皆列入 > ===================================
                # df_copy_4 = df_copy_4[df_copy_4["品類_list"] == 1]

                # # =================================== 5.通路_全通路 =================================== 
                # df_copy_4 = df_copy_4 #全通路
                # # df_copy_4 = df_copy_4[df_copy_4["通路"] == "全聯"] #全聯
                # # reset_index
                # df_copy_4 = df_copy_4.reset_index(drop = True)   


                # # 平均購買次數_總發票張數_(Grand_Total)
                # list_of_invNum__by_xdid__with_multiple_invNum = len(list(set(df_copy_4["invNum"])))


                # # Count unique values with pandas per groups
                # df_平均購買次數_總發票張數 = df_copy_4.groupby([str(訴求_column), "自定義品牌", "系列(一匙靈專用)"])['invNum'].nunique()

                # # # =================================== 8-6.指標_YTD_洗衣粉_平均購買次數 ===================================
                # df_平均購買次數_總發票張數 = df_平均購買次數_總發票張數.to_frame().reset_index()
                # df_平均購買次數_總裝置數 = df_平均購買次數_總裝置數.to_frame().reset_index()

                # df_平均購買次數 = pd.merge(df_平均購買次數_總發票張數, df_平均購買次數_總裝置數, on = [str(訴求_column), "自定義品牌", "系列(一匙靈專用)"], how = "outer")
                # df_平均購買次數["平均購買次數"] = df_平均購買次數["invNum"] / df_平均購買次數["xdid"]




                # # 各品牌_Total_平均購買次數
                # df_平均購買次數_total = pd.DataFrame()
                # list_平均購買次數_自定義品牌 = list(set(df_平均購買次數['自定義品牌']))
                # 平均購買次數_系列_total = []
                # 平均購買次數_訴求_total = []
                # for i in range(0, len(list_平均購買次數_自定義品牌)) :
                #     平均購買次數_系列_total.append("Total")
                #     平均購買次數_訴求_total.append(str(str(訴求_value)))
                # #                 平均購買次數_訴求_total.append(str(訴求_column))

                # df_平均購買次數_total["自定義品牌"] = list_平均購買次數_自定義品牌
                # df_平均購買次數_total["系列(一匙靈專用)"] = 平均購買次數_系列_total
                # # 訴求
                # #         df_平均購買次數_total[str(訴求_column)] = str(訴求_column) 
                # df_平均購買次數_total[str(訴求_column)] = 平均購買次數_訴求_total

                # df_平均購買次數_total = pd.merge(df_平均購買次數_total, df_copy_3.groupby([str(訴求_column), "自定義品牌"])['xdid'].nunique().to_frame(), on = ["自定義品牌"])
                # df_平均購買次數_total = pd.merge(df_平均購買次數_total, df_copy_4.groupby([str(訴求_column), "自定義品牌"])['invNum'].nunique().to_frame(), on = ["自定義品牌"])
                # df_平均購買次數_total["平均購買次數"] = df_平均購買次數_total["invNum"] / df_平均購買次數_total["xdid"]
                # # concat 品牌_各系列 和 品牌_total
                # df_指標6_平均購買次數 = pd.concat([df_平均購買次數, df_平均購買次數_total], axis = 0)




                # dfs = [df_指標4_每次購買金額_指標5_每次購買量, df_指標6_平均購買次數]
                # 指標總表_1_2_3_4_5_6_7_8 = reduce(lambda left,right: pd.merge(left, right, how = "outer", on = [str(訴求_column), '自定義品牌', "系列(一匙靈專用)"]), dfs)

                # # =============================================================================================================================
                # # 在算 "df_指標 7 _每人平均花費" 之前 :
                # # 手動修改的例外 : 
                # #    如果銷額、銷量有值 
                # # -> 從 6.平均購買次數開始，如果因為分母的"總裝置數"為0而造成後面運算結果為NA， 就要把平均購買次數補成"1"


                # 指標總表_1_2_3_4_5_6_7_8.loc[ (指標總表_1_2_3_4_5_6_7_8["平均購買次數"].isnull() == True)  & ((指標總表_1_2_3_4_5_6_7_8['銷額市佔率'] != None) | (指標總表_1_2_3_4_5_6_7_8['銷量市佔率'] != None)), ["平均購買次數"]] = 1

                # # =============================================================================================================================

                # # df_指標7_每人平均花費
                # 指標總表_1_2_3_4_5_6_7_8["每人平均花費"] = 指標總表_1_2_3_4_5_6_7_8["每次購買金額(元)"] * 指標總表_1_2_3_4_5_6_7_8["平均購買次數"]
                # # df_指標8_每人平均購買量
                # 指標總表_1_2_3_4_5_6_7_8["每人平均購買量"] = 指標總表_1_2_3_4_5_6_7_8["每次購買量(公升)"] * 指標總表_1_2_3_4_5_6_7_8["平均購買次數"]









                # # =================================== 8-9.指標_YTD_洗衣粉_普及率 ===================================
                # # 總裝置數
                # =================================== 挑有買過兩張發票的裝置 xdid ===================================
                df_copy_5 = df_全通路
#                 df_copy_5 = df_copy_2
                #---------------------------------------------------------------------------------------------------------

                #---------------------------------------------------------------------------------------------------------
                # for df_copy_5 : 要找到 總裝置數 的 那些"裝置(xdid)"候選人名單
                # =================================== 0. 總裝置數 =================================== 


                df_copy_5 = df_copy_5.loc[df_copy_5[str(訴求_column)] == str(訴求_value), :].reset_index(drop = True)



                # < 交叉變項 : 總裝置數 >
                df_copy_5 = df_copy_5[df_copy_5['xdid'] != "missing"]
                # =================================== 1. 處理與否 = 1 =================================== 
                df_copy_5 = df_copy_5[df_copy_5["處理與否"] == 1]
                # =================================== 2. 總容量有值 且 >=1 =================================== 
                df_copy_5 = df_copy_5[np.isfinite(df_copy_5['總容量'])]
                df_copy_5 = df_copy_5[df_copy_5['總容量'] >= 0]
                # =================================== 3.時間_YTD ===================================
                df_copy_5 = df_copy_5[(df_copy_5['invDate_datetime'] >= str(A_1)) & (df_copy_5['invDate_datetime'] < str(A_2))]
                # =================================== 4.品類_洗衣粉 - < 至少有一張發票有買到該品項 > ===================================
                df_copy_5 = df_copy_5[df_copy_5["品類_list"] == 1]
                # =================================== 5.通路_全通路 =================================== 
                # 全通路
                df_copy_5_全通路 = df_copy_5 
                # 單一通路
                # # df_copy_5_單一通路 = df_copy_5[df_copy_5["通路"] == "全聯"] #全聯
                # # reset_index
                # df_copy_5 = df_copy_5.reset_index(drop = True)   




                洗衣粉_市調結果購買率 = float(洗衣粉_市調結果購買率)
                # < 交叉變項 : 總裝置數 >
                #         all_distinct_xdid_of_one_item_list = list(set(df_copy_5_全通路["xdid"]))
                #         普及率_總裝置數_該品類總裝置數 = len(all_distinct_xdid_of_one_item_list)
                ALL_洗衣粉_ALL_全通路_普及率_總裝置數 = ALL_洗衣粉_ALL_全通路_普及率_總裝置數

                # Count unique values with pandas per groups
                df_指標9_普及率_總裝置數 = df_copy_5_全通路.groupby([str(訴求_column), "自定義品牌", "系列(一匙靈專用)"])['xdid'].nunique().to_frame()
                df_指標9_普及率_總裝置數['普及率'] = (df_指標9_普及率_總裝置數['xdid'] / ALL_洗衣粉_ALL_全通路_普及率_總裝置數)
                #         df_指標9_普及率_總裝置數['普及率_除以33915'] = 洗衣粉_市調結果購買率 * (df_指標9_普及率_總裝置數['xdid'] / 33915)
                df_指標9_普及率_總裝置數 = df_指標9_普及率_總裝置數.reset_index()


                # 各品牌 Total
                df_普及率_各品牌_Total_總裝置數 = df_copy_5_全通路.groupby([str(訴求_column), "自定義品牌"])['xdid'].nunique().to_frame()

                普及率_各品牌_Total_總裝置數_list = []
                for i in range(0, len(df_普及率_各品牌_Total_總裝置數["xdid"])) :
                    普及率_各品牌_Total_總裝置數_list.append("Total")
                df_普及率_各品牌_Total_總裝置數["系列(一匙靈專用)"] = 普及率_各品牌_Total_總裝置數_list

                df_普及率_各品牌_Total_總裝置數['普及率'] = (df_普及率_各品牌_Total_總裝置數['xdid'] / ALL_洗衣粉_ALL_全通路_普及率_總裝置數)
                #         df_普及率_各品牌_Total_總裝置數['普及率_除以33915'] = 洗衣粉_市調結果購買率 * (df_普及率_各品牌_Total_總裝置數['xdid'] / 33915)
                df_普及率_各品牌_Total_總裝置數 = df_普及率_各品牌_Total_總裝置數.reset_index()


                # concat
                df_指標9_普及率_總裝置數 = pd.concat([df_指標9_普及率_總裝置數, df_普及率_各品牌_Total_總裝置數], axis = 0)
                df_指標9_普及率_總裝置數
                # 總表 - merge
                指標總表_1_2_3_4_5_6_7_8_9_10_11 = pd.merge(df_指標3_每公升均價, df_指標9_普及率_總裝置數, on = [str(訴求_column), '自定義品牌', "系列(一匙靈專用)"], how = "outer")
                # 指標總表_1_2_3_4_5_6_7_8_9_10_11 = pd.merge(指標總表_1_2_3_4_5_6_7_8, df_指標9_普及率_總裝置數, on = [str(訴求_column), '自定義品牌', "系列(一匙靈專用)"], how = "outer")



                # =============================================================================================================================
                # 在算 "df_指標 9 _普及率" 的下一個指標 之前 :
                # 手動修改的例外 : 
                #    如果銷額、銷量有值 
                # -> 從 9.普及率 開始，如果因為空白的"裝置編號"而造成後面運算結果為NA， 就要把 普及率 強制改成"0"


                指標總表_1_2_3_4_5_6_7_8_9_10_11.loc[ (指標總表_1_2_3_4_5_6_7_8_9_10_11["普及率"].isnull() == True)  & ((指標總表_1_2_3_4_5_6_7_8_9_10_11['銷額市佔率'] != None) | (指標總表_1_2_3_4_5_6_7_8_9_10_11['銷量市佔率'] != None)), ["普及率"]] = 0

                # =============================================================================================================================







                洗衣粉_YTD_全通路總金額_Grand_Total = 0
                list_of_洗衣粉_YTD_全通路總金額_Grand_Total = []
                for i in range(0, len(df_某訴求_全通路["正確價錢"])) :
                    洗衣粉_YTD_全通路總金額_Grand_Total = 洗衣粉_YTD_全通路總金額_Grand_Total + float(df_某訴求_全通路["正確價錢"][i])



                洗衣粉_YTD_全通路總容量_Grand_Total = 0
                list_of_洗衣粉_YTD_全通路總容量_Grand_Total = []
                for i in range(0, len(df_某訴求_全通路["總容量"])) :
                    洗衣粉_YTD_全通路總容量_Grand_Total = 洗衣粉_YTD_全通路總容量_Grand_Total + float(df_某訴求_全通路["總容量"][i])




                # # =================================== 8-10.指標_YTD_洗衣粉_銷售額(百萬元) ===================================
                # # =================================== 8-11.指標_YTD_洗衣粉_銷售量(千公升) ===================================
                # # - 6.平均購買次數 - 兩張發票之不重複總發票張數
                # 洗衣粉_全通路_平均購買次數_兩張發票之不重複總發票張數 = list_of_invNum__by_xdid__with_multiple_invNum
                # # - 6.平均購買次數 - 兩張發票之不重複總裝置數
                # 洗衣粉_全通路_平均購買次數_兩張發票之不重複總裝置數 = 平均購買次數_總裝置數_list_of_xdid__with_multiple_invNum
                # # 全通路_平均購買次數
                # 全通路_平均購買次數 = 洗衣粉_全通路_平均購買次數_兩張發票之不重複總發票張數 / 洗衣粉_全通路_平均購買次數_兩張發票之不重複總裝置數
                # 全通路_平均購買次數

                # # - 4.每次購買金額 - 總金額
                洗衣粉_全通路_總銷額 = 洗衣粉_YTD_全通路總金額_Grand_Total
                # # - 4.每次購買金額 - 不重複總發票張數
                # 洗衣粉_全通路_每次購買金額_不重複總發票張數 = []
                # for i in range(0, len(df_corss_variable_distinct_invNum["invNum"])) :
                #     洗衣粉_全通路_每次購買金額_不重複總發票張數.append(df_corss_variable_distinct_invNum["invNum"][i])
                # 洗衣粉_全通路_每次購買金額_不重複總發票張數 = list(set(洗衣粉_全通路_每次購買金額_不重複總發票張數))

                # 洗衣粉_全通路_每次購買金額_不重複總發票張數 = len(洗衣粉_全通路_每次購買金額_不重複總發票張數) # 49344
                # # 全通路_每次購買金額
                # 全通路_每次購買金額 = 洗衣粉_全通路_總銷額 / 洗衣粉_全通路_每次購買金額_不重複總發票張數


                # # - 5.每次購買量 - 總容量
                洗衣粉_全通路_總容量 = 洗衣粉_YTD_全通路總容量_Grand_Total
                # # 全通路_每次購買量
                # 全通路_每次購買量 = 洗衣粉_全通路_總容量 / 洗衣粉_全通路_每次購買金額_不重複總發票張數 #/ 1000




                # 該通路銷額佔比
                # 全通路_銷額佔比
                全通路_銷額佔比 = 洗衣粉_全通路_總銷額 / 洗衣粉_全通路_總銷額
                # 單一通路_銷額佔比
                # 單一通路_銷額佔比 =                  / 洗衣粉_全通路_總銷額


                # 全通路_銷量
                全通路_銷量佔比 = 洗衣粉_全通路_總容量 / 洗衣粉_全通路_總容量













                全台家戶數 = float(全台家戶數)
                洗衣粉_市調結果購買率 = float(洗衣粉_市調結果購買率)

                # 全通路_銷額市佔率
                全通路_銷額市佔率 = 洗衣粉_全通路_總銷額 / ALL_洗衣粉_全通路_總銷額
                # 全通路_銷量市佔率
                全通路_銷量市佔率 = 洗衣粉_全通路_總容量 / ALL_洗衣粉_全通路_總容量
                # 全通路_每公升均價(元)
                全通路_每公升均價 = 洗衣粉_全通路_總銷額 / 洗衣粉_全通路_總容量 * 1000
                # # 全通路_每次購買金額(元)
                # 全通路_每次購買金額 = 洗衣粉_全通路_總銷額 / 洗衣粉_全通路_每次購買金額_不重複總發票張數
                # # 全通路_每次購買量(公升)
                # 全通路_每次購買量 = 洗衣粉_全通路_總容量 / 洗衣粉_全通路_每次購買金額_不重複總發票張數 / 1000
                # # 全通路_平均購買次數
                # 全通路_平均購買次數 = 洗衣粉_全通路_平均購買次數_兩張發票之不重複總發票張數 / 洗衣粉_全通路_平均購買次數_兩張發票之不重複總裝置數
                # # 全通路_每人平均花費
                # 全通路_每人平均花費 = 全通路_每次購買金額 * 全通路_平均購買次數
                # # 全通路_每人平均購買量
                # 全通路_每人平均購買量 = 全通路_每次購買量 * 全通路_平均購買次數


                # < 交叉變項 : 總裝置數 >
                all_distinct_xdid_of_one_item_list = list(set(df_copy_5_全通路["xdid"]))
                普及率_總裝置數_該品類總裝置數 = len(all_distinct_xdid_of_one_item_list)
                洗衣粉_全通路_普及率_總裝置數 = 普及率_總裝置數_該品類總裝置數 
                # 全通路_普及率
                全通路_普及率 = (洗衣粉_全通路_普及率_總裝置數 / ALL_洗衣粉_ALL_全通路_普及率_總裝置數)



                # 洗衣粉_單一通路_普及率_總裝置數 = 
                # 單一通路_普及率_除以33915 = 洗衣粉_市調結果購買率 * (洗衣粉_單一通路_普及率_總裝置數 / 洗衣粉_全通路_普及率_總裝置數)

                # 全通路_銷售額(百萬元)
                全通路_銷售額 = 全台家戶數 * 洗衣粉_市調結果購買率 * ALL_全通路_平均購買次數 * ALL_全通路_每次購買金額 / 1000000 * (洗衣粉_全通路_總銷額 / 洗衣粉_全通路_總銷額) * 全通路_銷額市佔率  
                # 全通路_銷售量(千公升)
                全通路_銷售量 = 全台家戶數 * 洗衣粉_市調結果購買率 * ALL_全通路_平均購買次數 * ALL_全通路_每次購買量 / 1000 * (洗衣粉_全通路_總容量 / 洗衣粉_全通路_總容量) * 全通路_銷量市佔率

                # 銷售額(百萬元)
                指標總表_1_2_3_4_5_6_7_8_9_10_11["銷售額(百萬元)"] = 全台家戶數 * 洗衣粉_市調結果購買率 * ALL_全通路_平均購買次數 * ALL_全通路_每次購買金額 / 1000000 * 全通路_銷額佔比 * 指標總表_1_2_3_4_5_6_7_8_9_10_11["銷額市佔率"]   
                # 銷售量(千公升)
                指標總表_1_2_3_4_5_6_7_8_9_10_11["銷售量(千公升)"] = 全台家戶數 * 洗衣粉_市調結果購買率 * ALL_全通路_平均購買次數 * ALL_全通路_每次購買量 / 1000 * 全通路_銷量佔比 * 指標總表_1_2_3_4_5_6_7_8_9_10_11["銷量市佔率"]   

                # # =================================== 8-12.YTD_洗衣粉_加入Grand_Total ===================================

                # 在加入Grand_Total之前 : sort_values
                指標總表_1_2_3_4_5_6_7_8_9_10_11 = 指標總表_1_2_3_4_5_6_7_8_9_10_11.sort_values(by=['銷額市佔率'], ascending=[False])
                指標總表_1_2_3_4_5_6_7_8_9_10_11 = 指標總表_1_2_3_4_5_6_7_8_9_10_11.reset_index(drop=True) 

                # 挑選適當欄位 : 只留11個指標當作column
                指標總表_1_2_3_4_5_6_7_8_9_10_11 = 指標總表_1_2_3_4_5_6_7_8_9_10_11[[str(訴求_column), "自定義品牌", "系列(一匙靈專用)", "銷額市佔率", "銷量市佔率", "每公升均價(元)", "普及率", "銷售額(百萬元)", "銷售量(千公升)"]]


                # adding a row : SubTotal
                指標總表_1_2_3_4_5_6_7_8_9_10_11.loc[-1] = [str(str(訴求_value)), "-", "SubTotal", 全通路_銷額市佔率, 全通路_銷量市佔率, 全通路_每公升均價, 全通路_普及率, 全通路_銷售額, 全通路_銷售量]  # adding a row 
                #             指標總表_1_2_3_4_5_6_7_8_9_10_11.loc[-1] = [str(訴求_column), "-", "SubTotal", 全通路_銷額市佔率, 全通路_銷量市佔率, 全通路_每公升均價, 全通路_每次購買金額, 全通路_每次購買量, 全通路_平均購買次數, 全通路_每人平均花費, 全通路_每人平均購買量, 全通路_普及率, 全通路_銷售額, 全通路_銷售量]  # adding a row 

                指標總表_1_2_3_4_5_6_7_8_9_10_11.index = 指標總表_1_2_3_4_5_6_7_8_9_10_11.index + 1  # shifting index
                指標總表_1_2_3_4_5_6_7_8_9_10_11.sort_index(inplace=True) 







                # -----------------------------------------------------------------------------------------------
                # 排序用的 df 要跟隨 最新的 df 喔!!!
                指標總表_1_2_3_4_5_6_7_8_9_10_11 = 品牌x系列_表頭排序(指標總表_1_2_3_4_5_6_7_8_9_10_11, 訴求_column, 訴求_value)
                # -----------------------------------------------------------------------------------------------

                return 指標總表_1_2_3_4_5_6_7_8_9_10_11


            except :

                指標總表_1_2_3_4_5_6_7_8_9_10_11 = pd.DataFrame()

                return 指標總表_1_2_3_4_5_6_7_8_9_10_11





        訴求正面敘述 = YTD_全通路_個別_訴求(訴求_column, 訴求_column, A_1, A_2, 品類_list, 全台家戶數, 洗衣粉_市調結果購買率)


    #     訴求_value = "非"+str(訴求_column) # 新增的作法
        訴求反面敘述 = YTD_全通路_個別_訴求(訴求_column, "非"+str(訴求_column), A_1, A_2, 品類_list, 全台家戶數, 洗衣粉_市調結果購買率)
    #     訴求反面敘述





        df_all = pd.concat([訴求正面敘述, 訴求反面敘述], axis = 0).reset_index(drop = True)
        # 把排序用的欄位drop掉
        df_all = df_all.drop(["訴求_表頭順序", "系列_表頭順序", "品牌_表頭順序", "總排序"], axis = 1)

        # adding a row : Grand Total
        df_all.loc[-1] = ["-", "-", "Grand Total", ALL_全通路_銷額市佔率, ALL_全通路_銷量市佔率, ALL_全通路_每公升均價, ALL_全通路_普及率, ALL_全通路_銷售額, ALL_全通路_銷售量]  # adding a row 
        df_all.index = df_all.index + 1  # shifting index
        df_all.sort_index(inplace=True)

        return df_all



    
    
    
    
    
    





    
    def YTD報表(x_1, x_2, y_1, y_2, x_3, y_3) :

        Year_2017_month_01_02_YTD_全通路 = YTD_全通路_總_訴求(訴求_column, x_1, x_2, 品類_list, 全台家戶數, 洗衣粉_市調結果購買率)
        Year_2018_month_01_02_YTD_全通路 = YTD_全通路_總_訴求(訴求_column, y_1, y_2, 品類_list, 全台家戶數, 洗衣粉_市調結果購買率)


        


        dfs = [Year_2017_month_01_02_YTD_全通路, Year_2018_month_01_02_YTD_全通路]
        Year_2017_2018_month_01_02_YTD_全通路 = reduce(lambda left,right: pd.merge(left, right, how = "outer", on = [str(訴求_column), '自定義品牌', "系列(一匙靈專用)"]), dfs)


        # 1 銷額市佔率_差異
        Year_2017_2018_month_01_02_YTD_全通路["銷額市佔率_差異"] = Year_2017_2018_month_01_02_YTD_全通路["銷額市佔率_y"] - Year_2017_2018_month_01_02_YTD_全通路["銷額市佔率_x"]
        # 2 銷量市佔率_差異
        Year_2017_2018_month_01_02_YTD_全通路["銷量市佔率_差異"] = Year_2017_2018_month_01_02_YTD_全通路["銷量市佔率_y"] - Year_2017_2018_month_01_02_YTD_全通路["銷量市佔率_x"]
        # 3 每公升均價(元)_成長率
        try :
            Year_2017_2018_month_01_02_YTD_全通路["每公升均價(元)_成長率"] = (Year_2017_2018_month_01_02_YTD_全通路["每公升均價(元)_y"] - Year_2017_2018_month_01_02_YTD_全通路["每公升均價(元)_x"]) / Year_2017_2018_month_01_02_YTD_全通路["每公升均價(元)_x"]
        except :
#             Year_2017_2018_month_01_02_YTD_全通路["每公升均價(元)_成長率"] = "-"
            Year_2017_2018_month_01_02_YTD_全通路["每公升均價(元)_成長率"] = pd.Series()
            for i in range(0, len(Year_2017_2018_month_01_02_YTD_全通路["每公升均價(元)_成長率"])) :
                if Year_2017_2018_month_01_02_YTD_全通路["每公升均價(元)_x"][i] == 0 :
                    Year_2017_2018_month_01_02_YTD_全通路["每公升均價(元)_成長率"][i] == "-"
                else :
                    Year_2017_2018_month_01_02_YTD_全通路["每公升均價(元)_成長率"][i] = (Year_2017_2018_month_01_02_YTD_全通路["每公升均價(元)_y"][i] - Year_2017_2018_month_01_02_YTD_全通路["每公升均價(元)_x"][i]) / Year_2017_2018_month_01_02_YTD_全通路["每公升均價(元)_x"][i]
#         # 4 每次購買金額(元)_成長率
#         try :
#             Year_2017_2018_month_01_02_YTD_全通路["每次購買金額(元)_成長率"] = (Year_2017_2018_month_01_02_YTD_全通路["每次購買金額(元)_y"] - Year_2017_2018_month_01_02_YTD_全通路["每次購買金額(元)_x"]) / Year_2017_2018_month_01_02_YTD_全通路["每次購買金額(元)_x"]
#         except :
# #             Year_2017_2018_month_01_02_YTD_全通路["每次購買金額(元)_成長率"] = "-"
#             Year_2017_2018_month_01_02_YTD_全通路["每次購買金額(元)_成長率"] = pd.Series()
#             for i in range(0, len(Year_2017_2018_month_01_02_YTD_全通路["每次購買金額(元)_成長率"])) :
#                 if Year_2017_2018_month_01_02_YTD_全通路["每次購買金額(元)_x"][i] == 0 :
#                     Year_2017_2018_month_01_02_YTD_全通路["每次購買金額(元)_成長率"][i] == "-"
#                 else :
#                     Year_2017_2018_month_01_02_YTD_全通路["每次購買金額(元)_成長率"][i] = (Year_2017_2018_month_01_02_YTD_全通路["每次購買金額(元)_y"][i] - Year_2017_2018_month_01_02_YTD_全通路["每次購買金額(元)_x"][i]) / Year_2017_2018_month_01_02_YTD_全通路["每次購買金額(元)_x"][i]
#         # 5 每次購買量(公升)_成長率
#         try :
#             Year_2017_2018_month_01_02_YTD_全通路["每次購買量(公升)_成長率"] = (Year_2017_2018_month_01_02_YTD_全通路["每次購買量(公升)_y"] - Year_2017_2018_month_01_02_YTD_全通路["每次購買量(公升)_x"]) / Year_2017_2018_month_01_02_YTD_全通路["每次購買量(公升)_x"]
#         except :
# #             Year_2017_2018_month_01_02_YTD_全通路["每次購買量(公升)_成長率"] = "-"
#             Year_2017_2018_month_01_02_YTD_全通路["每次購買量(公升)_成長率"] = pd.Series()
#             for i in range(0, len(Year_2017_2018_month_01_02_YTD_全通路["每次購買量(公升)_成長率"])) :
#                 if Year_2017_2018_month_01_02_YTD_全通路["每次購買量(公升)_x"][i] == 0 :
#                     Year_2017_2018_month_01_02_YTD_全通路["每次購買量(公升)_成長率"][i] == "-"
#                 else :
#                     Year_2017_2018_month_01_02_YTD_全通路["每次購買量(公升)_成長率"][i] = (Year_2017_2018_month_01_02_YTD_全通路["每次購買量(公升)_y"][i] - Year_2017_2018_month_01_02_YTD_全通路["每次購買量(公升)_x"][i]) / Year_2017_2018_month_01_02_YTD_全通路["每次購買量(公升)_x"][i]
#         # 6 平均購買次數_差異
#         Year_2017_2018_month_01_02_YTD_全通路["平均購買次數_差異"] = Year_2017_2018_month_01_02_YTD_全通路["平均購買次數_y"] - Year_2017_2018_month_01_02_YTD_全通路["平均購買次數_x"]
#         # 7 每人平均花費_成長率
#         try :
#             Year_2017_2018_month_01_02_YTD_全通路["每人平均花費_成長率"] = (Year_2017_2018_month_01_02_YTD_全通路["每人平均花費_y"] - Year_2017_2018_month_01_02_YTD_全通路["每人平均花費_x"]) / Year_2017_2018_month_01_02_YTD_全通路["每人平均花費_x"]
#         except :
# #             Year_2017_2018_month_01_02_YTD_全通路["每人平均花費_成長率"] = "-"
#             Year_2017_2018_month_01_02_YTD_全通路["每人平均花費_成長率"] = pd.Series()
#             for i in range(0, len(Year_2017_2018_month_01_02_YTD_全通路["每人平均花費_成長率"])) :
#                 if Year_2017_2018_month_01_02_YTD_全通路["每人平均花費_x"][i] == 0 :
#                     Year_2017_2018_month_01_02_YTD_全通路["每人平均花費_成長率"][i] == "-"
#                 else :
#                     Year_2017_2018_month_01_02_YTD_全通路["每人平均花費_成長率"][i] = (Year_2017_2018_month_01_02_YTD_全通路["每人平均花費_y"][i] - Year_2017_2018_month_01_02_YTD_全通路["每人平均花費_x"][i]) / Year_2017_2018_month_01_02_YTD_全通路["每人平均花費_x"][i]
#         # 8 每人平均購買量_成長率
#         try :
#             Year_2017_2018_month_01_02_YTD_全通路["每人平均購買量_成長率"] = (Year_2017_2018_month_01_02_YTD_全通路["每人平均購買量_y"] - Year_2017_2018_month_01_02_YTD_全通路["每人平均購買量_x"]) / Year_2017_2018_month_01_02_YTD_全通路["每人平均購買量_x"]
#         except :
# #             Year_2017_2018_month_01_02_YTD_全通路["每人平均購買量_成長率"] = "-"
#             Year_2017_2018_month_01_02_YTD_全通路["每人平均購買量_成長率"] = pd.Series()
#             for i in range(0, len(Year_2017_2018_month_01_02_YTD_全通路["每人平均購買量_成長率"])) :
#                 if Year_2017_2018_month_01_02_YTD_全通路["每人平均購買量_x"][i] == 0 :
#                     Year_2017_2018_month_01_02_YTD_全通路["每人平均購買量_成長率"][i] == "-"
#                 else :
#                     Year_2017_2018_month_01_02_YTD_全通路["每人平均購買量_成長率"][i] = (Year_2017_2018_month_01_02_YTD_全通路["每人平均購買量_y"][i] - Year_2017_2018_month_01_02_YTD_全通路["每人平均購買量_x"][i]) / Year_2017_2018_month_01_02_YTD_全通路["每人平均購買量_x"][i]
        # 9 普及率_差異
        Year_2017_2018_month_01_02_YTD_全通路["普及率_差異"] = Year_2017_2018_month_01_02_YTD_全通路["普及率_y"] - Year_2017_2018_month_01_02_YTD_全通路["普及率_x"]

        Year_2017_2018_month_01_02_YTD_全通路 = Year_2017_2018_month_01_02_YTD_全通路[[str(訴求_column), '自定義品牌', "系列(一匙靈專用)", "銷額市佔率_x", "銷額市佔率_y", "銷額市佔率_差異", "銷量市佔率_x", "銷量市佔率_y", "銷量市佔率_差異", "每公升均價(元)_x", "每公升均價(元)_y", "每公升均價(元)_成長率", "普及率_x", "普及率_y", "普及率_差異"]]

        Year_2017_2018_month_01_02_YTD_全通路 = Year_2017_2018_month_01_02_YTD_全通路.fillna("-")


        Year_2017_2018_month_01_02_YTD_全通路 = Year_2017_2018_month_01_02_YTD_全通路.rename(columns=lambda x: x.replace('x', str(x_3)))
        Year_2017_2018_month_01_02_YTD_全通路 = Year_2017_2018_month_01_02_YTD_全通路.rename(columns=lambda x: x.replace('y', str(y_3)))

        
        
#         # 讀MAT的表頭
#         # =============================================================================================================================
        
#         exec(f'Year_2017_2018_month_01_02_YTD_全通路 = pd.merge(MAT_訴求_{訴求_column}全通路_info[0], Year_2017_2018_month_01_02_YTD_全通路, how = "left", on = [str(訴求_column), "自定義品牌", "系列(一匙靈專用)"])')
    
#         # =============================================================================================================================

        
        
        # 去掉整個row都沒有值的品牌系列
#         # set_index 時，在這邊記得還有str(訴求_column)
#         Year_2017_2018_month_01_02_YTD_全通路 = Year_2017_2018_month_01_02_YTD_全通路.set_index([str(訴求_column), "自定義品牌", "系列(一匙靈專用)"])
        Year_2017_2018_month_01_02_YTD_全通路 = Year_2017_2018_month_01_02_YTD_全通路.replace("-", np.nan)
        Year_2017_2018_month_01_02_YTD_全通路 = Year_2017_2018_month_01_02_YTD_全通路.dropna(how = "all")
        Year_2017_2018_month_01_02_YTD_全通路 = Year_2017_2018_month_01_02_YTD_全通路.fillna("-")
        
        return Year_2017_2018_month_01_02_YTD_全通路

            
    Year_2017_2018_month_01_02_YTD_全通路 = YTD報表(x_1, x_2, y_1, y_2, x_3, y_3)
    
    
    
    
    
    return Year_2017_2018_month_01_02_YTD_全通路

# %%
df_我做的MAT = pd.read_excel("C:/Users/EOL/py_ds/2018.09.20 洗衣精訴求/洗衣精銷售表現_MAT_18JUN_訴求-2018.10.04.xlsx", sheet_name = "天然")
df_我做的MAT
# Out:
#      天然       自定義品牌     銷額市佔率     銷量市佔率    每公升均價(元)       普及率     銷售額(百萬元)  \
# 0     -           -  1.000000  1.000000   75.003353  0.794651  4352.710160
# 1    天然           -  0.171731  0.197835   65.106882  0.196369   747.496971
# 2   NaN        橘子工坊  0.028598  0.014848  144.460815  0.022523   124.479914
# 3   NaN      Frosch  0.001336  0.000480  208.693509  0.000684     5.814240
# 4   NaN          白鴿  0.049278  0.076393   48.381977  0.079481   214.493285
# 5   NaN  ARM&HAMMER  0.028849  0.038544   56.136887  0.015368   125.569167
# 6   NaN        南僑水晶  0.026185  0.021203   92.628773  0.027659   113.976170
# 7   NaN          皂福  0.006872  0.011156   46.199125  0.011091    29.909677
# 8   NaN        毛寶整體  0.006705  0.008415   59.769540  0.011375    29.187037
# 9   NaN         歐芮坦  0.003228  0.004886   49.553733  0.008871    14.050795
# 10  NaN     NAC NAC  0.003011  0.001762  128.171642  0.002065    13.105963
# ...

# %%
# YTD訴求表

# ================================================================
# 個別表

# YTD_訴求_天然全通路 = YTD_全通路_完整sheet("天然", x_1, x_2, y_1, y_2, x_3, y_3, 品類_list, 全台家戶數, 洗衣粉_市調結果購買率)
# YTD_訴求_天然全通路 = YTD_訴求_天然全通路.loc[YTD_訴求_天然全通路["系列(一匙靈專用)"].str.contains("Total|Grand Total")].reset_index(drop = True)

# # YTD_訴求_天然全通路 = 品牌x系列_表頭排序(YTD_訴求_天然全通路, "天然", "非"+"天然")
# YTD_訴求_天然全通路 = pd.merge(MAT_訴求_天然全通路_表頭, YTD_訴求_天然全通路, how = "left", on = ["天然", "自定義品牌"])
# YTD_訴求_天然全通路 = YTD_訴求_天然全通路.fillna("-")
# YTD_訴求_天然全通路
# # MAT_訴求_{訴求們[i]}全通路

# ================================================================


YTD_訴求_天然全通路 = YTD_全通路_完整sheet("天然", x_1, x_2, y_1, y_2, x_3, y_3, 品類_list, 全台家戶數, 洗衣粉_市調結果購買率)
YTD_訴求_天然全通路 = YTD_訴求_天然全通路.loc[YTD_訴求_天然全通路["系列(一匙靈專用)"].str.contains("Total|Grand Total")].reset_index(drop = True)
print("目前進度 : " + "{:.2%}".format( 1 / 20 ) )


YTD_訴求_香氛全通路 = YTD_全通路_完整sheet("香氛", x_1, x_2, y_1, y_2, x_3, y_3, 品類_list, 全台家戶數, 洗衣粉_市調結果購買率)
YTD_訴求_香氛全通路 = YTD_訴求_香氛全通路.loc[YTD_訴求_香氛全通路["系列(一匙靈專用)"].str.contains("Total|Grand Total")].reset_index(drop = True)
print("目前進度 : " + "{:.2%}".format( 2 / 20 ) )


YTD_訴求_強效全通路 = YTD_全通路_完整sheet("強效", x_1, x_2, y_1, y_2, x_3, y_3, 品類_list, 全台家戶數, 洗衣粉_市調結果購買率)
YTD_訴求_強效全通路 = YTD_訴求_強效全通路.loc[YTD_訴求_強效全通路["系列(一匙靈專用)"].str.contains("Total|Grand Total")].reset_index(drop = True)
print("目前進度 : " + "{:.2%}".format( 3 / 20 ) )


YTD_訴求_抗菌全通路 = YTD_全通路_完整sheet("抗菌", x_1, x_2, y_1, y_2, x_3, y_3, 品類_list, 全台家戶數, 洗衣粉_市調結果購買率)
YTD_訴求_抗菌全通路 = YTD_訴求_抗菌全通路.loc[YTD_訴求_抗菌全通路["系列(一匙靈專用)"].str.contains("Total|Grand Total")].reset_index(drop = True)
print("目前進度 : " + "{:.2%}".format( 4 / 20 ) )


YTD_訴求_防蟎全通路 = YTD_全通路_完整sheet("防蟎", x_1, x_2, y_1, y_2, x_3, y_3, 品類_list, 全台家戶數, 洗衣粉_市調結果購買率)
YTD_訴求_防蟎全通路 = YTD_訴求_防蟎全通路.loc[YTD_訴求_防蟎全通路["系列(一匙靈專用)"].str.contains("Total|Grand Total")].reset_index(drop = True)
print("目前進度 : " + "{:.2%}".format( 5 / 20 ) )


YTD_訴求_防霉全通路 = YTD_全通路_完整sheet("防霉", x_1, x_2, y_1, y_2, x_3, y_3, 品類_list, 全台家戶數, 洗衣粉_市調結果購買率)
YTD_訴求_防霉全通路 = YTD_訴求_防霉全通路.loc[YTD_訴求_防霉全通路["系列(一匙靈專用)"].str.contains("Total|Grand Total")].reset_index(drop = True)
print("目前進度 : " + "{:.2%}".format( 6 / 20 ) )


YTD_訴求_潔白全通路 = YTD_全通路_完整sheet("潔白", x_1, x_2, y_1, y_2, x_3, y_3, 品類_list, 全台家戶數, 洗衣粉_市調結果購買率)
YTD_訴求_潔白全通路 = YTD_訴求_潔白全通路.loc[YTD_訴求_潔白全通路["系列(一匙靈專用)"].str.contains("Total|Grand Total")].reset_index(drop = True)
print("目前進度 : " + "{:.2%}".format( 7 / 20 ) )


YTD_訴求_柔軟全通路 = YTD_全通路_完整sheet("柔軟", x_1, x_2, y_1, y_2, x_3, y_3, 品類_list, 全台家戶數, 洗衣粉_市調結果購買率)
YTD_訴求_柔軟全通路 = YTD_訴求_柔軟全通路.loc[YTD_訴求_柔軟全通路["系列(一匙靈專用)"].str.contains("Total|Grand Total")].reset_index(drop = True)
print("目前進度 : " + "{:.2%}".format( 8 / 20 ) )


YTD_訴求_亮彩_護色全通路 = YTD_全通路_完整sheet("亮彩_護色", x_1, x_2, y_1, y_2, x_3, y_3, 品類_list, 全台家戶數, 洗衣粉_市調結果購買率)
YTD_訴求_亮彩_護色全通路 = YTD_訴求_亮彩_護色全通路.loc[YTD_訴求_亮彩_護色全通路["系列(一匙靈專用)"].str.contains("Total|Grand Total")].reset_index(drop = True)
print("目前進度 : " + "{:.2%}".format( 9 / 20 ) )


YTD_訴求_不傷衣料全通路 = YTD_全通路_完整sheet("不傷衣料", x_1, x_2, y_1, y_2, x_3, y_3, 品類_list, 全台家戶數, 洗衣粉_市調結果購買率)
YTD_訴求_不傷衣料全通路 = YTD_訴求_不傷衣料全通路.loc[YTD_訴求_不傷衣料全通路["系列(一匙靈專用)"].str.contains("Total|Grand Total")].reset_index(drop = True)
print("目前進度 : " + "{:.2%}".format( 10 / 20 ) )


YTD_訴求_嬰兒全通路 = YTD_全通路_完整sheet("嬰兒", x_1, x_2, y_1, y_2, x_3, y_3, 品類_list, 全台家戶數, 洗衣粉_市調結果購買率)
YTD_訴求_嬰兒全通路 = YTD_訴求_嬰兒全通路.loc[YTD_訴求_嬰兒全通路["系列(一匙靈專用)"].str.contains("Total|Grand Total")].reset_index(drop = True)
print("目前進度 : " + "{:.2%}".format( 11 / 20 ) )


YTD_訴求_去味全通路 = YTD_全通路_完整sheet("去味", x_1, x_2, y_1, y_2, x_3, y_3, 品類_list, 全台家戶數, 洗衣粉_市調結果購買率)
YTD_訴求_去味全通路 = YTD_訴求_去味全通路.loc[YTD_訴求_去味全通路["系列(一匙靈專用)"].str.contains("Total|Grand Total")].reset_index(drop = True)
print("目前進度 : " + "{:.2%}".format( 12 / 20 ) )


YTD_訴求_柔膚全通路 = YTD_全通路_完整sheet("柔膚", x_1, x_2, y_1, y_2, x_3, y_3, 品類_list, 全台家戶數, 洗衣粉_市調結果購買率)
YTD_訴求_柔膚全通路 = YTD_訴求_柔膚全通路.loc[YTD_訴求_柔膚全通路["系列(一匙靈專用)"].str.contains("Total|Grand Total")].reset_index(drop = True)
print("目前進度 : " + "{:.2%}".format( 13 / 20 ) )


YTD_訴求_低敏全通路 = YTD_全通路_完整sheet("低敏", x_1, x_2, y_1, y_2, x_3, y_3, 品類_list, 全台家戶數, 洗衣粉_市調結果購買率)
YTD_訴求_低敏全通路 = YTD_訴求_低敏全通路.loc[YTD_訴求_低敏全通路["系列(一匙靈專用)"].str.contains("Total|Grand Total")].reset_index(drop = True)
print("目前進度 : " + "{:.2%}".format( 14 / 20 ) )


YTD_訴求_無味全通路 = YTD_全通路_完整sheet("無味", x_1, x_2, y_1, y_2, x_3, y_3, 品類_list, 全台家戶數, 洗衣粉_市調結果購買率)
YTD_訴求_無味全通路 = YTD_訴求_無味全通路.loc[YTD_訴求_無味全通路["系列(一匙靈專用)"].str.contains("Total|Grand Total")].reset_index(drop = True)
print("目前進度 : " + "{:.2%}".format( 15 / 20 ) )


YTD_訴求_超濃縮全通路 = YTD_全通路_完整sheet("超濃縮", x_1, x_2, y_1, y_2, x_3, y_3, 品類_list, 全台家戶數, 洗衣粉_市調結果購買率)
YTD_訴求_超濃縮全通路 = YTD_訴求_超濃縮全通路.loc[YTD_訴求_超濃縮全通路["系列(一匙靈專用)"].str.contains("Total|Grand Total")].reset_index(drop = True)
print("目前進度 : " + "{:.2%}".format( 16 / 20 ) )


YTD_訴求_環保全通路 = YTD_全通路_完整sheet("環保", x_1, x_2, y_1, y_2, x_3, y_3, 品類_list, 全台家戶數, 洗衣粉_市調結果購買率)
YTD_訴求_環保全通路 = YTD_訴求_環保全通路.loc[YTD_訴求_環保全通路["系列(一匙靈專用)"].str.contains("Total|Grand Total")].reset_index(drop = True)
print("目前進度 : " + "{:.2%}".format( 17 / 20 ) )


YTD_訴求_酵素全通路 = YTD_全通路_完整sheet("酵素", x_1, x_2, y_1, y_2, x_3, y_3, 品類_list, 全台家戶數, 洗衣粉_市調結果購買率)
YTD_訴求_酵素全通路 = YTD_訴求_酵素全通路.loc[YTD_訴求_酵素全通路["系列(一匙靈專用)"].str.contains("Total|Grand Total")].reset_index(drop = True)
print("目前進度 : " + "{:.2%}".format( 18 / 20 ) )


YTD_訴求_運動全通路 = YTD_全通路_完整sheet("運動", x_1, x_2, y_1, y_2, x_3, y_3, 品類_list, 全台家戶數, 洗衣粉_市調結果購買率)
YTD_訴求_運動全通路 = YTD_訴求_運動全通路.loc[YTD_訴求_運動全通路["系列(一匙靈專用)"].str.contains("Total|Grand Total")].reset_index(drop = True)
print("目前進度 : " + "{:.2%}".format( 19 / 20 ) )



# ================================================================
# 總表

# 亮彩護色有斜線 / ， 要處理

# ================================================================

# YTD_訴求_天然全通路 = YTD_全通路_完整sheet("天然", x_1, x_2, y_1, y_2, x_3, y_3, 品類_list, 全台家戶數, 洗衣粉_市調結果購買率)
# YTD_訴求_天然全通路 = YTD_訴求_天然全通路[0]
# YTD_訴求_天然全通路 = YTD_訴求_天然全通路.loc[YTD_訴求_天然全通路["系列(一匙靈專用)"].str.contains("Total|Grand Total")].reset_index(drop = True)

# YTD_訴求_天然全通路_正面訴求Total = YTD_訴求_天然全通路.loc[(YTD_訴求_天然全通路["系列(一匙靈專用)"].str.contains("SubTotal")), :].reset_index(drop = True)
# YTD_訴求_天然全通路_正面訴求Total

# ================================================================

訴求們 = ["天然", "香氛", "強效", "抗菌", "防蟎", "防霉", "潔白", "柔軟", "亮彩_護色", "不傷衣料", "嬰兒", "去味", "柔膚", "低敏", "無味", "超濃縮", "環保", "酵素", "運動"]

# 訴求們 = ["天然", "香氛", "強效", "抗菌", "防蟎", "防霉", "潔白", "柔軟", "不傷衣料", "嬰兒", "去味", "柔膚", "低敏", "無味", "超濃縮", "環保", "酵素", "運動"]

YTD_all訴求_全通路_正面訴求Total = pd.DataFrame()
for i in range(0, len(訴求們)) :
# df.columns = df.columns.str.replace('$','')
   
    exec(f'YTD_訴求_{訴求們[i]}全通路_正面訴求Total = YTD_訴求_{訴求們[i]}全通路.loc[(YTD_訴求_{訴求們[i]}全通路["系列(一匙靈專用)"].str.contains("SubTotal")), :].reset_index(drop = True)')
    exec(f'YTD_訴求_{訴求們[i]}全通路_正面訴求Total.columns = YTD_訴求_{訴求們[i]}全通路_正面訴求Total.columns.str.replace("{訴求們[i]}", "訴求")')

#     exec(f'YTD_all訴求_全通路_正面訴求Total = pd.concat([YTD_訴求_{訴求們[i]}全通路_正面訴求Total, YTD_訴求_{訴求們[i+1]}全通路_正面訴求Total], axis = 0)')
    exec(f'YTD_all訴求_全通路_正面訴求Total = YTD_all訴求_全通路_正面訴求Total.append(YTD_訴求_{訴求們[i]}全通路_正面訴求Total)')
    #----------------------------------------------------
    # YTD還要merge MAT表頭排序
#     YTD_訴求_天然全通路 = pd.merge(MAT_訴求_天然全通路_表頭, YTD_訴求_天然全通路, how = "left", on = ["天然", "自定義品牌"])
    exec(f'YTD_訴求_{訴求們[i]}全通路 = pd.merge(MAT_訴求_{訴求們[i]}全通路_表頭, YTD_訴求_{訴求們[i]}全通路, how = "left", on = ["{訴求們[i]}", "自定義品牌"])')
    #----------------------------------------------------
    # 把單一訴求sheet裡不必要的欄位drop掉
    exec(f'YTD_訴求_{訴求們[i]}全通路 = YTD_訴求_{訴求們[i]}全通路.drop(["系列(一匙靈專用)"], axis=1)')
    
    

YTD_all訴求_全通路_正面訴求Total = YTD_all訴求_全通路_正面訴求Total.drop_duplicates().reset_index(drop = True)
YTD_all訴求_全通路_正面訴求Total = YTD_all訴求_全通路_正面訴求Total.loc[~YTD_all訴求_全通路_正面訴求Total["訴求"].str.contains("非"), :].reset_index(drop = True)


YTD_單一訴求x品牌_總表 = YTD_all訴求_全通路_正面訴求Total.drop(["自定義品牌", "系列(一匙靈專用)"], axis=1)
YTD_單一訴求x品牌_總表 = YTD_單一訴求x品牌_總表.set_index(["訴求"])
YTD_單一訴求x品牌_總表


# 每一個訴求的sheet都set_index
for i in range(0, len(訴求們)) :
    exec(f'YTD_訴求_{訴求們[i]}全通路 = YTD_訴求_{訴求們[i]}全通路.set_index(["{訴求們[i]}", "自定義品牌"])')

print("目前進度 : " + "{:.2%}".format( 20 / 20 ) )

print("Done!")
# Out:
# C:\Users\EOL\Anaconda3\lib\site-packages\ipykernel_launcher.py:412: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
#
# C:\Users\EOL\Anaconda3\lib\site-packages\ipykernel_launcher.py:420: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
#
# C:\Users\EOL\Anaconda3\lib\site-packages\ipykernel_launcher.py:481: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# ...

# %% [markdown]
# ## YTD 匯出表格

# %%
# 匯出總表

writer = pd.ExcelWriter("%s-0926版.xlsx" % (YTD_檔名), engine = "xlsxwriter")
# 全通路
YTD_單一訴求x品牌_總表.to_excel(writer, sheet_name = "YTD總表", index = True)
# 單一通路
YTD_訴求_天然全通路.to_excel(writer, sheet_name = "天然", index = True)
YTD_訴求_香氛全通路.to_excel(writer, sheet_name = "香氛", index = True)
YTD_訴求_強效全通路.to_excel(writer, sheet_name = "強效", index = True)
YTD_訴求_抗菌全通路.to_excel(writer, sheet_name = "抗菌", index = True)
YTD_訴求_防蟎全通路.to_excel(writer, sheet_name = "防蟎", index = True)

YTD_訴求_防霉全通路.to_excel(writer, sheet_name = "防霉", index = True)
YTD_訴求_潔白全通路.to_excel(writer, sheet_name = "潔白", index = True)
YTD_訴求_柔軟全通路.to_excel(writer, sheet_name = "柔軟", index = True)
YTD_訴求_亮彩_護色全通路.to_excel(writer, sheet_name = "亮彩_護色", index = True)
YTD_訴求_不傷衣料全通路.to_excel(writer, sheet_name = "不傷衣料", index = True)

YTD_訴求_嬰兒全通路.to_excel(writer, sheet_name = "嬰兒", index = True)
YTD_訴求_去味全通路.to_excel(writer, sheet_name = "去味", index = True)
YTD_訴求_柔膚全通路.to_excel(writer, sheet_name = "柔膚", index = True)
YTD_訴求_低敏全通路.to_excel(writer, sheet_name = "低敏", index = True)
YTD_訴求_無味全通路.to_excel(writer, sheet_name = "無味", index = True)

YTD_訴求_超濃縮全通路.to_excel(writer, sheet_name = "超濃縮", index = True)
YTD_訴求_環保全通路.to_excel(writer, sheet_name = "環保", index = True)
YTD_訴求_酵素全通路.to_excel(writer, sheet_name = "酵素", index = True)
YTD_訴求_運動全通路.to_excel(writer, sheet_name = "運動", index = True)

writer.save()

# %%
# 訴求_test_column = "天然"
# a = exec(f'MAT_訴求_{訴求_test_column}全通路_info[0]')
# a

# %%
# YTD_天然_全通路_info = YTD_全通路_完整sheet("天然", x_1, x_2, y_1, y_2, x_3, y_3, 品類_list, 全台家戶數, 洗衣粉_市調結果購買率)
# YTD_天然_全通路_info

# %%
# YTD_訴求_天然全通路.loc[YTD_訴求_天然全通路["自定義品牌"] == "其他", :]

# %% [markdown]
# ------------------------------

# %% [markdown]
# -----------------------

# %% [markdown]
# ## 天然only的YTD - sheet by 通路

# %% [markdown]
# -----------------------

# %%
# # YTD
# x_1 = "2017-01-01"
# x_2 = "2017-05-01"

# y_1 = "2018-01-01"
# y_2 = "2018-05-01"

# x_3 = "2017年1-4月"
# y_3 = "2018年1-4月"

# %% [markdown]
# ## YTD
# >> YTD_全通路

# %%
def YTD_全通路_完整sheet(訴求_column, x_1, x_2, y_1, y_2, x_3, y_3, 品類_list, 全台家戶數, 洗衣粉_市調結果購買率) :

    def YTD_全通路_總_訴求(訴求_column, A_1, A_2, 品類_list, 全台家戶數, 洗衣粉_市調結果購買率) :  
        
        訴求_column = 訴求_column
        
        #------------------------------------------------------------------------------------------------------------------------
        global ALL_洗衣粉_ALL_全通路_普及率_總裝置數

        # =========================================================================================
        # for YTD各時間區間的ALL_全通路變數
        # =========================================================================================


        df = df_整理


        # =================================== 1. 處理與否 = 1 =================================== 
        df = df[df["處理與否"] == 1]
        # =================================== 2. 總容量有值 且 >=1 =================================== 
        df = df[np.isfinite(df['總容量'])]
        df = df[df['總容量'] >= 0]

        # =================================== 3.時間_MAT ===================================    
        df = df[(df['invDate_datetime'] >= str(A_1)) & (df['invDate_datetime'] < str(A_2))]

        # =================================== 4.品類_洗衣粉 ===================================
        df = df[df["品類_list"] == 1]

        # =================================== 5.通路_全通路 =================================== 
        #全通路
        df_全通路 = df 
        # reset_index
        df_全通路 = df.reset_index(drop = True)   




        # =================================== 8-1.指標_MAT_洗衣粉_銷額市佔率 ===================================
        # 算總金額(正確價錢 Grand Total)
        洗衣粉_MAT_全通路總金額_Grand_Total = 0
        list_of_洗衣粉_MAT_全通路總金額_Grand_Total = []
        for i in range(0, len(df_全通路["正確價錢"])) :
            洗衣粉_MAT_全通路總金額_Grand_Total = 洗衣粉_MAT_全通路總金額_Grand_Total + float(df_全通路["正確價錢"][i])






        # =================================== 8-2.指標_MAT_洗衣粉_銷量市佔率 ===================================
        # 算總金額(正確價錢 Grand Total)
        洗衣粉_MAT_全通路總容量_Grand_Total = 0
        list_of_洗衣粉_MAT_全通路總容量_Grand_Total = []
        for i in range(0, len(df_全通路["總容量"])) :
            洗衣粉_MAT_全通路總容量_Grand_Total = 洗衣粉_MAT_全通路總容量_Grand_Total + float(df_全通路["總容量"][i])






        # # =================================== 8-4.指標_MAT_洗衣粉_每次購買金額(元) ===================================
        # # =================================== 8-5.指標_MAT_洗衣粉_每次購買量(公升) ===================================
        df_copy = df_全通路
        df_copy = df_copy.reset_index(drop = True)
        #----------------------------------------------------------------------------------
        df_corss_variable_distinct_invNum = df_copy.loc[:, ["xdid", "invNum", "自定義品牌", "系列(一匙靈專用)"]]
        df_corss_variable_distinct_invNum['自定義品牌_系列'] = df_corss_variable_distinct_invNum[['自定義品牌', '系列(一匙靈專用)']].apply(lambda x: ','.join(x), axis=1)
        #----------------------------------------------------------------------------------
        # 各品牌各系列
        df_自定義品牌_系列 = df_corss_variable_distinct_invNum[['自定義品牌_系列']].drop_duplicates().reset_index(drop = True)
        df_自定義品牌_系列["不重複的發票編號"] = ""
        df_自定義品牌_系列["總發票張數(不重複)"] = ""

        for i in range(0, len(df_自定義品牌_系列["自定義品牌_系列"])) :
            不重複的發票編號_list = []
            for j in range(0, len(df_corss_variable_distinct_invNum["自定義品牌_系列"])) :
                if df_自定義品牌_系列["自定義品牌_系列"][i] == df_corss_variable_distinct_invNum["自定義品牌_系列"][j] :
                    不重複的發票編號_list.append(df_corss_variable_distinct_invNum["invNum"][j])
                else :
                    None
            df_自定義品牌_系列["不重複的發票編號"][i] = list(set(不重複的發票編號_list))
            df_自定義品牌_系列["總發票張數(不重複)"][i] = len(list(set(不重複的發票編號_list)))
            不重複的發票編號_list = []
        #--------------
        # 各品牌Total    
        df_自定義品牌_系列_Total = df_corss_variable_distinct_invNum[['自定義品牌']].drop_duplicates().reset_index(drop = True)
        df_自定義品牌_系列_Total["系列(一匙靈專用)"] = "Total"
        df_自定義品牌_系列_Total["不重複的發票編號"] = ""
        df_自定義品牌_系列_Total["總發票張數(不重複)"] = ""    

        for i in range(0, len(df_自定義品牌_系列_Total["自定義品牌"])) :
            不重複的發票編號_list = []
            for j in range(0, len(df_corss_variable_distinct_invNum["自定義品牌"])) :
                if df_自定義品牌_系列_Total["自定義品牌"][i] == df_corss_variable_distinct_invNum["自定義品牌"][j] :
                    不重複的發票編號_list.append(df_corss_variable_distinct_invNum["invNum"][j])
                else :
                    None
            df_自定義品牌_系列_Total["不重複的發票編號"][i] = list(set(不重複的發票編號_list))
            df_自定義品牌_系列_Total["總發票張數(不重複)"][i] = len(list(set(不重複的發票編號_list)))
            不重複的發票編號_list = []
        #----------------------------------------------------------------------------------            



        # # =================================== 8-6.指標_MAT_洗衣粉_平均購買次數 ===================================
        # 這裡有篩選條件需要選到 "品項" : "洗衣粉" !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!

        df_copy_2 = df_整理




        # =================================== 挑有買過兩張發票的裝置 xdid ===================================
        df_copy_3 = df_copy_2
        df_copy_4 = df_copy_2
        #---------------------------------------------------------------------------------------------------------

        #---------------------------------------------------------------------------------------------------------
        # for df_copy_2 : 要找到 總裝置數 的 那些"裝置(xdid)"候選人名單
        # =================================== 0. 挑有買過2張以上發票的裝置 =================================== 
        # 挑有買過兩張發票的裝置

        df_all_of_xdid_with_multiple_invNum_list = df_copy_2


        df_all_of_xdid_with_multiple_invNum_list = df_copy_2.loc[:, ["xdid", "invNum"]]
        # 將裝置數missing的刪除
        df_all_of_xdid_with_multiple_invNum_list = df_all_of_xdid_with_multiple_invNum_list.loc[df_all_of_xdid_with_multiple_invNum_list["xdid"] != "missing" ]
        df_all_of_xdid_with_multiple_invNum_list = df_all_of_xdid_with_multiple_invNum_list.drop_duplicates().reset_index(drop = True)

        df_all_of_xdid_with_multiple_invNum_list = df_all_of_xdid_with_multiple_invNum_list.groupby(["xdid"])['invNum'].nunique()

        df_all_of_xdid_with_multiple_invNum_list = df_all_of_xdid_with_multiple_invNum_list[df_all_of_xdid_with_multiple_invNum_list > 1]
        df_all_of_xdid_with_multiple_invNum_list = df_all_of_xdid_with_multiple_invNum_list.to_frame().reset_index()
        # #---------------------------------------------------------------------------------------------------------
        # < 交叉變項 : 總裝置數 的 那些"裝置(xdid)"候選人名單 >
        df_all_of_xdid_with_multiple_invNum_list = list(set(df_all_of_xdid_with_multiple_invNum_list["xdid"]))

        #---------------------------------------------------------------------------------------------------------
        # for df_copy_3 : 要從原始資料 找到 符合那些裝置候選人名單 & 符合後續條件 的那些row

        # < 交叉變項 : 總裝置數 的 那些"裝置(xdid)"候選人名單 ；待會兒要加上 原本1~5的篩選條件 再得到 df，最後才要groupby >
        df_copy_3 = df_copy_3[df_copy_3['xdid'].isin(df_all_of_xdid_with_multiple_invNum_list)]
        # =================================== 1. 處理與否 = 1 =================================== 
        df_copy_3 = df_copy_3[df_copy_3["處理與否"] == 1]
        # =================================== 2. 總容量有值 且 >=1 =================================== 
        df_copy_3 = df_copy_3[np.isfinite(df_copy_3['總容量'])]
        df_copy_3 = df_copy_3[df_copy_3['總容量'] >= 0]
        # =================================== 3.時間_MAT ===================================
        df_copy_3 = df_copy_3[(df_copy_3['invDate_datetime'] >= str(A_1)) & (df_copy_3['invDate_datetime'] < str(A_2))]
        # =================================== 4.品類_洗衣粉 - < 至少有一張發票有買到該品項 > ===================================
        df_copy_3 = df_copy_3[df_copy_3["品類_list"] == 1]
        # =================================== 5.通路_全通路 =================================== 
        df_copy_3 = df_copy_3 #全通路
        # # df_copy_3 = df_copy_3[df_copy_3["通路"] == "全聯"] #全聯
        # # reset_index
        # df_copy_3 = df_copy_3.reset_index(drop = True)   


        # Grand Total
        平均購買次數_總裝置數_list_of_xdid__with_multiple_invNum = len(list(set(df_copy_3["xdid"])))





        #---------------------------------------------------------------------------------------------------------
        # for df_copy_4 : 要找到總發票張數 : 1.挑有2張發票的裝置  2.其中有買到該品項的發票皆列入

        # 挑有買過兩張發票的裝置

        df_all_of_xdid_with_multiple_invNum_list = df_copy_2

        df_all_of_xdid_with_multiple_invNum_list = df_copy_2.loc[:, ["xdid", "invNum"]]
        # 將裝置數missing的保留
        # df_all_of_xdid_with_multiple_invNum_list = df_all_of_xdid_with_multiple_invNum_list.loc[df_all_of_xdid_with_multiple_invNum_list["xdid"] != "missing" ]
        df_all_of_xdid_with_multiple_invNum_list = df_all_of_xdid_with_multiple_invNum_list.drop_duplicates().reset_index(drop = True)

        df_all_of_xdid_with_multiple_invNum_list = df_all_of_xdid_with_multiple_invNum_list.groupby(["xdid"])['invNum'].nunique()

        df_all_of_xdid_with_multiple_invNum_list = df_all_of_xdid_with_multiple_invNum_list[df_all_of_xdid_with_multiple_invNum_list > 1]
        df_all_of_xdid_with_multiple_invNum_list = df_all_of_xdid_with_multiple_invNum_list.to_frame().reset_index()


        # #---------------------------------------------------------------------------------------------------------
        # < 交叉變項 : 總裝置數 的 那些"裝置(xdid)"候選人名單 >
        list_of_xdid__with_multiple_invNum = list(set(df_all_of_xdid_with_multiple_invNum_list["xdid"]))

        df_copy_4 = df_copy_4[df_copy_4['xdid'].isin(list_of_xdid__with_multiple_invNum)]

        # < 交叉變項 : 總裝置數 的 那些"裝置(xdid)"候選人名單 加上 原本1~5的篩選條件所得到的 df，接下來要groupby了 >
        # =================================== 1. 處理與否 = 1 =================================== 
        df_copy_4 = df_copy_4[df_copy_4["處理與否"] == 1]
        # =================================== 2. 總容量有值 且 >=1 =================================== 
        df_copy_4 = df_copy_4[np.isfinite(df_copy_4['總容量'])]
        df_copy_4 = df_copy_4[df_copy_4['總容量'] >= 0]
        # =================================== 3.時間_MAT ===================================    
        df_copy_4 = df_copy_4[(df_copy_4['invDate_datetime'] >= str(A_1)) & (df_copy_4['invDate_datetime'] < str(A_2))]
        # =================================== 4.品類_洗衣粉 - < 有買到該品項的皆列入 > ===================================
        df_copy_4 = df_copy_4[df_copy_4["品類_list"] == 1]

        # =================================== 5.通路_全通路 =================================== 
        df_copy_4 = df_copy_4 #全通路
        # df_copy_4 = df_copy_4[df_copy_4["通路"] == "全聯"] #全聯
        # reset_index
        df_copy_4 = df_copy_4.reset_index(drop = True)   


        # 平均購買次數_總發票張數_(Grand_Total)
        list_of_invNum__by_xdid__with_multiple_invNum = len(list(set(df_copy_4["invNum"])))



        # # =================================== 8-6.指標_MAT_洗衣粉_平均購買次數 ===================================



        # # =================================== 8-9.指標_MAT_洗衣粉_普及率 ===================================
        # # 總裝置數
        # =================================== 挑有買過兩張發票的裝置 xdid ===================================
        df_copy_5 = df_copy_2
        #---------------------------------------------------------------------------------------------------------

        #---------------------------------------------------------------------------------------------------------
        # for df_copy_5 : 要找到 總裝置數 的 那些"裝置(xdid)"候選人名單
        # =================================== 0. 總裝置數 =================================== 


        # < 交叉變項 : 總裝置數 >
        df_copy_5 = df_copy_5[df_copy_5['xdid'] != "missing"]
        # =================================== 1. 處理與否 = 1 =================================== 
        df_copy_5 = df_copy_5[df_copy_5["處理與否"] == 1]
        # =================================== 2. 總容量有值 且 >=1 =================================== 
        df_copy_5 = df_copy_5[np.isfinite(df_copy_5['總容量'])]
        df_copy_5 = df_copy_5[df_copy_5['總容量'] >= 0]
        # =================================== 3.時間_MAT ===================================
        df_copy_5 = df_copy_5[(df_copy_5['invDate_datetime'] >= str(A_1)) & (df_copy_5['invDate_datetime'] < str(A_2))]
        # =================================== 4.品類_洗衣粉 - < 至少有一張發票有買到該品項 > ===================================
        df_copy_5 = df_copy_5[df_copy_5["品類_list"] == 1]
        # =================================== 5.通路_全通路 =================================== 
        # 全通路
        df_copy_5_全通路 = df_copy_5 
        # 單一通路
        # # df_copy_5_單一通路 = df_copy_5[df_copy_5["通路"] == "全聯"] #全聯
        # # reset_index
        # df_copy_5 = df_copy_5.reset_index(drop = True)   




        洗衣粉_市調結果購買率 = float(洗衣粉_市調結果購買率)
        # < 交叉變項 : 總裝置數 >
        all_distinct_xdid_of_one_item_list = list(set(df_copy_5_全通路["xdid"]))
        ALL_普及率_總裝置數_該品類總裝置數 = len(all_distinct_xdid_of_one_item_list)





        # # =================================== 8-10.指標_MAT_洗衣粉_銷售額(百萬元) ===================================
        # # =================================== 8-11.指標_MAT_洗衣粉_銷售量(千公升) ===================================
        # - 6.平均購買次數 - 兩張發票之不重複總發票張數
        洗衣粉_ALL_全通路_平均購買次數_兩張發票之不重複總發票張數 = list_of_invNum__by_xdid__with_multiple_invNum
        # - 6.平均購買次數 - 兩張發票之不重複總裝置數
        洗衣粉_ALL_全通路_平均購買次數_兩張發票之不重複總裝置數 = 平均購買次數_總裝置數_list_of_xdid__with_multiple_invNum
        # ALL_全通路_平均購買次數
        ALL_全通路_平均購買次數 = 洗衣粉_ALL_全通路_平均購買次數_兩張發票之不重複總發票張數 / 洗衣粉_ALL_全通路_平均購買次數_兩張發票之不重複總裝置數
        ALL_全通路_平均購買次數

        # - 4.每次購買金額 - 總金額
        ALL_洗衣粉_全通路_總銷額 = 洗衣粉_MAT_全通路總金額_Grand_Total
        # - 4.每次購買金額 - 不重複總發票張數
        ALL_洗衣粉_ALL_全通路_每次購買金額_不重複總發票張數 = []
        for i in range(0, len(df_corss_variable_distinct_invNum["invNum"])) :
            ALL_洗衣粉_ALL_全通路_每次購買金額_不重複總發票張數.append(df_corss_variable_distinct_invNum["invNum"][i])
        ALL_洗衣粉_ALL_全通路_每次購買金額_不重複總發票張數 = list(set(ALL_洗衣粉_ALL_全通路_每次購買金額_不重複總發票張數))

        ALL_洗衣粉_ALL_全通路_每次購買金額_不重複總發票張數 = len(ALL_洗衣粉_ALL_全通路_每次購買金額_不重複總發票張數) # 49344
        # ALL_全通路_每次購買金額
        ALL_全通路_每次購買金額 = ALL_洗衣粉_全通路_總銷額 / ALL_洗衣粉_ALL_全通路_每次購買金額_不重複總發票張數


        # - 5.每次購買量 - 總容量
        ALL_洗衣粉_全通路_總容量 = 洗衣粉_MAT_全通路總容量_Grand_Total
        # ALL_全通路_每次購買量
        ALL_全通路_每次購買量 = ALL_洗衣粉_全通路_總容量 / ALL_洗衣粉_ALL_全通路_每次購買金額_不重複總發票張數 #/ 1000




        # 該通路銷額佔比
        # ALL_全通路_銷額佔比
        ALL_全通路_銷額佔比 = ALL_洗衣粉_全通路_總銷額 / ALL_洗衣粉_全通路_總銷額
        # 單一通路_銷額佔比
        # 單一通路_銷額佔比 =                  / ALL_洗衣粉_全通路_總銷額
















        全台家戶數 = float(全台家戶數)
        洗衣粉_市調結果購買率 = float(洗衣粉_市調結果購買率)

        # ALL_全通路_銷額市佔率
        ALL_全通路_銷額市佔率 = ALL_洗衣粉_全通路_總銷額 / ALL_洗衣粉_全通路_總銷額
        # ALL_全通路_銷量市佔率
        ALL_全通路_銷量市佔率 = ALL_洗衣粉_全通路_總容量 / ALL_洗衣粉_全通路_總容量
        # ALL_全通路_每公升均價(元)
        ALL_全通路_每公升均價 = ALL_洗衣粉_全通路_總銷額 / ALL_洗衣粉_全通路_總容量 * 1000
        # ALL_全通路_每次購買金額(元)
        ALL_全通路_每次購買金額 = ALL_洗衣粉_全通路_總銷額 / ALL_洗衣粉_ALL_全通路_每次購買金額_不重複總發票張數
        # ALL_全通路_每次購買量(公升)
        ALL_全通路_每次購買量 = ALL_洗衣粉_全通路_總容量 / ALL_洗衣粉_ALL_全通路_每次購買金額_不重複總發票張數 / 1000
        # ALL_全通路_平均購買次數
        ALL_全通路_平均購買次數 = 洗衣粉_ALL_全通路_平均購買次數_兩張發票之不重複總發票張數 / 洗衣粉_ALL_全通路_平均購買次數_兩張發票之不重複總裝置數
        # ALL_全通路_每人平均花費
        ALL_全通路_每人平均花費 = ALL_全通路_每次購買金額 * ALL_全通路_平均購買次數
        # ALL_全通路_每人平均購買量
        ALL_全通路_每人平均購買量 = ALL_全通路_每次購買量 * ALL_全通路_平均購買次數


        ALL_洗衣粉_ALL_全通路_普及率_總裝置數 = ALL_普及率_總裝置數_該品類總裝置數 
        # ALL_全通路_普及率
        ALL_全通路_普及率 = (ALL_洗衣粉_ALL_全通路_普及率_總裝置數 / ALL_洗衣粉_ALL_全通路_普及率_總裝置數)



        # 洗衣粉_單一通路_普及率_總裝置數 = 
        # 單一通路_普及率_除以33915 = 洗衣粉_市調結果購買率 * (洗衣粉_單一通路_普及率_總裝置數 / ALL_洗衣粉_ALL_全通路_普及率_總裝置數)

        # ALL_全通路_銷售額(百萬元)
        ALL_全通路_銷售額 = 全台家戶數 * 洗衣粉_市調結果購買率 * ALL_全通路_平均購買次數 * ALL_全通路_每次購買金額 / 1000000 * (ALL_洗衣粉_全通路_總銷額 / ALL_洗衣粉_全通路_總銷額) * ALL_全通路_銷額市佔率
        # ALL_全通路_銷售量(千公升)
        ALL_全通路_銷售量 = 全台家戶數 * 洗衣粉_市調結果購買率 * ALL_全通路_平均購買次數 * ALL_全通路_每次購買量 / 1000 * (ALL_洗衣粉_全通路_總容量 / ALL_洗衣粉_全通路_總容量) * ALL_全通路_銷量市佔率


        # # 挑選適當欄位 : 只留11個指標當作column
        # 指標總表_1_2_3_4_5_6_7_8_9_10_11 = 指標總表_1_2_3_4_5_6_7_8_9_10_11[["自定義品牌", "系列(一匙靈專用)", "銷額市佔率", "銷量市佔率", "每公升均價(元)", "每次購買金額(元)", "每次購買量(公升)", "平均購買次數", "每人平均花費", "每人平均購買量", "普及率", "普及率_除以33915", "銷售額(百萬元)", "銷售量(千公升)"]]


        # # adding a row : Grand_Total
        # 指標總表_1_2_3_4_5_6_7_8_9_10_11.loc[-1] = ["-", "Grand Total", ALL_全通路_銷額市佔率, ALL_全通路_銷量市佔率, ALL_全通路_每公升均價, ALL_全通路_每次購買金額, ALL_全通路_每次購買量, ALL_全通路_平均購買次數, ALL_全通路_每人平均花費, ALL_全通路_每人平均購買量, ALL_全通路_普及率, ALL_全通路_普及率_除以33915, ALL_全通路_銷售額, ALL_全通路_銷售量]  # adding a row 
        # 指標總表_1_2_3_4_5_6_7_8_9_10_11.index = 指標總表_1_2_3_4_5_6_7_8_9_10_11.index + 1  # shifting index
        # 指標總表_1_2_3_4_5_6_7_8_9_10_11.sort_index(inplace=True) 











        #------------------------------------------------------------------------------------------------------------------------
        
        
              
        
        
        
        def YTD_全通路_個別_訴求(訴求_column, 訴求_value, A_1, A_2, 品類_list, 全台家戶數, 洗衣粉_市調結果購買率) :    
            

            try :
            
            
            






        #         global 全台家戶數
        #         global 洗衣粉_市調結果購買率

    #             global ALL_洗衣粉_全通路_總銷額
    #             global ALL_全通路_銷額市佔率

    #             global ALL_洗衣粉_全通路_總容量
    #             global ALL_全通路_銷量市佔率

    #             global ALL_全通路_每公升均價

    #             global ALL_洗衣粉_ALL_全通路_每次購買金額_不重複總發票張數
    #             global ALL_全通路_每次購買金額
    #             global ALL_全通路_每次購買量

    #             global 洗衣粉_ALL_全通路_平均購買次數_兩張發票之不重複總發票張數
    #             global 洗衣粉_ALL_全通路_平均購買次數_兩張發票之不重複總裝置數
    #             global ALL_全通路_平均購買次數

    #             global ALL_全通路_每人平均花費
    #             global ALL_全通路_每人平均購買量

                global ALL_洗衣粉_ALL_全通路_普及率_總裝置數


                df_某訴求_全通路 = df_全通路.loc[df_全通路[訴求_column] == 訴求_value, :].reset_index(drop = True)

        # =================================== 8-1.指標_MAT_洗衣粉_銷額市佔率 ===================================

                list_of_ALL_洗衣粉_全通路_總銷額 = []
                for i in range(0, len(df_某訴求_全通路["正確價錢"])) :
                    list_of_ALL_洗衣粉_全通路_總銷額.append(ALL_洗衣粉_全通路_總銷額)

                df_某訴求_全通路["總銷額"] = list_of_ALL_洗衣粉_全通路_總銷額

                df_某訴求_全通路["各系列銷額市佔率"] = df_某訴求_全通路["正確價錢"] / df_某訴求_全通路["總銷額"]



                # 各品牌x各系列_之_各系列正確價錢
                df_1 = df_某訴求_全通路.groupby(['自定義品牌', "系列(一匙靈專用)"])["正確價錢"].sum().reset_index(name = '品項_品牌_系列_正確價錢')
                # 各品牌Total銷額市佔率
                df_2 = df_某訴求_全通路.groupby(['自定義品牌'])["正確價錢"].sum().reset_index(name = '品項_品牌_系列_正確價錢')
                # concat
                df_指標1_銷額市佔率_正確價錢 = pd.concat([df_1, df_2], axis = 0).reset_index(drop = True)
                df_指標1_銷額市佔率_正確價錢["系列(一匙靈專用)"] = df_指標1_銷額市佔率_正確價錢["系列(一匙靈專用)"].fillna("Total")

                # 各品牌x各系列_之_各系列銷額市佔率
                df_1 = df_某訴求_全通路.groupby([訴求_column, '自定義品牌', "系列(一匙靈專用)"])["各系列銷額市佔率"].sum().reset_index(name = '銷額市佔率')
                # 各品牌Total銷額市佔率
                df_2 = df_某訴求_全通路.groupby([訴求_column, '自定義品牌'])["各系列銷額市佔率"].sum().reset_index(name = '銷額市佔率')
                # concat
                df_指標1_銷額市佔率 = pd.concat([df_1, df_2], axis = 0).reset_index(drop = True)
                df_指標1_銷額市佔率["系列(一匙靈專用)"] = df_指標1_銷額市佔率["系列(一匙靈專用)"].fillna("Total")

                # merge
                df_指標1_銷額市佔率 = pd.merge(df_指標1_銷額市佔率, df_指標1_銷額市佔率_正確價錢, on = ['自定義品牌', "系列(一匙靈專用)"], how = "outer")






                # 調整欄位順序
                df_指標1_銷額市佔率 = df_指標1_銷額市佔率.loc[: , [訴求_column, "自定義品牌", "系列(一匙靈專用)", "銷額市佔率", "品項_品牌_系列_正確價錢"]]


        #         # # 插入 訴求 SubTotal
        #         洗衣粉_MAT_訴求_全通路總金額_Grand_Total = 0

        #         for i in range(0, len(df_某訴求_全通路["正確價錢"])) :
        #             洗衣粉_MAT_訴求_全通路總金額_Grand_Total = 洗衣粉_MAT_訴求_全通路總金額_Grand_Total + float(df_某訴求_全通路["正確價錢"][i])

        #         df_指標1_銷額市佔率.loc[-1] = [訴求_value, '-', 'SubTotal', (洗衣粉_MAT_訴求_全通路總金額_Grand_Total / ALL_洗衣粉_全通路_總銷額), 洗衣粉_MAT_訴求_全通路總金額_Grand_Total]  # adding a row 
        #         df_指標1_銷額市佔率.index = df_指標1_銷額市佔率.index + 1  # shifting index
        #         df_指標1_銷額市佔率.sort_index(inplace=True) 






        # =================================== 8-2.指標_MAT_洗衣粉_銷量市佔率 ===================================



                list_of_ALL_洗衣粉_全通路_總容量 = []
                for i in range(0, len(df_某訴求_全通路["總容量"])) :
                    list_of_ALL_洗衣粉_全通路_總容量.append(ALL_洗衣粉_全通路_總容量)

                df_某訴求_全通路["最後總銷量"] = list_of_ALL_洗衣粉_全通路_總容量

                df_某訴求_全通路["各系列銷量市佔率"] = df_某訴求_全通路["總容量"] / df_某訴求_全通路["最後總銷量"]





        #         list_of_洗衣粉_MAT_全通路總容量_Grand_Total = []
        #         for i in range(0, len(df_某訴求_全通路["總容量"])) :
        #             list_of_洗衣粉_MAT_全通路總容量_Grand_Total.append(洗衣粉_MAT_全通路總容量_Grand_Total)

        #         df_某訴求_全通路["總銷量"] = list_of_洗衣粉_MAT_全通路總容量_Grand_Total

        #         df_某訴求_全通路["各系列銷量市佔率"] = df_某訴求_全通路["總容量"] / df_某訴求_全通路["總銷量"]



                # 各品牌x各系列_之_各系列總容量
                df_1 = df_某訴求_全通路.groupby(['自定義品牌', "系列(一匙靈專用)"])["總容量"].sum().reset_index(name = '品項_品牌_系列_總容量')
                # 各品牌Total銷量市佔率
                df_2 = df_某訴求_全通路.groupby(['自定義品牌'])["總容量"].sum().reset_index(name = '品項_品牌_系列_總容量')
                # concat
                df_指標2_銷量市佔率_總容量 = pd.concat([df_1, df_2], axis = 0).reset_index(drop = True)
                df_指標2_銷量市佔率_總容量["系列(一匙靈專用)"] = df_指標2_銷量市佔率_總容量["系列(一匙靈專用)"].fillna("Total")

                # 各品牌x各系列_之_各系列銷量市佔率
                df_1 = df_某訴求_全通路.groupby([訴求_column, '自定義品牌', "系列(一匙靈專用)"])["各系列銷量市佔率"].sum().reset_index(name = '銷量市佔率')
                # 各品牌Total銷量市佔率
                df_2 = df_某訴求_全通路.groupby([訴求_column, '自定義品牌'])["各系列銷量市佔率"].sum().reset_index(name = '銷量市佔率')
                # concat
                df_指標2_銷量市佔率 = pd.concat([df_1, df_2], axis = 0).reset_index(drop = True)
                df_指標2_銷量市佔率["系列(一匙靈專用)"] = df_指標2_銷量市佔率["系列(一匙靈專用)"].fillna("Total")

                # merge
                df_指標2_銷量市佔率 = pd.merge(df_指標2_銷量市佔率, df_指標2_銷量市佔率_總容量, on = ['自定義品牌', "系列(一匙靈專用)"], how = "outer")






                # 調整欄位順序
                df_指標2_銷量市佔率 = df_指標2_銷量市佔率.loc[: , [訴求_column, "自定義品牌", "系列(一匙靈專用)", "銷量市佔率", "品項_品牌_系列_總容量"]]


        #         # # 插入 訴求 Total
        #         洗衣粉_MAT_訴求_全通路總容量_Grand_Total = 0

        #         for i in range(0, len(df_某訴求_全通路["總容量"])) :
        #             洗衣粉_MAT_訴求_全通路總容量_Grand_Total = 洗衣粉_MAT_訴求_全通路總容量_Grand_Total + float(df_某訴求_全通路["總容量"][i])

        #         df_指標2_銷量市佔率.loc[-1] = [訴求_value, '-', 'SubTotal', (洗衣粉_MAT_訴求_全通路總容量_Grand_Total / 洗衣粉_MAT_全通路總容量_Grand_Total), 洗衣粉_MAT_訴求_全通路總容量_Grand_Total]  # adding a row 
        #         df_指標2_銷量市佔率.index = df_指標2_銷量市佔率.index + 1  # shifting index
        #         df_指標2_銷量市佔率.sort_index(inplace=True) 





                # # =================================== 8-3.指標_MAT_洗衣粉_每公升均價(元) ===================================
                dfs = [df_指標1_銷額市佔率, df_指標2_銷量市佔率]
                df_指標3_每公升均價 = reduce(lambda left,right: pd.merge(left, right, how = "outer", on = [訴求_column, '自定義品牌', "系列(一匙靈專用)"]), dfs)

                df_指標3_每公升均價["每公升均價(元)"] = df_指標3_每公升均價["品項_品牌_系列_正確價錢"] / df_指標3_每公升均價["品項_品牌_系列_總容量"] * 1000
                df_指標3_每公升均價





                # # =================================== 8-4.指標_MAT_洗衣粉_每次購買金額(元) ===================================
                # # =================================== 8-5.指標_MAT_洗衣粉_每次購買量(公升) ===================================
                df_copy = df_全通路
                df_copy = df_copy.reset_index(drop = True)

                df_corss_variable_distinct_invNum = df_copy.loc[:, ["xdid", "invNum", "自定義品牌", "系列(一匙靈專用)"]]



                df_copy = df_全通路
                df_copy = df_copy.reset_index(drop = True)


                df_copy = df_copy.loc[df_copy[訴求_column] == 訴求_value, :].reset_index(drop = True)


                #----------------------------------------------------------------------------------
                df_corss_variable_distinct_invNum = df_copy.loc[:, ["xdid", "invNum", "自定義品牌", "系列(一匙靈專用)", 訴求_column, "正確價錢", "總容量"]]
                df_corss_variable_distinct_invNum['自定義品牌_系列_訴求'] = df_corss_variable_distinct_invNum[['自定義品牌', '系列(一匙靈專用)', 訴求_column]].apply(lambda x: ','.join(x), axis=1)
                #----------------------------------------------------------------------------------

                # 訴求各品牌各系列
                df_自定義品牌_系列_訴求 = df_corss_variable_distinct_invNum[['自定義品牌_系列_訴求']].drop_duplicates().reset_index(drop = True)
                df_自定義品牌_系列_訴求["不重複的發票編號"] = ""
                df_自定義品牌_系列_訴求["總發票張數(不重複)"] = ""

                for i in range(0, len(df_自定義品牌_系列_訴求["自定義品牌_系列_訴求"])) :
                    不重複的發票編號_list = []
                    for j in range(0, len(df_corss_variable_distinct_invNum["自定義品牌_系列_訴求"])) :
                        if df_自定義品牌_系列_訴求["自定義品牌_系列_訴求"][i] == df_corss_variable_distinct_invNum["自定義品牌_系列_訴求"][j] :
                            不重複的發票編號_list.append(df_corss_variable_distinct_invNum["invNum"][j])
                        else :
                            None
                    df_自定義品牌_系列_訴求["不重複的發票編號"][i] = list(set(不重複的發票編號_list))
                    df_自定義品牌_系列_訴求["總發票張數(不重複)"][i] = len(list(set(不重複的發票編號_list)))
                    不重複的發票編號_list = []
                #--------------
                # 各品牌Total    
                df_自定義品牌_系列_訴求_Total = df_corss_variable_distinct_invNum[['自定義品牌']].drop_duplicates().reset_index(drop = True)
                df_自定義品牌_系列_訴求_Total["系列(一匙靈專用)"] = "Total"
                # 訴求
                df_自定義品牌_系列_訴求_Total[訴求_column] = 訴求_value

                df_自定義品牌_系列_訴求_Total["不重複的發票編號"] = ""
                df_自定義品牌_系列_訴求_Total["總發票張數(不重複)"] = ""    

                for i in range(0, len(df_自定義品牌_系列_訴求_Total["自定義品牌"])) :
                    不重複的發票編號_list = []
                    for j in range(0, len(df_corss_variable_distinct_invNum["自定義品牌"])) :
                        if df_自定義品牌_系列_訴求_Total["自定義品牌"][i] == df_corss_variable_distinct_invNum["自定義品牌"][j] :
                            不重複的發票編號_list.append(df_corss_variable_distinct_invNum["invNum"][j])
                        else :
                            None
                    df_自定義品牌_系列_訴求_Total["不重複的發票編號"][i] = list(set(不重複的發票編號_list))
                    df_自定義品牌_系列_訴求_Total["總發票張數(不重複)"][i] = len(list(set(不重複的發票編號_list)))
                    不重複的發票編號_list = []
                #----------------------------------------------------------------------------------            
                # 彙整
                df_自定義品牌_系列_訴求["自定義品牌"] = df_自定義品牌_系列_訴求["自定義品牌_系列_訴求"].apply(lambda x: x.split(',')[0])
                df_自定義品牌_系列_訴求["系列(一匙靈專用)"] = df_自定義品牌_系列_訴求["自定義品牌_系列_訴求"].apply(lambda x: x.split(',')[1])
                df_自定義品牌_系列_訴求[訴求_column] = df_自定義品牌_系列_訴求["自定義品牌_系列_訴求"].apply(lambda x: x.split(',')[2])

                df_自定義品牌_系列_訴求_看各系列不重複發票數 = df_自定義品牌_系列_訴求[[訴求_column, "自定義品牌", "系列(一匙靈專用)", "總發票張數(不重複)"]]

                df_自定義品牌_系列_訴求_看各品牌Total不重複發票數 = df_自定義品牌_系列_訴求_Total[[訴求_column, "自定義品牌", "系列(一匙靈專用)", "總發票張數(不重複)"]]
                #----------------------------------------------------------------------------------
                # 各品牌x各系列
                df_1 = df_自定義品牌_系列_訴求_看各系列不重複發票數
                # 各品牌
                df_2 = df_自定義品牌_系列_訴求_看各品牌Total不重複發票數
                # 總表
                df_自定義品牌_系列_訴求_不重複發票數_總表 = pd.concat([df_1, df_2], axis = 0).reset_index(drop = True)
        #         #----------------------------------------------------------------------------------
        #         # 插入 訴求 SubTotal
        #         #----------------------------------------------------------------------------------
        #         df_corss_variable_distinct_invNum = df_copy.loc[:, ["xdid", "invNum", "自定義品牌", "系列(一匙靈專用)", 訴求_column, "正確價錢", "總容量"]]

        #         洗衣粉_全通路_每次購買金額_不重複總發票張數 = []
        #         for i in range(0, len(df_corss_variable_distinct_invNum["invNum"])) :
        #             洗衣粉_全通路_每次購買金額_不重複總發票張數.append(df_corss_variable_distinct_invNum["invNum"][i])
        #         洗衣粉_全通路_每次購買金額_不重複總發票張數 = len(list(set(洗衣粉_全通路_每次購買金額_不重複總發票張數)))

        #         df_自定義品牌_系列_訴求_不重複發票數_總表.loc[-1] = [訴求_value, '-', 'SubTotal', 洗衣粉_全通路_每次購買金額_不重複總發票張數]  # adding a row 
        #         df_自定義品牌_系列_訴求_不重複發票數_總表.index = df_自定義品牌_系列_訴求_不重複發票數_總表.index + 1  # shifting index
        #         df_自定義品牌_系列_訴求_不重複發票數_總表.sort_index(inplace=True) 

                #----------------------------------------------------------------------------------    
                df_指標4_每次購買金額_指標5_每次購買量 = pd.merge(df_指標3_每公升均價, df_自定義品牌_系列_訴求_不重複發票數_總表, on = [訴求_column, '自定義品牌', "系列(一匙靈專用)"], how = "outer")
                df_指標4_每次購買金額_指標5_每次購買量["每次購買金額(元)"] = df_指標4_每次購買金額_指標5_每次購買量["品項_品牌_系列_正確價錢"] / df_指標4_每次購買金額_指標5_每次購買量["總發票張數(不重複)"]
                df_指標4_每次購買金額_指標5_每次購買量["每次購買量(公升)"] = df_指標4_每次購買金額_指標5_每次購買量["品項_品牌_系列_總容量"] / df_指標4_每次購買金額_指標5_每次購買量["總發票張數(不重複)"] / 1000
                #----------------------------------------------------------------------------------







                # # =================================== 8-6.指標_MAT_洗衣粉_平均購買次數 ===================================
                # 這裡有篩選條件需要選到 "品項" : "洗衣粉" !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!

                df_copy_2 = df_整理
                df_copy_3 = df_copy_2
                df_copy_4 = df_copy_2


        #         df_copy_2 = df_copy_2.loc[df_copy_2[訴求_column] == 訴求_value, :].reset_index(drop = True)





                # =================================== 挑有買過兩張發票的裝置 xdid ===================================
                #---------------------------------------------------------------------------------------------------------

                #---------------------------------------------------------------------------------------------------------
                # for df_copy_2 : 要找到 總裝置數 的 那些"裝置(xdid)"候選人名單
                # =================================== 0. 挑有買過2張以上發票的裝置 =================================== 
                # 挑有買過兩張發票的裝置

                df_all_of_xdid_with_multiple_invNum_list = df_copy_2


                df_all_of_xdid_with_multiple_invNum_list = df_copy_2.loc[:, [訴求_column, "xdid", "invNum"]]
                # 將裝置數missing的刪除
                df_all_of_xdid_with_multiple_invNum_list = df_all_of_xdid_with_multiple_invNum_list.loc[df_all_of_xdid_with_multiple_invNum_list["xdid"] != "missing" ]
                df_all_of_xdid_with_multiple_invNum_list = df_all_of_xdid_with_multiple_invNum_list.drop_duplicates().reset_index(drop = True)

                df_all_of_xdid_with_multiple_invNum_list = df_all_of_xdid_with_multiple_invNum_list.groupby(["xdid"])['invNum'].nunique()

                df_all_of_xdid_with_multiple_invNum_list = df_all_of_xdid_with_multiple_invNum_list[df_all_of_xdid_with_multiple_invNum_list > 1]
                df_all_of_xdid_with_multiple_invNum_list = df_all_of_xdid_with_multiple_invNum_list.to_frame().reset_index()
                # #---------------------------------------------------------------------------------------------------------
                # < 交叉變項 : 總裝置數 的 那些"裝置(xdid)"候選人名單 >
                df_all_of_xdid_with_multiple_invNum_list = list(set(df_all_of_xdid_with_multiple_invNum_list["xdid"]))

                #---------------------------------------------------------------------------------------------------------
                # for df_copy_3 : 要從原始資料 找到 符合那些裝置候選人名單 & 符合後續條件 的那些row



                df_copy_3 = df_copy_3.loc[df_copy_3[訴求_column] == 訴求_value, :].reset_index(drop = True)



                # < 交叉變項 : 總裝置數 的 那些"裝置(xdid)"候選人名單 ；待會兒要加上 原本1~5的篩選條件 再得到 df，最後才要groupby >
                df_copy_3 = df_copy_3[df_copy_3['xdid'].isin(df_all_of_xdid_with_multiple_invNum_list)]
                # =================================== 1. 處理與否 = 1 =================================== 
                df_copy_3 = df_copy_3[df_copy_3["處理與否"] == 1]
                # =================================== 2. 總容量有值 且 >=1 =================================== 
                df_copy_3 = df_copy_3[np.isfinite(df_copy_3['總容量'])]
                df_copy_3 = df_copy_3[df_copy_3['總容量'] >= 0]
                # =================================== 3.時間_MAT ===================================
                df_copy_3 = df_copy_3[(df_copy_3['invDate_datetime'] >= str(A_1)) & (df_copy_3['invDate_datetime'] < str(A_2))]
                # =================================== 4.品類_洗衣粉 - < 至少有一張發票有買到該品項 > ===================================
                df_copy_3 = df_copy_3[df_copy_3["品類_list"] == 1]
                # =================================== 5.通路_全通路 =================================== 
                df_copy_3 = df_copy_3 #全通路
                # # df_copy_3 = df_copy_3[df_copy_3["通路"] == "全聯"] #全聯
                # # reset_index
                # df_copy_3 = df_copy_3.reset_index(drop = True)   


                # Grand Total
                平均購買次數_總裝置數_list_of_xdid__with_multiple_invNum = len(list(set(df_copy_3["xdid"])))



                # Count unique values with pandas per groups
                df_平均購買次數_總裝置數 = df_copy_3.groupby([訴求_column, "自定義品牌", "系列(一匙靈專用)"])['xdid'].nunique()










                #---------------------------------------------------------------------------------------------------------
                # for df_copy_4 : 要找到總發票張數 : 1.挑有2張發票的裝置  2.其中有買到該品項的發票皆列入

                # 挑有買過兩張發票的裝置

                df_all_of_xdid_with_multiple_invNum_list = df_copy_2

                df_all_of_xdid_with_multiple_invNum_list = df_copy_2.loc[:, [訴求_column, "xdid", "invNum"]]
                # 將裝置數missing的保留
                # df_all_of_xdid_with_multiple_invNum_list = df_all_of_xdid_with_multiple_invNum_list.loc[df_all_of_xdid_with_multiple_invNum_list["xdid"] != "missing" ]
                df_all_of_xdid_with_multiple_invNum_list = df_all_of_xdid_with_multiple_invNum_list.drop_duplicates().reset_index(drop = True)

                df_all_of_xdid_with_multiple_invNum_list = df_all_of_xdid_with_multiple_invNum_list.groupby(["xdid"])['invNum'].nunique()

                df_all_of_xdid_with_multiple_invNum_list = df_all_of_xdid_with_multiple_invNum_list[df_all_of_xdid_with_multiple_invNum_list > 1]
                df_all_of_xdid_with_multiple_invNum_list = df_all_of_xdid_with_multiple_invNum_list.to_frame().reset_index()


                # #---------------------------------------------------------------------------------------------------------
                # < 交叉變項 : 總裝置數 的 那些"裝置(xdid)"候選人名單 >
                list_of_xdid__with_multiple_invNum = list(set(df_all_of_xdid_with_multiple_invNum_list["xdid"]))



                df_copy_4 = df_copy_4[df_copy_4['xdid'].isin(list_of_xdid__with_multiple_invNum)]


                df_copy_4 = df_copy_4.loc[df_copy_4[訴求_column] == 訴求_value, :].reset_index(drop = True)        



                # < 交叉變項 : 總裝置數 的 那些"裝置(xdid)"候選人名單 加上 原本1~5的篩選條件所得到的 df，接下來要groupby了 >
                # =================================== 1. 處理與否 = 1 =================================== 
                df_copy_4 = df_copy_4[df_copy_4["處理與否"] == 1]
                # =================================== 2. 總容量有值 且 >=1 =================================== 
                df_copy_4 = df_copy_4[np.isfinite(df_copy_4['總容量'])]
                df_copy_4 = df_copy_4[df_copy_4['總容量'] >= 0]
                # =================================== 3.時間_MAT ===================================    
                df_copy_4 = df_copy_4[(df_copy_4['invDate_datetime'] >= str(A_1)) & (df_copy_4['invDate_datetime'] < str(A_2))]
                # =================================== 4.品類_洗衣粉 - < 有買到該品項的皆列入 > ===================================
                df_copy_4 = df_copy_4[df_copy_4["品類_list"] == 1]

                # =================================== 5.通路_全通路 =================================== 
                df_copy_4 = df_copy_4 #全通路
                # df_copy_4 = df_copy_4[df_copy_4["通路"] == "全聯"] #全聯
                # reset_index
                df_copy_4 = df_copy_4.reset_index(drop = True)   


                # 平均購買次數_總發票張數_(Grand_Total)
                list_of_invNum__by_xdid__with_multiple_invNum = len(list(set(df_copy_4["invNum"])))



                # Count unique values with pandas per groups
                df_平均購買次數_總發票張數 = df_copy_4.groupby([訴求_column, "自定義品牌", "系列(一匙靈專用)"])['invNum'].nunique()

                # # =================================== 8-6.指標_MAT_洗衣粉_平均購買次數 ===================================
                df_平均購買次數_總發票張數 = df_平均購買次數_總發票張數.to_frame().reset_index()
                df_平均購買次數_總裝置數 = df_平均購買次數_總裝置數.to_frame().reset_index()

                df_平均購買次數 = pd.merge(df_平均購買次數_總發票張數, df_平均購買次數_總裝置數, on = [訴求_column, "自定義品牌", "系列(一匙靈專用)"], how = "outer")
                df_平均購買次數["平均購買次數"] = df_平均購買次數["invNum"] / df_平均購買次數["xdid"]




                # 各品牌_Total_平均購買次數
                df_平均購買次數_total = pd.DataFrame()
                list_平均購買次數_自定義品牌 = list(set(df_平均購買次數['自定義品牌']))
                平均購買次數_系列_total = []
                平均購買次數_訴求_total = []
                for i in range(0, len(list_平均購買次數_自定義品牌)) :
                    平均購買次數_系列_total.append("Total")
                    平均購買次數_訴求_total.append(訴求_value)

                df_平均購買次數_total["自定義品牌"] = list_平均購買次數_自定義品牌
                df_平均購買次數_total["系列(一匙靈專用)"] = 平均購買次數_系列_total
                # 訴求
        #         df_平均購買次數_total[訴求_column] = 訴求_value 
                df_平均購買次數_total[訴求_column] = 平均購買次數_訴求_total

                df_平均購買次數_total = pd.merge(df_平均購買次數_total, df_copy_3.groupby([訴求_column, "自定義品牌"])['xdid'].nunique().to_frame(), on = ["自定義品牌"])
                df_平均購買次數_total = pd.merge(df_平均購買次數_total, df_copy_4.groupby([訴求_column, "自定義品牌"])['invNum'].nunique().to_frame(), on = ["自定義品牌"])
                df_平均購買次數_total["平均購買次數"] = df_平均購買次數_total["invNum"] / df_平均購買次數_total["xdid"]
                # concat 品牌_各系列 和 品牌_total
                df_指標6_平均購買次數 = pd.concat([df_平均購買次數, df_平均購買次數_total], axis = 0)












        # #         #----------------------------------------------------------------------------------
        # #         # 插入 訴求 SubTotal
        # #         #----------------------------------------------------------------------------------
        # #         df_corss_variable_distinct_invNum = df_copy.loc[:, ["xdid", "invNum", "自定義品牌", "系列(一匙靈專用)", 訴求_column, "正確價錢", "總容量"]]

        # #         洗衣粉_全通路_每次購買金額_不重複總發票張數 = []
        # #         for i in range(0, len(df_corss_variable_distinct_invNum["invNum"])) :
        # #             洗衣粉_全通路_每次購買金額_不重複總發票張數.append(df_corss_variable_distinct_invNum["invNum"][i])
        # #         洗衣粉_全通路_每次購買金額_不重複總發票張數 = len(list(set(洗衣粉_全通路_每次購買金額_不重複總發票張數)))

        # #         df_自定義品牌_系列_訴求_不重複發票數_總表.loc[-1] = [訴求_value, '-', 'SubTotal', 洗衣粉_全通路_每次購買金額_不重複總發票張數]  # adding a row 
        # #         df_自定義品牌_系列_訴求_不重複發票數_總表.index = df_自定義品牌_系列_訴求_不重複發票數_總表.index + 1  # shifting index
        # #         df_自定義品牌_系列_訴求_不重複發票數_總表.sort_index(inplace=True) 

        # #         #----------------------------------------------------------------------------------    
        # #         df_指標4_每次購買金額_指標5_每次購買量 = pd.merge(df_指標3_每公升均價, df_自定義品牌_系列_訴求_不重複發票數_總表, on = [訴求_column, '自定義品牌', "系列(一匙靈專用)"])
        # #         df_指標4_每次購買金額_指標5_每次購買量["每次購買金額(元)"] = df_指標4_每次購買金額_指標5_每次購買量["品項_品牌_系列_正確價錢"] / df_指標4_每次購買金額_指標5_每次購買量["總發票張數(不重複)"]
        # #         df_指標4_每次購買金額_指標5_每次購買量["每次購買量(公升)"] = df_指標4_每次購買金額_指標5_每次購買量["品項_品牌_系列_總容量"] / df_指標4_每次購買金額_指標5_每次購買量["總發票張數(不重複)"] / 1000
        # #         #----------------------------------------------------------------------------------



        # #         # 指標總表_1_2_3_4_5_6_7_8 = pd.merge(指標總表_1_2_3_4_5, df_指標6_平均購買次數, on = ['自定義品牌', "系列(一匙靈專用)"])


                dfs = [df_指標4_每次購買金額_指標5_每次購買量, df_指標6_平均購買次數]
                指標總表_1_2_3_4_5_6_7_8 = reduce(lambda left,right: pd.merge(left, right, how = "outer", on = [訴求_column, '自定義品牌', "系列(一匙靈專用)"]), dfs)

                # =============================================================================================================================
                # 在算 "df_指標 7 _每人平均花費" 之前 :
                # 手動修改的例外 : 
                #    如果銷額、銷量有值 
                # -> 從 6.平均購買次數開始，如果因為分母的"總裝置數"為0而造成後面運算結果為NA， 就要把平均購買次數補成"1"


                指標總表_1_2_3_4_5_6_7_8.loc[ (指標總表_1_2_3_4_5_6_7_8["平均購買次數"].isnull() == True)  & ((指標總表_1_2_3_4_5_6_7_8['銷額市佔率'] != None) | (指標總表_1_2_3_4_5_6_7_8['銷量市佔率'] != None)), ["平均購買次數"]] = 1

                # =============================================================================================================================

                # df_指標7_每人平均花費
                指標總表_1_2_3_4_5_6_7_8["每人平均花費"] = 指標總表_1_2_3_4_5_6_7_8["每次購買金額(元)"] * 指標總表_1_2_3_4_5_6_7_8["平均購買次數"]
                # df_指標8_每人平均購買量
                指標總表_1_2_3_4_5_6_7_8["每人平均購買量"] = 指標總表_1_2_3_4_5_6_7_8["每次購買量(公升)"] * 指標總表_1_2_3_4_5_6_7_8["平均購買次數"]









                # # =================================== 8-9.指標_MAT_洗衣粉_普及率 ===================================
                # # 總裝置數
                # =================================== 挑有買過兩張發票的裝置 xdid ===================================
                df_copy_5 = df_copy_2
                #---------------------------------------------------------------------------------------------------------

                #---------------------------------------------------------------------------------------------------------
                # for df_copy_5 : 要找到 總裝置數 的 那些"裝置(xdid)"候選人名單
                # =================================== 0. 總裝置數 =================================== 


                df_copy_5 = df_copy_5.loc[df_copy_5[訴求_column] == 訴求_value, :].reset_index(drop = True)



                # < 交叉變項 : 總裝置數 >
                df_copy_5 = df_copy_5[df_copy_5['xdid'] != "missing"]
                # =================================== 1. 處理與否 = 1 =================================== 
                df_copy_5 = df_copy_5[df_copy_5["處理與否"] == 1]
                # =================================== 2. 總容量有值 且 >=1 =================================== 
                df_copy_5 = df_copy_5[np.isfinite(df_copy_5['總容量'])]
                df_copy_5 = df_copy_5[df_copy_5['總容量'] >= 0]
                # =================================== 3.時間_MAT ===================================
                df_copy_5 = df_copy_5[(df_copy_5['invDate_datetime'] >= str(A_1)) & (df_copy_5['invDate_datetime'] < str(A_2))]
                # =================================== 4.品類_洗衣粉 - < 至少有一張發票有買到該品項 > ===================================
                df_copy_5 = df_copy_5[df_copy_5["品類_list"] == 1]
                # =================================== 5.通路_全通路 =================================== 
                # 全通路
                df_copy_5_全通路 = df_copy_5 
                # 單一通路
                # # df_copy_5_單一通路 = df_copy_5[df_copy_5["通路"] == "全聯"] #全聯
                # # reset_index
                # df_copy_5 = df_copy_5.reset_index(drop = True)   

    #             # ---------------------------------------------------------------------------------------------------
    #             all_distinct_xdid_of_one_item_list = list(set(df_copy_5_全通路["xdid"]))
    #             普及率_總裝置數_該品類總裝置數 = len(all_distinct_xdid_of_one_item_list)
    #             洗衣粉_全通路_普及率_總裝置數 = 普及率_總裝置數_該品類總裝置數 
    #             # ---------------------------------------------------------------------------------------------------


                洗衣粉_市調結果購買率 = float(洗衣粉_市調結果購買率)
                # < 交叉變項 : 總裝置數 >
        #         all_distinct_xdid_of_one_item_list = list(set(df_copy_5_全通路["xdid"]))
        #         普及率_總裝置數_該品類總裝置數 = len(all_distinct_xdid_of_one_item_list)
                ALL_洗衣粉_ALL_全通路_普及率_總裝置數 = ALL_洗衣粉_ALL_全通路_普及率_總裝置數

                # Count unique values with pandas per groups
                df_指標9_普及率_總裝置數 = df_copy_5_全通路.groupby([訴求_column, "自定義品牌", "系列(一匙靈專用)"])['xdid'].nunique().to_frame()
                df_指標9_普及率_總裝置數['普及率'] = (df_指標9_普及率_總裝置數['xdid'] / ALL_洗衣粉_ALL_全通路_普及率_總裝置數)
        #         df_指標9_普及率_總裝置數['普及率_除以33915'] = 洗衣粉_市調結果購買率 * (df_指標9_普及率_總裝置數['xdid'] / 33915)
                df_指標9_普及率_總裝置數 = df_指標9_普及率_總裝置數.reset_index()


                # 各品牌 Total
                df_普及率_各品牌_Total_總裝置數 = df_copy_5_全通路.groupby([訴求_column, "自定義品牌"])['xdid'].nunique().to_frame()

                普及率_各品牌_Total_總裝置數_list = []
                for i in range(0, len(df_普及率_各品牌_Total_總裝置數["xdid"])) :
                    普及率_各品牌_Total_總裝置數_list.append("Total")
                df_普及率_各品牌_Total_總裝置數["系列(一匙靈專用)"] = 普及率_各品牌_Total_總裝置數_list

                df_普及率_各品牌_Total_總裝置數['普及率'] = (df_普及率_各品牌_Total_總裝置數['xdid'] / ALL_洗衣粉_ALL_全通路_普及率_總裝置數)
        #         df_普及率_各品牌_Total_總裝置數['普及率_除以33915'] = 洗衣粉_市調結果購買率 * (df_普及率_各品牌_Total_總裝置數['xdid'] / 33915)
                df_普及率_各品牌_Total_總裝置數 = df_普及率_各品牌_Total_總裝置數.reset_index()


                # concat
                df_指標9_普及率_總裝置數 = pd.concat([df_指標9_普及率_總裝置數, df_普及率_各品牌_Total_總裝置數], axis = 0)
                df_指標9_普及率_總裝置數
                # 總表 - merge
                指標總表_1_2_3_4_5_6_7_8_9_10_11 = pd.merge(指標總表_1_2_3_4_5_6_7_8, df_指標9_普及率_總裝置數, on = [訴求_column, '自定義品牌', "系列(一匙靈專用)"], how = "outer")



                # =============================================================================================================================
                # 在算 "df_指標 9 _普及率" 的下一個指標 之前 :
                # 手動修改的例外 : 
                #    如果銷額、銷量有值 
                # -> 從 9.普及率 開始，如果因為空白的"裝置編號"而造成後面運算結果為NA， 就要把 普及率 強制改成"0"


                指標總表_1_2_3_4_5_6_7_8_9_10_11.loc[ (指標總表_1_2_3_4_5_6_7_8_9_10_11["普及率"].isnull() == True)  & ((指標總表_1_2_3_4_5_6_7_8_9_10_11['銷額市佔率'] != None) | (指標總表_1_2_3_4_5_6_7_8_9_10_11['銷量市佔率'] != None)), ["普及率"]] = 0

                # =============================================================================================================================







                洗衣粉_MAT_全通路總金額_Grand_Total = 0
                list_of_洗衣粉_MAT_全通路總金額_Grand_Total = []
                for i in range(0, len(df_某訴求_全通路["正確價錢"])) :
                    洗衣粉_MAT_全通路總金額_Grand_Total = 洗衣粉_MAT_全通路總金額_Grand_Total + float(df_某訴求_全通路["正確價錢"][i])



                洗衣粉_MAT_全通路總容量_Grand_Total = 0
                list_of_洗衣粉_MAT_全通路總容量_Grand_Total = []
                for i in range(0, len(df_某訴求_全通路["總容量"])) :
                    洗衣粉_MAT_全通路總容量_Grand_Total = 洗衣粉_MAT_全通路總容量_Grand_Total + float(df_某訴求_全通路["總容量"][i])




                # # =================================== 8-10.指標_MAT_洗衣粉_銷售額(百萬元) ===================================
                # # =================================== 8-11.指標_MAT_洗衣粉_銷售量(千公升) ===================================
                # - 6.平均購買次數 - 兩張發票之不重複總發票張數
                洗衣粉_全通路_平均購買次數_兩張發票之不重複總發票張數 = list_of_invNum__by_xdid__with_multiple_invNum
                # - 6.平均購買次數 - 兩張發票之不重複總裝置數
                洗衣粉_全通路_平均購買次數_兩張發票之不重複總裝置數 = 平均購買次數_總裝置數_list_of_xdid__with_multiple_invNum
                # 全通路_平均購買次數
                全通路_平均購買次數 = 洗衣粉_全通路_平均購買次數_兩張發票之不重複總發票張數 / 洗衣粉_全通路_平均購買次數_兩張發票之不重複總裝置數
                全通路_平均購買次數

                # - 4.每次購買金額 - 總金額
                洗衣粉_全通路_總銷額 = 洗衣粉_MAT_全通路總金額_Grand_Total
                # - 4.每次購買金額 - 不重複總發票張數
                洗衣粉_全通路_每次購買金額_不重複總發票張數 = []
                for i in range(0, len(df_corss_variable_distinct_invNum["invNum"])) :
                    洗衣粉_全通路_每次購買金額_不重複總發票張數.append(df_corss_variable_distinct_invNum["invNum"][i])
                洗衣粉_全通路_每次購買金額_不重複總發票張數 = list(set(洗衣粉_全通路_每次購買金額_不重複總發票張數))

                洗衣粉_全通路_每次購買金額_不重複總發票張數 = len(洗衣粉_全通路_每次購買金額_不重複總發票張數) # 49344
                # 全通路_每次購買金額
                全通路_每次購買金額 = 洗衣粉_全通路_總銷額 / 洗衣粉_全通路_每次購買金額_不重複總發票張數


                # - 5.每次購買量 - 總容量
                洗衣粉_全通路_總容量 = 洗衣粉_MAT_全通路總容量_Grand_Total
                # 全通路_每次購買量
                全通路_每次購買量 = 洗衣粉_全通路_總容量 / 洗衣粉_全通路_每次購買金額_不重複總發票張數 #/ 1000




                # 該通路銷額佔比
                # 全通路_銷額佔比
                全通路_銷額佔比 = 洗衣粉_全通路_總銷額 / 洗衣粉_全通路_總銷額
                # 單一通路_銷額佔比
                # 單一通路_銷額佔比 =                  / 洗衣粉_全通路_總銷額


                # 全通路_銷量
                全通路_銷量佔比 = 洗衣粉_全通路_總容量 / 洗衣粉_全通路_總容量













                全台家戶數 = float(全台家戶數)
                洗衣粉_市調結果購買率 = float(洗衣粉_市調結果購買率)

                # 全通路_銷額市佔率
                全通路_銷額市佔率 = 洗衣粉_全通路_總銷額 / ALL_洗衣粉_全通路_總銷額
                # 全通路_銷量市佔率
                全通路_銷量市佔率 = 洗衣粉_全通路_總容量 / ALL_洗衣粉_全通路_總容量
                # 全通路_每公升均價(元)
                全通路_每公升均價 = 洗衣粉_全通路_總銷額 / 洗衣粉_全通路_總容量 * 1000
                # 全通路_每次購買金額(元)
                全通路_每次購買金額 = 洗衣粉_全通路_總銷額 / 洗衣粉_全通路_每次購買金額_不重複總發票張數
                # 全通路_每次購買量(公升)
                全通路_每次購買量 = 洗衣粉_全通路_總容量 / 洗衣粉_全通路_每次購買金額_不重複總發票張數 / 1000
                # 全通路_平均購買次數
                全通路_平均購買次數 = 洗衣粉_全通路_平均購買次數_兩張發票之不重複總發票張數 / 洗衣粉_全通路_平均購買次數_兩張發票之不重複總裝置數
                # 全通路_每人平均花費
                全通路_每人平均花費 = 全通路_每次購買金額 * 全通路_平均購買次數
                # 全通路_每人平均購買量
                全通路_每人平均購買量 = 全通路_每次購買量 * 全通路_平均購買次數


                # < 交叉變項 : 總裝置數 >
                all_distinct_xdid_of_one_item_list = list(set(df_copy_5_全通路["xdid"]))
                普及率_總裝置數_該品類總裝置數 = len(all_distinct_xdid_of_one_item_list)
                洗衣粉_全通路_普及率_總裝置數 = 普及率_總裝置數_該品類總裝置數
                # 全通路_普及率
                全通路_普及率 = (洗衣粉_全通路_普及率_總裝置數 / ALL_洗衣粉_ALL_全通路_普及率_總裝置數)



                # 洗衣粉_單一通路_普及率_總裝置數 = 
                # 單一通路_普及率_除以33915 = 洗衣粉_市調結果購買率 * (洗衣粉_單一通路_普及率_總裝置數 / 洗衣粉_全通路_普及率_總裝置數)

                # 全通路_銷售額(百萬元)
                全通路_銷售額 = 全台家戶數 * 洗衣粉_市調結果購買率 * ALL_全通路_平均購買次數 * ALL_全通路_每次購買金額 / 1000000 * (洗衣粉_全通路_總銷額 / 洗衣粉_全通路_總銷額) * 全通路_銷額市佔率  
                # 全通路_銷售量(千公升)
                全通路_銷售量 = 全台家戶數 * 洗衣粉_市調結果購買率 * ALL_全通路_平均購買次數 * ALL_全通路_每次購買量 / 1000 * (洗衣粉_全通路_總容量 / 洗衣粉_全通路_總容量) * 全通路_銷量市佔率

                # 銷售額(百萬元)
                指標總表_1_2_3_4_5_6_7_8_9_10_11["銷售額(百萬元)"] = 全台家戶數 * 洗衣粉_市調結果購買率 * ALL_全通路_平均購買次數 * ALL_全通路_每次購買金額 / 1000000 * 全通路_銷額佔比 * 指標總表_1_2_3_4_5_6_7_8_9_10_11["銷額市佔率"]   
                # 銷售量(千公升)
                指標總表_1_2_3_4_5_6_7_8_9_10_11["銷售量(千公升)"] = 全台家戶數 * 洗衣粉_市調結果購買率 * ALL_全通路_平均購買次數 * ALL_全通路_每次購買量 / 1000 * 全通路_銷量佔比 * 指標總表_1_2_3_4_5_6_7_8_9_10_11["銷量市佔率"]   

                # # =================================== 8-12.MAT_洗衣粉_加入Grand_Total ===================================

                # 在加入Grand_Total之前 : sort_values
                指標總表_1_2_3_4_5_6_7_8_9_10_11 = 指標總表_1_2_3_4_5_6_7_8_9_10_11.sort_values(by=['銷額市佔率'], ascending=[False])
                指標總表_1_2_3_4_5_6_7_8_9_10_11 = 指標總表_1_2_3_4_5_6_7_8_9_10_11.reset_index(drop=True) 

                # 挑選適當欄位 : 只留11個指標當作column
                指標總表_1_2_3_4_5_6_7_8_9_10_11 = 指標總表_1_2_3_4_5_6_7_8_9_10_11[[訴求_column, "自定義品牌", "系列(一匙靈專用)", "銷額市佔率", "銷量市佔率", "每公升均價(元)", "每次購買金額(元)", "每次購買量(公升)", "平均購買次數", "每人平均花費", "每人平均購買量", "普及率", "銷售額(百萬元)", "銷售量(千公升)"]]


                # adding a row : SubTotal
                指標總表_1_2_3_4_5_6_7_8_9_10_11.loc[-1] = [訴求_value, "-", "SubTotal", 全通路_銷額市佔率, 全通路_銷量市佔率, 全通路_每公升均價, 全通路_每次購買金額, 全通路_每次購買量, 全通路_平均購買次數, 全通路_每人平均花費, 全通路_每人平均購買量, 全通路_普及率, 全通路_銷售額, 全通路_銷售量]  # adding a row 
                指標總表_1_2_3_4_5_6_7_8_9_10_11.index = 指標總表_1_2_3_4_5_6_7_8_9_10_11.index + 1  # shifting index
                指標總表_1_2_3_4_5_6_7_8_9_10_11.sort_index(inplace=True) 







                # -----------------------------------------------------------------------------------------------
                # 排序用的 df 要跟隨 最新的 df 喔!!!
                指標總表_1_2_3_4_5_6_7_8_9_10_11 = 品牌x系列_表頭排序(指標總表_1_2_3_4_5_6_7_8_9_10_11, 訴求_column, 訴求_value)
                # -----------------------------------------------------------------------------------------------

                return 指標總表_1_2_3_4_5_6_7_8_9_10_11
            
            
            except :
            
                指標總表_1_2_3_4_5_6_7_8_9_10_11 = pd.DataFrame()

                return 指標總表_1_2_3_4_5_6_7_8_9_10_11
            
            



        訴求正面敘述 = YTD_全通路_個別_訴求(訴求_column, 訴求_column, A_1, A_2, 品類_list, 全台家戶數, 洗衣粉_市調結果購買率)
    #     訴求反面敘述
    #     訴求_value = "非"+str(訴求_column) # 新增的作法
        訴求反面敘述 = YTD_全通路_個別_訴求(訴求_column, "非"+str(訴求_column), A_1, A_2, 品類_list, 全台家戶數, 洗衣粉_市調結果購買率)


        df_all = pd.concat([訴求正面敘述, 訴求反面敘述], axis = 0).reset_index(drop = True)
        # 把排序用的欄位drop掉
        df_all = df_all.drop(["訴求_表頭順序", "系列_表頭順序", "品牌_表頭順序", "總排序"], axis = 1)

        # adding a row : Grand Total
        df_all.loc[-1] = ["-", "-", "Grand Total", ALL_全通路_銷額市佔率, ALL_全通路_銷量市佔率, ALL_全通路_每公升均價, ALL_全通路_每次購買金額, ALL_全通路_每次購買量, ALL_全通路_平均購買次數, ALL_全通路_每人平均花費, ALL_全通路_每人平均購買量, ALL_全通路_普及率, ALL_全通路_銷售額, ALL_全通路_銷售量]  # adding a row 
        df_all.index = df_all.index + 1  # shifting index
        df_all.sort_index(inplace=True)




#         MAT_表頭 = df_all[[訴求_column, "自定義品牌", "系列(一匙靈專用)"]].reset_index(drop = True)

        # 去掉整個row都沒有值的品牌系列
#         df_all = df_all.set_index([訴求_column, "自定義品牌", "系列(一匙靈專用)"])  ---------- 先不要把表頭 set index
#         df_all = df_all.replace("-", np.nan)                                  ---------- 先不要把沒有的都刪掉，先全部保留
#         df_all = df_all.dropna(how = "all")
#         df_all = df_all.fillna("-")


        return df_all





    
    
    
    
    
    





    
    def YTD報表(x_1, x_2, y_1, y_2, x_3, y_3) :

        Year_2017_month_01_02_YTD_全通路 = YTD_全通路_總_訴求(訴求_column, x_1, x_2, 品類_list, 全台家戶數, 洗衣粉_市調結果購買率)
        Year_2018_month_01_02_YTD_全通路 = YTD_全通路_總_訴求(訴求_column, y_1, y_2, 品類_list, 全台家戶數, 洗衣粉_市調結果購買率)


        


        dfs = [Year_2017_month_01_02_YTD_全通路, Year_2018_month_01_02_YTD_全通路]
        Year_2017_2018_month_01_02_YTD_全通路 = reduce(lambda left,right: pd.merge(left, right, how = "outer", on = [訴求_column, '自定義品牌', "系列(一匙靈專用)"]), dfs)


        # 1 銷額市佔率_差異
        Year_2017_2018_month_01_02_YTD_全通路["銷額市佔率_差異"] = Year_2017_2018_month_01_02_YTD_全通路["銷額市佔率_y"] - Year_2017_2018_month_01_02_YTD_全通路["銷額市佔率_x"]
        # 2 銷量市佔率_差異
        Year_2017_2018_month_01_02_YTD_全通路["銷量市佔率_差異"] = Year_2017_2018_month_01_02_YTD_全通路["銷量市佔率_y"] - Year_2017_2018_month_01_02_YTD_全通路["銷量市佔率_x"]
        # 3 每公升均價(元)_成長率
        try :
            Year_2017_2018_month_01_02_YTD_全通路["每公升均價(元)_成長率"] = (Year_2017_2018_month_01_02_YTD_全通路["每公升均價(元)_y"] - Year_2017_2018_month_01_02_YTD_全通路["每公升均價(元)_x"]) / Year_2017_2018_month_01_02_YTD_全通路["每公升均價(元)_x"]
        except :
#             Year_2017_2018_month_01_02_YTD_全通路["每公升均價(元)_成長率"] = "-"
            Year_2017_2018_month_01_02_YTD_全通路["每公升均價(元)_成長率"] = pd.Series()
            for i in range(0, len(Year_2017_2018_month_01_02_YTD_全通路["每公升均價(元)_成長率"])) :
                if Year_2017_2018_month_01_02_YTD_全通路["每公升均價(元)_x"][i] == 0 :
                    Year_2017_2018_month_01_02_YTD_全通路["每公升均價(元)_成長率"][i] == "-"
                else :
                    Year_2017_2018_month_01_02_YTD_全通路["每公升均價(元)_成長率"][i] = (Year_2017_2018_month_01_02_YTD_全通路["每公升均價(元)_y"][i] - Year_2017_2018_month_01_02_YTD_全通路["每公升均價(元)_x"][i]) / Year_2017_2018_month_01_02_YTD_全通路["每公升均價(元)_x"][i]
        # 4 每次購買金額(元)_成長率
        try :
            Year_2017_2018_month_01_02_YTD_全通路["每次購買金額(元)_成長率"] = (Year_2017_2018_month_01_02_YTD_全通路["每次購買金額(元)_y"] - Year_2017_2018_month_01_02_YTD_全通路["每次購買金額(元)_x"]) / Year_2017_2018_month_01_02_YTD_全通路["每次購買金額(元)_x"]
        except :
#             Year_2017_2018_month_01_02_YTD_全通路["每次購買金額(元)_成長率"] = "-"
            Year_2017_2018_month_01_02_YTD_全通路["每次購買金額(元)_成長率"] = pd.Series()
            for i in range(0, len(Year_2017_2018_month_01_02_YTD_全通路["每次購買金額(元)_成長率"])) :
                if Year_2017_2018_month_01_02_YTD_全通路["每次購買金額(元)_x"][i] == 0 :
                    Year_2017_2018_month_01_02_YTD_全通路["每次購買金額(元)_成長率"][i] == "-"
                else :
                    Year_2017_2018_month_01_02_YTD_全通路["每次購買金額(元)_成長率"][i] = (Year_2017_2018_month_01_02_YTD_全通路["每次購買金額(元)_y"][i] - Year_2017_2018_month_01_02_YTD_全通路["每次購買金額(元)_x"][i]) / Year_2017_2018_month_01_02_YTD_全通路["每次購買金額(元)_x"][i]
        # 5 每次購買量(公升)_成長率
        try :
            Year_2017_2018_month_01_02_YTD_全通路["每次購買量(公升)_成長率"] = (Year_2017_2018_month_01_02_YTD_全通路["每次購買量(公升)_y"] - Year_2017_2018_month_01_02_YTD_全通路["每次購買量(公升)_x"]) / Year_2017_2018_month_01_02_YTD_全通路["每次購買量(公升)_x"]
        except :
#             Year_2017_2018_month_01_02_YTD_全通路["每次購買量(公升)_成長率"] = "-"
            Year_2017_2018_month_01_02_YTD_全通路["每次購買量(公升)_成長率"] = pd.Series()
            for i in range(0, len(Year_2017_2018_month_01_02_YTD_全通路["每次購買量(公升)_成長率"])) :
                if Year_2017_2018_month_01_02_YTD_全通路["每次購買量(公升)_x"][i] == 0 :
                    Year_2017_2018_month_01_02_YTD_全通路["每次購買量(公升)_成長率"][i] == "-"
                else :
                    Year_2017_2018_month_01_02_YTD_全通路["每次購買量(公升)_成長率"][i] = (Year_2017_2018_month_01_02_YTD_全通路["每次購買量(公升)_y"][i] - Year_2017_2018_month_01_02_YTD_全通路["每次購買量(公升)_x"][i]) / Year_2017_2018_month_01_02_YTD_全通路["每次購買量(公升)_x"][i]
        # 6 平均購買次數_差異
        Year_2017_2018_month_01_02_YTD_全通路["平均購買次數_差異"] = Year_2017_2018_month_01_02_YTD_全通路["平均購買次數_y"] - Year_2017_2018_month_01_02_YTD_全通路["平均購買次數_x"]
        # 7 每人平均花費_成長率
        try :
            Year_2017_2018_month_01_02_YTD_全通路["每人平均花費_成長率"] = (Year_2017_2018_month_01_02_YTD_全通路["每人平均花費_y"] - Year_2017_2018_month_01_02_YTD_全通路["每人平均花費_x"]) / Year_2017_2018_month_01_02_YTD_全通路["每人平均花費_x"]
        except :
#             Year_2017_2018_month_01_02_YTD_全通路["每人平均花費_成長率"] = "-"
            Year_2017_2018_month_01_02_YTD_全通路["每人平均花費_成長率"] = pd.Series()
            for i in range(0, len(Year_2017_2018_month_01_02_YTD_全通路["每人平均花費_成長率"])) :
                if Year_2017_2018_month_01_02_YTD_全通路["每人平均花費_x"][i] == 0 :
                    Year_2017_2018_month_01_02_YTD_全通路["每人平均花費_成長率"][i] == "-"
                else :
                    Year_2017_2018_month_01_02_YTD_全通路["每人平均花費_成長率"][i] = (Year_2017_2018_month_01_02_YTD_全通路["每人平均花費_y"][i] - Year_2017_2018_month_01_02_YTD_全通路["每人平均花費_x"][i]) / Year_2017_2018_month_01_02_YTD_全通路["每人平均花費_x"][i]
        # 8 每人平均購買量_成長率
        try :
            Year_2017_2018_month_01_02_YTD_全通路["每人平均購買量_成長率"] = (Year_2017_2018_month_01_02_YTD_全通路["每人平均購買量_y"] - Year_2017_2018_month_01_02_YTD_全通路["每人平均購買量_x"]) / Year_2017_2018_month_01_02_YTD_全通路["每人平均購買量_x"]
        except :
#             Year_2017_2018_month_01_02_YTD_全通路["每人平均購買量_成長率"] = "-"
            Year_2017_2018_month_01_02_YTD_全通路["每人平均購買量_成長率"] = pd.Series()
            for i in range(0, len(Year_2017_2018_month_01_02_YTD_全通路["每人平均購買量_成長率"])) :
                if Year_2017_2018_month_01_02_YTD_全通路["每人平均購買量_x"][i] == 0 :
                    Year_2017_2018_month_01_02_YTD_全通路["每人平均購買量_成長率"][i] == "-"
                else :
                    Year_2017_2018_month_01_02_YTD_全通路["每人平均購買量_成長率"][i] = (Year_2017_2018_month_01_02_YTD_全通路["每人平均購買量_y"][i] - Year_2017_2018_month_01_02_YTD_全通路["每人平均購買量_x"][i]) / Year_2017_2018_month_01_02_YTD_全通路["每人平均購買量_x"][i]
        # 9 普及率_差異
        Year_2017_2018_month_01_02_YTD_全通路["普及率_差異"] = Year_2017_2018_month_01_02_YTD_全通路["普及率_y"] - Year_2017_2018_month_01_02_YTD_全通路["普及率_x"]

        Year_2017_2018_month_01_02_YTD_全通路 = Year_2017_2018_month_01_02_YTD_全通路[[訴求_column, '自定義品牌', "系列(一匙靈專用)", "銷額市佔率_x", "銷額市佔率_y", "銷額市佔率_差異", "銷量市佔率_x", "銷量市佔率_y", "銷量市佔率_差異", "每公升均價(元)_x", "每公升均價(元)_y", "每公升均價(元)_成長率", "每次購買金額(元)_x", "每次購買金額(元)_y", "每次購買金額(元)_成長率", "每次購買量(公升)_x", "每次購買量(公升)_y", "每次購買量(公升)_成長率", "平均購買次數_x", "平均購買次數_y", "平均購買次數_差異", "每人平均花費_x", "每人平均花費_y", "每人平均花費_成長率", "每人平均購買量_x", "每人平均購買量_y", "每人平均購買量_成長率", "普及率_x", "普及率_y", "普及率_差異"]]

        Year_2017_2018_month_01_02_YTD_全通路 = Year_2017_2018_month_01_02_YTD_全通路.fillna("-")


        Year_2017_2018_month_01_02_YTD_全通路 = Year_2017_2018_month_01_02_YTD_全通路.rename(columns=lambda x: x.replace('x', str(x_3)))
        Year_2017_2018_month_01_02_YTD_全通路 = Year_2017_2018_month_01_02_YTD_全通路.rename(columns=lambda x: x.replace('y', str(y_3)))

        
        
#         # 讀MAT的表頭
#         # =============================================================================================================================
     
#         Year_2017_2018_month_01_02_YTD_全通路 = pd.merge(MAT_表頭, Year_2017_2018_month_01_02_YTD_全通路, how = "left", on = [訴求_column, "自定義品牌", "系列(一匙靈專用)"])
    
#         # =============================================================================================================================

        # 讀MAT的表頭
        # =============================================================================================================================
     
        # Year_2017_2018_month_01_02_YTD_全通路 = pd.merge(MAT_表頭, Year_2017_2018_month_01_02_YTD_全通路, how = "left", on = [訴求_column, "自定義品牌", "系列(一匙靈專用)"])
    
        # exec(f'YTD_訴求_{訴求們[i]}全通路 = pd.merge(MAT_訴求_{訴求們[i]}全通路_表頭, YTD_訴求_{訴求們[i]}全通路, how = "left", on = ["{訴求們[i]}", "自定義品牌"])')
#         exec(f'Year_2017_2018_month_01_02_YTD_全通路 = pd.merge(MAT_訴求_{訴求_column}全通路_表頭, Year_2017_2018_month_01_02_YTD_全通路, how = "left", on = ["{訴求_column}", "自定義品牌"])')

#         Year_2017_2018_month_01_02_YTD_全通路 = pd.merge(MAT_訴求_天然全通路_for_sheet_by通路_表頭, Year_2017_2018_month_01_02_YTD_全通路, how = "left", on = ["天然", "自定義品牌"])
        
#-------------------------------------------------------------------------------------------------------------
        # 用exec的去merge會出錯，天然、非天然的順序不知道為什麼會跑掉
#         exec(f'Year_2017_2018_month_01_02_YTD_全通路 = pd.merge(MAT_訴求_{訴求_column}全通路_for_sheet_by通路_表頭, Year_2017_2018_month_01_02_YTD_全通路, how = "left", on = ["天然", "自定義品牌", "系列(一匙靈專用)"])')
        Year_2017_2018_month_01_02_YTD_全通路 = pd.merge(MAT_訴求_天然全通路_for_sheet_by通路_表頭, Year_2017_2018_month_01_02_YTD_全通路, how = "left", on = ["天然", "自定義品牌", "系列(一匙靈專用)"])
#-------------------------------------------------------------------------------------------------------------
        
        # =============================================================================================================================




        
        
        # 去掉整個row都沒有值的品牌系列
        # set_index 時，在這邊記得還有訴求_column
        Year_2017_2018_month_01_02_YTD_全通路 = Year_2017_2018_month_01_02_YTD_全通路.set_index([訴求_column, "自定義品牌", "系列(一匙靈專用)"])
        Year_2017_2018_month_01_02_YTD_全通路 = Year_2017_2018_month_01_02_YTD_全通路.replace("-", np.nan)
        Year_2017_2018_month_01_02_YTD_全通路 = Year_2017_2018_month_01_02_YTD_全通路.dropna(how = "all")
        Year_2017_2018_month_01_02_YTD_全通路 = Year_2017_2018_month_01_02_YTD_全通路.fillna("-")
        
        return Year_2017_2018_month_01_02_YTD_全通路

            
    Year_2017_2018_month_01_02_YTD_全通路 = YTD報表(x_1, x_2, y_1, y_2, x_3, y_3)
    
    
    
    
    
    return Year_2017_2018_month_01_02_YTD_全通路

# %%
# # 現在定義時間(為了配合對答案)
# '''
# # YTD
# x_1 = "2017-01-01"
# x_2 = "2017-05-01"

# y_1 = "2018-01-01"
# y_2 = "2018-05-01"

# x_3 = "2017年1-4月"
# y_3 = "2018年1-4月"

# def YTD_全通路_完整sheet(訴求_column, x_1, x_2, y_1, y_2, x_3, y_3, 品類_list, 全台家戶數, 洗衣粉_市調結果購買率) :

# '''

# a = YTD_全通路_完整sheet("天然", x_1, x_2, y_1, y_2, x_3, y_3, 品類_list, 全台家戶數, 洗衣粉_市調結果購買率)
# a

# %% [markdown]
# ## YTD
# >> YTD_單一通路

# %%
def YTD_單一通路_完整sheet(訴求_column, x_1, x_2, y_1, y_2, x_3, y_3, 品類_list, 通路的變數欄位名稱, 通路的變數欄位之篩選條件, 全台家戶數, 洗衣粉_市調結果購買率) :
        
    訴求_column = str(訴求_column)
    通路的變數欄位名稱 = str(通路的變數欄位名稱)
    通路的變數欄位之篩選條件 = str(通路的變數欄位之篩選條件)
        

    def YTD_單一通路_總_訴求(訴求_column, A_1, A_2, 品類_list, 通路的變數欄位名稱, 通路的變數欄位之篩選條件, 全台家戶數, 洗衣粉_市調結果購買率) :     
        
        訴求_column = str(訴求_column)
        通路的變數欄位名稱 = str(通路的變數欄位名稱)
        通路的變數欄位之篩選條件 = str(通路的變數欄位之篩選條件)
    
        global 訴求GT_單一通路_銷額市佔率
        global 訴求GT_單一通路_銷量市佔率
        global 訴求GT_單一通路_每公升均價
        global 訴求GT_單一通路_每次購買金額
        global 訴求GT_單一通路_每次購買量
        global 訴求GT_單一通路_平均購買次數
        global 訴求GT_單一通路_每人平均花費
        global 訴求GT_單一通路_每人平均購買量
        global 訴求GT_單一通路_普及率
        global 訴求GT_單一通路_銷售額
        global 訴求GT_單一通路_銷售量
        

        df = df_整理


        # =================================== 1. 處理與否 = 1 =================================== 
        df = df[df["處理與否"] == 1]
        # =================================== 2. 總容量有值 且 >=1 =================================== 
        df = df[np.isfinite(df['總容量'])]
        df = df[df['總容量'] >= 0]

        # =================================== 3.時間_MAT ===================================    
        df = df[(df['invDate_datetime'] >= str(A_1)) & (df['invDate_datetime'] < str(A_2))]

        # =================================== 4.品類_洗衣粉 ===================================
        df = df[df["品類_list"] == 1]

        # =================================== 5.通路_單一通路 =================================== 


        #單一通路
        df_單一通路 = df[df[str(通路的變數欄位名稱)] == str(通路的變數欄位之篩選條件)]
        # reset_index
        df_單一通路 = df_單一通路.reset_index(drop = True)   




        # =================================== 8-1.指標_MAT_洗衣粉_銷額市佔率 ===================================
        # 算總金額(正確價錢 Grand Total)
        洗衣粉_MAT_單一通路總金額_Grand_Total = 0
        list_of_洗衣粉_MAT_單一通路總金額_Grand_Total = []
        for i in range(0, len(df_單一通路["正確價錢"])) :
            洗衣粉_MAT_單一通路總金額_Grand_Total = 洗衣粉_MAT_單一通路總金額_Grand_Total + float(df_單一通路["正確價錢"][i])






        # =================================== 8-2.指標_MAT_洗衣粉_銷量市佔率 ===================================
        # 算總金額(正確價錢 Grand Total)
        洗衣粉_MAT_單一通路總容量_Grand_Total = 0
        list_of_洗衣粉_MAT_單一通路總容量_Grand_Total = []
        for i in range(0, len(df_單一通路["總容量"])) :
            洗衣粉_MAT_單一通路總容量_Grand_Total = 洗衣粉_MAT_單一通路總容量_Grand_Total + float(df_單一通路["總容量"][i])






        # # =================================== 8-4.指標_MAT_洗衣粉_每次購買金額(元) ===================================
        # # =================================== 8-5.指標_MAT_洗衣粉_每次購買量(公升) ===================================
        df_copy = df_單一通路
        df_copy = df_copy.reset_index(drop = True)
        #----------------------------------------------------------------------------------
        df_corss_variable_distinct_invNum = df_copy.loc[:, ["xdid", "invNum", "自定義品牌", "系列(一匙靈專用)"]]
        df_corss_variable_distinct_invNum['自定義品牌_系列'] = df_corss_variable_distinct_invNum[['自定義品牌', '系列(一匙靈專用)']].apply(lambda x: ','.join(x), axis=1)
        #----------------------------------------------------------------------------------
        # 各品牌各系列
        df_自定義品牌_系列 = df_corss_variable_distinct_invNum[['自定義品牌_系列']].drop_duplicates().reset_index(drop = True)
        df_自定義品牌_系列["不重複的發票編號"] = ""
        df_自定義品牌_系列["總發票張數(不重複)"] = ""

        for i in range(0, len(df_自定義品牌_系列["自定義品牌_系列"])) :
            不重複的發票編號_list = []
            for j in range(0, len(df_corss_variable_distinct_invNum["自定義品牌_系列"])) :
                if df_自定義品牌_系列["自定義品牌_系列"][i] == df_corss_variable_distinct_invNum["自定義品牌_系列"][j] :
                    不重複的發票編號_list.append(df_corss_variable_distinct_invNum["invNum"][j])
                else :
                    None
            df_自定義品牌_系列["不重複的發票編號"][i] = list(set(不重複的發票編號_list))
            df_自定義品牌_系列["總發票張數(不重複)"][i] = len(list(set(不重複的發票編號_list)))
            不重複的發票編號_list = []
        #--------------
        # 各品牌Total    
        df_自定義品牌_系列_Total = df_corss_variable_distinct_invNum[['自定義品牌']].drop_duplicates().reset_index(drop = True)
        df_自定義品牌_系列_Total["系列(一匙靈專用)"] = "Total"
        df_自定義品牌_系列_Total["不重複的發票編號"] = ""
        df_自定義品牌_系列_Total["總發票張數(不重複)"] = ""    

        for i in range(0, len(df_自定義品牌_系列_Total["自定義品牌"])) :
            不重複的發票編號_list = []
            for j in range(0, len(df_corss_variable_distinct_invNum["自定義品牌"])) :
                if df_自定義品牌_系列_Total["自定義品牌"][i] == df_corss_variable_distinct_invNum["自定義品牌"][j] :
                    不重複的發票編號_list.append(df_corss_variable_distinct_invNum["invNum"][j])
                else :
                    None
            df_自定義品牌_系列_Total["不重複的發票編號"][i] = list(set(不重複的發票編號_list))
            df_自定義品牌_系列_Total["總發票張數(不重複)"][i] = len(list(set(不重複的發票編號_list)))
            不重複的發票編號_list = []
        #----------------------------------------------------------------------------------            



        # # =================================== 8-6.指標_MAT_洗衣粉_平均購買次數 ===================================
        # 這裡有篩選條件需要選到 "品項" : "洗衣粉" !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!

        df_copy_2 = df_整理




        # =================================== 挑有買過兩張發票的裝置 xdid ===================================
        df_copy_3 = df_copy_2
        df_copy_4 = df_copy_2
        #---------------------------------------------------------------------------------------------------------

        #---------------------------------------------------------------------------------------------------------
        # for df_copy_2 : 要找到 總裝置數 的 那些"裝置(xdid)"候選人名單
        # =================================== 0. 挑有買過2張以上發票的裝置 =================================== 
        # 挑有買過兩張發票的裝置

        df_all_of_xdid_with_multiple_invNum_list = df_copy_2


        df_all_of_xdid_with_multiple_invNum_list = df_copy_2.loc[:, ["xdid", "invNum"]]
        # 將裝置數missing的刪除
        df_all_of_xdid_with_multiple_invNum_list = df_all_of_xdid_with_multiple_invNum_list.loc[df_all_of_xdid_with_multiple_invNum_list["xdid"] != "missing" ]
        df_all_of_xdid_with_multiple_invNum_list = df_all_of_xdid_with_multiple_invNum_list.drop_duplicates().reset_index(drop = True)

        df_all_of_xdid_with_multiple_invNum_list = df_all_of_xdid_with_multiple_invNum_list.groupby(["xdid"])['invNum'].nunique()

        df_all_of_xdid_with_multiple_invNum_list = df_all_of_xdid_with_multiple_invNum_list[df_all_of_xdid_with_multiple_invNum_list > 1]
        df_all_of_xdid_with_multiple_invNum_list = df_all_of_xdid_with_multiple_invNum_list.to_frame().reset_index()
        # #---------------------------------------------------------------------------------------------------------
        # < 交叉變項 : 總裝置數 的 那些"裝置(xdid)"候選人名單 >
        df_all_of_xdid_with_multiple_invNum_list = list(set(df_all_of_xdid_with_multiple_invNum_list["xdid"]))

        #---------------------------------------------------------------------------------------------------------
        # for df_copy_3 : 要從原始資料 找到 符合那些裝置候選人名單 & 符合後續條件 的那些row

        # < 交叉變項 : 總裝置數 的 那些"裝置(xdid)"候選人名單 ；待會兒要加上 原本1~5的篩選條件 再得到 df，最後才要groupby >
        df_copy_3 = df_copy_3[df_copy_3['xdid'].isin(df_all_of_xdid_with_multiple_invNum_list)]
        # =================================== 1. 處理與否 = 1 =================================== 
        df_copy_3 = df_copy_3[df_copy_3["處理與否"] == 1]
        # =================================== 2. 總容量有值 且 >=1 =================================== 
        df_copy_3 = df_copy_3[np.isfinite(df_copy_3['總容量'])]
        df_copy_3 = df_copy_3[df_copy_3['總容量'] >= 0]
        # =================================== 3.時間_MAT ===================================
        df_copy_3 = df_copy_3[(df_copy_3['invDate_datetime'] >= str(A_1)) & (df_copy_3['invDate_datetime'] < str(A_2))]
        # =================================== 4.品類_洗衣粉 - < 至少有一張發票有買到該品項 > ===================================
        df_copy_3 = df_copy_3[df_copy_3["品類_list"] == 1]
        # =================================== 5.通路_單一通路 =================================== 
        #單一通路
        df_copy_3 = df_copy_3[df_copy_3[str(通路的變數欄位名稱)] == str(通路的變數欄位之篩選條件)]
        # reset_index
        df_copy_3 = df_copy_3.reset_index(drop = True)   



        # Grand Total
        平均購買次數_總裝置數_list_of_xdid__with_multiple_invNum = len(list(set(df_copy_3["xdid"])))





        #---------------------------------------------------------------------------------------------------------
        # for df_copy_4 : 要找到總發票張數 : 1.挑有2張發票的裝置  2.其中有買到該品項的發票皆列入

        # 挑有買過兩張發票的裝置

        df_all_of_xdid_with_multiple_invNum_list = df_copy_2

        df_all_of_xdid_with_multiple_invNum_list = df_copy_2.loc[:, ["xdid", "invNum"]]
        # 將裝置數missing的保留
        # df_all_of_xdid_with_multiple_invNum_list = df_all_of_xdid_with_multiple_invNum_list.loc[df_all_of_xdid_with_multiple_invNum_list["xdid"] != "missing" ]
        df_all_of_xdid_with_multiple_invNum_list = df_all_of_xdid_with_multiple_invNum_list.drop_duplicates().reset_index(drop = True)

        df_all_of_xdid_with_multiple_invNum_list = df_all_of_xdid_with_multiple_invNum_list.groupby(["xdid"])['invNum'].nunique()

        df_all_of_xdid_with_multiple_invNum_list = df_all_of_xdid_with_multiple_invNum_list[df_all_of_xdid_with_multiple_invNum_list > 1]
        df_all_of_xdid_with_multiple_invNum_list = df_all_of_xdid_with_multiple_invNum_list.to_frame().reset_index()


        # #---------------------------------------------------------------------------------------------------------
        # < 交叉變項 : 總裝置數 的 那些"裝置(xdid)"候選人名單 >
        list_of_xdid__with_multiple_invNum = list(set(df_all_of_xdid_with_multiple_invNum_list["xdid"]))

        df_copy_4 = df_copy_4[df_copy_4['xdid'].isin(list_of_xdid__with_multiple_invNum)]

        # < 交叉變項 : 總裝置數 的 那些"裝置(xdid)"候選人名單 加上 原本1~5的篩選條件所得到的 df，接下來要groupby了 >
        # =================================== 1. 處理與否 = 1 =================================== 
        df_copy_4 = df_copy_4[df_copy_4["處理與否"] == 1]
        # =================================== 2. 總容量有值 且 >=1 =================================== 
        df_copy_4 = df_copy_4[np.isfinite(df_copy_4['總容量'])]
        df_copy_4 = df_copy_4[df_copy_4['總容量'] >= 0]
        # =================================== 3.時間_MAT ===================================    
        df_copy_4 = df_copy_4[(df_copy_4['invDate_datetime'] >= str(A_1)) & (df_copy_4['invDate_datetime'] < str(A_2))]
        # =================================== 4.品類_洗衣粉 - < 有買到該品項的皆列入 > ===================================
        df_copy_4 = df_copy_4[df_copy_4["品類_list"] == 1]

        # =================================== 5.通路_單一通路 =================================== 
        #單一通路
        df_copy_4 = df_copy_4[df_copy_4[str(通路的變數欄位名稱)] == str(通路的變數欄位之篩選條件)]
        # reset_index
        df_copy_4 = df_copy_4.reset_index(drop = True)  





        # 平均購買次數_總發票張數_(Grand_Total)
        list_of_invNum__by_xdid__with_multiple_invNum = len(list(set(df_copy_4["invNum"])))



        # # =================================== 8-6.指標_MAT_洗衣粉_平均購買次數 ===================================



        # # =================================== 8-9.指標_MAT_洗衣粉_普及率 ===================================
        # # 總裝置數
        # =================================== 挑有買過兩張發票的裝置 xdid ===================================
        df_copy_5 = df_copy_2
        #---------------------------------------------------------------------------------------------------------

        #---------------------------------------------------------------------------------------------------------
        # for df_copy_5 : 要找到 總裝置數 的 那些"裝置(xdid)"候選人名單
        # =================================== 0. 總裝置數 =================================== 


        # < 交叉變項 : 總裝置數 >
        df_copy_5 = df_copy_5[df_copy_5['xdid'] != "missing"]
        # =================================== 1. 處理與否 = 1 =================================== 
        df_copy_5 = df_copy_5[df_copy_5["處理與否"] == 1]
        # =================================== 2. 總容量有值 且 >=1 =================================== 
        df_copy_5 = df_copy_5[np.isfinite(df_copy_5['總容量'])]
        df_copy_5 = df_copy_5[df_copy_5['總容量'] >= 0]
        # =================================== 3.時間_MAT ===================================
        df_copy_5 = df_copy_5[(df_copy_5['invDate_datetime'] >= str(A_1)) & (df_copy_5['invDate_datetime'] < str(A_2))]
        # =================================== 4.品類_洗衣粉 - < 至少有一張發票有買到該品項 > ===================================
        df_copy_5 = df_copy_5[df_copy_5["品類_list"] == 1]
        # =================================== 5.通路_單一通路 =================================== 
        # 單一通路
        df_copy_5_單一通路 = df_copy_5[df_copy_5[str(通路的變數欄位名稱)] == str(通路的變數欄位之篩選條件)] 
        df_copy_5_單一通路 = df_copy_5_單一通路.reset_index(drop = True)   





        洗衣粉_市調結果購買率 = float(洗衣粉_市調結果購買率)
        # < 交叉變項 : 總裝置數 >
        all_distinct_xdid_of_one_item_list = list(set(df_copy_5_單一通路["xdid"]))
        訴求GT_普及率_總裝置數_該品類總裝置數 = len(all_distinct_xdid_of_one_item_list)





        # # =================================== 8-10.指標_MAT_洗衣粉_銷售額(百萬元) ===================================
        # # =================================== 8-11.指標_MAT_洗衣粉_銷售量(千公升) ===================================
        # - 6.平均購買次數 - 兩張發票之不重複總發票張數
        洗衣粉_訴求GT_單一通路_平均購買次數_兩張發票之不重複總發票張數 = list_of_invNum__by_xdid__with_multiple_invNum
        # - 6.平均購買次數 - 兩張發票之不重複總裝置數
        洗衣粉_訴求GT_單一通路_平均購買次數_兩張發票之不重複總裝置數 = 平均購買次數_總裝置數_list_of_xdid__with_multiple_invNum
        # 訴求GT_單一通路_平均購買次數
        訴求GT_單一通路_平均購買次數 = 洗衣粉_訴求GT_單一通路_平均購買次數_兩張發票之不重複總發票張數 / 洗衣粉_訴求GT_單一通路_平均購買次數_兩張發票之不重複總裝置數
        訴求GT_單一通路_平均購買次數

        # - 4.每次購買金額 - 總金額
        訴求GT_洗衣粉_單一通路_總銷額 = 洗衣粉_MAT_單一通路總金額_Grand_Total
        # - 4.每次購買金額 - 不重複總發票張數
        訴求GT_洗衣粉_訴求GT_單一通路_每次購買金額_不重複總發票張數 = []
        for i in range(0, len(df_corss_variable_distinct_invNum["invNum"])) :
            訴求GT_洗衣粉_訴求GT_單一通路_每次購買金額_不重複總發票張數.append(df_corss_variable_distinct_invNum["invNum"][i])
        訴求GT_洗衣粉_訴求GT_單一通路_每次購買金額_不重複總發票張數 = list(set(訴求GT_洗衣粉_訴求GT_單一通路_每次購買金額_不重複總發票張數))

        訴求GT_洗衣粉_訴求GT_單一通路_每次購買金額_不重複總發票張數 = len(訴求GT_洗衣粉_訴求GT_單一通路_每次購買金額_不重複總發票張數) # 49344
        # 訴求GT_單一通路_每次購買金額
        訴求GT_單一通路_每次購買金額 = 訴求GT_洗衣粉_單一通路_總銷額 / 訴求GT_洗衣粉_訴求GT_單一通路_每次購買金額_不重複總發票張數


        # - 5.每次購買量 - 總容量
        訴求GT_洗衣粉_單一通路_總容量 = 洗衣粉_MAT_單一通路總容量_Grand_Total
        # 訴求GT_單一通路_每次購買量
        訴求GT_單一通路_每次購買量 = 訴求GT_洗衣粉_單一通路_總容量 / 訴求GT_洗衣粉_訴求GT_單一通路_每次購買金額_不重複總發票張數 #/ 1000




        # 該通路銷額佔比
        # 訴求GT_單一通路_銷額佔比
        訴求GT_單一通路_銷額佔比 = 訴求GT_洗衣粉_單一通路_總銷額 / ALL_洗衣粉_全通路_總銷額



        # 訴求GT_單一通路_銷量佔比
        訴求GT_單一通路_銷額佔比 = 訴求GT_洗衣粉_單一通路_總容量 / ALL_洗衣粉_全通路_總容量













        全台家戶數 = float(全台家戶數)
        洗衣粉_市調結果購買率 = float(洗衣粉_市調結果購買率)

        # 訴求GT_單一通路_銷額市佔率
        訴求GT_單一通路_銷額市佔率 = 訴求GT_洗衣粉_單一通路_總銷額 / 訴求GT_洗衣粉_單一通路_總銷額
        # 訴求GT_單一通路_銷量市佔率
        訴求GT_單一通路_銷量市佔率 = 訴求GT_洗衣粉_單一通路_總容量 / 訴求GT_洗衣粉_單一通路_總容量
        # 訴求GT_單一通路_每公升均價(元)
        訴求GT_單一通路_每公升均價 = 訴求GT_洗衣粉_單一通路_總銷額 / 訴求GT_洗衣粉_單一通路_總容量 * 1000
        # 訴求GT_單一通路_每次購買金額(元)
        訴求GT_單一通路_每次購買金額 = 訴求GT_洗衣粉_單一通路_總銷額 / 訴求GT_洗衣粉_訴求GT_單一通路_每次購買金額_不重複總發票張數
        # 訴求GT_單一通路_每次購買量(公升)
        訴求GT_單一通路_每次購買量 = 訴求GT_洗衣粉_單一通路_總容量 / 訴求GT_洗衣粉_訴求GT_單一通路_每次購買金額_不重複總發票張數 / 1000
        # 訴求GT_單一通路_平均購買次數
        訴求GT_單一通路_平均購買次數 = 洗衣粉_訴求GT_單一通路_平均購買次數_兩張發票之不重複總發票張數 / 洗衣粉_訴求GT_單一通路_平均購買次數_兩張發票之不重複總裝置數
        # 訴求GT_單一通路_每人平均花費
        訴求GT_單一通路_每人平均花費 = 訴求GT_單一通路_每次購買金額 * 訴求GT_單一通路_平均購買次數
        # 訴求GT_單一通路_每人平均購買量
        訴求GT_單一通路_每人平均購買量 = 訴求GT_單一通路_每次購買量 * 訴求GT_單一通路_平均購買次數


        訴求GT_洗衣粉_訴求GT_單一通路_普及率_總裝置數 = 訴求GT_普及率_總裝置數_該品類總裝置數 
        # 訴求GT_單一通路_普及率
        訴求GT_單一通路_普及率 = (訴求GT_洗衣粉_訴求GT_單一通路_普及率_總裝置數 / 訴求GT_洗衣粉_訴求GT_單一通路_普及率_總裝置數)



        # 洗衣粉_單一通路_普及率_總裝置數 = 
        # 單一通路_普及率_除以33915 = 洗衣粉_市調結果購買率 * (洗衣粉_單一通路_普及率_總裝置數 / 訴求GT_洗衣粉_訴求GT_單一通路_普及率_總裝置數)

        # 訴求GT_單一通路_銷售額(百萬元)
        訴求GT_單一通路_銷售額 = 全台家戶數 * 洗衣粉_市調結果購買率 * ALL_全通路_平均購買次數 * ALL_全通路_每次購買金額 / 1000000 * (訴求GT_洗衣粉_單一通路_總銷額 / ALL_洗衣粉_全通路_總銷額) * 訴求GT_單一通路_銷額市佔率
        # 訴求GT_單一通路_銷售量(千公升)
        訴求GT_單一通路_銷售量 = 全台家戶數 * 洗衣粉_市調結果購買率 * ALL_全通路_平均購買次數 * ALL_全通路_每次購買量 / 1000 * (訴求GT_洗衣粉_單一通路_總容量 / ALL_洗衣粉_全通路_總容量) * 訴求GT_單一通路_銷量市佔率


        # # 挑選適當欄位 : 只留11個指標當作column
        # 指標總表_1_2_3_4_5_6_7_8_9_10_11 = 指標總表_1_2_3_4_5_6_7_8_9_10_11[["自定義品牌", "系列(一匙靈專用)", "銷額市佔率", "銷量市佔率", "每公升均價(元)", "每次購買金額(元)", "每次購買量(公升)", "平均購買次數", "每人平均花費", "每人平均購買量", "普及率", "普及率_除以33915", "銷售額(百萬元)", "銷售量(千公升)"]]


        # # adding a row : Grand_Total
        # 指標總表_1_2_3_4_5_6_7_8_9_10_11.loc[-1] = ["-", "Grand Total", 訴求GT_單一通路_銷額市佔率, 訴求GT_單一通路_銷量市佔率, 訴求GT_單一通路_每公升均價, 訴求GT_單一通路_每次購買金額, 訴求GT_單一通路_每次購買量, 訴求GT_單一通路_平均購買次數, 訴求GT_單一通路_每人平均花費, 訴求GT_單一通路_每人平均購買量, 訴求GT_單一通路_普及率, 訴求GT_單一通路_普及率_除以33915, 訴求GT_單一通路_銷售額, 訴求GT_單一通路_銷售量]  # adding a row 
        # 指標總表_1_2_3_4_5_6_7_8_9_10_11.index = 指標總表_1_2_3_4_5_6_7_8_9_10_11.index + 1  # shifting index
        # 指標總表_1_2_3_4_5_6_7_8_9_10_11.sort_index(inplace=True) 












        def YTD_單一通路_個別_訴求(訴求_column, 訴求_value, A_1, A_2, 品類_list, 通路的變數欄位名稱, 通路的變數欄位之篩選條件, 全台家戶數, 洗衣粉_市調結果購買率) :    

            try :

        #         global 訴求GT_單一通路_銷額市佔率
        #         global 訴求GT_單一通路_銷量市佔率
        #         global 訴求GT_單一通路_每公升均價
        #         global 訴求GT_單一通路_每次購買金額
        #         global 訴求GT_單一通路_每次購買量
        #         global 訴求GT_單一通路_平均購買次數
        #         global 訴求GT_單一通路_每人平均花費
        #         global 訴求GT_單一通路_每人平均購買量
        #         global 訴求GT_單一通路_普及率
        #         global 訴求GT_單一通路_銷售額
        #         global 訴求GT_單一通路_銷售量
        #         global 訴求GT_洗衣粉_訴求GT_單一通路_普及率_總裝置數


        # #         global 全台家戶數
        # #         global 洗衣粉_市調結果購買率

                global ALL_洗衣粉_全通路_總銷額
                global ALL_全通路_銷額市佔率

                global ALL_洗衣粉_全通路_總容量
                global ALL_全通路_銷量市佔率

                global ALL_全通路_每公升均價

                global ALL_洗衣粉_ALL_全通路_每次購買金額_不重複總發票張數
                global ALL_全通路_每次購買金額
                global ALL_全通路_每次購買量

                global 洗衣粉_ALL_全通路_平均購買次數_兩張發票之不重複總發票張數
                global 洗衣粉_ALL_全通路_平均購買次數_兩張發票之不重複總裝置數
                global ALL_全通路_平均購買次數

                global ALL_全通路_每人平均花費
                global ALL_全通路_每人平均購買量

                global ALL_洗衣粉_ALL_全通路_普及率_總裝置數





                df = df_整理


                # =================================== 1. 處理與否 = 1 =================================== 
                df = df[df["處理與否"] == 1]
                # =================================== 2. 總容量有值 且 >=1 =================================== 
                df = df[np.isfinite(df['總容量'])]
                df = df[df['總容量'] >= 0]

                # =================================== 3.時間_MAT ===================================    
                df = df[(df['invDate_datetime'] >= str(A_1)) & (df['invDate_datetime'] < str(A_2))]

                # =================================== 4.品類_洗衣粉 ===================================
                df = df[df["品類_list"] == 1]

                # =================================== 5.通路_單一通路 =================================== 


                #單一通路
                df_單一通路 = df[df[str(通路的變數欄位名稱)] == str(通路的變數欄位之篩選條件)]
                # reset_index
                df_單一通路 = df_單一通路.reset_index(drop = True)  




                df_某訴求_單一通路 = df_單一通路.loc[df_單一通路[訴求_column] == 訴求_value, :].reset_index(drop = True)

        #         df_某訴求_單一通路 = df_某訴求_單一通路[df_某訴求_單一通路[str(通路的變數欄位名稱)] == str(通路的變數欄位之篩選條件)] 
        #         df_某訴求_單一通路 = df_某訴求_單一通路.reset_index(drop = True)

        # =================================== 8-1.指標_MAT_洗衣粉_銷額市佔率 ===================================

                list_of_ALL_洗衣粉_全通路_總銷額 = []
                for i in range(0, len(df_某訴求_單一通路["正確價錢"])) :
                    list_of_ALL_洗衣粉_全通路_總銷額.append(訴求GT_洗衣粉_單一通路_總銷額)

                df_某訴求_單一通路["總銷額"] = list_of_ALL_洗衣粉_全通路_總銷額

                df_某訴求_單一通路["各系列銷額市佔率"] = df_某訴求_單一通路["正確價錢"] / df_某訴求_單一通路["總銷額"]



                # 各品牌x各系列_之_各系列正確價錢
                df_1 = df_某訴求_單一通路.groupby(['自定義品牌', "系列(一匙靈專用)"])["正確價錢"].sum().reset_index(name = '品項_品牌_系列_正確價錢')
                # 各品牌Total銷額市佔率
                df_2 = df_某訴求_單一通路.groupby(['自定義品牌'])["正確價錢"].sum().reset_index(name = '品項_品牌_系列_正確價錢')
                # concat
                df_指標1_銷額市佔率_正確價錢 = pd.concat([df_1, df_2], axis = 0).reset_index(drop = True)
                df_指標1_銷額市佔率_正確價錢["系列(一匙靈專用)"] = df_指標1_銷額市佔率_正確價錢["系列(一匙靈專用)"].fillna("Total")

                # 各品牌x各系列_之_各系列銷額市佔率
                df_1 = df_某訴求_單一通路.groupby([訴求_column, '自定義品牌', "系列(一匙靈專用)"])["各系列銷額市佔率"].sum().reset_index(name = '銷額市佔率')
                # 各品牌Total銷額市佔率
                df_2 = df_某訴求_單一通路.groupby([訴求_column, '自定義品牌'])["各系列銷額市佔率"].sum().reset_index(name = '銷額市佔率')
                # concat
                df_指標1_銷額市佔率 = pd.concat([df_1, df_2], axis = 0).reset_index(drop = True)
                df_指標1_銷額市佔率["系列(一匙靈專用)"] = df_指標1_銷額市佔率["系列(一匙靈專用)"].fillna("Total")

                # merge
                df_指標1_銷額市佔率 = pd.merge(df_指標1_銷額市佔率, df_指標1_銷額市佔率_正確價錢, on = ['自定義品牌', "系列(一匙靈專用)"], how = "outer")






                # 調整欄位順序
                df_指標1_銷額市佔率 = df_指標1_銷額市佔率.loc[: , [訴求_column, "自定義品牌", "系列(一匙靈專用)", "銷額市佔率", "品項_品牌_系列_正確價錢"]]


        #         # # 插入 訴求 SubTotal
        #         洗衣粉_MAT_訴求_單一通路總金額_Grand_Total = 0

        #         for i in range(0, len(df_某訴求_單一通路["正確價錢"])) :
        #             洗衣粉_MAT_訴求_單一通路總金額_Grand_Total = 洗衣粉_MAT_訴求_單一通路總金額_Grand_Total + float(df_某訴求_單一通路["正確價錢"][i])

        #         df_指標1_銷額市佔率.loc[-1] = [訴求_value, '-', 'SubTotal', (洗衣粉_MAT_訴求_單一通路總金額_Grand_Total / ALL_洗衣粉_全通路_總銷額), 洗衣粉_MAT_訴求_單一通路總金額_Grand_Total]  # adding a row 
        #         df_指標1_銷額市佔率.index = df_指標1_銷額市佔率.index + 1  # shifting index
        #         df_指標1_銷額市佔率.sort_index(inplace=True) 






        # =================================== 8-2.指標_MAT_洗衣粉_銷量市佔率 ===================================



                list_of_ALL_洗衣粉_全通路_總容量 = []
                for i in range(0, len(df_某訴求_單一通路["總容量"])) :
                    list_of_ALL_洗衣粉_全通路_總容量.append(訴求GT_洗衣粉_單一通路_總容量)

                df_某訴求_單一通路["最後總銷量"] = list_of_ALL_洗衣粉_全通路_總容量

                df_某訴求_單一通路["各系列銷量市佔率"] = df_某訴求_單一通路["總容量"] / df_某訴求_單一通路["最後總銷量"]





        #         list_of_洗衣粉_MAT_單一通路總容量_Grand_Total = []
        #         for i in range(0, len(df_某訴求_單一通路["總容量"])) :
        #             list_of_洗衣粉_MAT_單一通路總容量_Grand_Total.append(洗衣粉_MAT_單一通路總容量_Grand_Total)

        #         df_某訴求_單一通路["總銷量"] = list_of_洗衣粉_MAT_單一通路總容量_Grand_Total

        #         df_某訴求_單一通路["各系列銷量市佔率"] = df_某訴求_單一通路["總容量"] / df_某訴求_單一通路["總銷量"]



                # 各品牌x各系列_之_各系列總容量
                df_1 = df_某訴求_單一通路.groupby(['自定義品牌', "系列(一匙靈專用)"])["總容量"].sum().reset_index(name = '品項_品牌_系列_總容量')
                # 各品牌Total銷量市佔率
                df_2 = df_某訴求_單一通路.groupby(['自定義品牌'])["總容量"].sum().reset_index(name = '品項_品牌_系列_總容量')
                # concat
                df_指標2_銷量市佔率_總容量 = pd.concat([df_1, df_2], axis = 0).reset_index(drop = True)
                df_指標2_銷量市佔率_總容量["系列(一匙靈專用)"] = df_指標2_銷量市佔率_總容量["系列(一匙靈專用)"].fillna("Total")

                # 各品牌x各系列_之_各系列銷量市佔率
                df_1 = df_某訴求_單一通路.groupby([訴求_column, '自定義品牌', "系列(一匙靈專用)"])["各系列銷量市佔率"].sum().reset_index(name = '銷量市佔率')
                # 各品牌Total銷量市佔率
                df_2 = df_某訴求_單一通路.groupby([訴求_column, '自定義品牌'])["各系列銷量市佔率"].sum().reset_index(name = '銷量市佔率')
                # concat
                df_指標2_銷量市佔率 = pd.concat([df_1, df_2], axis = 0).reset_index(drop = True)
                df_指標2_銷量市佔率["系列(一匙靈專用)"] = df_指標2_銷量市佔率["系列(一匙靈專用)"].fillna("Total")

                # merge
                df_指標2_銷量市佔率 = pd.merge(df_指標2_銷量市佔率, df_指標2_銷量市佔率_總容量, on = ['自定義品牌', "系列(一匙靈專用)"], how = "outer")






                # 調整欄位順序
                df_指標2_銷量市佔率 = df_指標2_銷量市佔率.loc[: , [訴求_column, "自定義品牌", "系列(一匙靈專用)", "銷量市佔率", "品項_品牌_系列_總容量"]]


        #         # # 插入 訴求 Total
        #         洗衣粉_MAT_訴求_單一通路總容量_Grand_Total = 0

        #         for i in range(0, len(df_某訴求_單一通路["總容量"])) :
        #             洗衣粉_MAT_訴求_單一通路總容量_Grand_Total = 洗衣粉_MAT_訴求_單一通路總容量_Grand_Total + float(df_某訴求_單一通路["總容量"][i])

        #         df_指標2_銷量市佔率.loc[-1] = [訴求_value, '-', 'SubTotal', (洗衣粉_MAT_訴求_單一通路總容量_Grand_Total / 洗衣粉_MAT_單一通路總容量_Grand_Total), 洗衣粉_MAT_訴求_單一通路總容量_Grand_Total]  # adding a row 
        #         df_指標2_銷量市佔率.index = df_指標2_銷量市佔率.index + 1  # shifting index
        #         df_指標2_銷量市佔率.sort_index(inplace=True) 





                # # =================================== 8-3.指標_MAT_洗衣粉_每公升均價(元) ===================================
                dfs = [df_指標1_銷額市佔率, df_指標2_銷量市佔率]
                df_指標3_每公升均價 = reduce(lambda left,right: pd.merge(left, right, how = "outer", on = [訴求_column, '自定義品牌', "系列(一匙靈專用)"]), dfs)

                df_指標3_每公升均價["每公升均價(元)"] = df_指標3_每公升均價["品項_品牌_系列_正確價錢"] / df_指標3_每公升均價["品項_品牌_系列_總容量"] * 1000
                df_指標3_每公升均價





                # # =================================== 8-4.指標_MAT_洗衣粉_每次購買金額(元) ===================================
                # # =================================== 8-5.指標_MAT_洗衣粉_每次購買量(公升) ===================================
                df_copy = df_單一通路
                df_copy = df_copy.reset_index(drop = True)

                df_corss_variable_distinct_invNum = df_copy.loc[:, ["xdid", "invNum", "自定義品牌", "系列(一匙靈專用)"]]



                df_copy = df_單一通路
                df_copy = df_copy.reset_index(drop = True)


                df_copy = df_copy.loc[df_copy[訴求_column] == 訴求_value, :].reset_index(drop = True)


                #----------------------------------------------------------------------------------
                df_corss_variable_distinct_invNum = df_copy.loc[:, ["xdid", "invNum", "自定義品牌", "系列(一匙靈專用)", 訴求_column, "正確價錢", "總容量"]]
                df_corss_variable_distinct_invNum['自定義品牌_系列_訴求'] = df_corss_variable_distinct_invNum[['自定義品牌', '系列(一匙靈專用)', 訴求_column]].apply(lambda x: ','.join(x), axis=1)
                #----------------------------------------------------------------------------------

                # 訴求各品牌各系列
                df_自定義品牌_系列_訴求 = df_corss_variable_distinct_invNum[['自定義品牌_系列_訴求']].drop_duplicates().reset_index(drop = True)
                df_自定義品牌_系列_訴求["不重複的發票編號"] = ""
                df_自定義品牌_系列_訴求["總發票張數(不重複)"] = ""

                for i in range(0, len(df_自定義品牌_系列_訴求["自定義品牌_系列_訴求"])) :
                    不重複的發票編號_list = []
                    for j in range(0, len(df_corss_variable_distinct_invNum["自定義品牌_系列_訴求"])) :
                        if df_自定義品牌_系列_訴求["自定義品牌_系列_訴求"][i] == df_corss_variable_distinct_invNum["自定義品牌_系列_訴求"][j] :
                            不重複的發票編號_list.append(df_corss_variable_distinct_invNum["invNum"][j])
                        else :
                            None
                    df_自定義品牌_系列_訴求["不重複的發票編號"][i] = list(set(不重複的發票編號_list))
                    df_自定義品牌_系列_訴求["總發票張數(不重複)"][i] = len(list(set(不重複的發票編號_list)))
                    不重複的發票編號_list = []
                #--------------
                # 各品牌Total    
                df_自定義品牌_系列_訴求_Total = df_corss_variable_distinct_invNum[['自定義品牌']].drop_duplicates().reset_index(drop = True)
                df_自定義品牌_系列_訴求_Total["系列(一匙靈專用)"] = "Total"
                # 訴求
                df_自定義品牌_系列_訴求_Total[訴求_column] = 訴求_value

                df_自定義品牌_系列_訴求_Total["不重複的發票編號"] = ""
                df_自定義品牌_系列_訴求_Total["總發票張數(不重複)"] = ""    

                for i in range(0, len(df_自定義品牌_系列_訴求_Total["自定義品牌"])) :
                    不重複的發票編號_list = []
                    for j in range(0, len(df_corss_variable_distinct_invNum["自定義品牌"])) :
                        if df_自定義品牌_系列_訴求_Total["自定義品牌"][i] == df_corss_variable_distinct_invNum["自定義品牌"][j] :
                            不重複的發票編號_list.append(df_corss_variable_distinct_invNum["invNum"][j])
                        else :
                            None
                    df_自定義品牌_系列_訴求_Total["不重複的發票編號"][i] = list(set(不重複的發票編號_list))
                    df_自定義品牌_系列_訴求_Total["總發票張數(不重複)"][i] = len(list(set(不重複的發票編號_list)))
                    不重複的發票編號_list = []
                #----------------------------------------------------------------------------------            
                # 彙整
                df_自定義品牌_系列_訴求["自定義品牌"] = df_自定義品牌_系列_訴求["自定義品牌_系列_訴求"].apply(lambda x: x.split(',')[0])
                df_自定義品牌_系列_訴求["系列(一匙靈專用)"] = df_自定義品牌_系列_訴求["自定義品牌_系列_訴求"].apply(lambda x: x.split(',')[1])
                df_自定義品牌_系列_訴求[訴求_column] = df_自定義品牌_系列_訴求["自定義品牌_系列_訴求"].apply(lambda x: x.split(',')[2])

                df_自定義品牌_系列_訴求_看各系列不重複發票數 = df_自定義品牌_系列_訴求[[訴求_column, "自定義品牌", "系列(一匙靈專用)", "總發票張數(不重複)"]]

                df_自定義品牌_系列_訴求_看各品牌Total不重複發票數 = df_自定義品牌_系列_訴求_Total[[訴求_column, "自定義品牌", "系列(一匙靈專用)", "總發票張數(不重複)"]]
                #----------------------------------------------------------------------------------
                # 各品牌x各系列
                df_1 = df_自定義品牌_系列_訴求_看各系列不重複發票數
                # 各品牌
                df_2 = df_自定義品牌_系列_訴求_看各品牌Total不重複發票數
                # 總表
                df_自定義品牌_系列_訴求_不重複發票數_總表 = pd.concat([df_1, df_2], axis = 0).reset_index(drop = True)
        #         #----------------------------------------------------------------------------------
        #         # 插入 訴求 SubTotal
        #         #----------------------------------------------------------------------------------
        #         df_corss_variable_distinct_invNum = df_copy.loc[:, ["xdid", "invNum", "自定義品牌", "系列(一匙靈專用)", 訴求_column, "正確價錢", "總容量"]]

        #         洗衣粉_單一通路_每次購買金額_不重複總發票張數 = []
        #         for i in range(0, len(df_corss_variable_distinct_invNum["invNum"])) :
        #             洗衣粉_單一通路_每次購買金額_不重複總發票張數.append(df_corss_variable_distinct_invNum["invNum"][i])
        #         洗衣粉_單一通路_每次購買金額_不重複總發票張數 = len(list(set(洗衣粉_單一通路_每次購買金額_不重複總發票張數)))

        #         df_自定義品牌_系列_訴求_不重複發票數_總表.loc[-1] = [訴求_value, '-', 'SubTotal', 洗衣粉_單一通路_每次購買金額_不重複總發票張數]  # adding a row 
        #         df_自定義品牌_系列_訴求_不重複發票數_總表.index = df_自定義品牌_系列_訴求_不重複發票數_總表.index + 1  # shifting index
        #         df_自定義品牌_系列_訴求_不重複發票數_總表.sort_index(inplace=True) 

                #----------------------------------------------------------------------------------    
                df_指標4_每次購買金額_指標5_每次購買量 = pd.merge(df_指標3_每公升均價, df_自定義品牌_系列_訴求_不重複發票數_總表, on = [訴求_column, '自定義品牌', "系列(一匙靈專用)"], how = "outer")
                df_指標4_每次購買金額_指標5_每次購買量["每次購買金額(元)"] = df_指標4_每次購買金額_指標5_每次購買量["品項_品牌_系列_正確價錢"] / df_指標4_每次購買金額_指標5_每次購買量["總發票張數(不重複)"]
                df_指標4_每次購買金額_指標5_每次購買量["每次購買量(公升)"] = df_指標4_每次購買金額_指標5_每次購買量["品項_品牌_系列_總容量"] / df_指標4_每次購買金額_指標5_每次購買量["總發票張數(不重複)"] / 1000
                #----------------------------------------------------------------------------------







                # # =================================== 8-6.指標_MAT_洗衣粉_平均購買次數 ===================================
                # 這裡有篩選條件需要選到 "品項" : "洗衣粉" !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!

                df_copy_2 = df_整理
                df_copy_3 = df_copy_2
                df_copy_4 = df_copy_2


        #         df_copy_2 = df_copy_2.loc[df_copy_2[訴求_column] == 訴求_value, :].reset_index(drop = True)





                # =================================== 挑有買過兩張發票的裝置 xdid ===================================
                #---------------------------------------------------------------------------------------------------------

                #---------------------------------------------------------------------------------------------------------
                # for df_copy_2 : 要找到 總裝置數 的 那些"裝置(xdid)"候選人名單
                # =================================== 0. 挑有買過2張以上發票的裝置 =================================== 
                # 挑有買過兩張發票的裝置

                df_all_of_xdid_with_multiple_invNum_list = df_copy_2


                df_all_of_xdid_with_multiple_invNum_list = df_copy_2.loc[:, [訴求_column, "xdid", "invNum"]]
                # 將裝置數missing的刪除
                df_all_of_xdid_with_multiple_invNum_list = df_all_of_xdid_with_multiple_invNum_list.loc[df_all_of_xdid_with_multiple_invNum_list["xdid"] != "missing" ]
                df_all_of_xdid_with_multiple_invNum_list = df_all_of_xdid_with_multiple_invNum_list.drop_duplicates().reset_index(drop = True)

                df_all_of_xdid_with_multiple_invNum_list = df_all_of_xdid_with_multiple_invNum_list.groupby(["xdid"])['invNum'].nunique()

                df_all_of_xdid_with_multiple_invNum_list = df_all_of_xdid_with_multiple_invNum_list[df_all_of_xdid_with_multiple_invNum_list > 1]
                df_all_of_xdid_with_multiple_invNum_list = df_all_of_xdid_with_multiple_invNum_list.to_frame().reset_index()
                # #---------------------------------------------------------------------------------------------------------
                # < 交叉變項 : 總裝置數 的 那些"裝置(xdid)"候選人名單 >
                df_all_of_xdid_with_multiple_invNum_list = list(set(df_all_of_xdid_with_multiple_invNum_list["xdid"]))

                #---------------------------------------------------------------------------------------------------------
                # for df_copy_3 : 要從原始資料 找到 符合那些裝置候選人名單 & 符合後續條件 的那些row



                df_copy_3 = df_copy_3.loc[df_copy_3[訴求_column] == 訴求_value, :].reset_index(drop = True)



                # < 交叉變項 : 總裝置數 的 那些"裝置(xdid)"候選人名單 ；待會兒要加上 原本1~5的篩選條件 再得到 df，最後才要groupby >
                df_copy_3 = df_copy_3[df_copy_3['xdid'].isin(df_all_of_xdid_with_multiple_invNum_list)]
                # =================================== 1. 處理與否 = 1 =================================== 
                df_copy_3 = df_copy_3[df_copy_3["處理與否"] == 1]
                # =================================== 2. 總容量有值 且 >=1 =================================== 
                df_copy_3 = df_copy_3[np.isfinite(df_copy_3['總容量'])]
                df_copy_3 = df_copy_3[df_copy_3['總容量'] >= 0]
                # =================================== 3.時間_MAT ===================================
                df_copy_3 = df_copy_3[(df_copy_3['invDate_datetime'] >= str(A_1)) & (df_copy_3['invDate_datetime'] < str(A_2))]
                # =================================== 4.品類_洗衣粉 - < 至少有一張發票有買到該品項 > ===================================
                df_copy_3 = df_copy_3[df_copy_3["品類_list"] == 1]
                # =================================== 5.通路_單一通路 =================================== 
                df_copy_3 = df_copy_3 #單一通路

                #單一通路
                df_copy_3 = df_copy_3[df_copy_3[str(通路的變數欄位名稱)] == str(通路的變數欄位之篩選條件)] 
                df_copy_3 = df_copy_3.reset_index(drop = True)  


                # Grand Total
                平均購買次數_總裝置數_list_of_xdid__with_multiple_invNum = len(list(set(df_copy_3["xdid"])))



                # Count unique values with pandas per groups
                df_平均購買次數_總裝置數 = df_copy_3.groupby([訴求_column, "自定義品牌", "系列(一匙靈專用)"])['xdid'].nunique()










                #---------------------------------------------------------------------------------------------------------
                # for df_copy_4 : 要找到總發票張數 : 1.挑有2張發票的裝置  2.其中有買到該品項的發票皆列入

                # 挑有買過兩張發票的裝置

                df_all_of_xdid_with_multiple_invNum_list = df_copy_2

                df_all_of_xdid_with_multiple_invNum_list = df_copy_2.loc[:, [訴求_column, "xdid", "invNum"]]
                # 將裝置數missing的保留
                # df_all_of_xdid_with_multiple_invNum_list = df_all_of_xdid_with_multiple_invNum_list.loc[df_all_of_xdid_with_multiple_invNum_list["xdid"] != "missing" ]
                df_all_of_xdid_with_multiple_invNum_list = df_all_of_xdid_with_multiple_invNum_list.drop_duplicates().reset_index(drop = True)

                df_all_of_xdid_with_multiple_invNum_list = df_all_of_xdid_with_multiple_invNum_list.groupby(["xdid"])['invNum'].nunique()

                df_all_of_xdid_with_multiple_invNum_list = df_all_of_xdid_with_multiple_invNum_list[df_all_of_xdid_with_multiple_invNum_list > 1]
                df_all_of_xdid_with_multiple_invNum_list = df_all_of_xdid_with_multiple_invNum_list.to_frame().reset_index()


                # #---------------------------------------------------------------------------------------------------------
                # < 交叉變項 : 總裝置數 的 那些"裝置(xdid)"候選人名單 >
                list_of_xdid__with_multiple_invNum = list(set(df_all_of_xdid_with_multiple_invNum_list["xdid"]))



                df_copy_4 = df_copy_4[df_copy_4['xdid'].isin(list_of_xdid__with_multiple_invNum)]


                df_copy_4 = df_copy_4.loc[df_copy_4[訴求_column] == 訴求_value, :].reset_index(drop = True)        



                # < 交叉變項 : 總裝置數 的 那些"裝置(xdid)"候選人名單 加上 原本1~5的篩選條件所得到的 df，接下來要groupby了 >
                # =================================== 1. 處理與否 = 1 =================================== 
                df_copy_4 = df_copy_4[df_copy_4["處理與否"] == 1]
                # =================================== 2. 總容量有值 且 >=1 =================================== 
                df_copy_4 = df_copy_4[np.isfinite(df_copy_4['總容量'])]
                df_copy_4 = df_copy_4[df_copy_4['總容量'] >= 0]
                # =================================== 3.時間_MAT ===================================    
                df_copy_4 = df_copy_4[(df_copy_4['invDate_datetime'] >= str(A_1)) & (df_copy_4['invDate_datetime'] < str(A_2))]
                # =================================== 4.品類_洗衣粉 - < 有買到該品項的皆列入 > ===================================
                df_copy_4 = df_copy_4[df_copy_4["品類_list"] == 1]

                # =================================== 5.通路_單一通路 =================================== 
                #單一通路
                df_copy_4 = df_copy_4[df_copy_4[str(通路的變數欄位名稱)] == str(通路的變數欄位之篩選條件)] 
                df_copy_4 = df_copy_4.reset_index(drop = True)  


                # 平均購買次數_總發票張數_(Grand_Total)
                list_of_invNum__by_xdid__with_multiple_invNum = len(list(set(df_copy_4["invNum"])))



                # Count unique values with pandas per groups
                df_平均購買次數_總發票張數 = df_copy_4.groupby([訴求_column, "自定義品牌", "系列(一匙靈專用)"])['invNum'].nunique()

                # # =================================== 8-6.指標_MAT_洗衣粉_平均購買次數 ===================================
                df_平均購買次數_總發票張數 = df_平均購買次數_總發票張數.to_frame().reset_index()
                df_平均購買次數_總裝置數 = df_平均購買次數_總裝置數.to_frame().reset_index()

                df_平均購買次數 = pd.merge(df_平均購買次數_總發票張數, df_平均購買次數_總裝置數, on = [訴求_column, "自定義品牌", "系列(一匙靈專用)"], how = "outer")
                df_平均購買次數["平均購買次數"] = df_平均購買次數["invNum"] / df_平均購買次數["xdid"]




                # 各品牌_Total_平均購買次數
                df_平均購買次數_total = pd.DataFrame()
                list_平均購買次數_自定義品牌 = list(set(df_平均購買次數['自定義品牌']))
                平均購買次數_系列_total = []
                平均購買次數_訴求_total = []
                for i in range(0, len(list_平均購買次數_自定義品牌)) :
                    平均購買次數_系列_total.append("Total")
                    平均購買次數_訴求_total.append(訴求_value)

                df_平均購買次數_total["自定義品牌"] = list_平均購買次數_自定義品牌
                df_平均購買次數_total["系列(一匙靈專用)"] = 平均購買次數_系列_total
                # 訴求
        #         df_平均購買次數_total[訴求_column] = 訴求_value 
                df_平均購買次數_total[訴求_column] = 平均購買次數_訴求_total

                df_平均購買次數_total = pd.merge(df_平均購買次數_total, df_copy_3.groupby([訴求_column, "自定義品牌"])['xdid'].nunique().to_frame(), on = ["自定義品牌"])
                df_平均購買次數_total = pd.merge(df_平均購買次數_total, df_copy_4.groupby([訴求_column, "自定義品牌"])['invNum'].nunique().to_frame(), on = ["自定義品牌"])
                df_平均購買次數_total["平均購買次數"] = df_平均購買次數_total["invNum"] / df_平均購買次數_total["xdid"]
                # concat 品牌_各系列 和 品牌_total
                df_指標6_平均購買次數 = pd.concat([df_平均購買次數, df_平均購買次數_total], axis = 0)












        # #         #----------------------------------------------------------------------------------
        # #         # 插入 訴求 SubTotal
        # #         #----------------------------------------------------------------------------------
        # #         df_corss_variable_distinct_invNum = df_copy.loc[:, ["xdid", "invNum", "自定義品牌", "系列(一匙靈專用)", 訴求_column, "正確價錢", "總容量"]]

        # #         洗衣粉_單一通路_每次購買金額_不重複總發票張數 = []
        # #         for i in range(0, len(df_corss_variable_distinct_invNum["invNum"])) :
        # #             洗衣粉_單一通路_每次購買金額_不重複總發票張數.append(df_corss_variable_distinct_invNum["invNum"][i])
        # #         洗衣粉_單一通路_每次購買金額_不重複總發票張數 = len(list(set(洗衣粉_單一通路_每次購買金額_不重複總發票張數)))

        # #         df_自定義品牌_系列_訴求_不重複發票數_總表.loc[-1] = [訴求_value, '-', 'SubTotal', 洗衣粉_單一通路_每次購買金額_不重複總發票張數]  # adding a row 
        # #         df_自定義品牌_系列_訴求_不重複發票數_總表.index = df_自定義品牌_系列_訴求_不重複發票數_總表.index + 1  # shifting index
        # #         df_自定義品牌_系列_訴求_不重複發票數_總表.sort_index(inplace=True) 

        # #         #----------------------------------------------------------------------------------    
        # #         df_指標4_每次購買金額_指標5_每次購買量 = pd.merge(df_指標3_每公升均價, df_自定義品牌_系列_訴求_不重複發票數_總表, on = [訴求_column, '自定義品牌', "系列(一匙靈專用)"])
        # #         df_指標4_每次購買金額_指標5_每次購買量["每次購買金額(元)"] = df_指標4_每次購買金額_指標5_每次購買量["品項_品牌_系列_正確價錢"] / df_指標4_每次購買金額_指標5_每次購買量["總發票張數(不重複)"]
        # #         df_指標4_每次購買金額_指標5_每次購買量["每次購買量(公升)"] = df_指標4_每次購買金額_指標5_每次購買量["品項_品牌_系列_總容量"] / df_指標4_每次購買金額_指標5_每次購買量["總發票張數(不重複)"] / 1000
        # #         #----------------------------------------------------------------------------------



        # #         # 指標總表_1_2_3_4_5_6_7_8 = pd.merge(指標總表_1_2_3_4_5, df_指標6_平均購買次數, on = ['自定義品牌', "系列(一匙靈專用)"])


                dfs = [df_指標4_每次購買金額_指標5_每次購買量, df_指標6_平均購買次數]
                指標總表_1_2_3_4_5_6_7_8 = reduce(lambda left,right: pd.merge(left, right, how = "outer", on = [訴求_column, '自定義品牌', "系列(一匙靈專用)"]), dfs)

                # =============================================================================================================================
                # 在算 "df_指標 7 _每人平均花費" 之前 :
                # 手動修改的例外 : 
                #    如果銷額、銷量有值 
                # -> 從 6.平均購買次數開始，如果因為分母的"總裝置數"為0而造成後面運算結果為NA， 就要把平均購買次數補成"1"


                指標總表_1_2_3_4_5_6_7_8.loc[ (指標總表_1_2_3_4_5_6_7_8["平均購買次數"].isnull() == True)  & ((指標總表_1_2_3_4_5_6_7_8['銷額市佔率'] != None) | (指標總表_1_2_3_4_5_6_7_8['銷量市佔率'] != None)), ["平均購買次數"]] = 1

                # =============================================================================================================================

                # df_指標7_每人平均花費
                指標總表_1_2_3_4_5_6_7_8["每人平均花費"] = 指標總表_1_2_3_4_5_6_7_8["每次購買金額(元)"] * 指標總表_1_2_3_4_5_6_7_8["平均購買次數"]
                # df_指標8_每人平均購買量
                指標總表_1_2_3_4_5_6_7_8["每人平均購買量"] = 指標總表_1_2_3_4_5_6_7_8["每次購買量(公升)"] * 指標總表_1_2_3_4_5_6_7_8["平均購買次數"]









                # # =================================== 8-9.指標_MAT_洗衣粉_普及率 ===================================
                # # 總裝置數
                # =================================== 挑有買過兩張發票的裝置 xdid ===================================
                df_copy_5 = df_copy_2
                #---------------------------------------------------------------------------------------------------------

                #---------------------------------------------------------------------------------------------------------
                # for df_copy_5 : 要找到 總裝置數 的 那些"裝置(xdid)"候選人名單
                # =================================== 0. 總裝置數 =================================== 


                df_copy_5 = df_copy_5.loc[df_copy_5[訴求_column] == 訴求_value, :].reset_index(drop = True)



                # < 交叉變項 : 總裝置數 >
                df_copy_5 = df_copy_5[df_copy_5['xdid'] != "missing"]
                # =================================== 1. 處理與否 = 1 =================================== 
                df_copy_5 = df_copy_5[df_copy_5["處理與否"] == 1]
                # =================================== 2. 總容量有值 且 >=1 =================================== 
                df_copy_5 = df_copy_5[np.isfinite(df_copy_5['總容量'])]
                df_copy_5 = df_copy_5[df_copy_5['總容量'] >= 0]
                # =================================== 3.時間_MAT ===================================
                df_copy_5 = df_copy_5[(df_copy_5['invDate_datetime'] >= str(A_1)) & (df_copy_5['invDate_datetime'] < str(A_2))]
                # =================================== 4.品類_洗衣粉 - < 至少有一張發票有買到該品項 > ===================================
                df_copy_5 = df_copy_5[df_copy_5["品類_list"] == 1]
                # =================================== 5.通路_單一通路 =================================== 
                # 單一通路
                df_copy_5_單一通路 = df_copy_5 

                #單一通路
                df_copy_5_單一通路 = df_copy_5_單一通路[df_copy_5_單一通路[str(通路的變數欄位名稱)] == str(通路的變數欄位之篩選條件)] 
                df_copy_5_單一通路 = df_copy_5_單一通路.reset_index(drop = True)  




                洗衣粉_市調結果購買率 = float(洗衣粉_市調結果購買率)
                # < 交叉變項 : 總裝置數 >
        #         all_distinct_xdid_of_one_item_list = list(set(df_copy_5_單一通路["xdid"]))
        #         普及率_總裝置數_該品類總裝置數 = len(all_distinct_xdid_of_one_item_list)
                ALL_洗衣粉_ALL_全通路_普及率_總裝置數 = ALL_洗衣粉_ALL_全通路_普及率_總裝置數

                # Count unique values with pandas per groups
                df_指標9_普及率_總裝置數 = df_copy_5_單一通路.groupby([訴求_column, "自定義品牌", "系列(一匙靈專用)"])['xdid'].nunique().to_frame()
                df_指標9_普及率_總裝置數['普及率'] = (df_指標9_普及率_總裝置數['xdid'] / 訴求GT_洗衣粉_訴求GT_單一通路_普及率_總裝置數)
        #         df_指標9_普及率_總裝置數['普及率_除以33915'] = 洗衣粉_市調結果購買率 * (df_指標9_普及率_總裝置數['xdid'] / 33915)
                df_指標9_普及率_總裝置數 = df_指標9_普及率_總裝置數.reset_index()


                # 各品牌 Total
                df_普及率_各品牌_Total_總裝置數 = df_copy_5_單一通路.groupby([訴求_column, "自定義品牌"])['xdid'].nunique().to_frame()

                普及率_各品牌_Total_總裝置數_list = []
                for i in range(0, len(df_普及率_各品牌_Total_總裝置數["xdid"])) :
                    普及率_各品牌_Total_總裝置數_list.append("Total")
                df_普及率_各品牌_Total_總裝置數["系列(一匙靈專用)"] = 普及率_各品牌_Total_總裝置數_list

                df_普及率_各品牌_Total_總裝置數['普及率'] = (df_普及率_各品牌_Total_總裝置數['xdid'] / 訴求GT_洗衣粉_訴求GT_單一通路_普及率_總裝置數)
        #         df_普及率_各品牌_Total_總裝置數['普及率_除以33915'] = 洗衣粉_市調結果購買率 * (df_普及率_各品牌_Total_總裝置數['xdid'] / 33915)
                df_普及率_各品牌_Total_總裝置數 = df_普及率_各品牌_Total_總裝置數.reset_index()


                # concat
                df_指標9_普及率_總裝置數 = pd.concat([df_指標9_普及率_總裝置數, df_普及率_各品牌_Total_總裝置數], axis = 0)
                df_指標9_普及率_總裝置數
                # 總表 - merge
                指標總表_1_2_3_4_5_6_7_8_9_10_11 = pd.merge(指標總表_1_2_3_4_5_6_7_8, df_指標9_普及率_總裝置數, on = [訴求_column, '自定義品牌', "系列(一匙靈專用)"], how = "outer")



                # =============================================================================================================================
                # 在算 "df_指標 9 _普及率" 的下一個指標 之前 :
                # 手動修改的例外 : 
                #    如果銷額、銷量有值 
                # -> 從 9.普及率 開始，如果因為空白的"裝置編號"而造成後面運算結果為NA， 就要把 普及率 強制改成"0"


                指標總表_1_2_3_4_5_6_7_8_9_10_11.loc[ (指標總表_1_2_3_4_5_6_7_8_9_10_11["普及率"].isnull() == True)  & ((指標總表_1_2_3_4_5_6_7_8_9_10_11['銷額市佔率'] != None) | (指標總表_1_2_3_4_5_6_7_8_9_10_11['銷量市佔率'] != None)), ["普及率"]] = 0

                # =============================================================================================================================







                洗衣粉_MAT_某訴求單一通路總金額_Grand_Total = 0
                for i in range(0, len(df_某訴求_單一通路["正確價錢"])) :
                    洗衣粉_MAT_某訴求單一通路總金額_Grand_Total = 洗衣粉_MAT_某訴求單一通路總金額_Grand_Total + float(df_某訴求_單一通路["正確價錢"][i])



                洗衣粉_MAT_某訴求單一通路總容量_Grand_Total = 0
                for i in range(0, len(df_某訴求_單一通路["總容量"])) :
                    洗衣粉_MAT_某訴求單一通路總容量_Grand_Total = 洗衣粉_MAT_某訴求單一通路總容量_Grand_Total + float(df_某訴求_單一通路["總容量"][i])




                # # =================================== 8-10.指標_MAT_洗衣粉_銷售額(百萬元) ===================================
                # # =================================== 8-11.指標_MAT_洗衣粉_銷售量(千公升) ===================================
                # - 6.平均購買次數 - 兩張發票之不重複總發票張數
                洗衣粉_單一通路_平均購買次數_兩張發票之不重複總發票張數 = list_of_invNum__by_xdid__with_multiple_invNum
                # - 6.平均購買次數 - 兩張發票之不重複總裝置數
                洗衣粉_單一通路_平均購買次數_兩張發票之不重複總裝置數 = 平均購買次數_總裝置數_list_of_xdid__with_multiple_invNum
                # 單一通路_平均購買次數
                單一通路_平均購買次數 = 洗衣粉_單一通路_平均購買次數_兩張發票之不重複總發票張數 / 洗衣粉_單一通路_平均購買次數_兩張發票之不重複總裝置數
                單一通路_平均購買次數

                # - 4.每次購買金額 - 總金額
                洗衣粉_單一通路_總銷額 = 洗衣粉_MAT_某訴求單一通路總金額_Grand_Total
                # - 4.每次購買金額 - 不重複總發票張數
                洗衣粉_單一通路_每次購買金額_不重複總發票張數 = []
                for i in range(0, len(df_corss_variable_distinct_invNum["invNum"])) :
                    洗衣粉_單一通路_每次購買金額_不重複總發票張數.append(df_corss_variable_distinct_invNum["invNum"][i])
                洗衣粉_單一通路_每次購買金額_不重複總發票張數 = list(set(洗衣粉_單一通路_每次購買金額_不重複總發票張數))

                洗衣粉_單一通路_每次購買金額_不重複總發票張數 = len(洗衣粉_單一通路_每次購買金額_不重複總發票張數) # 49344
                # 單一通路_每次購買金額
                單一通路_每次購買金額 = 洗衣粉_單一通路_總銷額 / 洗衣粉_單一通路_每次購買金額_不重複總發票張數


                # - 5.每次購買量 - 總容量
                洗衣粉_單一通路_總容量 = 洗衣粉_MAT_某訴求單一通路總容量_Grand_Total
                # 單一通路_每次購買量
                單一通路_每次購買量 = 洗衣粉_單一通路_總容量 / 洗衣粉_單一通路_每次購買金額_不重複總發票張數 #/ 1000




                # 該通路銷額佔比
                # 單一通路_銷額佔比
                單一通路_銷額佔比 = 訴求GT_洗衣粉_單一通路_總銷額 / ALL_洗衣粉_全通路_總銷額
                # 單一通路_銷額佔比
                # 單一通路_銷額佔比 =                  / 洗衣粉_單一通路_總銷額


                # 單一通路_銷量
                單一通路_銷量佔比 = 訴求GT_洗衣粉_單一通路_總容量 / ALL_洗衣粉_全通路_總容量













                全台家戶數 = float(全台家戶數)
                洗衣粉_市調結果購買率 = float(洗衣粉_市調結果購買率)

                # 單一通路_銷額市佔率
                單一通路_銷額市佔率 = 洗衣粉_單一通路_總銷額 / 訴求GT_洗衣粉_單一通路_總銷額
                # 單一通路_銷量市佔率
                單一通路_銷量市佔率 = 洗衣粉_單一通路_總容量 / 訴求GT_洗衣粉_單一通路_總容量
                # 單一通路_每公升均價(元)
                單一通路_每公升均價 = 洗衣粉_單一通路_總銷額 / 洗衣粉_單一通路_總容量 * 1000
                # 單一通路_每次購買金額(元)
                單一通路_每次購買金額 = 洗衣粉_單一通路_總銷額 / 洗衣粉_單一通路_每次購買金額_不重複總發票張數
                # 單一通路_每次購買量(公升)
                單一通路_每次購買量 = 洗衣粉_單一通路_總容量 / 洗衣粉_單一通路_每次購買金額_不重複總發票張數 / 1000
                # 單一通路_平均購買次數
                單一通路_平均購買次數 = 洗衣粉_單一通路_平均購買次數_兩張發票之不重複總發票張數 / 洗衣粉_單一通路_平均購買次數_兩張發票之不重複總裝置數
                # 單一通路_每人平均花費
                單一通路_每人平均花費 = 單一通路_每次購買金額 * 單一通路_平均購買次數
                # 單一通路_每人平均購買量
                單一通路_每人平均購買量 = 單一通路_每次購買量 * 單一通路_平均購買次數


                # < 交叉變項 : 總裝置數 >
                all_distinct_xdid_of_one_item_list = list(set(df_copy_5_單一通路["xdid"]))
                普及率_總裝置數_該品類總裝置數 = len(all_distinct_xdid_of_one_item_list)
                洗衣粉_單一通路_普及率_總裝置數 = 普及率_總裝置數_該品類總裝置數 
                # 單一通路_普及率
                單一通路_普及率 = (洗衣粉_單一通路_普及率_總裝置數 / 訴求GT_洗衣粉_訴求GT_單一通路_普及率_總裝置數)



                # 洗衣粉_單一通路_普及率_總裝置數 = 
                # 單一通路_普及率_除以33915 = 洗衣粉_市調結果購買率 * (洗衣粉_單一通路_普及率_總裝置數 / 洗衣粉_單一通路_普及率_總裝置數)

                # 單一通路_銷售額(百萬元)
                單一通路_銷售額 = 全台家戶數 * 洗衣粉_市調結果購買率 * ALL_全通路_平均購買次數 * ALL_全通路_每次購買金額 / 1000000 * (訴求GT_洗衣粉_單一通路_總銷額 / ALL_洗衣粉_全通路_總銷額) * 單一通路_銷額市佔率  
                # 單一通路_銷售量(千公升)
                單一通路_銷售量 = 全台家戶數 * 洗衣粉_市調結果購買率 * ALL_全通路_平均購買次數 * ALL_全通路_每次購買量 / 1000 * (訴求GT_洗衣粉_單一通路_總容量 / ALL_洗衣粉_全通路_總容量) * 單一通路_銷量市佔率

                # 銷售額(百萬元)
                指標總表_1_2_3_4_5_6_7_8_9_10_11["銷售額(百萬元)"] = 全台家戶數 * 洗衣粉_市調結果購買率 * ALL_全通路_平均購買次數 * ALL_全通路_每次購買金額 / 1000000 * 單一通路_銷額佔比 * 指標總表_1_2_3_4_5_6_7_8_9_10_11["銷額市佔率"]   
                # 銷售量(千公升)
                指標總表_1_2_3_4_5_6_7_8_9_10_11["銷售量(千公升)"] = 全台家戶數 * 洗衣粉_市調結果購買率 * ALL_全通路_平均購買次數 * ALL_全通路_每次購買量 / 1000 * 單一通路_銷量佔比 * 指標總表_1_2_3_4_5_6_7_8_9_10_11["銷量市佔率"]   

                # # =================================== 8-12.MAT_洗衣粉_加入Grand_Total ===================================

                # 在加入Grand_Total之前 : sort_values
                指標總表_1_2_3_4_5_6_7_8_9_10_11 = 指標總表_1_2_3_4_5_6_7_8_9_10_11.sort_values(by=['銷額市佔率'], ascending=[False])
                指標總表_1_2_3_4_5_6_7_8_9_10_11 = 指標總表_1_2_3_4_5_6_7_8_9_10_11.reset_index(drop=True) 

                # 挑選適當欄位 : 只留11個指標當作column
                指標總表_1_2_3_4_5_6_7_8_9_10_11 = 指標總表_1_2_3_4_5_6_7_8_9_10_11[[訴求_column, "自定義品牌", "系列(一匙靈專用)", "銷額市佔率", "銷量市佔率", "每公升均價(元)", "每次購買金額(元)", "每次購買量(公升)", "平均購買次數", "每人平均花費", "每人平均購買量", "普及率", "銷售額(百萬元)", "銷售量(千公升)"]]


                # adding a row : SubTotal
                指標總表_1_2_3_4_5_6_7_8_9_10_11.loc[-1] = [訴求_value, "-", "SubTotal", 單一通路_銷額市佔率, 單一通路_銷量市佔率, 單一通路_每公升均價, 單一通路_每次購買金額, 單一通路_每次購買量, 單一通路_平均購買次數, 單一通路_每人平均花費, 單一通路_每人平均購買量, 單一通路_普及率, 單一通路_銷售額, 單一通路_銷售量]  # adding a row 
                指標總表_1_2_3_4_5_6_7_8_9_10_11.index = 指標總表_1_2_3_4_5_6_7_8_9_10_11.index + 1  # shifting index
                指標總表_1_2_3_4_5_6_7_8_9_10_11.sort_index(inplace=True) 

                return 指標總表_1_2_3_4_5_6_7_8_9_10_11
            
            
            except :
            
                指標總表_1_2_3_4_5_6_7_8_9_10_11 = pd.DataFrame()

                return 指標總表_1_2_3_4_5_6_7_8_9_10_11
            
            
            

            
    
        訴求正面敘述 = YTD_單一通路_個別_訴求(訴求_column, 訴求_column, A_1, A_2, 品類_list, 通路的變數欄位名稱, 通路的變數欄位之篩選條件, 全台家戶數, 洗衣粉_市調結果購買率)


       #     訴求_value = "非"+str(訴求_column) # 新增的作法
        訴求反面敘述 = YTD_單一通路_個別_訴求(訴求_column, "非"+str(訴求_column), A_1, A_2, 品類_list, 通路的變數欄位名稱, 通路的變數欄位之篩選條件, 全台家戶數, 洗衣粉_市調結果購買率)
       #     訴求反面敘述

        df_all = pd.concat([訴求正面敘述, 訴求反面敘述], axis = 0).reset_index(drop = True)
#            # 把排序用的欄位drop掉
#         df_all = df_all.drop(["訴求_表頭順序", "系列_表頭順序", "品牌_表頭順序", "總排序"], axis = 1)




    
    #     # 把排序用的欄位drop掉
    #     df_all = df_all.drop(["訴求_表頭順序", "系列_表頭順序", "品牌_表頭順序", "總排序"], axis = 1)

        # adding a row : Grand Total
        df_all.loc[-1] = ["-", "-", "Grand Total", 訴求GT_單一通路_銷額市佔率, 訴求GT_單一通路_銷量市佔率, 訴求GT_單一通路_每公升均價, 訴求GT_單一通路_每次購買金額, 訴求GT_單一通路_每次購買量, 訴求GT_單一通路_平均購買次數, 訴求GT_單一通路_每人平均花費, 訴求GT_單一通路_每人平均購買量, 訴求GT_單一通路_普及率, 訴求GT_單一通路_銷售額, 訴求GT_單一通路_銷售量]  # adding a row 
        df_all.index = df_all.index + 1  # shifting index
        df_all.sort_index(inplace=True)




#         # =============================================================================================================================
#         # 讀MAT表頭

#         df_all = pd.merge(MAT_表頭, df_all, how = "left", on = [訴求_column, "自定義品牌", "系列(一匙靈專用)"])

#         # =============================================================================================================================



        # 去掉整個row都沒有值的品牌系列
#         df_all = df_all.set_index([訴求_column, "自定義品牌", "系列(一匙靈專用)"])
        df_all = df_all.replace("-", np.nan)
        df_all = df_all.dropna(how = "all")
        df_all = df_all.fillna("-")


        return df_all





    
    
    
    
    
    





    
    def YTD報表(x_1, x_2, y_1, y_2, x_3, y_3) :

        Year_2017_month_01_02_YTD_全通路 = YTD_單一通路_總_訴求(訴求_column, x_1, x_2, 品類_list, 通路的變數欄位名稱, 通路的變數欄位之篩選條件, 全台家戶數, 洗衣粉_市調結果購買率)
        Year_2018_month_01_02_YTD_全通路 = YTD_單一通路_總_訴求(訴求_column, y_1, y_2, 品類_list, 通路的變數欄位名稱, 通路的變數欄位之篩選條件, 全台家戶數, 洗衣粉_市調結果購買率)


        


        dfs = [Year_2017_month_01_02_YTD_全通路, Year_2018_month_01_02_YTD_全通路]
        Year_2017_2018_month_01_02_YTD_全通路 = reduce(lambda left,right: pd.merge(left, right, how = "outer", on = [訴求_column, '自定義品牌', "系列(一匙靈專用)"]), dfs)


        # 1 銷額市佔率_差異
        Year_2017_2018_month_01_02_YTD_全通路["銷額市佔率_差異"] = Year_2017_2018_month_01_02_YTD_全通路["銷額市佔率_y"] - Year_2017_2018_month_01_02_YTD_全通路["銷額市佔率_x"]
        # 2 銷量市佔率_差異
        Year_2017_2018_month_01_02_YTD_全通路["銷量市佔率_差異"] = Year_2017_2018_month_01_02_YTD_全通路["銷量市佔率_y"] - Year_2017_2018_month_01_02_YTD_全通路["銷量市佔率_x"]
        # 3 每公升均價(元)_成長率
        try :
            Year_2017_2018_month_01_02_YTD_全通路["每公升均價(元)_成長率"] = (Year_2017_2018_month_01_02_YTD_全通路["每公升均價(元)_y"] - Year_2017_2018_month_01_02_YTD_全通路["每公升均價(元)_x"]) / Year_2017_2018_month_01_02_YTD_全通路["每公升均價(元)_x"]
        except :
#             Year_2017_2018_month_01_02_YTD_全通路["每公升均價(元)_成長率"] = "-"
            Year_2017_2018_month_01_02_YTD_全通路["每公升均價(元)_成長率"] = pd.Series()
            for i in range(0, len(Year_2017_2018_month_01_02_YTD_全通路["每公升均價(元)_成長率"])) :
                if Year_2017_2018_month_01_02_YTD_全通路["每公升均價(元)_x"][i] == 0 :
                    Year_2017_2018_month_01_02_YTD_全通路["每公升均價(元)_成長率"][i] == "-"
                else :
                    Year_2017_2018_month_01_02_YTD_全通路["每公升均價(元)_成長率"][i] = (Year_2017_2018_month_01_02_YTD_全通路["每公升均價(元)_y"][i] - Year_2017_2018_month_01_02_YTD_全通路["每公升均價(元)_x"][i]) / Year_2017_2018_month_01_02_YTD_全通路["每公升均價(元)_x"][i]
        # 4 每次購買金額(元)_成長率
        try :
            Year_2017_2018_month_01_02_YTD_全通路["每次購買金額(元)_成長率"] = (Year_2017_2018_month_01_02_YTD_全通路["每次購買金額(元)_y"] - Year_2017_2018_month_01_02_YTD_全通路["每次購買金額(元)_x"]) / Year_2017_2018_month_01_02_YTD_全通路["每次購買金額(元)_x"]
        except :
#             Year_2017_2018_month_01_02_YTD_全通路["每次購買金額(元)_成長率"] = "-"
            Year_2017_2018_month_01_02_YTD_全通路["每次購買金額(元)_成長率"] = pd.Series()
            for i in range(0, len(Year_2017_2018_month_01_02_YTD_全通路["每次購買金額(元)_成長率"])) :
                if Year_2017_2018_month_01_02_YTD_全通路["每次購買金額(元)_x"][i] == 0 :
                    Year_2017_2018_month_01_02_YTD_全通路["每次購買金額(元)_成長率"][i] == "-"
                else :
                    Year_2017_2018_month_01_02_YTD_全通路["每次購買金額(元)_成長率"][i] = (Year_2017_2018_month_01_02_YTD_全通路["每次購買金額(元)_y"][i] - Year_2017_2018_month_01_02_YTD_全通路["每次購買金額(元)_x"][i]) / Year_2017_2018_month_01_02_YTD_全通路["每次購買金額(元)_x"][i]
        # 5 每次購買量(公升)_成長率
        try :
            Year_2017_2018_month_01_02_YTD_全通路["每次購買量(公升)_成長率"] = (Year_2017_2018_month_01_02_YTD_全通路["每次購買量(公升)_y"] - Year_2017_2018_month_01_02_YTD_全通路["每次購買量(公升)_x"]) / Year_2017_2018_month_01_02_YTD_全通路["每次購買量(公升)_x"]
        except :
#             Year_2017_2018_month_01_02_YTD_全通路["每次購買量(公升)_成長率"] = "-"
            Year_2017_2018_month_01_02_YTD_全通路["每次購買量(公升)_成長率"] = pd.Series()
            for i in range(0, len(Year_2017_2018_month_01_02_YTD_全通路["每次購買量(公升)_成長率"])) :
                if Year_2017_2018_month_01_02_YTD_全通路["每次購買量(公升)_x"][i] == 0 :
                    Year_2017_2018_month_01_02_YTD_全通路["每次購買量(公升)_成長率"][i] == "-"
                else :
                    Year_2017_2018_month_01_02_YTD_全通路["每次購買量(公升)_成長率"][i] = (Year_2017_2018_month_01_02_YTD_全通路["每次購買量(公升)_y"][i] - Year_2017_2018_month_01_02_YTD_全通路["每次購買量(公升)_x"][i]) / Year_2017_2018_month_01_02_YTD_全通路["每次購買量(公升)_x"][i]
        # 6 平均購買次數_差異
        Year_2017_2018_month_01_02_YTD_全通路["平均購買次數_差異"] = Year_2017_2018_month_01_02_YTD_全通路["平均購買次數_y"] - Year_2017_2018_month_01_02_YTD_全通路["平均購買次數_x"]
        # 7 每人平均花費_成長率
        try :
            Year_2017_2018_month_01_02_YTD_全通路["每人平均花費_成長率"] = (Year_2017_2018_month_01_02_YTD_全通路["每人平均花費_y"] - Year_2017_2018_month_01_02_YTD_全通路["每人平均花費_x"]) / Year_2017_2018_month_01_02_YTD_全通路["每人平均花費_x"]
        except :
#             Year_2017_2018_month_01_02_YTD_全通路["每人平均花費_成長率"] = "-"
            Year_2017_2018_month_01_02_YTD_全通路["每人平均花費_成長率"] = pd.Series()
            for i in range(0, len(Year_2017_2018_month_01_02_YTD_全通路["每人平均花費_成長率"])) :
                if Year_2017_2018_month_01_02_YTD_全通路["每人平均花費_x"][i] == 0 :
                    Year_2017_2018_month_01_02_YTD_全通路["每人平均花費_成長率"][i] == "-"
                else :
                    Year_2017_2018_month_01_02_YTD_全通路["每人平均花費_成長率"][i] = (Year_2017_2018_month_01_02_YTD_全通路["每人平均花費_y"][i] - Year_2017_2018_month_01_02_YTD_全通路["每人平均花費_x"][i]) / Year_2017_2018_month_01_02_YTD_全通路["每人平均花費_x"][i]
        # 8 每人平均購買量_成長率
        try :
            Year_2017_2018_month_01_02_YTD_全通路["每人平均購買量_成長率"] = (Year_2017_2018_month_01_02_YTD_全通路["每人平均購買量_y"] - Year_2017_2018_month_01_02_YTD_全通路["每人平均購買量_x"]) / Year_2017_2018_month_01_02_YTD_全通路["每人平均購買量_x"]
        except :
#             Year_2017_2018_month_01_02_YTD_全通路["每人平均購買量_成長率"] = "-"
            Year_2017_2018_month_01_02_YTD_全通路["每人平均購買量_成長率"] = pd.Series()
            for i in range(0, len(Year_2017_2018_month_01_02_YTD_全通路["每人平均購買量_成長率"])) :
                if Year_2017_2018_month_01_02_YTD_全通路["每人平均購買量_x"][i] == 0 :
                    Year_2017_2018_month_01_02_YTD_全通路["每人平均購買量_成長率"][i] == "-"
                else :
                    Year_2017_2018_month_01_02_YTD_全通路["每人平均購買量_成長率"][i] = (Year_2017_2018_month_01_02_YTD_全通路["每人平均購買量_y"][i] - Year_2017_2018_month_01_02_YTD_全通路["每人平均購買量_x"][i]) / Year_2017_2018_month_01_02_YTD_全通路["每人平均購買量_x"][i]
        # 9 普及率_差異
        Year_2017_2018_month_01_02_YTD_全通路["普及率_差異"] = Year_2017_2018_month_01_02_YTD_全通路["普及率_y"] - Year_2017_2018_month_01_02_YTD_全通路["普及率_x"]

        Year_2017_2018_month_01_02_YTD_全通路 = Year_2017_2018_month_01_02_YTD_全通路[[訴求_column, '自定義品牌', "系列(一匙靈專用)", "銷額市佔率_x", "銷額市佔率_y", "銷額市佔率_差異", "銷量市佔率_x", "銷量市佔率_y", "銷量市佔率_差異", "每公升均價(元)_x", "每公升均價(元)_y", "每公升均價(元)_成長率", "每次購買金額(元)_x", "每次購買金額(元)_y", "每次購買金額(元)_成長率", "每次購買量(公升)_x", "每次購買量(公升)_y", "每次購買量(公升)_成長率", "平均購買次數_x", "平均購買次數_y", "平均購買次數_差異", "每人平均花費_x", "每人平均花費_y", "每人平均花費_成長率", "每人平均購買量_x", "每人平均購買量_y", "每人平均購買量_成長率", "普及率_x", "普及率_y", "普及率_差異"]]

        Year_2017_2018_month_01_02_YTD_全通路 = Year_2017_2018_month_01_02_YTD_全通路.fillna("-")


        Year_2017_2018_month_01_02_YTD_全通路 = Year_2017_2018_month_01_02_YTD_全通路.rename(columns=lambda x: x.replace('x', str(x_3)))
        Year_2017_2018_month_01_02_YTD_全通路 = Year_2017_2018_month_01_02_YTD_全通路.rename(columns=lambda x: x.replace('y', str(y_3)))

        
        
        # 讀MAT的表頭
        # =============================================================================================================================
     
        # Year_2017_2018_month_01_02_YTD_全通路 = pd.merge(MAT_表頭, Year_2017_2018_month_01_02_YTD_全通路, how = "left", on = [訴求_column, "自定義品牌", "系列(一匙靈專用)"])
    
        # exec(f'YTD_訴求_{訴求們[i]}全通路 = pd.merge(MAT_訴求_{訴求們[i]}全通路_表頭, YTD_訴求_{訴求們[i]}全通路, how = "left", on = ["{訴求們[i]}", "自定義品牌"])')
#         exec(f'Year_2017_2018_month_01_02_YTD_全通路 = pd.merge(MAT_訴求_{訴求_column}全通路_表頭, Year_2017_2018_month_01_02_YTD_全通路, how = "left", on = ["{訴求_column}", "自定義品牌"])')

#         Year_2017_2018_month_01_02_YTD_全通路 = pd.merge(MAT_訴求_天然全通路_for_sheet_by通路_表頭, Year_2017_2018_month_01_02_YTD_全通路, how = "left", on = ["天然", "自定義品牌"])
        
#-------------------------------------------------------------------------------------------------------------
        # 用exec的去merge會出錯，天然、非天然的順序不知道為什麼會跑掉
#         exec(f'Year_2017_2018_month_01_02_YTD_全通路 = pd.merge(MAT_訴求_{訴求_column}全通路_for_sheet_by通路_表頭, Year_2017_2018_month_01_02_YTD_全通路, how = "left", on = ["{訴求_column}", "自定義品牌", "系列(一匙靈專用)"])')
        Year_2017_2018_month_01_02_YTD_全通路 = pd.merge(MAT_訴求_天然全通路_for_sheet_by通路_表頭, Year_2017_2018_month_01_02_YTD_全通路, how = "left", on = ["天然", "自定義品牌", "系列(一匙靈專用)"])
#-------------------------------------------------------------------------------------------------------------
        
        # =============================================================================================================================

        
        
        # set_index 時，在這邊記得還有訴求_column
        Year_2017_2018_month_01_02_YTD_全通路 = Year_2017_2018_month_01_02_YTD_全通路.set_index([訴求_column, "自定義品牌", "系列(一匙靈專用)"])
        # 去掉整個row都沒有值的品牌系列
        Year_2017_2018_month_01_02_YTD_全通路 = Year_2017_2018_month_01_02_YTD_全通路.replace("-", np.nan)
        Year_2017_2018_month_01_02_YTD_全通路 = Year_2017_2018_month_01_02_YTD_全通路.dropna(how = "all")
        Year_2017_2018_month_01_02_YTD_全通路 = Year_2017_2018_month_01_02_YTD_全通路.fillna("-")
        
        return Year_2017_2018_month_01_02_YTD_全通路

            
    Year_2017_2018_month_01_02_YTD_全通路 = YTD報表(x_1, x_2, y_1, y_2, x_3, y_3)
    
    
    
    
    
    return Year_2017_2018_month_01_02_YTD_全通路

# %%
YTD_201701_02_vs_201801_02_單一通路_好市多 = YTD_單一通路_完整sheet("天然", x_1, x_2, y_1, y_2, x_3, y_3, 品類_list, "通路", "COSTCO 好市多", 全台家戶數, 洗衣粉_市調結果購買率)
YTD_201701_02_vs_201801_02_單一通路_好市多
# Out:
# C:\Users\EOL\Anaconda3\lib\site-packages\ipykernel_launcher.py:480: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
#
# C:\Users\EOL\Anaconda3\lib\site-packages\ipykernel_launcher.py:488: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
#
# C:\Users\EOL\Anaconda3\lib\site-packages\ipykernel_launcher.py:549: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# ...

# %%
YTD_201701_02_vs_201801_02_單一通路_全通路不含C = YTD_單一通路_完整sheet("天然", x_1, x_2, y_1, y_2, x_3, y_3, 品類_list, "全通路何者不含C", "0", 全台家戶數, 洗衣粉_市調結果購買率)
YTD_201701_02_vs_201801_02_單一通路_全通路不含C
# Out:
# C:\Users\EOL\Anaconda3\lib\site-packages\ipykernel_launcher.py:480: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
#
# C:\Users\EOL\Anaconda3\lib\site-packages\ipykernel_launcher.py:488: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
#
# C:\Users\EOL\Anaconda3\lib\site-packages\ipykernel_launcher.py:549: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# ...

# %%
now = datetime.datetime.now()
print(now)
# Out:
# 2018-10-03 18:31:35.972203

# %%
# 全通路

YTD_201701_02_vs_201801_02_全通路_info = YTD_全通路_完整sheet("天然", x_1, x_2, y_1, y_2, x_3, y_3, 品類_list, 全台家戶數, 洗衣粉_市調結果購買率)
print("目前進度 : " + "{:.2%}".format( 1 / 22 ) )

# YTD_單一通路_完整sheet("天然", x_1, x_2, y_1, y_2, x_3, y_3, 品類_list, 通路的變數欄位名稱, 通路的變數欄位之篩選條件, 全台家戶數, 洗衣粉_市調結果購買率) :
# 單一通路
YTD_201701_02_vs_201801_02_單一通路_全通路不含C = YTD_單一通路_完整sheet("天然", x_1, x_2, y_1, y_2, x_3, y_3, 品類_list, "全通路何者不含C", "0", 全台家戶數, 洗衣粉_市調結果購買率)
print("目前進度 : " + "{:.2%}".format( 2 / 22 ) )
YTD_201701_02_vs_201801_02_單一通路_好市多 = YTD_單一通路_完整sheet("天然", x_1, x_2, y_1, y_2, x_3, y_3, 品類_list, "通路", "COSTCO 好市多", 全台家戶數, 洗衣粉_市調結果購買率)
print("目前進度 : " + "{:.2%}".format( 3 / 22 ) )
YTD_201701_02_vs_201801_02_單一通路_全聯 = YTD_單一通路_完整sheet("天然", x_1, x_2, y_1, y_2, x_3, y_3, 品類_list, "通路", "全聯", 全台家戶數, 洗衣粉_市調結果購買率)
print("目前進度 : " + "{:.2%}".format( 4 / 22 ) )
YTD_201701_02_vs_201801_02_單一通路_家樂福 = YTD_單一通路_完整sheet("天然", x_1, x_2, y_1, y_2, x_3, y_3, 品類_list, "通路", "家樂福", 全台家戶數, 洗衣粉_市調結果購買率)
print("目前進度 : " + "{:.2%}".format( 5 / 22 ) )
YTD_201701_02_vs_201801_02_單一通路_大潤發 = YTD_單一通路_完整sheet("天然", x_1, x_2, y_1, y_2, x_3, y_3, 品類_list, "通路", "大潤發", 全台家戶數, 洗衣粉_市調結果購買率)
print("目前進度 : " + "{:.2%}".format( 6 / 22 ) )
YTD_201701_02_vs_201801_02_單一通路_寶雅 = YTD_單一通路_完整sheet("天然", x_1, x_2, y_1, y_2, x_3, y_3, 品類_list, "通路", "寶雅", 全台家戶數, 洗衣粉_市調結果購買率)
print("目前進度 : " + "{:.2%}".format( 7 / 22 ) )
# YTD_201701_02_vs_201801_02_單一通路_頂好 = YTD_單一通路_完整sheet("天然", x_1, x_2, y_1, y_2, x_3, y_3, 品類_list, "通路", "頂好", 全台家戶數, 洗衣粉_市調結果購買率)
# print("目前進度 : " + "{:.2%}".format( 8 / 22 ) )
YTD_201701_02_vs_201801_02_單一通路_愛買 = YTD_單一通路_完整sheet("天然", x_1, x_2, y_1, y_2, x_3, y_3, 品類_list, "通路", "愛買", 全台家戶數, 洗衣粉_市調結果購買率)
print("目前進度 : " + "{:.2%}".format( 9 / 22 ) )
# YTD_201701_02_vs_201801_02_單一通路_711 = YTD_單一通路_完整sheet("天然", x_1, x_2, y_1, y_2, x_3, y_3, 品類_list, "通路", "7-11", 全台家戶數, 洗衣粉_市調結果購買率)
# print("目前進度 : " + "{:.2%}".format( 10 / 22 ) )
# YTD_201701_02_vs_201801_02_單一通路_屈臣氏 = YTD_單一通路_完整sheet("天然", x_1, x_2, y_1, y_2, x_3, y_3, 品類_list, "通路", "屈臣氏", 全台家戶數, 洗衣粉_市調結果購買率)
# print("目前進度 : " + "{:.2%}".format( 11 / 22 ) )
# YTD_201701_02_vs_201801_02_單一通路_美廉社 = YTD_單一通路_完整sheet("天然", x_1, x_2, y_1, y_2, x_3, y_3, 品類_list, "通路", "美廉社", 全台家戶數, 洗衣粉_市調結果購買率)
# print("目前進度 : " + "{:.2%}".format( 12 / 22 ) )
# YTD_201701_02_vs_201801_02_單一通路_康是美 = YTD_單一通路_完整sheet("天然", x_1, x_2, y_1, y_2, x_3, y_3, 品類_list, "通路", "康是美", 全台家戶數, 洗衣粉_市調結果購買率)
# print("目前進度 : " + "{:.2%}".format( 13 / 22 ) )


# YTD_201701_02_vs_201801_02_單一通路_1_經銷_超市 = YTD_單一通路_完整sheet("天然", x_1, x_2, y_1, y_2, x_3, y_3, 品類_list, "YFY經銷", "1.經銷-超市(整體超市扣除全聯、頂好、楓康)", 全台家戶數, 洗衣粉_市調結果購買率)
# print("目前進度 : " + "{:.2%}".format( 14 / 22 ) )
# YTD_201701_02_vs_201801_02_單一通路_2_經銷_藥妝 = YTD_單一通路_完整sheet("天然", x_1, x_2, y_1, y_2, x_3, y_3, 品類_list, "YFY經銷", "2.經銷-藥妝(整體個人用品店扣除美華泰、寶雅、屈臣氏、康是美)", 全台家戶數, 洗衣粉_市調結果購買率)
# print("目前進度 : " + "{:.2%}".format( 15 / 22 ) )
# YTD_201701_02_vs_201801_02_單一通路_3_經銷_藥局_嬰幼 = YTD_單一通路_完整sheet("天然", x_1, x_2, y_1, y_2, x_3, y_3, 品類_list, "YFY經銷", "3.經銷-藥局/嬰幼(包括全部藥局&嬰幼兒店)", 全台家戶數, 洗衣粉_市調結果購買率)
# print("目前進度 : " + "{:.2%}".format( 16 / 22 ) )
# YTD_201701_02_vs_201801_02_單一通路_4_經銷_五金百貨 = YTD_單一通路_完整sheet("天然", x_1, x_2, y_1, y_2, x_3, y_3, 品類_list, "YFY經銷", "4.經銷-五金百貨(包括五金、百貨行、文具行、雜貨店)", 全台家戶數, 洗衣粉_市調結果購買率)
# print("目前進度 : " + "{:.2%}".format( 17 / 22 ) )
YTD_201701_02_vs_201801_02_單一通路_YFY經銷含_1_2_3_4 = YTD_單一通路_完整sheet("天然", x_1, x_2, y_1, y_2, x_3, y_3, 品類_list, "YFY經銷含_1_2_3_4", "1", 全台家戶數, 洗衣粉_市調結果購買率)
print("目前進度 : " + "{:.2%}".format( 18 / 22 ) )


YTD_201701_02_vs_201801_02_單一通路_量販_無C = YTD_單一通路_完整sheet("天然", x_1, x_2, y_1, y_2, x_3, y_3, 品類_list, "通路類型(客戶用)", "量販(無C)", 全台家戶數, 洗衣粉_市調結果購買率)
print("目前進度 : " + "{:.2%}".format( 19 / 22 ) )
YTD_201701_02_vs_201801_02_單一通路_超市_無PX = YTD_單一通路_完整sheet("天然", x_1, x_2, y_1, y_2, x_3, y_3, 品類_list, "通路類型(客戶用)", "超市(無PX)", 全台家戶數, 洗衣粉_市調結果購買率)
print("目前進度 : " + "{:.2%}".format( 20 / 22 ) )
# YTD_201701_02_vs_201801_02_單一通路_個人用品店 = YTD_單一通路_完整sheet("天然", x_1, x_2, y_1, y_2, x_3, y_3, 品類_list, "通路類型(客戶用)", "個人用品店", 全台家戶數, 洗衣粉_市調結果購買率)
# print("目前進度 : " + "{:.2%}".format( 21 / 22 ) )
# YTD_201701_02_vs_201801_02_單一通路_便利商店 = YTD_單一通路_完整sheet("天然", x_1, x_2, y_1, y_2, x_3, y_3, 品類_list, "通路類型(客戶用)", "便利商店", 全台家戶數, 洗衣粉_市調結果購買率)
# print("目前進度 : " + "{:.2%}".format( 22 / 22 ) )


print("Done!")
# Out:
# C:\Users\EOL\Anaconda3\lib\site-packages\ipykernel_launcher.py:433: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
#
# C:\Users\EOL\Anaconda3\lib\site-packages\ipykernel_launcher.py:441: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
#
# C:\Users\EOL\Anaconda3\lib\site-packages\ipykernel_launcher.py:502: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# ...

# %%
now2 = datetime.datetime.now()
print(now2-now)
# Out:
# 0:51:16.001660

# %%
writer = pd.ExcelWriter("%s-sheet_by_通路-0928.xlsx" % (YTD_檔名), engine = "xlsxwriter")
# 全通路
YTD_201701_02_vs_201801_02_全通路_info.to_excel(writer, sheet_name = "全通路", index = True)
# 單一通路
YTD_201701_02_vs_201801_02_單一通路_全通路不含C.to_excel(writer, sheet_name = "全通路不含C", index = True)
YTD_201701_02_vs_201801_02_單一通路_好市多.to_excel(writer, sheet_name = "好市多", index = True)
YTD_201701_02_vs_201801_02_單一通路_全聯.to_excel(writer, sheet_name = "全聯", index = True)
YTD_201701_02_vs_201801_02_單一通路_家樂福.to_excel(writer, sheet_name = "家樂福", index = True)
YTD_201701_02_vs_201801_02_單一通路_大潤發.to_excel(writer, sheet_name = "大潤發", index = True)
# YTD_201701_02_vs_201801_02_單一通路_寶雅.to_excel(writer, sheet_name = "寶雅", index = True)
# YTD_201701_02_vs_201801_02_單一通路_頂好.to_excel(writer, sheet_name = "頂好", index = True)
YTD_201701_02_vs_201801_02_單一通路_愛買.to_excel(writer, sheet_name = "愛買", index = True)
# YTD_201701_02_vs_201801_02_單一通路_711.to_excel(writer, sheet_name = "7-11", index = True)
# YTD_201701_02_vs_201801_02_單一通路_屈臣氏.to_excel(writer, sheet_name = "屈臣氏", index = True)
# YTD_201701_02_vs_201801_02_單一通路_美廉社.to_excel(writer, sheet_name = "美廉社", index = True)
# YTD_201701_02_vs_201801_02_單一通路_康是美.to_excel(writer, sheet_name = "康是美", index = True)

# YTD_201701_02_vs_201801_02_單一通路_1_經銷_超市.to_excel(writer, sheet_name = "經銷超市", index = True)
# YTD_201701_02_vs_201801_02_單一通路_2_經銷_藥妝.to_excel(writer, sheet_name = "經銷藥妝", index = True)
# YTD_201701_02_vs_201801_02_單一通路_3_經銷_藥局_嬰幼.to_excel(writer, sheet_name = "經銷藥局", index = True)
# YTD_201701_02_vs_201801_02_單一通路_4_經銷_五金百貨.to_excel(writer, sheet_name = "經銷五金", index = True)
YTD_201701_02_vs_201801_02_單一通路_YFY經銷含_1_2_3_4.to_excel(writer, sheet_name = "經銷全部", index = True)

YTD_201701_02_vs_201801_02_單一通路_量販_無C.to_excel(writer, sheet_name = "量販無C", index = True)
YTD_201701_02_vs_201801_02_單一通路_超市_無PX.to_excel(writer, sheet_name = "超市無PX", index = True)
# YTD_201701_02_vs_201801_02_單一通路_個人用品店.to_excel(writer, sheet_name = "個人用品店", index = True)
# YTD_201701_02_vs_201801_02_單一通路_便利商店.to_excel(writer, sheet_name = "便利商店", index = True)

writer.save()

# %%
def sqrt(x) :
    x = x ** (1/2)
    return x

def sqrt(x) :
    x = x ** (1/3)
    return x

from math import sqrt
sqrt(16)
# Out:
# 4.0
